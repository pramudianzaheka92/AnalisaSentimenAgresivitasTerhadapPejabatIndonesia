# %% [markdown]
# # Analisa Sentimen Dari Media Sosial Twitter Tentang Agresivitas Kepada Para Pejabat Indonesia Di Tahun 2016

# %% [markdown]
# ## 1. Import Library & Load Dataset Dari Local Device

# %%
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
from sklearn.metrics import confusion_matrix, classification_report

# %%
data_2016 = pd.read_excel("Data Tahun 2016.xlsx")
data_2016.tail()
# Out:
#                        tanggal  \
# 690  2016-11-27 12:47:34+00:00
# 691  2016-11-27 12:29:23+00:00
# 692  2016-11-27 11:55:23+00:00
# 693  2016-11-27 00:50:43+00:00
# 694  2016-11-26 22:05:02+00:00
#
#                                                content    label
# 690  @kompascom yg nda diundang Jokowi &amp; Antasa...  positif
# 691  @anggit1ar @jokowi @republikaonline ini sih pu...  positif
# 692  @republikaonline ini beneran bodoh atau pura2 ...  positif
# 693  ga ada koneksi internet pak? apa masa bodoh de...  negatif
# 694  pengibaran bendera RRC efek dr jokowi buka pel...  negatif

# %%
# Mengecek tipe data dan juga apakah di dalam data memiliki nilai NaN/tidak
data_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 695 entries, 0 to 694
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tanggal  695 non-null    object
#  1   content  695 non-null    object
#  2   label    695 non-null    object
# dtypes: object(3)
# memory usage: 16.4+ KB

# %%
# Melakukan visualisasi untuk kolom "Sentimen"

plt.style.use("seaborn")
plt.title("Perhitungan Label Sentimen Setelah Dilakukan Pelabellan Secara Manual")
sns.countplot(x="label", hue="label", data=data_2016)
plt.figure(figsize=(10, 10))
plt.show()

# %%
# Menghitung sekaligus mengurutkan jumlah label terbanyak berdasarkan tweet
jmlh_tweet = data_2016.groupby("label").count()["content"].reset_index().sort_values(by="content", ascending=False)
jmlh_tweet.style.background_gradient(cmap="winter")
# Out:
# <style  type="text/css" >
# #T_0191191d_fb1c_11eb_9f3f_8a52637b5ce0row0_col1{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_0191191d_fb1c_11eb_9f3f_8a52637b5ce0row1_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_0191191d_fb1c_11eb_9f3f_8a52637b5ce0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >label</th>        <th class="col_heading level0 col1" >content</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0191191d_fb1c_11eb_9f3f_8a52637b5ce0level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_0191191d_fb1c_11eb_9f3f_8a52637b5ce0row0_col0" class="data row0 col0" >positif</td>
#                         <td id="T_0191191d_fb1c_11eb_9f3f_8a52637b5ce0row0_col1" class="data row0 col1" >358</td>
#             </tr>
#             <tr>
#                         <th id="T_0191191d_fb1c_11eb_9f3f_8a52637b5ce0level0_row1" class="row_heading level0 row1" >0</th>
#                         <td id="T_0191191d_fb1c_11eb_9f3f_8a52637b5ce0row1_col0" class="data row1 col0" >negatif</td>
#                         <td id="T_0191191d_fb1c_11eb_9f3f_8a52637b5ce0row1_col1" class="data row1 col1" >337</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Dapat dilihat dari perhitungan diatas, dari 695 jumlah data netizen twitter ketika melakukan tweet tentang topik para pejabat di Indonesia mendapatkan label positif yang sangat tinggi daripada label negatif yang memiliki jumlah sentimen sebanyak 358 tweet sedangkan label negatif memiliki jumlah sentimen sebanyak 337. Bisa dikatakan jumlah label sentimen memiliki nilai yang cukup balanced (seimbang).

# %% [markdown]
# ## 2. Text Processing (Cleansing, Case Folding, Tokenizing, Stopwords & Stemming)

# %%
# Menghilangkan tweet dan username dari kalimat-kalimat, simbol-simbol, emoticon yang tidak dibutuhkan selama pengujian
def bersih_text(text):
    text = re.sub(r'[^a-zA-z0-9]',' ', str(text))
    text = re.sub(r'\b\w{1,2}\b','', text)
    text = re.sub(r'\s\s+',' ', text)
    text = re.sub(r'https?:\/\/\S+', '', text)  
    text = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text)
    return text

data_2016["content"] = data_2016["content"].apply(bersih_text)

data_2016.head()
# Out:
#                      tanggal  \
# 0  2016-12-21 04:36:51+00:00
# 1  2016-12-19 19:20:46+00:00
# 2  2016-12-09 11:21:17+00:00
# 3  2016-11-24 21:22:09+00:00
# 4  2016-11-18 17:40:30+00:00
#
#                                              content    label
# 0  jakartans bego mending kalo anies ini agus htt...  negatif
# 1   kaskus Apa Anies itu dipikir bego ahok Jauh l...  positif
# 2  Mau debatnya klo bertempat Petamburan kali klo...  negatif
# 3  BEGO bngt ASU Anies Sandi Uno itu pantes aja d...  positif
# 4   sam arif  kalo orang tidak bego dan tidak tol...  negatif

# %%
# Menghapus spasi pada kolom "label"
data_2016.label = list(map(lambda x: x.strip(), data_2016.label))
data_2016.head()
# Out:
#                      tanggal  \
# 0  2016-12-21 04:36:51+00:00
# 1  2016-12-19 19:20:46+00:00
# 2  2016-12-09 11:21:17+00:00
# 3  2016-11-24 21:22:09+00:00
# 4  2016-11-18 17:40:30+00:00
#
#                                              content    label
# 0  jakartans bego mending kalo anies ini agus htt...  negatif
# 1   kaskus Apa Anies itu dipikir bego ahok Jauh l...  positif
# 2  Mau debatnya klo bertempat Petamburan kali klo...  negatif
# 3  BEGO bngt ASU Anies Sandi Uno itu pantes aja d...  positif
# 4   sam arif  kalo orang tidak bego dan tidak tol...  negatif

# %% [markdown]
# Setelah melakukan proses cleansing teks yaitu menghapus beberapa simbol/karakter-karakter yang tidak dipentingkan dalam kolom content tweet, langkah selanjutnya adalah case folding. Case folding merupakan sebuah tahapan untuk mengubah huruf-huruf kapital menjadi huruf-huruf kecil

# %% [markdown]
# ### Case Folding

# %%
# Mengubah ukuran setiap kalimat yang ada di kolom "content" menjadi huruf kecil
data_2016["content"] = data_2016["content"].str.lower()

data_2016.head()
# Out:
#                      tanggal  \
# 0  2016-12-21 04:36:51+00:00
# 1  2016-12-19 19:20:46+00:00
# 2  2016-12-09 11:21:17+00:00
# 3  2016-11-24 21:22:09+00:00
# 4  2016-11-18 17:40:30+00:00
#
#                                              content    label
# 0  jakartans bego mending kalo anies ini agus htt...  negatif
# 1   kaskus apa anies itu dipikir bego ahok jauh l...  positif
# 2  mau debatnya klo bertempat petamburan kali klo...  negatif
# 3  bego bngt asu anies sandi uno itu pantes aja d...  positif
# 4   sam arif  kalo orang tidak bego dan tidak tol...  negatif

# %% [markdown]
# Setelah melakukan proses case folding, langkah selanjutnya adalah tokenizing/tokenisasi. Tahap tokenizing merupakan tahap pemotongan teks ke dalam satuan kata.

# %% [markdown]
# ### Tokenizing

# %%
# Melakukan Tahapan Tokenisasi. 
# Tokenisasi adalah tahapan prepocessing data yang digunakan untuk membagi kalimat menjadi perkata
def tokennization(text):
    return word_tokenize(text)

data_2016["content_tokenizing"] = data_2016["content"].apply(tokennization)
data_2016.head()
# Out:
#                      tanggal  \
# 0  2016-12-21 04:36:51+00:00
# 1  2016-12-19 19:20:46+00:00
# 2  2016-12-09 11:21:17+00:00
# 3  2016-11-24 21:22:09+00:00
# 4  2016-11-18 17:40:30+00:00
#
#                                              content    label  \
# 0  jakartans bego mending kalo anies ini agus htt...  negatif
# 1   kaskus apa anies itu dipikir bego ahok jauh l...  positif
# 2  mau debatnya klo bertempat petamburan kali klo...  negatif
# 3  bego bngt asu anies sandi uno itu pantes aja d...  positif
# 4   sam arif  kalo orang tidak bego dan tidak tol...  negatif
#
#                                   content_tokenizing
# 0  [jakartans, bego, mending, kalo, anies, ini, a...
# 1  [kaskus, apa, anies, itu, dipikir, bego, ahok,...
# 2  [mau, debatnya, klo, bertempat, petamburan, ka...
# 3  [bego, bngt, asu, anies, sandi, uno, itu, pant...
# 4  [sam, arif, kalo, orang, tidak, bego, dan, tid...

# %% [markdown]
# Setelah melakukan tahapan tokenisasi, selanjutnya saya akan melakukan proses filtering (stowords). Proses stopwords ini merupakan tahapan mengambil kata-kata dari tahapan tokenisasi. Stopword merupakan sebuah tahapan yang dimana bertujuan untuk membuang kata-kata yang tidak deskriptif dalam melakukan pendekatan bag-of-words.

# %% [markdown]
# ### Stopwords

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
 
factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()
print(stopwords)
# Out:
# ['yang', 'untuk', 'pada', 'ke', 'para', 'namun', 'menurut', 'antara', 'dia', 'dua', 'ia', 'seperti', 'jika', 'jika', 'sehingga', 'kembali', 'dan', 'tidak', 'ini', 'karena', 'kepada', 'oleh', 'saat', 'harus', 'sementara', 'setelah', 'belum', 'kami', 'sekitar', 'bagi', 'serta', 'di', 'dari', 'telah', 'sebagai', 'masih', 'hal', 'ketika', 'adalah', 'itu', 'dalam', 'bisa', 'bahwa', 'atau', 'hanya', 'kita', 'dengan', 'akan', 'juga', 'ada', 'mereka', 'sudah', 'saya', 'terhadap', 'secara', 'agar', 'lain', 'anda', 'begitu', 'mengapa', 'kenapa', 'yaitu', 'yakni', 'daripada', 'itulah', 'lagi', 'maka', 'tentang', 'demi', 'dimana', 'kemana', 'pula', 'sambil', 'sebelum', 'sesudah', 'supaya', 'guna', 'kah', 'pun', 'sampai', 'sedangkan', 'selagi', 'sementara', 'tetapi', 'apakah', 'kecuali', 'sebab', 'selain', 'seolah', 'seraya', 'seterusnya', 'tanpa', 'agak', 'boleh', 'dapat', 'dsb', 'dst', 'dll', 'dahulu', 'dulunya', 'anu', 'demikian', 'tapi', 'ingin', 'juga', 'nggak', 'mari', 'nanti', 'melainkan', 'oh', 'ok', 'seharusnya', 'sebetulnya', 'setiap', 'setidaknya', 'sesuatu', 'pasti', 'saja', 'toh', 'ya', 'walau', 'tolong', 'tentu', 'amat', 'apalagi', 'bagaimanapun']

# %% [markdown]
# Proses stopwords saya lakukan dengan mengambil nilai-nilai yang ada diatas yang sudah ditentukan oleh library Sastrawi. Kata-kata diatas boleh digunakan secara keseluruhan/diambil hanya beberapa saja.

# %%
# Proses Filtering dari kolom "Tweet_Tokenizing"
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords

list_delete = ["yang", "untuk", "pada", "ke", "antara", "dua", "ia", "seperti", "antara", "dia", "seperti", "jika",
               "tidak", "oleh", "saat", "harus", "sementara", "mereka", "sudah", "terhadap", "sehingga",
               "secara", "agar", "lain", "begitu", "mengapa", "kenapa", "yaitu", "yakni", "daripada",
               "sekitar", "serta", "di", "dari", "telah", "sebagai", "masih", 'setidaknya', "sesuatu", "pasti", 
               "saja", "toh", "ya", "walau", "hal", "bahwa", "atau", "hanya", "ada", "mereka", "agar", "lain", 
               "anda", "begitu", "yaitu", "yakni", "itulah", "demi", "dimana", "pula", "sambil", "sebelum", 
               "sesudah", "guna", "ia", "dengan", "https", "supaya", "kah", "pun", "sampai", 
               "sedangkan", "selagi", "seharusnya", "sebetulnya", "setiap"]

list_stopwords = stopwords.words("indonesian")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Mendeklarasikan fungsi untuk list_stopwords
def stopword(text):
    return [word for word in text if word not in list_stopwords]

data_2016["content_stopwords"] = data_2016["content_tokenizing"].apply(stopword)

# %%
# Mendeklarasikan fungsi untuk list_delete
def stopwords_removal(text):
    return [word for word in text if word not in list_delete]

data_2016["content_stopwords"] = data_2016["content_stopwords"].apply(stopwords_removal)
data_2016.head()
# Out:
#                      tanggal  \
# 0  2016-12-21 04:36:51+00:00
# 1  2016-12-19 19:20:46+00:00
# 2  2016-12-09 11:21:17+00:00
# 3  2016-11-24 21:22:09+00:00
# 4  2016-11-18 17:40:30+00:00
#
#                                              content    label  \
# 0  jakartans bego mending kalo anies ini agus htt...  negatif
# 1   kaskus apa anies itu dipikir bego ahok jauh l...  positif
# 2  mau debatnya klo bertempat petamburan kali klo...  negatif
# 3  bego bngt asu anies sandi uno itu pantes aja d...  positif
# 4   sam arif  kalo orang tidak bego dan tidak tol...  negatif
#
#                                   content_tokenizing  \
# 0  [jakartans, bego, mending, kalo, anies, ini, a...
# 1  [kaskus, apa, anies, itu, dipikir, bego, ahok,...
# 2  [mau, debatnya, klo, bertempat, petamburan, ka...
# 3  [bego, bngt, asu, anies, sandi, uno, itu, pant...
# 4  [sam, arif, kalo, orang, tidak, bego, dan, tid...
#
#                                    content_stopwords
# 0  [jakartans, bego, mending, kalo, anies, agus, ...
# 1     [kaskus, anies, dipikir, bego, ahok, loe, hok]
# 2  [debatnya, klo, bertempat, petamburan, kali, k...
# 3  [bego, bngt, asu, anies, sandi, uno, pantes, a...
# 4  [sam, arif, kalo, orang, bego, tolol, milih, a...

# %% [markdown]
# Tahapan terakhir dalam text mining adalah proses stemming. Teknik Stemming merupakan sebuah tahapan kegiatan text preprocessing untuk memperkecil jumlah indeks yang berbeda dari suatu data dan juga untuk melakukan pengelompokan kata-kata lain yang memiliki kata dasar dan arti yang serupa namun memiliki bentuk yang berbeda karena mendapatkan imbuhan yang berbeda pula.

# %% [markdown]
# ### Stemming

# %%
# Proses Stemming dibantu dengan bantuan swifter
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter # Swifter berfungsi untuk mempercepat froses stemming pada Dataframe dengan menjalankan task secara parallel

# Membuat Stemmer dari sastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Membuat fungsi stemming
def stemming(text):
    return stemmer.stem(text)

term_dict = {}

# Menghitung ada berapa kata/words di dalam kolom "content_stopwords"
for document in data_2016["content_stopwords"]:
    for text in document:
        if text not in term_dict:
            term_dict[text] = " "
            
print(len(term_dict))
print("------------------------")

# Menampilkan isi kata/words yang telah dilakukan proses stemming
for text in term_dict:
    term_dict[text] = stemming(text)
    print(text,":" ,term_dict[text])
    
print(term_dict)
print("------------------------")

# Membuat fungsi baru untuk proses stemming
def stemming_word(document):
    return [term_dict[text] for text in document]

data_2016["content_stemming"] = data_2016["content_stopwords"].swifter.apply(stemming_word)
# Out:
# 3236
# ------------------------
# jakartans : jakartans
# bego : bego
# mending : mending
# kalo : kalo
# anies : anies
# agus : agus
# c66jtx7qoz : c66jtx7qoz
# kaskus : kaskus
# dipikir : pikir
# ahok : ahok
# loe : loe
# hok : hok
# debatnya : debat
# klo : klo
# bertempat : tempat
# petamburan : tambur
# kali : kali
# kalah : kalah
# debat : debat
# kasih : kasih
# kode : kode
# teriak2 : teriak2
# cemen : cemen
# hebat : hebat
# swlwyu8q4c : swlwyu8q4c
# bngt : bngt
# asu : asu
# sandi : sandi
# uno : uno
# pantes : pantes
# aja : aja
# dipecat : pecat
# jkw : jkw
# proyek2 : proyek2
# foke : foke
# proyek : proyek
# kkn : kkn
# pnbj7r1mjk : pnbj7r1mjk
# sam : sam
# arif : arif
# orang : orang
# tolol : tolol
# milih : milih
# ahy : ahy
# percetakanku : cetak
# iwanfals : iwanfals
# polling : polling
# menang : menang
# iwan : iwan
# fals : fals
# dibilang : bilang
# pendukung : dukung
# dipiara : piara
# masukan : masuk
# dana : dana
# csr : csr
# apbd : apbd
# anis : anis
# swasta : swasta
# rngsupzbaj : rngsupzbaj
# imanhermawan23 : imanhermawan23
# marcel : marcel
# prawira : prawira
# herilatief : herilatief
# ulilalbab : ulilalbab
# hs : hs
# edo : edo
# macho : macho
# jemmybond : jemmybond
# wisnu : wisnu
# buana : buana
# zqhqjplsno : zqhqjplsno
# pandji : pandji
# tanggapin : tanggapin
# baswedan : baswedan
# dukung : dukung
# provokator : provokator
# sara : sara
# pura : pura
# lmkhrngery : lmkhrngery
# njaoigfrly : njaoigfrly
# gsohcpvyaw : gsohcpvyaw
# wahhabicc : wahhabicc
# bener : bener
# angkutan : angkut
# jkt : jkt
# mahal : mahal
# taunya : tau
# emang : emang
# stasiun : stasiun
# halte : halte
# jalan : jalan
# kaki : kaki
# hehehe : hehehe
# vvpptfljm0 : vvpptfljm0
# pakar : pakar
# mantan : mantan
# jijxtaftzo : jijxtaftzo
# qgvp0zbxv1 : qgvp0zbxv1
# d8tfc7yilz : d8tfc7yilz
# wow : wow
# keren : keren
# qzr7xr30v2 : qzr7xr30v2
# colek : colek
# aniesbaswedan : aniesbaswedan
# xxxgtgak8t : xxxgtgak8t
# pura2 : pura2
# wnwbdhdf1c : wnwbdhdf1c
# takviri : takviri
# gunromli : gunromli
# orng : orng
# bodoh : bodoh
# percaya : percaya
# memimpin : pimpin
# emank : emank
# gak : gak
# kritis : kritis
# biar : biar
# sinis : sinis
# hasil : hasil
# survei : survei
# rutin : rutin
# dirilis : rilis
# ajak : ajak
# warga : warga
# cvdbkccdfh : cvdbkccdfh
# hahahahahahaha : hahahahahahaha
# nyer : nyer
# uguxzqflqq : uguxzqflqq
# msh : msh
# akses : akses
# pendidikan : didik
# org : org
# pake : pake
# bhs : bhs
# inggris : inggris
# membodohi : bodoh
# sumpah : sumpah
# bicara : bicara
# seakan2 : seakan2
# mendengar : dengar
# gatau : gatau
# apa2 : apa2
# nonton : nonton
# ftv : ftv
# cengeng : cengeng
# berbobot : bobot
# teman : teman
# bagus : bagus
# nih : nih
# bahan : bahan
# kampanye : kampanye
# orang2nya : orang2nya
# elu : elu
# kidpztslrr : kidpztslrr
# huahaha : huahaha
# hah : hah
# akn : akn
# pilkada : pilkada
# yah : yah
# cf9hokwdkb : cf9hokwdkb
# iwank1404 : iwank1404
# krn : krn
# cerdas : cerdas
# dilepas : lepas
# mendikbud : mendikbud
# bhayakan : bhayakan
# mencerdaskan : cerdas
# bangsa : bangsa
# tau : tau
# gagal : gagal
# pham : pham
# officialinewstv : officialinewstv
# zuhairimisrawi : zuhairimisrawi
# kau : kau
# keadilan : adil
# ditegakkan : tegak
# direshuffle : direshuffle
# republikaonline : republikaonline
# giman : gim
# siluman : siluman
# punbelum : punbelum
# cerita : cerita
# masuk : masuk
# akal : akal
# takut : takut
# usa : usa
# otak : otak
# kerbau : kerbau
# sedih : sedih
# gitu : gitu
# bang : bang
# renecc : renecc
# amp : amp
# zrj5oxnio7 : zrj5oxnio7
# sibuniyani : sibuniyani
# kabarnya : kabar
# seneng : neng
# bgt : bgt
# doi : doi
# niatnya : niat
# mbantu : mbantu
# diuntungkan : untung
# ahaye : ahaye
# siak : siak
# wuzd4chqsj : wuzd4chqsj
# partaisocmed : partaisocmed
# bolak : bolak
# blunder : blunder
# utk : utk
# levelnya : level
# spt : spt
# disengaja : sengaja
# plus : plus
# kmngkn : kmngkn
# liberal : liberal
# aksi : aksi
# demo : demo
# november : november
# lcfwq6hfj7 : lcfwq6hfj7
# veywiniy : veywiniy
# yggregory : yggregory
# detikcom : detikcom
# jgn : jgn
# rusak : rusak
# citra : citra
# smart : smart
# nya : nya
# banget : banget
# matematika : matematika
# pinteran : pinteran
# waitress : waitress
# resto : resto
# boss : boss
# walo : walo
# tamat : tamat
# fakta : fakta
# celaka : celaka
# triwul82 : triwul82
# bantar : bantar
# gebang : gebang
# ngomong : ngomong
# sampah : sampah
# salah : salah
# kelola : kelola
# janji : janji
# kjp : kjp
# kip : kip
# dibagi : bagi
# bersamaan : sama
# pjzwuwksfd : pjzwuwksfd
# pintar : pintar
# koq : koq
# pintar2 : pintar2
# duluuu : duluuu
# rakyat : rakyat
# kagum : kagum
# ketauan : tau
# belangnya : belang
# 5fkypzlgev : 5fkypzlgev
# pertanyaannya : tanya
# bpk : bpk
# congrats : congrats
# temanahok : temanahok
# 5zydrfdtgs : 5zydrfdtgs
# kompascom : kompascom
# jadikan : jadi
# kolong : kolong
# tol : tol
# wadah : wadah
# berekspresi : ekspres
# tirwtqbb1p : tirwtqbb1p
# ide : ide
# xn7vnaeer5 : xn7vnaeer5
# panca66 : panca66
# org2 : org2
# pks : pks
# picik : picik
# bro : bro
# udah : udah
# eneg : eneg
# liat : liat
# idola : idola
# terkesan : kes
# bias : bias
# scr : scr
# terbuka : buka
# mendukung : dukung
# serius : serius
# deh : deh
# knp : knp
# srg : srg
# ngeluarin : ngeluarin
# statement : statement
# sih : sih
# gubernur : gubernur
# dki : dki
# 2012 : 2012
# 2016 : 2016
# versi : versi
# hti : hti
# fpi : fpi
# brizieq : brizieq
# semoga : moga
# sefaham : sefaham
# dgn : dgn
# shxb9dgkzs : shxb9dgkzs
# kristen : kristen
# protestan : protestan
# katholik : katholik
# sylvi : sylvi
# muslim : muslim
# pilih : pilih
# dianggap : anggap
# rsephf9yct : rsephf9yct
# dear : dear
# terdidik : didik
# tolong : tolong
# maju : maju
# 6potzigwvh : 6potzigwvh
# permutindo : permutindo
# kubu : kubu
# incumbent : incumbent
# sentuh : sentuh
# ekonomi : ekonomi
# tim : tim
# buka : buka
# mata : mata
# kgbbsxylze : kgbbsxylze
# mentri : tri
# istimewa : istimewa
# tnyata : tnyata
# jakarta : jakarta
# butuh : butuh
# pemimpin : pimpin
# tdk : tdk
# kasar : kasar
# visioner : visioner
# bilg : bilg
# responsif : responsif
# membabi : babi
# buta : buta
# sandiagafordki1 : sandiagafordki1
# posko : posko
# pemenangan : menang
# smakin : smakin
# o2azpx5ath : o2azpx5ath
# pernyataan : nyata
# pengikut : ikut
# menteri : menteri
# brani2an : brani2an
# nyalon : nyalon
# dki1 : dki1
# hsl : hsl
# 4r9vumoysz : 4r9vumoysz
# ahmaddhaniprast : ahmaddhaniprast
# gampang : gampang
# dihasut : hasut
# agama : agama
# alat : alat
# politik : politik
# hehe : hehe
# syihabrizieq : syihabrizieq
# byk : byk
# mdh : mdh
# pantesan : pantesan
# dicukupkan : cukup
# jokowi : jokowi
# pling : pling
# malas : malas
# beria : ria
# beritasatu : beritasatu
# cendikiawan : cendikiawan
# knapa : knapa
# skrg : skrg
# diusung : usung
# cagub : cagub
# partai : partai
# yahh : yahh
# mohmahfudmd : mohmahfudmd
# silkybiru : silkybiru
# rada2 : rada2
# massa : massa
# jujur : jujur
# realita : realita
# gendeng : gendeng
# tribunnews : tribunnews
# berkawan : kawan
# politisi : politis
# omong : omong
# kosong : kosong
# syrf : syrf
# hbb : hbb
# dkk : dkk
# ikutan : ikut
# guoblok : guoblok
# keliatan : liat
# ivan23683770 : ivan23683770
# batalin : batalin
# murka : murka
# bkn : bkn
# keblinger : keblinger
# 2hr : 2hr
# berpikir : pikir
# pftee : pftee
# ych7168 : ych7168
# alex : alex
# hunter146 : hunter146
# bamsbulaksumur4 : bamsbulaksumur4
# elektabilitas : elektabilitas
# langsung : langsung
# drop : drop
# sepintar : pintar
# apapun : apa
# ketemu : ketemu
# sapi : sapi
# kuda : kuda
# pikirannya : pikir
# sempit : sempit
# kasihan : kasihan
# ahauwlim : ahauwlim
# bloon : bloon
# goceng : goceng
# angkot : angkot
# subsidi : subsidi
# 3500 : 3500
# dipelihara : pelihara
# hahahaha : hahahaha
# kayak : kayak
# teukuarie : teukuarie
# komplain : komplain
# sukses : sukses
# ato : ato
# buzzer : buzzer
# ngata2in : ngata2in
# goblok : goblok
# risih : risih
# jengah : jengah
# bacanya : baca
# s4k1rr4 : s4k1rr4
# sdh : sdh
# anak : anak
# putus : putus
# sekolah : sekolah
# mki : mki
# dpt : dpt
# paham : paham
# mah : mah
# munafik : munafik
# sungai : sungai
# bersih : bersih
# bilang : bilang
# karna : karna
# pinter : pinter
# kurawa : rawa
# dodol : dodol
# halojakarta : halojakarta
# tinggal : tinggal
# wajib : wajib
# gusur : gusur
# tanah : tanah
# mnusia : mnusia
# berintegritas : integritas
# kontributif : kontributif
# sesalkan : sesal
# habibie : habibie
# disebabkan : sebab
# kangdede78 : kangdede78
# arif253162 : arif253162
# stres : stres
# kyk : kyk
# jawa : jawa
# igonious : igonious
# maya : maya
# arifin : arifin
# bernadetamurnip : bernadetamurnip
# sosmedbw : sosmedbw
# ignosius : ignosius
# idiot : idiot
# pendukungnya : dukung
# goblog : goblog
# piye : piye
# bergbung : bergbung
# amamafi2 : amamafi2
# bajigurceleng : bajigurceleng
# amorricon : amorricon
# jaychou881 : jaychou881
# henry : henry
# gpp : gpp
# cari : cari
# program : program
# franstone888 : franstone888
# kangsemproel : kangsemproel
# yup : yup
# jamin : jamin
# ketahuan : tahu
# pndukung : pndukung
# jaman : jaman
# info : info
# dipotong : potong
# khuhus : khuhus
# pemilih : pilih
# parah : parah
# pakai : pakai
# dtsjgdocq6 : dtsjgdocq6
# merdekadotcom : merdekadotcom
# dasar : dasar
# ketinggalan : tinggal
# tiru2 : tiru2
# langkah : langkah
# mega : mega
# bner2 : bner2
# tukang : tukang
# copy : copy
# doang : doang
# tbayupatti : tbayupatti
# kencing : kencing
# lurus : lurus
# bekas : bekas
# pect : pect
# otaknya : otak
# ed : ed
# tirta : tirta
# yudh4sampurna : yudh4sampurna
# tonywibowo12 : tonywibowo12
# zulemo15 : zulemo15
# donywenas : donywenas
# mlmkabeh : mlmkabeh
# fariz1234 : fariz1234
# wewenang : wewenang
# ektp : ektp
# iih : iih
# rinjanijb : rinjanijb
# pedukung : dukung
# wis : wis
# wedan : wedan
# koplak : koplak
# amrik : amrik
# fitnah : fitnah
# waljamaah : waljamaah
# jonru : jonru
# fadlizon : fadlizon
# fahrihamzah : fahrihamzah
# dpp : dpp
# halus24 : halus24
# ratnaspaet : ratnaspaet
# fahiraidris : fahiraidris
# gerindra : gerindra
# history : history
# diatas : atas
# rhomaihrama : rhomaihrama
# ngibul : ngibul
# uda : uda
# mimik : mimik
# susu : susu
# trs : trs
# bobo : bobo
# gih : gih
# bambang34640775 : bambang34640775
# makan : makan
# tuh : tuh
# doktrin : doktrin
# brisik : brisik
# kaya : kaya
# habiburokhman : habiburokhman
# dll : dll
# sebenernya : sebenernya
# pinter2 : pinter2
# hukum : hukum
# mendadak : dadak
# napsu : napsu
# cagubnyinyir : cagubnyinyir
# semiaji : semiaji
# w : w
# sastromedia : sastromedia
# mohamadfalah11 : mohamadfalah11
# fatwa : fatwa
# mui : mui
# dasarnya : dasar
# dihierarki : hierarki
# uud : uud
# dpr : dpr
# ri : ri
# zon : zon
# kapolri : kapolri
# nggak : nggak
# bunyi : bunyi
# ente : ente
# plintarplintir : plintarplintir
# zonk : zonk
# foto : foto
# ableh : ableh
# muncul : muncul
# perasaan : asa
# sll : sll
# lgsg : lgsg
# mual : mual
# pitam : pitam
# muak : muak
# sinting : sinting
# spvfxfk1i7 : spvfxfk1i7
# ferrykoto : ferrykoto
# hmskaban : hmskaban
# azissubekti : azissubekti
# him : him
# nk : nk
# ideas : ideas
# masawep : masawep
# tvonenews : tvonenews
# carolineverbund : carolineverbund
# emng : emng
# tikus : tikus
# got : got
# ngerti : ngerti
# piara : piara
# mahendradatta : mahendradatta
# konteksnya : konteks
# melawan : lawan
# penjajah : jajah
# senasib : nasib
# klu : klu
# kepentingan : penting
# busuk : busuk
# provoktor : provoktor
# dibelakang : belakang
# beranggapan : anggap
# bgtu : bgtu
# jman : jman
# klw : klw
# lengser : lengser
# okezonenews : okezonenews
# berkuasa : kuasa
# mengatasnamakan : mengatasnamakan
# ikutttt : ikutttt
# pembisik : bisik
# bikin : bikin
# iyalah : iya
# rhe : rhe
# best : best
# wkl : wkl
# jls : jls
# kerjanya : kerja
# sirik : sirik
# iri : iri
# basuki : basuki
# btp : btp
# yunartowijaya : yunartowijaya
# si : si
# cleaning : cleaning
# servicenya : servicenya
# trump : trump
# kepake : kepake
# jagonya : jago
# puisi : puisi
# abal2 : abal2
# woy : woy
# trumpt : trumpt
# kampaye : kampaye
# menghina : hina
# wkkwkwk : wkkwkwk
# emg : emg
# penista : nista
# coba : coba
# namanya : nama
# udh : udh
# jelas2 : jelas2
# dikit : dikit
# napa : napa
# shintamyllito : shintamyllito
# realdonaldtrump : realdonaldtrump
# dah : dah
# ganteng : ganteng
# donal : donal
# kliatan : kliatan
# iqnazlaya : iqnazlaya
# habibthink : habibthink
# hei : hei
# rempong : rempong
# lihat : lihat
# blg : blg
# jdi : jdi
# stop : stop
# alay : alay
# bin : bin
# membedakan : beda
# pengawasan : awas
# memprovokasi : provokasi
# 77unrsj9x0 : 77unrsj9x0
# kartu : kartu
# mate : mate
# kirain : kirain
# tarot : tarot
# hahaha : hahaha
# jonk : jonk
# lama2 : lama2
# maksud : maksud
# mrtao1188 : mrtao1188
# kepo : kepo
# belagak : bagak
# dompleng : dompleng
# situ : situ
# proses : proses
# polri : polri
# fadjroel : fadjroel
# ruhutsitompul : ruhutsitompul
# yqs2oakjvr : yqs2oakjvr
# ngaca : ngaca
# presidennya : presiden
# komen : komen
# bau : bau
# enny : enny
# endah : endah
# denbagoesputro : denbagoesputro
# belaga : belaga
# penunggangnya : tunggang
# tempodotco : tempodotco
# elah : elah
# orang2 : orang2
# dikibulin : dikibulin
# yqgs1tulhu : yqgs1tulhu
# ismi143 : ismi143
# iya : iya
# pengadilan : adil
# aparat : aparat
# vj : vj
# efraim : efraim
# ferrymaitimu : ferrymaitimu
# sahal : sahal
# as : as
# disalahin : disalahin
# wakil : wakil
# ketua : ketua
# sejarah : sejarah
# pedoman : pedoman
# id : id
# kompastv : kompastv
# dlm : dlm
# gaar2 : gaar2
# undang : undang
# mrk : mrk
# gedung : gedung
# bener2 : bener2
# oon : oon
# dibawa : bawa
# kemana : mana
# negri : negri
# ulama : ulama
# tembak : tembak
# gas : gas
# air : air
# presiden : presiden
# sok : sok
# pahlawan : pahlawan
# kesiangan : siang
# pdhl : pdhl
# biangny : biangny
# masakkkk : masakkkk
# maksuddd : maksuddd
# loooo : loooo
# ikut2an : ikut2an
# pamer : pamer
# nyata2 : nyata2
# berbau : bau
# dihadiri : hadir
# tokoh2 : tokoh2
# parpol : parpol
# rival : rival
# imbisil : imbisil
# junjungan : junjung
# erdogan : erdogan
# noh : noh
# qfzentu6iz : qfzentu6iz
# faldomaldini : faldomaldini
# zul : zul
# hasan : hasan
# istirahat : istirahat
# masjid : masjid
# nguasai : nguasai
# parlemen : parlemen
# divhumaspolri : divhumaspolri
# suru : suru
# tertib : tertib
# goyang2 : goyang2
# mobil : mobil
# polisi : polisi
# bakar : bakar
# mengaku : aku
# rkyt : rkyt
# turun : turun
# malu2in : malu2in
# gatra : gatra
# news : news
# tuk : tuk
# temui : temu
# mudah : mudah
# diprovokasi : provokasi
# pecah : pecah
# belah : belah
# nkri : nkri
# trantibmas : trantibmas
# prabowo : prabowo
# laporin : laporin
# penuh : penuh
# kantor : kantor
# laporan : lapor
# bulls : bulls
# rakyak : rakyak
# kagak : kagak
# dhidioemar : dhidioemar
# badut : badut
# senayan : senayan
# ahli : ahli
# asbun : asbun
# mewancarai : mewancarai
# ngajak : ngajak
# atw : atw
# mengarahkan : arah
# akun : akun
# palsu : palsu
# disosmed : disosmed
# milik : milik
# kader : kader
# w2xfz2uiq6 : w2xfz2uiq6
# bantu : bantu
# harga : harga
# bertahan : tahan
# nyindir : nyindir
# ngpn : ngpn
# pencitraan : citra
# sgla : sgla
# krja : krja
# nyata : nyata
# beda : beda
# ngom : ngom
# elo : elo
# lampu : lampu
# mati : mati
# pln : pln
# emak : emak
# perempuan : perempuan
# waketu : waketu
# dewan : dewan
# suuzon : suuzon
# mrasa : mrasa
# pdhal : pdhal
# tsk : tsk
# tupoksinya : tupoksinya
# shg : shg
# mulutmu : mulut
# gua : gua
# terima : terima
# pejabat : jabat
# pilpres : pilpres
# blum : blum
# move : move
# gue : gue
# smpe : smpe
# mantau : mantau
# ott : ott
# 7annya : 7annya
# pengalihan : alih
# isu : isu
# alih : alih
# rssw : rssw
# reklamasi : reklamasi
# pemerintah : perintah
# babi : babi
# ikmal : ikmal
# mmi : mmi
# ilc : ilc
# ngeles : ngeles
# yosspunky : yosspunky
# pelihara : pelihara
# yos : yos
# ewan : ewan
# pluit : pluit
# pik : pik
# banjir : banjir
# berani : berani
# aseng : aseng
# mangga : mangga
# maksiat : maksiat
# malangtodaynet : malangtodaynet
# kebijakan : bijak
# super : super
# ngomongnya : ngomongnya
# jeplak : jeplak
# bukti : bukti
# rakyatnya : rakyat
# wakilnya : wakil
# berduka : duka
# tindakan : tindak
# ormas : ormas
# jabar : jabar
# 1pun : 1pun
# ngomentarin : ngomentarin
# makany : makany
# bnyk : bnyk
# suai : suai
# solusinya : solusi
# arahnya : arah
# kategori : kategori
# sombong : sombong
# dani : dan
# menggap : gap
# abumawasan : abumawasan
# tdak : tdak
# bela : bela
# dhani : dhani
# maki : maki
# kecuali : kecuali
# istana : istana
# philipina : philipina
# 212cintadamaiindonesiaku : 212cintadamaiindonesiaku
# makar : makar
# turunkan : turun
# lolos : lolos
# opini : opini
# kata2 : kata2
# kadang : kadang
# kluar : kluar
# sadar : sadar
# mulut : mulut
# mmang : mmang
# allah : allah
# slalu : slalu
# sign : sign
# tnp : tnp
# udang : udang
# blok : blok
# kangen : kangen
# kicauan : kicau
# kocak : kocak
# salam : salam
# lemper : lemper
# 212 : 212
# diikuti : ikut
# love : love
# islam : islam
# idn : idn
# budimandjatmiko : budimandjatmiko
# mnckoransindo : mnckoransindo
# fadlizonlibrary : fadlizonlibrary
# biasalah : biasa
# media : media
# bahas : bahas
# ttg : ttg
# manusia : manusia
# berkurang : kurang
# just : just
# onoy : onoy
# lulung : lulung
# tersangka : sangka
# residivis : residivis
# hapeproperti : hapeproperti
# tetapahokdjarot : tetapahokdjarot
# aspirasi : aspirasi
# bapak2 : bapak2
# serap : serap
# kaga : kaga
# anti : anti
# kritik : kritik
# rombongan : rombong
# sbyudhoyono : sbyudhoyono
# mantap : mantap
# msih : msih
# setia : setia
# nyatakn : nyatakn
# maklum : maklum
# yunarto : yunarto
# diedit : edit
# leher : leher
# dibodohi : bodoh
# pinterpun : pinterpun
# satanjiminie : satanjiminie
# sayton : sayton
# sama2 : sama2
# majin : majin
# terra : terra
# digembok : gembok
# aneh : aneh
# kblingerrr : kblingerrr
# bodo : bodo
# terhormat : hormat
# mendingan : mending
# sindonews : sindonews
# ngak : ngak
# heran : heran
# fadli : fadli
# dibohongi : bohong
# pura2ngak : pura2ngak
# skrng : skrng
# mslh : mslh
# kerjaan : kerja
# sby : sby
# hati : hati
# dengki : dengki
# memaksa : paksa
# ucapan : ucap
# edit : edit
# buni : buni
# sbg : sbg
# penistaan : nista
# stress : stress
# poor : poor
# babies : babies
# couldn : couldn
# bully : bully
# the : the
# president : president
# because : because
# there : there
# case : case
# hysteris : hysteris
# anggota : anggota
# dpdri : dpdri
# nekat : nekat
# merencanakan : rencana
# aksimakaralawakilrakyat411 : aksimakaralawakilrakyat411
# jngn : jngn
# agma : agma
# cra2 : cra2
# kotor : kotor
# lbh : lbh
# barokah : barokah
# sosmed : sosmed
# kuliah : kuliah
# ecek : ecek
# pas : pas
# gagu : gagu
# gagap : gagap
# ngopijahe : ngopijahe
# 09 : 09
# habibrizieq : habibrizieq
# sendok : sendok
# almaidah : almaidah
# 8xllaxga2g : 8xllaxga2g
# radioelshinta : radioelshinta
# temuan : temu
# inteljen : inteljen
# rahasia : rahasia
# indonesia : indonesia
# estiningsihdwi : estiningsihdwi
# demokrasi : demokrasi
# omongan : omong
# ditelan : tel
# mujib170472 : mujib170472
# ditemui : temu
# wapres : wapres
# konstitusi : konstitusi
# hrsnya : hrsnya
# sindotrijayafm : sindotrijayafm
# kmi : kmi
# bayaran : bayar
# suap : suap
# kampungan : kampung
# tvonenewsdotcom : tvonenewsdotcom
# jagan : jagan
# radikal : radikal
# kurs : kurs
# 070 : 070
# hhh : hhh
# nambah : nambah
# sudjiwotedjo : sudjiwotedjo
# ama : ama
# ratna : ratna
# speot : speot
# ideal : ideal
# odwohd5omc : odwohd5omc
# licik : licik
# menggulingkn : menggulingkn
# dengn : dengn
# nebeng : nebeng
# khasus : khasus
# b0sss : b0sss
# jalanan : jalan
# dudukin : dudukin
# politikus : politikus
# negeri : negeri
# gendheng : gendheng
# dihiraukan : hirau
# ngumpul : ngumpul
# duo : duo
# domain : domain
# rezakurniawn : rezakurniawn
# malu : malu
# wacana : wacana
# sungguh : sungguh
# mas : mas
# rikitop : rikitop
# karno : karno
# merumuskan : rumus
# pancasila : pancasila
# ampuni : ampun
# dinas : dinas
# mang : mang
# ngurus : ngurus
# xnatjnrlfi : xnatjnrlfi
# sandiuno : sandiuno
# merendahkan : rendah
# uyyhirapl7 : uyyhirapl7
# berita : berita
# dimuat : muat
# halodetikcom : halodetikcom
# isi : isi
# provokasi : provokasi
# diberitakan : berita
# korantempo : korantempo
# diawasi : awas
# artikel : artikel
# unras : unras
# kominfo : kominfo
# jlnkan : jlnkan
# ite : ite
# disuruh : suruh
# sw3s5papky : sw3s5papky
# ditungganilah : ditungganilah
# andar : andar
# sihombing : sihombing
# buniyani : buniyani
# menafsirkannya : tafsir
# memiliki : milik
# tei3qrgt0h : tei3qrgt0h
# pandang : pandang
# pegang : pegang
# materi : materi
# utama : utama
# ummat : ummat
# rustamibrahim : rustamibrahim
# sknya : sknya
# profokator : profokator
# buruk : buruk
# negatif : negatif
# tingking : tingking
# mciptkan : mciptkan
# kedamaian : damai
# pesertanya : serta
# ngarang : ngarang
# hahhahhahah : hahhahhahah
# sikap : sikap
# prilaku : prilaku
# mencerminkan : cermin
# persatuan : satu
# lomba : lomba
# bermutu : mutu
# kek : kek
# gini : gin
# muka : muka
# jelek : jelek
# keberatan : berat
# jln2 : jln2
# uang : uang
# bangsat : bangsat
# badak : badak
# abang : abang
# heheeheheheh : heheeheheheh
# ajaib : ajaib
# priksa : priksa
# pjbat : pjbat
# hrus : hrus
# nunggu : nunggu
# jwbn : jwbn
# desa : desa
# pasal : pasal
# tsb : tsb
# tuli : tuli
# berati : berat
# bisu : bisu
# diam : diam
# tong : tong
# plis : plis
# 31cc4pebpg : 31cc4pebpg
# jk : jk
# ditulis : tulis
# catatan : catat
# kepala : kepala
# tulisan : tulis
# maksudnya : maksud
# helmifelis : helmifelis
# pencuri : curi
# pahamin : pahamin
# bedanya : beda
# eksekutif : eksekutif
# legislatif : legislatif
# nanya : nanya
# nga : nga
# 0itcb0qvoo : 0itcb0qvoo
# memilih : pilih
# iman : iman
# surga : surga
# apaa : apaa
# neraka : neraka
# bisanya : bisa
# mengkritik : kritik
# kerja : kerja
# kabinet : kabinet
# bayangan : bayang
# ngakak : ngakak
# pikiran : pikir
# menderita : derita
# masyarakat : masyarakat
# pqnd6nriz8 : pqnd6nriz8
# srigalapagi : srigalapagi
# rotatimu : rotatimu
# takdir : takdir
# mudahnya : mudah
# terprovokasi : provokasi
# fix : fix
# 2019 : 2019
# mxvyeg0rbi : mxvyeg0rbi
# rendahnya : rendah
# akhlak : akhlak
# beragama : agama
# mbok : mbok
# insstansi : insstansi
# yng : yng
# miskin : miskin
# taurusian78 : taurusian78
# abuhudzaifah82 : abuhudzaifah82
# ssirah : ssirah
# gelar : gelar
# profesor : profesor
# jaminan : jamin
# taat : taat
# pribadi : pribadi
# anggap : anggap
# meremehkan : remeh
# terbelah : belah
# pandangan : pandang
# muhammadiyah : muhammadiyah
# bangga : bangga
# astaghfirullah : astaghfirullah
# marah : marah
# kpd : kpd
# maspiyungan : maspiyungan
# cvkt2g5pwa : cvkt2g5pwa
# ajarin : ajarin
# arekgubeng2 : arekgubeng2
# grand : grand
# light88 : light88
# asepapit : asepapit
# arifinp76 : arifinp76
# kpk : kpk
# ribut : ribut
# didumay : didumay
# lapor : lapor
# sono : sono
# 22similikiti : 22similikiti
# resmi : resmi
# medsos : medsos
# ngk : ngk
# blh : blh
# l951amqc62 : l951amqc62
# hendry : hendry
# candra : candra
# wijaya : wijaya
# sugeng : sugeng
# asupan : asupan
# vitamin : vitamin
# kelulungan : kelulungan
# novri75 : novri75
# emwe : emwe
# nafis : naf
# blau : blau
# layar : layar
# dennyja : dennyja
# world : world
# rudysarwa : rudysarwa
# crescentst4r : crescentst4r
# nongandah : nongandah
# bigot2 : bigot2
# indon : indon
# boikotsariroti : boikotsariroti
# 5gqnrkknpi : 5gqnrkknpi
# garayendra : garayendra
# mikir : mikir
# abualghazali19 : abualghazali19
# gundul : gundul
# kuping : kuping
# budeg : budeg
# denger : denger
# anjing : anjing
# sutrisnodavinci : sutrisnodavinci
# nganggap : nganggap
# orasi : orasi
# indo : indo
# mgkn : mgkn
# presdn : presdn
# zimbabwe : zimbabwe
# ahok4indonesia : ahok4indonesia
# twitter : twitter
# buatan : buat
# jepang : jepang
# mihak : mihak
# 411 : 411
# sisa : sisa
# gram : gram
# 48cfahxjr3 : 48cfahxjr3
# diamini : amin
# nina17111240 : nina17111240
# ngetawain : ngetawain
# dibully : dibully
# donk : donk
# nnt : nnt
# dibilangnya : bilang
# menista : nista
# lho : lho
# membully : membully
# irwan2324 : irwan2324
# sindiran : sindir
# kunyuk : kunyuk
# guling2 : guling2
# 0b6odlfrgp : 0b6odlfrgp
# rajadki : rajadki
# ustadtengku : ustadtengku
# didepan : depan
# ubaidilmuhaimin : ubaidilmuhaimin
# ala : ala
# bunglon : bunglon
# quran : quran
# gara2 : gara2
# donald : donald
# syekaleeee : syekaleeee
# nyet : nyet
# anarkis : anarkis
# setuju : tuju
# praperadilan : praperadilan
# bacot : bacot
# nuntut : nuntut
# berubah : ubah
# munafiknya : munafik
# berkedok : kedok
# kudetagagal : kudetagagal
# bo5qmz7ehg : bo5qmz7ehg
# hey : hey
# nov : nov
# seupil : upil
# itupun : itu
# koar : koar
# binal : binal
# babaj : babaj
# belur : bur
# pendemo : demo
# nathanaelsalem : nathanaelsalem
# hendrikk168 : hendrikk168
# karman : karman
# mustamin : mustamin
# sepenanggungan : tanggung
# diblok : blok
# bertepi : tepi
# abdulma68325766 : abdulma68325766
# abaaah : abaaah
# aamiin : aamiin
# inshaallah : inshaallah
# msyrakat : msyrakat
# aplg : aplg
# dongoknya : dongok
# laskar : laskar
# quvvatt : quvvatt
# tanpadelusi : tanpadelusi
# tanpaagama : tanpaagama
# injeffwetrust : injeffwetrust
# donny7etrost : donny7etrost
# el : el
# atheos : atheos
# isme : isme
# qitmr : qitmr
# apnwztyaxo : apnwztyaxo
# komisi : komisi
# jokohq : jokohq
# fahruroziishaq : fahruroziishaq
# basimafaysal : basimafaysal
# gprindonesia : gprindonesia
# thomsdil : thomsdil
# xykunscmbs : xykunscmbs
# drp : drp
# bapakmu : bapak
# anfgota : anfgota
# ngomporin : ngomporin
# memanfaatkan : manfaat
# situasi : situasi
# dng : dng
# dkodenk : dkodenk
# whahahhaa : whahahhaa
# tua : tua
# tetep : tetep
# lucu : lucu
# ajakan : aja
# sibonekakayu : sibonekakayu
# uninstall : uninstall
# boikot : boikot
# gojekindonesia : gojekindonesia
# rweejaya : rweejaya
# tofalemon : tofalemon
# zarazettirazr : zarazettirazr
# bingittss : bingittss
# waahh : waahh
# gampar : gampar
# bos : bos
# terbiasa : biasa
# lancang : lancang
# nti : nti
# minion : minion
# metro : metro
# tv : tv
# umat : umat
# diadu : adu
# jenius : jenius
# ckckck : ckckck
# istighfar : istighfar
# emeng : emeng
# grup : grup
# arifmalikmalika : arifmalikmalika
# pemkabbekasi : pemkabbekasi
# o66uppn8l3 : o66uppn8l3
# menebar : tebar
# bara : bara
# cuci : cuci
# keras : keras
# kampret : kampret
# ynelv9ej89 : ynelv9ej89
# dijadikan : jadi
# pegangan : pegang
# musim : musim
# era : era
# antonio : antonio
# glory : glory
# islamnya : islam
# yusron : yusron
# ngajarin : ngajarin
# ajar : ajar
# thdp : thdp
# pribumi : pribumi
# pny : pny
# kekuatan : kuat
# kebanggaanmu : bangga
# negerimu : negeri
# ml6wiuwarf : ml6wiuwarf
# anita : anita
# sukur : sukur
# woi : woi
# ttd : ttd
# kepres : pres
# ryesties : ryesties
# timomanullang : timomanullang
# hanifdhakiri : hanifdhakiri
# intelnya : intel
# nyari : nyari
# resti : resti
# mulu : mulu
# ahokers : ahokers
# tai : tai
# dalang : dalang
# cmn : cmn
# 1qk851ogwv : 1qk851ogwv
# bah : bah
# belajar : ajar
# bedakan : beda
# kota : kota
# mengapung : apung
# apartemen : apartemen
# mesin : mesin
# kemarahan : marah
# die : die
# pembantu : bantu
# loh : loh
# maen : maen
# suruh : suruh
# aje : aje
# njing : njing
# myoiie : myoiie
# tnasionalis : tnasionalis
# lumi4sure : lumi4sure
# pastorgilbertl : pastorgilbertl
# jalalhusin : jalalhusin
# golovkinnn : golovkinnn
# senang : senang
# komunis : komunis
# ngmng : ngmng
# drpd : drpd
# faham : faham
# maunya : mau
# jlsrhi7ion : jlsrhi7ion
# kekurang : kurang
# tegasan : tegas
# dyarnikchd : dyarnikchd
# royrenaldo1 : royrenaldo1
# ehh : ehh
# memproses : proses
# ancaman : ancam
# pembunuhan : bunuh
# wajar : wajar
# mayoritas : mayoritas
# aidi : aidi
# suryadarma : suryadarma
# daizlaode : daizlaode
# jutaan : juta
# mendagri : mendagri
# ngebantah : ngebantah
# pki : pki
# ngeletus : ngeletus
# usia : usia
# nye : nye
# kate : kate
# tjahtjo : tjahtjo
# pdip : pdip
# yak : yak
# kemnakerri : kemnakerri
# gusdur : gusdur
# amburadul : amburadul
# energi : energi
# dihapus : hapus
# pokok : pokok
# tka : tka
# ilegal : ilegal
# calonin : calonin
# serbuan : serbu
# cina : cina
# mengganggu : ganggu
# biarkan : biar
# keutuhan : utuh
# ayumakaka : ayumakaka
# yakan : yakan
# pst : pst
# krj : krj
# pnya : pnya
# ngapain : ngapain
# kere : kere
# maximvs09 : maximvs09
# kesian : kesi
# lahirin : lahirin
# pro : pro
# disandera : sandera
# backing : backing
# mahkamahagung : mahkamahagung
# plt : plt
# acak : acak
# tjahjo : tjahjo
# kumolo : kumolo
# cuti : cuti
# glpromozar : glpromozar
# 100 : 100
# ngarepin : ngarepin
# bubar : bubar
# besok : besok
# dibantai : bantai
# syiah : syiah
# kamgbinah : kamgbinah
# araboji : araboji
# lovely : lovely
# fatha : fatha
# sebel : sebel
# terus2 : terus2
# model : model
# lsm : lsm
# preman : preman
# negara : negara
# prmainan : prmainan
# klau : klau
# off : off
# gemacan70 : gemacan70
# lgian : lgian
# ahoker : ahoker
# tedi : tedi
# r : r
# m : m
# bega : bega
# omongin : omongin
# syukur : syukur
# hrs : hrs
# filter : filter
# telan : telan
# ooowh : ooowh
# beneran : beneran
# cyber : cyber
# army : army
# panglima : panglima
# dede : dede
# jongos : jongos
# 4gyvkxhdyp : 4gyvkxhdyp
# jarenjarfa : jarenjarfa
# marah2 : marah2
# ampe : ampe
# hastag : hastag
# jokowitakutfpi : jokowitakutfpi
# hasut : hasut
# pendukungmu : dukung
# java : java
# import : import
# nanininanina : nanininanina
# onta : onta
# goblokin : goblokin
# puyeng : puyeng
# soeharto : soeharto
# bebas : bebas
# ngelarang : ngelarang
# natal : natal
# jancuk : jancuk
# donasi : donasi
# pungut2 : pungut2
# jln : jln
# apasih : apasih
# membantu : bantu
# saudara2 : saudara2
# aleppo : aleppo
# kerjasama : kerjasama
# pembunuhnya : bunuh
# savealeppo : savealeppo
# bantoro29 : bantoro29
# ra : ra
# ria : ria
# rana : rana
# ronavioleta : ronavioleta
# jiler : jiler
# ndlosor : ndlosor
# mrsa : mrsa
# hny : hny
# ijasah : ijasah
# glr : glr
# santri : santri
# vnus208 : vnus208
# kafir : kafir
# tsamaradki : tsamaradki
# intoleran : intoleran
# maksain : maksain
# atribut : atribut
# ahytakterbendung : ahytakterbendung
# andiarief : andiarief
# aa : aa
# pikir : pikir
# junjunganmu : junjung
# bermoral : moral
# antonbagaspati : antonbagaspati
# nyesal : nyesal
# tito : tito
# rizieq : rizieq
# payah : payah
# la : la
# ras : ras
# primitif : primitif
# suku : suku
# indian : indian
# pembalasan : balas
# ditangan : tang
# tuham : tuham
# laras : laras
# adot1998 : adot1998
# adiseti2730888 : adiseti2730888
# kodok : kodok
# ketawa : ketawa
# dgr : dgr
# tetangga : tetangga
# aink : aink
# penggerebekan : gerebek
# bom : bom
# bekasi : bekas
# benci : benci
# bonisantosa : bonisantosa
# wjb : wjb
# ktika : ktika
# nyuruh : nyuruh
# tanda : tanda
# darurat : darurat
# dengerin : dengerin
# malaysia : malaysia
# najib : najib
# razak : razak
# buktikan : bukti
# benar2 : benar2
# menegakkan : tegak
# kuhp : kuhp
# tegakan : tega
# alquran : alquran
# memerangi : rang
# bencana : bencana
# ngarti : ngarti
# mrk2 : mrk2
# berlagak : lagak
# suci : suci
# pelaku : laku
# kriminal : kriminal
# dikasihani : kasihan
# diperlakukan : laku
# manusiawi : manusiawi
# riedsbudiono : riedsbudiono
# titokarnavian87 : titokarnavian87
# prastow : prastow
# r1 : r1
# ppatk : ppatk
# rahma : rahma
# puspen : puspen
# tni : tni
# candoelslankers : candoelslankers
# menghormati : hormat
# rasis : ras
# g : g
# paseksuardika : paseksuardika
# rudynico : rudynico
# katakn : katakn
# terbukti : bukti
# lht : lht
# daerah2 : daerah2
# kmajuan : kmajuan
# pemb : pemb
# notalkingnow : notalkingnow
# segitu : segitu
# pantatan : pantat
# lembaran : lembar
# diberakin : diberakin
# pade : pade
# ngatain : ngatain
# bisnis : bisnis
# yen : yen
# china : china
# yuan : yuan
# ngga : ngga
# melulu : melulu
# pekok : kok
# justpambudi : justpambudi
# emm4nuel : emm4nuel
# ariyandi32 : ariyandi32
# o : o
# pripot : pripot
# mbahuyok : mbahuyok
# malakmalakmal : malakmalakmal
# frans : frans
# surya : surya
# share : share
# hoax : hoax
# mentimoen : mentimoen
# larang : larang
# baca : baca
# aturan : atur
# kesindir : sindir
# kmrn : kmrn
# pgn : pgn
# ibib : ibib
# berenti : renti
# gibah : gibah
# ngejek2 : ngejek2
# pantatcina : pantatcina
# orangnya : orang
# gm : gm
# suryadelalu : suryadelalu
# hadapan : hadap
# adlh : adlh
# api : api
# intelektual : intelektual
# cap : cap
# temen : temen
# kuliahku : kuliah
# msa : msa
# bayar : bayar
# helloowww : helloowww
# capa : capa
# dbyar : dbyar
# dmo : dmo
# tuch : tuch
# beliau : beliau
# ucapkan : ucap
# terimakasih : terimakasih
# penduking : penduking
# 8clb7v1lxc : 8clb7v1lxc
# brani : brani
# mention : mention
# fariznst01 : fariznst01
# brarti : brarti
# siap2 : siap2
# intai : intai
# idolane : idolane
# nnek : nnek
# rohmat : rohmat
# ogah : ogah
# cawapres : cawapres
# nemenin : nemenin
# ape : ape
# xty0rdgqhv : xty0rdgqhv
# akipfirmanshah : akipfirmanshah
# stone : stone
# cobain : cobain
# agusyudhoyono : agusyudhoyono
# pepo : pepo
# kebo : kebo
# diriku : diri
# jatuhkan : jatuh
# secepatnya : cepat
# dungu : dungu
# phobia : phobia
# sampe : sampe
# lebaran : lebaran
# nglarang : nglarang
# ketertiban : tertib
# google : google
# kuadrat : kuadrat
# sj3ifwrgyt : sj3ifwrgyt
# nicelamb : nicelamb
# ronin : ronin
# israel : israel
# bungaji : bungaji
# bemz : bemz
# q : q
# memangnya : memang
# jony : jony
# mattz : mattz
# cumarachel : cumarachel
# bnr : bnr
# juta : juta
# mewakili : wakil
# 250 : 250
# indinesia : indinesia
# rumah : rumah
# bangun : bangun
# shame : shame
# one : one
# you : you
# chilli : chilli
# pari : pari
# hecy : hecy
# nola : nola
# detikinet : detikinet
# setkabgoid : setkabgoid
# teriak : teriak
# sndri : sndri
# blo : blo
# cemburu : cemburu
# yuris : yuris
# ab : ab
# tukangkoprol : tukangkoprol
# mikirnya : mikirnya
# mundur : mundur
# blkng : blkng
# kenal : kenal
# didi : didi
# irawadi : irawadi
# translate : translate
# bahasa : bahasa
# limsy : limsy
# consultanpublik : consultanpublik
# indrajpiliang : indrajpiliang
# editan : edit
# 2014 : 2014
# sopo : sopo
# sah : sah
# dipilih : pilih
# dilindungi : lindung
# m4owezmhzd : m4owezmhzd
# gila : gila
# snt80s : snt80s
# tafawidjaya : tafawidjaya
# cgngbmksud : cgngbmksud
# muhammad : muhammad
# dlya : dlya
# pakde : pakde
# manuvernya : manuver
# sekarang2 : sekarang2
# konsolidasi : konsolidasi
# cek : cek
# keloyalan : loyal
# hanlie555 : hanlie555
# wiranto1947 : wiranto1947
# maklumlah : maklum
# susur : susur
# hanahaluma261 : hanahaluma261
# wuihh : wuihh
# heboh : heboh
# editannya : edit
# camera : camera
# 360 : 360
# yee : yee
# dangkal : dangkal
# savenkri : savenkri
# kamiahok : kamiahok
# nasikamin : nasikamin
# manado : manado
# drummer : drummer
# platina : platina
# kudeta : kudeta
# dengar : dengar
# heyitssoffi : heyitssoffi
# usutnya : usut
# polos : polos
# kluarga : kluarga
# cikeas : cikeas
# kontras : kontras
# haris : haris
# azhar : azhar
# pelakunya : laku
# lgsng : lgsng
# siapkan : siap
# ngeribetin : ngeribetin
# utang : utang
# 30th : 30th
# lunas : lunas
# blom : blom
# beban : beban
# jusuf : jusuf
# kalla : kalla
# permanent : permanent
# 4n2e2pxuek : 4n2e2pxuek
# youtube : youtube
# nek : nek
# pikirin : pikirin
# mesum : mesum
# gianislav : gianislav
# mem : mem
# framing : framing
# disambut : sambut
# menilai : nilai
# dibutakan : buta
# jabatan : jabat
# dukungan : dukung
# maklumi : maklum
# transparan : transparan
# secuil : cuil
# ngelempar : ngelempar
# menyakiti : sakit
# kriminil : kriminil
# ntah : ntah
# bina : bina
# urusan : urus
# nasional : nasional
# internasional : internasional
# belokkan : belok
# keurusan : urus
# repost : repost
# sorotan : sorot
# publik : publik
# with : with
# repostapp : repostapp
# henti2nya : henti2nya
# pengen : ken
# bfxauc8lhe : bfxauc8lhe
# safari : safari
# menyelesaikan : selesai
# msl : msl
# beol : beol
# comen : comen
# scrolling : scrolling
# dicekal : cekal
# nurut : nurut
# sedihnyabangsaku : sedihnyabangsaku
# bfz2sbhmwh : bfz2sbhmwh
# humaira979 : humaira979
# nipu : nipu
# ktipu : ktipu
# nnti : nnti
# krna : krna
# sopan : sopan
# kcwa : kcwa
# mmbla : mmbla
# topppp : topppp
# nge : nge
# tes : tes
# bar : bar
# adp : adp
# wktu : wktu
# maksa2 : maksa2
# sorban : sorban
# mnrt : mnrt
# paan : paan
# mash : mash
# layanin : layanin
# mbygtwhnbo : mbygtwhnbo
# dilecehkan : leceh
# olh : olh
# diperbudak : budak
# dedemit : dedemit
# banteng : banteng
# ryamizard : ryamizard
# tetiba : tetiba
# ggo3y96bd8 : ggo3y96bd8
# marjoso71 : marjoso71
# vivacoid : vivacoid
# plonga : plonga
# plongo : plongo
# nista : nista
# komenin : komenin
# nggubris : nggubris
# narkoba : narkoba
# biayai : biaya
# jatuh : jatuh
# hina : hina
# simbol : simbol
# amanogawa09 : amanogawa09
# lari : lari
# kabur : kabur
# sendoknya : sendok
# gerakin : gerakin
# orng2 : orng2
# bebaju : bebaju
# putih : putih
# nunggangin : nunggangin
# tunggangi : tunggang
# fahri : fahri
# hamzah : hamzah
# diinjek : diinjek
# hina2 : hina2
# smp : smp
# blm : blm
# lapori : lapor
# keterusan : terus
# kelana83 : kelana83
# boro2 : boro2
# daging : daging
# arie : arie
# edhie : edhie
# baskoro : baskoro
# ibas : ibas
# dilempar : lempar
# nusakambangan : nusakambangan
# keadilanakandtg : keadilanakandtg
# mikirin : mikirin
# lapisan : lapis
# makannya : makan
# amet : amet
# av : av
# tos : tos
# heleh : heleh
# tuanarief : tuanarief
# smua : smua
# sering2 : sering2
# gaul : gaul
# guorong69 : guorong69
# ramadan32401426 : ramadan32401426
# rusuh : rusuh
# aza : aza
# damai : damai
# audreyratri : audreyratri
# d : d
# mafiawasit : mafiawasit
# lakuin : lakuin
# diserang : serang
# pengsmat : pengsmat
# demonya : demo
# mikirrrrrr : mikirrrrrr
# spy : spy
# tujuannya : tuju
# turunin : turunin
# tax : tax
# amnesty : amnesty
# emangnya : emang
# smg : smg
# jwb : jwb
# kegelisahan : gelisah
# aagym : aagym
# dmn : dmn
# ahokdjarot : ahokdjarot
# jexrqd9lm1 : jexrqd9lm1
# androidtuner : androidtuner
# jakmaniaontweet : jakmaniaontweet
# trevorhallz : trevorhallz
# tipis : tipis
# definisi : definisi
# nyambit : nyambit
# spa : spa
# sapa : sapa
# sit : sit
# janagan : janagan
# yusrilihza : yusrilihza
# mhd : mhd
# mengorbankn : mengorbankn
# untu : untu
# haeraniulfa : haeraniulfa
# daripda : daripda
# begoin : begoin
# cnta : cnta
# cinta : cinta
# scara : scara
# utuh : utuh
# apresiasi : apresiasi
# isya : isya
# aktor : aktor
# ari : ari
# sup : sup
# amanatindo : amanatindo
# rendranila : rendranila
# ngabehi : ngabehi
# pandu : pandu
# gusrizal7866 : gusrizal7866
# koar2nya : koar2nya
# ortu : ortu
# nyasar : nyasar
# gimana : gimana
# temuin : temuin
# mreka : mreka
# embel2 : embel2
# diskusi : diskusi
# makzulkan : makzul
# sdfwlfyyhh : sdfwlfyyhh
# mashary71 : mashary71
# error : error
# analisanya : analisanya
# menyesatkan : sesat
# srhingga : srhingga
# ngikuti : ngikuti
# puutriannisa : puutriannisa
# nalarmu : nalar
# beliu : beliu
# peesis : peesis
# gemna : gemna
# msti : msti
# ladeni : laden
# bungtomsss : bungtomsss
# presidenkemana : presidenkemana
# ktmu : ktmu
# jokowibego : jokowibego
# saritimbul : saritimbul
# dhannyprima : dhannyprima
# wkwkwk : wkwkwk
# membuktikan : bukti
# restyies : restyies
# sofiaaja62 : sofiaaja62
# konprensi : konprensi
# pers : pers
# menyentuh : sentuh
# subtansi : subtansi
# peserta : serta
# membela : bela
# diteriakin : diteriakin
# kwkw : kwkw
# ngomongin : ngomongin
# penjara : penjara
# imaginer : imaginer
# mzulkifli168 : mzulkifli168
# menjarain : menjarain
# main : main
# hakim : hakim
# demonstran : demonstran
# j6fxw9pqg1 : j6fxw9pqg1
# sampiyan : sampiyan
# krungu : krungu
# wiwit : wiwit
# wingi : wing
# owh : owh
# arep : arep
# ono : ono
# ojo : ojo
# kelewat : lewat
# knpbpapua : knpbpapua
# papua : papua
# merdeka : merdeka
# admin : admin
# jakoutline : jakoutline
# benteng : benteng
# tkp : tkp
# diem : diem
# nyinyir : nyinyir
# kbur : kbur
# hahaaa : hahaaa
# bohong : bohong
# abc : abc
# moxca : moxca
# hariadhi : hariadhi
# wkt : wkt
# tugas : tugas
# menghadapi : hadap
# aksidamai411 : aksidamai411
# skedul : skedul
# jauh2 : jauh2
# pergi : pergi
# kga : kga
# skedulnya : skedul
# hoiiii : hoiiii
# hati2 : hati2
# azab : azab
# amin : amin
# rakus : rakus
# untungnya : untung
# lindungi : lindung
# ardyharnanto : ardyharnanto
# vandawa : vandawa
# dunia : dunia
# nol : nol
# hutang : hutang
# impor : impor
# mimpin : mimpin
# lugu : lugu
# yantohuang : yantohuang
# skalian : skalian
# mintain : mintain
# data : data
# profesi : profesi
# drmn : drmn
# gliran : gliran
# slah : slah
# sdkit : sdkit
# lngsng : lngsng
# tntut : tntut
# dsar : dsar
# tuntut : tuntut
# nntut : nntut
# jga : jga
# sring : sring
# mnistakan : mnistakan
# cuk000 : cuk000
# setiaaa24 : setiaaa24
# gubernurnya : gubernur
# gub : gub
# kalopun : kalo
# keamanan : aman
# berat : berat
# rame : rame
# dlu : dlu
# dijelasin : dijelasin
# kecurangan : curang
# lem : lem
# aibon : aibon
# abis : abis
# ngetwit : ngetwit
# keliatann : keliatann
# syamim : syamim
# shahab : shahab
# ernestprakasa : ernestprakasa
# nest : nest
# luu : luu
# sebut2 : sebut2
# sandingin : sandingin
# ame : ame
# ernest : ernest
# prakasa : prakasa
# gegara : gegara
# makhluk : makhluk
# terkutuk : kutuk
# perusak : usak
# toleransi : toleransi
# linglung : linglung
# mahabrantakanjkw : mahabrantakanjkw
# dibj8aq0ek : dibj8aq0ek
# gtu : gtu
# melindungi : lindung
# menjilat2 : menjilat2
# ancurrr : ancurrr
# jok : jok
# umyg50xipt : umyg50xipt
# kebohongan : bohong
# kebodohan : bodoh
# z12tbcvlnn : z12tbcvlnn
# kandargalang : kandargalang
# umar : umar
# hasibuan : hasibuan
# nuduh : nuduh
# nyalahin : nyalahin
# bangzul : bangzul
# pni : pni
# ntmclantaspolri : ntmclantaspolri
# auliazein75 : auliazein75
# panggil : panggil
# sabar : sabar
# ups : ups
# kayaknya : kayak
# ketularan : tular
# petinggi : petinggi
# tifsembiring : tifsembiring
# buah : buah
# diasut : diasut
# luhut : luhut
# cahyo : cahyo
# penyusun : susun
# ketidakadilan : ketidakadilan
# penegakan : tega
# mlh : mlh
# settingan : settingan
# kemensetnegri : kemensetnegri
# geyelicius : geyelicius
# kesitu : kesitu
# triger : triger
# ahox : ahox
# bkl : bkl
# mempertahankan : tahan
# cpt : cpt
# beezays : beezays
# nickpertom : nickpertom
# boudyhru5x : boudyhru5x
# dodot2014 : dodot2014
# artofimbalance : artofimbalance
# lukmansaifuddin : lukmansaifuddin
# odyiusjacare : odyiusjacare
# dikadalin : dikadalin
# ayat : ayat
# amar : amar
# maruf : maruf
# naimungkar : naimungkar
# mmg : mmg
# batasnya : batas
# pengrajin : rajin
# lokal : lokal
# mematikannya : mati
# rezim : rezim
# recehan : receh
# slbf5crfbq : slbf5crfbq
# suciwati : suciwati
# kjadian : kjadian
# munir : munir
# periode : periode
# nyimak : nyimak
# sakit : sakit
# tensi : tensi
# naek : naek
# capek : capek
# dongo : dongo
# ripperadilanindonesia : ripperadilanindonesia
# hendro : hendro
# mcm2 : mcm2
# terpental : pental
# kunci : kunci
# joko : joko
# dipegang : pegang
# rooidn4rk6 : rooidn4rk6
# edan : edan
# ydixmwn7b2 : ydixmwn7b2
# dokumen : dokumen
# tpf : tpf
# prihatin : prihatin
# janur : janur
# koening : koening
# rmolco : rmolco
# dapet : dapet
# nemu : nemu
# facebook : facebook
# ki7j2j7qtr : ki7j2j7qtr
# kuat : kuat
# dibeking : beking
# cyuv41x1ni : cyuv41x1ni
# wartapolitik : wartapolitik
# bemol : bol
# jaya : jaya
# pangkat : pangkat
# pangkatnya : pangkat
# mahasiswa : mahasiswa
# pemerintahan : perintah
# indrawan : indrawan
# x : x
# jerat : jerat
# megawati : megawati
# oknum : oknum
# mhsisawa : mhsisawa
# titip : titip
# wibisono1 : wibisono1
# iren : iren
# me : me
# pramonoanung : pramonoanung
# ganjarpranowo : ganjarpranowo
# mengkriti : mengkriti
# lucunya : lucu
# follow : follow
# metion : metion
# ngeblock : ngeblock
# bhd : bhd
# 58 : 58
# jual : jual
# eceran : ecer
# sesui : sesui
# spbu : spbu
# untung : untung
# harismz : harismz
# chatime888 : chatime888
# knoton793 : knoton793
# jazz : jazz
# mewekan : mewek
# netek : netek
# rita : rita
# tj : tj
# luh : luh
# ngaku2 : ngaku2
# belo : belo
# cong : cong
# huruf : huruf
# lol : lol
# suaraanies : suaraanies
# chirpstory : chirpstory
# disalahkan : salah
# lkpp : lkpp
# salahin : salahin
# cctv : cctv
# mk : mk
# hancur : hancur
# rekaman : rekam
# stlh : stlh
# kepojok : pojok
# tiba2 : tiba2
# teraniaya : aniaya
# tabiat : tabiat
# mathphilosophia : mathphilosophia
# ninjacapkampack : ninjacapkampack
# rapplerid : rapplerid
# tirtoid : tirtoid
# buddysatriaz : buddysatriaz
# legalin : legalin
# kebiadabam : kebiadabam
# ngaku : ngaku
# daftar : daftar
# orkay : orkay
# forbes : forbes
# nasionalis : nasionalis
# sejati : sejati
# dikuasai : asai
# dipimpin : pimpin
# dijual : jual
# fw5g5jykki : fw5g5jykki
# jeremy : jeremy
# h : h
# generalgatot : generalgatot
# tniau : tniau
# load : load
# moh67u1484 : moh67u1484
# juli : juli
# regime : regime
# suharto : suharto
# kesrimpet : kesrimpet
# jahat : jahat
# bentr : bentr
# krmtroysuryo : krmtroysuryo
# euy : euy
# effect : effect
# lebayyy : lebayyy
# e8qprzqedz : e8qprzqedz
# sengaja : sengaja
# tdksengaja : tdksengaja
# perbuatan : buat
# abaikan : abai
# ajah : ajah
# haters : haters
# junjungannya : junjung
# ujaran : ujar
# kebencian : benci
# sprti : sprti
# anehnya : aneh
# abal : abal
# diolah : olah
# mentah : mentah
# dhe : dhe
# doaku : doa
# nadi : nadi
# 705h3 : 705h3
# tindak : tindak
# habib : habib
# bersalah : salah
# ibnupurna : ibnupurna
# pekerjaan : kerja
# didunia : dunia
# pekerja : kerja
# dipulangkan : pulang
# transfer : transfer
# ilmu : ilmu
# selesai : selesai
# lau : lau
# hbdr21 : hbdr21
# irwank2k2 : irwank2k2
# membencimu : benci
# kritiklah : kritik
# berakal : akal
# mencintaimu : cinta
# imam : imam
# ali : ali
# taufan : taufan
# alatas : alatas
# komentar : komentar
# menyedihkan : sedih
# rudyey70 : rudyey70
# skumar176 : skumar176
# uping : uping
# maki2 : maki2
# penduduk : duduk
# memakai : pakai
# asing : asing
# nasionaliskah : nasionalis
# ssuatu : ssuatu
# alamat : alamat
# bibit : bibit
# pertikaian : tikai
# didengar : dengar
# didienazhar : didienazhar
# pulang : pulang
# dkzznbz7ur : dkzznbz7ur
# abislah : abis
# kedepan : depan
# prof : prof
# strategi : strategi
# berlin : lin
# hassan : hassan
# ribu : ribu
# ntar : ntar
# rakyatmu : rakyat
# jelata : jelata
# buruh : buruh
# srcbnsyfbh : srcbnsyfbh
# sehat : sehat
# menjaga : jaga
# sumbu : sumbu
# pendek : pendek
# membunuh : bunuh
# halal : halal
# bunuh : bunuh
# kampang : kampang
# nyebelin : nyebelin
# 0bha6widuu : 0bha6widuu
# sayareya : sayareya
# diaem : diaem
# aparatpun : aparat
# bertambah : tambah
# mangsamu : mangsa
# spo : spo
# sek : sek
# apek : apek
# ganggu : ganggu
# tolikara : tolikara
# sembarangan : sembarang
# buku : buku
# konfirmasi : konfirmasi
# sebelah : belah
# vqab1qpqqo : vqab1qpqqo
# elfizal : elfizal
# tutup2i : tutup2i
# nindak : nindak
# maaf : maaf
# beribu : ibu
# panggilan : panggil
# etis : etis
# spti : spti
# saran : saran
# bermental : mental
# korup : korup
# suka : suka
# perubahan : ubah
# bring : bring
# give : give
# our : our
# positive : positive
# changes : changes
# wwdm8m6ze6 : wwdm8m6ze6
# barat : barat
# utara : utara
# sibuk : sibuk
# teknologi : teknologi
# butuhin : butuhin
# dpn : dpn
# 10jt : 10jt
# turis : turis
# jerman : jerman
# uangnya : uang
# belanja : belanja
# maafkan : maaf
# pendapat : dapat
# jhon : jhon
# ciyeee : ciyeee
# komunitas : komunitas
# minoritas : minoritas
# memaksakan : paksa
# kehendak : hendak
# arytp : arytp
# lha : lha
# gunanya : guna
# menyejahterakan : sejahtera
# koe : koe
# ditambah : tambah
# emosi : emosi
# jdnya : jdnya
# syp : syp
# berulah : ulah
# banyakin : banyakin
# susah : susah
# bodohi : bodoh
# tiongkok : tiongkok
# melancong : lancong
# jago : jago
# ong : ong
# emgx : emgx
# video : video
# nyatakan : nyata
# walikota : walikota
# jambi : jambi
# tlah : tlah
# mpermasalhkan : mpermasalhkan
# arab : arab
# dpohon : dpohon
# tribunjambiku : tribunjambiku
# infojbi : infojbi
# liriksoe : liriksoe
# lirik : lirik
# koreksi : koreksi
# bgs : bgs
# blng : blng
# antobangko : antobangko
# pasang : pasang
# titel : titel
# kalimat : kalimat
# termakan : makan
# dilahirkan : lahir
# mlindungi : mlindungi
# bnyak : bnyak
# 86hyizt9n5 : 86hyizt9n5
# dibikin : bikin
# doni17 : doni17
# kemin : min
# alhamdulillah : alhamdulillah
# lecehkan : leceh
# ccicpolri : ccicpolri
# buming : buming
# undercover : undercover
# diganti : ganti
# telolet : telolet
# ketipu : tipu
# jokower : jokower
# liqqa62w9t : liqqa62w9t
# nalarnya : nalar
# terjajah : jajah
# detik : detik
# gusdurians : gusdurians
# laut : laut
# garam : garam
# haulgusdur : haulgusdur
# songong : songong
# silahkan : silah
# padat : padat
# 123 : 123
# jawabannya : jawab
# default : default
# 20kv : 20kv
# pelanggan : langgan
# ylki : ylki
# jlwyrqnl4j : jlwyrqnl4j
# roymz : roymz
# 13 : 13
# tabbayun : tabbayun
# ymnze7eczt : ymnze7eczt
# ianzainal : ianzainal
# solo : solo
# permintaan : minta
# anak2 : anak2
# supir : supir
# bus : bus
# bunyikan : bunyi
# kelakson : kelakson
# tty : tty
# mulut2 : mulut2
# ngapa : ngapa
# sewot : sewot
# pemilih2 : pemilih2
# sya : sya
# ancur : ancur
# nergara : nergara
# datangnya : datang
# tenaga : tenaga
# dri : dri
# haram : haram
# mengucapkn : mengucapkn
# pengaruh : pengaruh
# fokuslah : fokus
# indonesiaharustau : indonesiaharustau
# jqkywmowyq : jqkywmowyq
# sejahtera : sejahtera
# korupsi : korupsi
# lancar : lancar
# lupa : lupa
# 10th : 10th
# 300t : 300t
# menguap : uap
# bbm : bbm
# 3th : 3th
# 6dz5nccqot : 6dz5nccqot
# sesungguna : sesungguna
# menghinda : menghinda
# refolusi : refolusi
# f715eb3d926d416 : f715eb3d926d416
# matamu : mata
# dibebaskan : bebas
# cucu : cucu
# sengkewe : sengkewe
# almaghribis : almaghribis
# naifnya : naif
# menutup : tutup
# byknya : byknya
# bpp : bpp
# benerkah : benerkah
# kasi : kasi
# berwenang : wenang
# polhukamri : polhukamri
# kemenag : kemenag
# kemendikbud : kemendikbud
# pemahaman : paham
# nilai2 : nilai2
# pokokkee : pokokkee
# shihab : shihab
# idolaku : idola
# utamakannkri : utamakannkri
# partaikecoa : partaikecoa
# seakan : akan
# sempurna : sempurna
# berargumen : argumen
# nasochiachmad : nasochiachmad
# sgala : sgala
# caplok : caplok
# bijak : bijak
# berbicara : bicara
# menolak : tolak
# katadatanews : katadatanews
# ubah : ubah
# 000 : 000
# rmmaihxbyg : rmmaihxbyg
# ane : ane
# fasisme : fasisme
# radikalisme : radikalisme
# cantik : cantik
# apik : apik
# percayalah : percaya
# gitaputrid : gitaputrid
# dibuatkan : buat
# infografis : infografis
# relawan : rawan
# pintarpilihdua : pintarpilihdua
# naudzubillah : naudzubillah
# terbelakang : belakang
# isinya : isi
# perang : perang
# amit : amit
# insyalloh : insyalloh
# ilmi : ilmi
# rhoudhotul : rhoudhotul
# serahkan : serah
# kaena : kaena
# ceroboh : ceroboh
# bertindak : tindak
# 9u8ykmmhn7 : 9u8ykmmhn7
# setahu : tahu
# redam : redam
# dipadamkan : padam
# warta : warta
# gus : gus
# gusmusgusmu : gusmusgusmu
# wc : wc
# portable : portable
# budisi : budisi
# na : na
# dirs : dirs
# berlaku : laku
# muslimah : muslimah
# indigo : indigo
# biarin : biarin
# tunggu : tunggu
# klarifikasi : klarifikasi
# kemkominfo : kemkominfo
# iasmardiyah : iasmardiyah
# gaptek : gaptek
# teleprompter : teleprompter
# tusahkckn1 : tusahkckn1
# ir0ne7no : ir0ne7no
# dedy : dedy
# steven80 : steven80
# riziq : riziq
# mendoakan : doa
# membantainya : bantai
# chikacikhaka : chikacikhaka
# rais : rais
# biang : biang
# kerok : kerok
# apanya : apa
# bandingkan : banding
# noniekiandry : noniekiandry
# sniper : sniper
# sekeliking : sekeliking
# ndak : ndak
# tmbk : tmbk
# kawal : kawal
# investor : investor
# dilatih : latih
# acting : acting
# patuh : patuh
# setenar : tenar
# korban : korban
# pengusaha : usaha
# kspgoid : kspgoid
# bantuan : bantu
# prajurit : prajurit
# atwpun : atwpun
# bangan : bangan
# pangan : pangan
# stafny : stafny
# bnr2x : bnr2x
# remuk : remuk
# logika : logika
# tnohoax : tnohoax
# 7koikyoixt : 7koikyoixt
# maria00708 : maria00708
# sulit : sulit
# mustahil : mustahil
# bebal : bebal
# terburuk : buruk
# lakukan : laku
# kebenaran : benar
# menerimanya : terima
# liu : liu
# chan : chan
# tentera : tentera
# menyerah : serah
# musuh : musuh
# alasan : alas
# dicap : cap
# pengecut : kecut
# cnnindonesia : cnnindonesia
# usatoday : usatoday
# bubarkan : bubar
# sidang : sidang
# tutup : tutup
# telinga : telinga
# kbjakan : kbjakan
# sbgn : sbgn
# prmegang : prmegang
# saham : saham
# geram : geram
# orabg : orabg
# prmaksulkan : prmaksulkan
# prcaya : prcaya
# guru2 : guru2
# mnyampaikan : mnyampaikan
# kesesatan : sesat
# ptunjuk : ptunjuk
# yaa : yaa
# doyan : doyan
# sex : sex
# qc61tfqeik : qc61tfqeik
# isyu2 : isyu2
# teroris : teroris
# isyu : isyu
# suda : suda
# ivjxlxxh5q : ivjxlxxh5q
# aman : aman
# bertanggung : tanggung
# iffa : iffa
# qq : qq
# dipikirnya : pikir
# tegakkan : tegak
# aksibelaislam4 : aksibelaislam4
# sayangnya : sayang
# mediapun : media
# dipercaya : percaya
# jayalahnkri : jayalahnkri
# laskarkristus51 : laskarkristus51
# alytyson81 : alytyson81
# manispolos : manispolos
# sipitung64 : sipitung64
# agoeng : agoeng
# boebrah : boebrah
# panas : panas
# trus : trus
# lengserkn : lengserkn
# monethamrin : monethamrin
# bawasludkijakar : bawasludkijakar
# merugikan : rugi
# cagubnya : cagubnya
# masrilkoto : masrilkoto
# mjd : mjd
# praktek : praktek
# berdagang : dagang
# kertas : kertas
# jangan2 : jangan2
# memproduksi : produksi
# sesjen : sesjen
# dikbud : dikbud
# riodamardjati : riodamardjati
# 12hmsn6l7h : 12hmsn6l7h
# tolakbigotri : tolakbigotri
# msyrkat : msyrkat
# berhak : hak
# dihalangi : halang
# msyrkt : msyrkt
# bnar : bnar
# dibangka : bangka
# belitung : belitung
# sumut : sumut
# numpang : numpang
# qh5vbnchbx : qh5vbnchbx
# begimana : begimana
# im3ooredoo : im3ooredoo
# pop : pop
# upnya : upnya
# satellite : satellite
# hadeuhhh : hadeuhhh
# indosatcare : indosatcare
# elnkk2rvqh : elnkk2rvqh
# nangkep : nangkep
# irham : irham
# nasution : nasution
# ghazalisil : ghazalisil
# jibrok : jibrok
# b : b
# segilintir : segilintir
# pserta : pserta
# waras : waras
# hadir : hadir
# dicaci : caci
# lambat : lambat
# hashtag : hashtag
# kpkusutahok : kpkusutahok
# kendala : kendala
# xdpatbwhou : xdpatbwhou
# rizki : rizki
# saptyadi : saptyadi
# saveidn : saveidn
# netnews : netnews
# metrotv : metrotv
# jamaah : jamaah
# diajak : ajak
# membubarkan : bubar
# kkr : kkr
# dibhg11opt : dibhg11opt
# pemaaf : maaf
# suruhlah : suruh
# makruf : makruf
# pedulikan : peduli
# raf : raf
# 199 : 199
# taatalquran : taatalquran
# ditindak : tindak
# toleransinya : toleransi
# beritanya : berita
# 6rand : 6rand
# don6 : don6
# surotoroi : surotoroi
# mscendani : mscendani
# momentum : momentum
# bandungintoleran : bandungintoleran
# diproses : proses
# makgondut : makgondut
# ridwankamil : ridwankamil
# tangkap : tangkap
# adili : adil
# 4weyc7gtka : 4weyc7gtka
# samapai : samapai
# syeitonnnnn : syeitonnnnn
# yvktfpfo2s : yvktfpfo2s
# 412 : 412
# malam : malam
# romantis : romantis
# mengisap : isap
# rokok : rokok
# lembab : lembab
# sugi : sugi
# 0706 : 0706
# rt1ooxs6eo : rt1ooxs6eo
# orgnya : orgnya
# afnigates : afnigates
# fafamangstab : fafamangstab
# panitia : panitia
# acara : acara
# kitaindonesia : kitaindonesia
# memalukan : malu
# humor : humor
# tuan : tuan
# sejakarta : sejakarta
# datanglah : datang
# monas : monas
# desember : desember
# disangka : sangka
# repot2 : repot2
# masy : masy
# aksi212 : aksi212
# bodong : bodong
# karinaien : karinaien
# tgl : tgl
# giliran : gilir
# dateng : dateng
# bingung : bingung
# muji2 : muji2
# proamdalrtb : proamdalrtb
# kementerianlhk : kementerianlhk
# sumatera : sumatera
# bajer : bajer
# sbnrnya : sbnrnya
# sayang : sayang
# dimanfaatin : dimanfaatin
# kasian : kasi
# yonasukmalara : yonasukmalara
# yohaneseko : yohaneseko
# fletzha : fletzha
# persis : persis
# jateng : jateng
# walkot : walkot
# tanggal : tanggal
# s08kta8qex : s08kta8qex
# kebangeten : kebangeten
# kamupun : kamu
# bolen : bolen
# lantas : lantas
# terkait : kait
# pilgub : pilgub
# eddavdrq27 : eddavdrq27
# lapak : lapak
# jualan : jual
# payung : payung
# biru : biru
# identik : identik
# paspampres : paspampres
# ttrywqlpel : ttrywqlpel
# singa : singa
# betawi26 : betawi26
# gerak : gerak
# kebajikan : kebaji
# akut : akut
# kemaren : kemaren
# gagalpinter : gagalpinter
# jagankrikita : jagankrikita
# basukl : basukl
# zumpio : zumpio
# mari : mari
# bangkit : bangkit
# hikam : hikam
# ptanyaan : ptanyaan
# brp : brp
# des : des
# smelter212 : smelter212
# tangkapahok : tangkapahok
# umnia77 : umnia77
# intinya : inti
# nadir : nadir
# monash : monash
# berkualitas : kualitas
# 2hilbq68xj : 2hilbq68xj
# disalahfahami : disalahfahami
# saudariku : saudari
# kaji : kaji
# kualitas : kualitas
# berbeda : beda
# dijadika : dijadika
# perumpamaanya : perumpamaanya
# buktinya : bukti
# hey2 : hey2
# qtaj9vdfyx : qtaj9vdfyx
# hahahahaha : hahahahaha
# statemen : statemen
# lemah : lemah
# diblg : diblg
# mebellah : mebel
# bla : bla
# sepelekan : sepele
# mebel : mebel
# herry165 : herry165
# berkerumun : kerumun
# indonese : indonese
# mengenaskan : enas
# tirtahadichand1 : tirtahadichand1
# wkwk : wkwk
# penghinaan : hina
# diluar : luar
# nalar : nalar
# buzzernya : buzzernya
# hayak : hayak
# dimonas : dimonas
# drbcwflbpk : drbcwflbpk
# arandamawei : arandamawei
# kinerja : kerja
# o1r6sdzkzj : o1r6sdzkzj
# ulil : ulil
# dicinta : cinta
# sepandai : pandai
# bertolak : tolak
# eagusfatahillah : eagusfatahillah
# ferymokoginta : ferymokoginta
# ditangkap : tangkap
# andisumantri : andisumantri
# yudissejahtera : yudissejahtera
# yusuf : yusuf
# dblg : dblg
# selamat : selamat
# mndukung : mndukung
# prnyataan : prnyataan
# trmsk : trmsk
# pres : pres
# haduh : haduh
# brimob : brimob
# bfgpumlagc : bfgpumlagc
# ampuuun : ampuuun
# lansung : lansung
# hidung : hidung
# neh : neh
# pol : pol
# dahnilanzar : dahnilanzar
# kamarin : kamarin
# bolang : bolang
# begok : begok
# sendirilah : sendiri
# bbodoh : bbodoh
# msyukran : msyukran
# propokator : propokator
# siang : siang
# ber : ber
# rjzqcpwjhr : rjzqcpwjhr
# halah : halah
# 9vannbryk9 : 9vannbryk9
# umaro : umaro
# pengawas : awas
# 66if7tbebz : 66if7tbebz
# mario : mario
# aip44 : aip44
# susiloyudoyono : susiloyudoyono
# lhhat : lhhat
# kampung : kampung
# tercerdas : cerdas
# anjisudirman : anjisudirman
# ekagumilars : ekagumilars
# lohh : lohh
# lohhh : lohhh
# ituu : ituu
# cuman : cuman
# buih : buih
# diralat : ralat
# katain : katain
# 63ml1hqmi3 : 63ml1hqmi3
# armangn8 : armangn8
# kog : kog
# reinhard : reinhard
# s : s
# sholat : sholat
# jum : jum
# wkjjyphhcs : wkjjyphhcs
# dihitung : hitung
# sesuai : sesuai
# twiten : twiten
# urutan : urut
# keberapa : berapa
# zg4mnahiqj : zg4mnahiqj
# tlng : tlng
# dalil : dalil
# lapangan : lapang
# trbuka : trbuka
# lbih : lbih
# dhan : dhan
# brilian : brilian
# bru : bru
# bravo : bravo
# ikuti : ikut
# terhasut : hasut
# antohas6 : antohas6
# ridlwandjogja : ridlwandjogja
# nguasain : nguasain
# bungkus : bungkus
# indomie : indomie
# kebuka : buka
# bermain : main
# sgn : sgn
# tujuan : tuju
# terpilih : pilih
# cxuxkcaxhl : cxuxkcaxhl
# joejoe : joejoe
# tango : tango
# dalih : dalih
# murahan : murah
# dimengerti : erti
# diserap : serap
# denny : denny
# siregar : siregar
# rcrbj6ovyx : rcrbj6ovyx
# paggaru : paggaru
# nemuin : nemuin
# entar : entar
# sandera : sandera
# presidenku : presiden
# dibantu : bantu
# ikut2 : ikut2
# kendali : kendali
# kuasa : kuasa
# tegak : tegak
# hancurnya : hancur
# tergantung : gantung
# persen : persen
# infrastruktur : infrastruktur
# diresmikan : resmi
# ssefrjvxvo : ssefrjvxvo
# p21penjarakanbasuki : p21penjarakanbasuki
# penemu : temu
# balitunggurtb : balitunggurtb
# salahkn : salahkn
# kurngnya : kurngnya
# fasilitas : fasilitas
# dimanggarai : dimanggarai
# salahkan : salah
# malasnya : malas
# pngmbl : pngmbl
# kbijakan : kbijakan
# kai121 : kai121
# commuterline : commuterline
# budikaryas : budikaryas
# erikarlebang : erikarlebang
# pokoknya : pokok
# berkata2 : berkata2
# juara : juara
# tingkat : tingkat
# agungwijayaawp : agungwijayaawp
# duh : duh
# nyerang : nyerang
# doa : doa
# ibadah : ibadah
# jjrizal : jjrizal
# ask : ask
# not : not
# what : what
# your : your
# country : country
# can : can
# for : for
# indikasi : indikasi
# sngaja : sngaja
# trkihat : trkihat
# orba : orba
# harapan : harap
# jpy9nrfgdk : jpy9nrfgdk
# me5ir5v2hz : me5ir5v2hz
# xhyopqlldt : xhyopqlldt
# trigger : trigger
# pelengseran : lengser
# nda : nda
# diundang : undang
# antasari : antasari
# koruptor : koruptor
# penghianat : penghianat
# rela : rela
# merusak : rusak
# negaranya : negara
# anggit1ar : anggit1ar
# casing : casing
# babak : babak
# koneksi : koneksi
# internet : internet
# rohingya : rohingya
# asean : asean
# pengibaran : kibar
# bendera : bendera
# rrc : rrc
# efek : efek
# peluang : peluang
# cukong : cukong
# pemodal : modal
# investasi : investasi
# ind : ind
# bhw : bhw
# kedaulatan : daulat
# zjerakpdvb : zjerakpdvb
# {'jakartans': 'jakartans', 'bego': 'bego', 'mending': 'mending', 'kalo': 'kalo', 'anies': 'anies', 'agus': 'agus', 'c66jtx7qoz': 'c66jtx7qoz', 'kaskus': 'kaskus', 'dipikir': 'pikir', 'ahok': 'ahok', 'loe': 'loe', 'hok': 'hok', 'debatnya': 'debat', 'klo': 'klo', 'bertempat': 'tempat', 'petamburan': 'tambur', 'kali': 'kali', 'kalah': 'kalah', 'debat': 'debat', 'kasih': 'kasih', 'kode': 'kode', 'teriak2': 'teriak2', 'cemen': 'cemen', 'hebat': 'hebat', 'swlwyu8q4c': 'swlwyu8q4c', 'bngt': 'bngt', 'asu': 'asu', 'sandi': 'sandi', 'uno': 'uno', 'pantes': 'pantes', 'aja': 'aja', 'dipecat': 'pecat', 'jkw': 'jkw', 'proyek2': 'proyek2', 'foke': 'foke', 'proyek': 'proyek', 'kkn': 'kkn', 'pnbj7r1mjk': 'pnbj7r1mjk', 'sam': 'sam', 'arif': 'arif', 'orang': 'orang', 'tolol': 'tolol', 'milih': 'milih', 'ahy': 'ahy', 'percetakanku': 'cetak', 'iwanfals': 'iwanfals', 'polling': 'polling', 'menang': 'menang', 'iwan': 'iwan', 'fals': 'fals', 'dibilang': 'bilang', 'pendukung': 'dukung', 'dipiara': 'piara', 'masukan': 'masuk', 'dana': 'dana', 'csr': 'csr', 'apbd': 'apbd', 'anis': 'anis', 'swasta': 'swasta', 'rngsupzbaj': 'rngsupzbaj', 'imanhermawan23': 'imanhermawan23', 'marcel': 'marcel', 'prawira': 'prawira', 'herilatief': 'herilatief', 'ulilalbab': 'ulilalbab', 'hs': 'hs', 'edo': 'edo', 'macho': 'macho', 'jemmybond': 'jemmybond', 'wisnu': 'wisnu', 'buana': 'buana', 'zqhqjplsno': 'zqhqjplsno', 'pandji': 'pandji', 'tanggapin': 'tanggapin', 'baswedan': 'baswedan', 'dukung': 'dukung', 'provokator': 'provokator', 'sara': 'sara', 'pura': 'pura', 'lmkhrngery': 'lmkhrngery', 'njaoigfrly': 'njaoigfrly', 'gsohcpvyaw': 'gsohcpvyaw', 'wahhabicc': 'wahhabicc', 'bener': 'bener', 'angkutan': 'angkut', 'jkt': 'jkt', 'mahal': 'mahal', 'taunya': 'tau', 'emang': 'emang', 'stasiun': 'stasiun', 'halte': 'halte', 'jalan': 'jalan', 'kaki': 'kaki', 'hehehe': 'hehehe', 'vvpptfljm0': 'vvpptfljm0', 'pakar': 'pakar', 'mantan': 'mantan', 'jijxtaftzo': 'jijxtaftzo', 'qgvp0zbxv1': 'qgvp0zbxv1', 'd8tfc7yilz': 'd8tfc7yilz', 'wow': 'wow', 'keren': 'keren', 'qzr7xr30v2': 'qzr7xr30v2', 'colek': 'colek', 'aniesbaswedan': 'aniesbaswedan', 'xxxgtgak8t': 'xxxgtgak8t', 'pura2': 'pura2', 'wnwbdhdf1c': 'wnwbdhdf1c', 'takviri': 'takviri', 'gunromli': 'gunromli', 'orng': 'orng', 'bodoh': 'bodoh', 'percaya': 'percaya', 'memimpin': 'pimpin', 'emank': 'emank', 'gak': 'gak', 'kritis': 'kritis', 'biar': 'biar', 'sinis': 'sinis', 'hasil': 'hasil', 'survei': 'survei', 'rutin': 'rutin', 'dirilis': 'rilis', 'ajak': 'ajak', 'warga': 'warga', 'cvdbkccdfh': 'cvdbkccdfh', 'hahahahahahaha': 'hahahahahahaha', 'nyer': 'nyer', 'uguxzqflqq': 'uguxzqflqq', 'msh': 'msh', 'akses': 'akses', 'pendidikan': 'didik', 'org': 'org', 'pake': 'pake', 'bhs': 'bhs', 'inggris': 'inggris', 'membodohi': 'bodoh', 'sumpah': 'sumpah', 'bicara': 'bicara', 'seakan2': 'seakan2', 'mendengar': 'dengar', 'gatau': 'gatau', 'apa2': 'apa2', 'nonton': 'nonton', 'ftv': 'ftv', 'cengeng': 'cengeng', 'berbobot': 'bobot', 'teman': 'teman', 'bagus': 'bagus', 'nih': 'nih', 'bahan': 'bahan', 'kampanye': 'kampanye', 'orang2nya': 'orang2nya', 'elu': 'elu', 'kidpztslrr': 'kidpztslrr', 'huahaha': 'huahaha', 'hah': 'hah', 'akn': 'akn', 'pilkada': 'pilkada', 'yah': 'yah', 'cf9hokwdkb': 'cf9hokwdkb', 'iwank1404': 'iwank1404', 'krn': 'krn', 'cerdas': 'cerdas', 'dilepas': 'lepas', 'mendikbud': 'mendikbud', 'bhayakan': 'bhayakan', 'mencerdaskan': 'cerdas', 'bangsa': 'bangsa', 'tau': 'tau', 'gagal': 'gagal', 'pham': 'pham', 'officialinewstv': 'officialinewstv', 'zuhairimisrawi': 'zuhairimisrawi', 'kau': 'kau', 'keadilan': 'adil', 'ditegakkan': 'tegak', 'direshuffle': 'direshuffle', 'republikaonline': 'republikaonline', 'giman': 'gim', 'siluman': 'siluman', 'punbelum': 'punbelum', 'cerita': 'cerita', 'masuk': 'masuk', 'akal': 'akal', 'takut': 'takut', 'usa': 'usa', 'otak': 'otak', 'kerbau': 'kerbau', 'sedih': 'sedih', 'gitu': 'gitu', 'bang': 'bang', 'renecc': 'renecc', 'amp': 'amp', 'zrj5oxnio7': 'zrj5oxnio7', 'sibuniyani': 'sibuniyani', 'kabarnya': 'kabar', ' ...
# ------------------------
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=695.0), HTML(value='')))

# %%
# Membuat kolom yang bernama "content_bersih" pada DataFrame "data_2016" yang telah selesai dilakukan proses text preprocessing
data_2016["content_bersih"] = [" ".join(map(str, i)) for i in data_2016["content_stemming"]]
data_2016.head()
# Out:
#                      tanggal  \
# 0  2016-12-21 04:36:51+00:00
# 1  2016-12-19 19:20:46+00:00
# 2  2016-12-09 11:21:17+00:00
# 3  2016-11-24 21:22:09+00:00
# 4  2016-11-18 17:40:30+00:00
#
#                                              content    label  \
# 0  jakartans bego mending kalo anies ini agus htt...  negatif
# 1   kaskus apa anies itu dipikir bego ahok jauh l...  positif
# 2  mau debatnya klo bertempat petamburan kali klo...  negatif
# 3  bego bngt asu anies sandi uno itu pantes aja d...  positif
# 4   sam arif  kalo orang tidak bego dan tidak tol...  negatif
#
#                                   content_tokenizing  \
# 0  [jakartans, bego, mending, kalo, anies, ini, a...
# 1  [kaskus, apa, anies, itu, dipikir, bego, ahok,...
# 2  [mau, debatnya, klo, bertempat, petamburan, ka...
# 3  [bego, bngt, asu, anies, sandi, uno, itu, pant...
# 4  [sam, arif, kalo, orang, tidak, bego, dan, tid...
#
#                                    content_stopwords  \
# 0  [jakartans, bego, mending, kalo, anies, agus, ...
# 1     [kaskus, anies, dipikir, bego, ahok, loe, hok]
# 2  [debatnya, klo, bertempat, petamburan, kali, k...
# 3  [bego, bngt, asu, anies, sandi, uno, pantes, a...
# 4  [sam, arif, kalo, orang, bego, tolol, milih, a...
#
#                                     content_stemming  \
# 0  [jakartans, bego, mending, kalo, anies, agus, ...
# 1       [kaskus, anies, pikir, bego, ahok, loe, hok]
# 2  [debat, klo, tempat, tambur, kali, klo, kalah,...
# 3  [bego, bngt, asu, anies, sandi, uno, pantes, a...
# 4  [sam, arif, kalo, orang, bego, tolol, milih, a...
#
#                                       content_bersih
# 0  jakartans bego mending kalo anies agus c66jtx7qoz
# 1               kaskus anies pikir bego ahok loe hok
# 2  debat klo tempat tambur kali klo kalah debat k...
# 3  bego bngt asu anies sandi uno pantes aja pecat...
# 4     sam arif kalo orang bego tolol milih ahy anies

# %% [markdown]
# ## 3. Mengambil Isi Kolom "content_bersih"

# %%
# Mengeluarkan isi tweet bersih dari DataFrame "data"
ekstraksi_data = " ".join(str(c) for c in data_2016["content_bersih"])
ekstraksi_data
# Out:
# 'jakartans bego mending kalo anies agus c66jtx7qoz kaskus anies pikir bego ahok loe hok debat klo tempat tambur kali klo kalah debat kasih kode teriak2 ahok bego anies cemen agus hebat swlwyu8q4c bego bngt asu anies sandi uno pantes aja pecat jkw klo proyek2 foke proyek kkn pnbj7r1mjk sam arif kalo orang bego tolol milih ahy anies cetak iwanfals kalo polling anies menang iwan fals bilang dukung anies bego piara anies masuk dana csr apbd anis bego dana swasta rngsupzbaj imanhermawan23 marcel prawira herilatief anies masuk dana csr apbd anis bego dana swasta rngsupzbaj ulilalbab hs edo macho jemmybond wisnu buana anies masuk dana csr apbd anis bego dana swasta rngsupzbaj zqhqjplsno pandji tanggapin anies baswedan dukung provokator sara pura pura bego lmkhrngery anies baswedan dukung provokator sara pura pura bego njaoigfrly anies baswedan dukung provokator sara pura pura bego gsohcpvyaw wahhabicc anies bener angkut jkt mahal kalo tau bego aja emang stasiun halte jalan kaki hehehe anies baswedan dukung provokator sara pura pura bego vvpptfljm0 anies baswedan dukung provokator sara pura pura bego pakar mantan jijxtaftzo qgvp0zbxv1 anies dukung provokator sara pura pura bego pakar mantan jijxtaftzo qgvp0zbxv1 anies baswedan dukung provokator sara pura pura bego pakar mantan d8tfc7yilz wow keren anies baswedan dukung provokator sara pura pura bego pakar mantan qzr7xr30v2 colek aniesbaswedan anies baswedan dukung provokator sara pura pura bego xxxgtgak8t anies baswedan dukung provokator sara pura2 bego pakar mantan wnwbdhdf1c takviri gunromli orng bodoh percaya agus pimpin jkt mending anies kalo emank ahok gak menang kritis biar bodoh sinis hasil survei rutin rilis anies ajak warga kritis cvdbkccdfh hahahahahahaha bodoh nyer uguxzqflqq anies agus sandi msh akses didik org jkt bodoh pake bhs inggris bodoh sumpah anies bicara seakan2 dengar bodoh gatau apa2 nonton ftv cengeng ahok orang bodoh anies bobot agus teman bagus nih bahan kampanye orang2nya anies elu bodoh kidpztslrr huahaha hah klo anies bodoh akn menang pilkada huahaha yah huahaha menang cf9hokwdkb iwank1404 krn cerdas anies lepas mendikbud bhayakan cerdas bangsa tau bodoh gagal pham officialinewstv aniesbaswedan zuhairimisrawi anies kau bodoh adil tegak kau direshuffle republikaonline gim siluman pilkada punbelum cerita gak masuk akal takut gak usa pilkada bodoh otak kerbau anies pandji kalo milih anies bilang bodoh sedih gitu bang dukung anies bodoh msh renecc amp pandji zrj5oxnio7 sibuniyani kabar neng bgt doi niat mbantu anies untung ahaye bodoh gak menang hahahahahahaha bodoh siak wuzd4chqsj partaisocmed anies bolak blunder bodoh utk level spt sengaja plus ahok agus kmngkn menang krn anies liberal anies bodoh aksi demo november lcfwq6hfj7 veywiniy yggregory detikcom aniesbaswedan anies jgn rusak citra smart kalo nya bodoh anies bodoh banget yah matematika nya pinteran waitress resto boss walo tamat fakta celaka triwul82 officialinewstv orang bodoh percaya anies bantar gebang ngomong sampah salah kelola anies janji warga kjp kip bagi sama ahok pjzwuwksfd anies pintar bodoh anies pintar koq pintar2 bodoh duluuu rakyat kagum aniesbaswedan tau belang 5fkypzlgev tanya bodoh gitu bpk anies congrats temanahok bodoh cerdas 5zydrfdtgs kompascom anies jadi kolong tol wadah ekspres tirwtqbb1p ide bodoh anies bodoh tau apa2 pantes pecat xn7vnaeer5 gunromli panca66 bodoh pikir org2 milih anies pks picik bro org milih agus anies krn udah eneg liat idola kes bias krn scr buka dukung ahok serius deh knp anies agus srg ngeluarin statement bodoh sih gubernur dki 2012 2016 versi hti fpi brizieq dukung anies sandi moga bodoh sefaham dgn shxb9dgkzs warga kristen protestan amp katholik anies sandi agus sylvi bodoh muslim pilih muslim anggap sara rsephf9yct dear anies didik tolong deh anies bodoh maju 6potzigwvh permutindo kubu anies incumbent sentuh ekonomi tim ahok buka mata kgbbsxylze bodoh anies aniesbaswedan anies tri bpk istimewa tnyata pecat bodoh jakarta butuh pimpin tdk kasar visione ...

# %%
# Melihat isi tweet per kata yang telak dilakukan proses ekstraksi menggunakan word_tokenize dari library nltk
word_tokenize_content = word_tokenize(ekstraksi_data)
word_tokenize_content
# Out:
# ['jakartans',
#  'bego',
#  'mending',
#  'kalo',
#  'anies',
#  'agus',
#  'c66jtx7qoz',
#  'kaskus',
#  'anies',
#  'pikir',
#  'bego',
#  'ahok',
#  'loe',
#  'hok',
#  'debat',
#  'klo',
#  'tempat',
#  'tambur',
#  'kali',
#  'klo',
#  'kalah',
#  'debat',
#  'kasih',
#  'kode',
#  'teriak2',
#  'ahok',
#  'bego',
#  'anies',
#  'cemen',
#  'agus',
#  'hebat',
#  'swlwyu8q4c',
#  'bego',
#  'bngt',
#  'asu',
#  'anies',
#  'sandi',
#  'uno',
#  'pantes',
#  'aja',
#  'pecat',
#  'jkw',
#  'klo',
#  'proyek2',
#  'foke',
#  'proyek',
#  'kkn',
#  'pnbj7r1mjk',
#  'sam',
#  'arif',
#  'kalo',
#  'orang',
#  'bego',
#  'tolol',
#  'milih',
#  'ahy',
#  'anies',
#  'cetak',
#  'iwanfals',
#  'kalo',
#  'polling',
#  'anies',
#  'menang',
#  'iwan',
#  'fals',
#  'bilang',
#  'dukung',
#  'anies',
#  'bego',
#  'piara',
#  'anies',
#  'masuk',
#  'dana',
#  'csr',
#  'apbd',
#  'anis',
#  'bego',
#  'dana',
#  'swasta',
#  'rngsupzbaj',
#  'imanhermawan23',
#  'marcel',
#  'prawira',
#  'herilatief',
#  'anies',
#  'masuk',
#  'dana',
#  'csr',
#  'apbd',
#  'anis',
#  'bego',
#  'dana',
#  'swasta',
#  'rngsupzbaj',
#  'ulilalbab',
#  'hs',
#  'edo',
#  'macho',
#  'jemmybond',
#  'wisnu',
#  'buana',
#  'anies',
#  'masuk',
#  'dana',
#  'csr',
#  'apbd',
#  'anis',
#  'bego',
#  'dana',
#  'swasta',
#  'rngsupzbaj',
#  'zqhqjplsno',
#  'pandji',
#  'tanggapin',
#  'anies',
#  'baswedan',
#  'dukung',
#  'provokator',
#  'sara',
#  'pura',
#  'pura',
#  'bego',
#  'lmkhrngery',
#  'anies',
#  'baswedan',
#  'dukung',
#  'provokator',
#  'sara',
#  'pura',
#  'pura',
#  'bego',
#  'njaoigfrly',
#  'anies',
#  'baswedan',
#  'dukung',
#  'provokator',
#  'sara',
#  'pura',
#  'pura',
#  'bego',
#  'gsohcpvyaw',
#  'wahhabicc',
#  'anies',
#  'bener',
#  'angkut',
#  'jkt',
#  'mahal',
#  'kalo',
#  'tau',
#  'bego',
#  'aja',
#  'emang',
#  'stasiun',
#  'halte',
#  'jalan',
#  'kaki',
#  'hehehe',
#  'anies',
#  'baswedan',
#  'dukung',
#  'provokator',
#  'sara',
#  'pura',
#  'pura',
#  'bego',
#  'vvpptfljm0',
#  'anies',
#  'baswedan',
#  'dukung',
#  'provokator',
#  'sara',
#  'pura',
#  'pura',
#  'bego',
#  'pakar',
#  'mantan',
#  'jijxtaftzo',
#  'qgvp0zbxv1',
#  'anies',
#  'dukung',
#  'provokator',
#  'sara',
#  'pura',
#  'pura',
#  'bego',
#  'pakar',
#  'mantan',
#  'jijxtaftzo',
#  'qgvp0zbxv1',
#  'anies',
#  'baswedan',
#  'dukung',
#  'provokator',
#  'sara',
#  'pura',
#  'pura',
#  'bego',
#  'pakar',
#  'mantan',
#  'd8tfc7yilz',
#  'wow',
#  'keren',
#  'anies',
#  'baswedan',
#  'dukung',
#  'provokator',
#  'sara',
#  'pura',
#  'pura',
#  'bego',
#  'pakar',
#  'mantan',
#  'qzr7xr30v2',
#  'colek',
#  'aniesbaswedan',
#  'anies',
#  'baswedan',
#  'dukung',
#  'provokator',
#  'sara',
#  'pura',
#  'pura',
#  'bego',
#  'xxxgtgak8t',
#  'anies',
#  'baswedan',
#  'dukung',
#  'provokator',
#  'sara',
#  'pura2',
#  'bego',
#  'pakar',
#  'mantan',
#  'wnwbdhdf1c',
#  'takviri',
#  'gunromli',
#  'orng',
#  'bodoh',
#  'percaya',
#  'agus',
#  'pimpin',
#  'jkt',
#  'mending',
#  'anies',
#  'kalo',
#  'emank',
#  'ahok',
#  'gak',
#  'menang',
#  'kritis',
#  'biar',
#  'bodoh',
#  'sinis',
#  'hasil',
#  'survei',
#  'rutin',
#  'rilis',
#  'anies',
#  'ajak',
#  'warga',
#  'kritis',
#  'cvdbkccdfh',
#  'hahahahahahaha',
#  'bodoh',
#  'nyer',
#  'uguxzqflqq',
#  'anies',
#  'agus',
#  'sandi',
#  'msh',
#  'akses',
#  'didik',
#  'org',
#  'jkt',
#  'bodoh',
#  'pake',
#  'bhs',
#  'inggris',
#  'bodoh',
#  'sumpah',
#  'anies',
#  'bicara',
#  'seakan2',
#  'dengar',
#  'bodoh',
#  'gatau',
#  'apa2',
#  'nonton',
#  'ftv',
#  'cengeng',
#  'ahok',
#  'orang',
#  'bodoh',
#  'anies',
#  'bobot',
#  'agus',
#  'teman',
#  'bagus',
#  'nih',
#  'bahan',
#  'kampanye',
#  'orang2nya',
#  'anies',
#  'elu',
#  'bodoh',
#  'kidpztslrr',
#  'huahaha',
#  'hah',
#  'klo',
#  'anies',
#  'bodoh',
#  'akn',
#  'menang',
#  'pilkada',
#  'huahaha',
#  'yah',
#  'huahaha',
#  'menang',
#  'cf9hokwdkb',
#  'iwank1404',
#  'krn',
#  'cerdas',
#  'anies',
#  'lepas',
#  'mendikbud',
#  'bhayakan',
#  'cerdas',
#  'bangsa',
#  'tau',
#  'bodoh',
#  'gagal',
#  'pham',
#  'officialinewstv',
#  'aniesbaswedan',
#  'zuhairimisrawi',
#  'anies',
#  'kau',
#  'bodoh',
#  'adil',
#  'tegak',
#  'kau',
#  'direshuffle',
#  'republikaonline',
#  'gim',
#  'siluman',
#  'pilkada',
#  'punbelum',
#  'cerita',
#  'gak',
#  'masuk',
#  'akal',
#  'takut',
#  'gak',
#  'usa',
#  'pilkada',
#  'bodoh',
#  'otak',
#  'kerbau',
#  'anies',
#  'pandji',
#  'kalo',
#  'milih',
#  'anies',
#  'bilang',
#  'bodoh',
#  'sedih',
#  'gitu',
#  'bang',
#  'dukung',
#  'anies',
#  'bodoh',
#  'msh',
#  'renecc',
#  'amp',
#  'pandji',
#  'zrj5oxnio7',
#  'sibuniyani',
#  'kabar',
#  'neng',
#  'bgt',
#  'doi',
#  'niat',
#  'mbantu',
#  'anies',
#  'untung',
#  'ahaye',
#  'bodoh',
#  'gak',
#  'menang',
#  'hahahahahahaha',
#  'bodoh',
#  'siak',
#  'wuzd4chqsj',
#  'partaisocmed',
#  'anies',
#  'bolak',
#  'blunder',
#  'bodoh',
#  'utk',
#  'level',
#  'spt',
#  'sengaja',
#  'plus',
#  'ahok',
#  'agus',
#  'kmngkn',
#  'menang',
#  'krn',
#  'anies',
#  'liberal',
#  'anies',
#  'bodoh',
#  'aksi',
#  'demo',
#  'november',
#  'lcfwq6hfj7',
#  'veywiniy',
#  'yggregory',
#  'detikcom',
#  'aniesbaswedan',
#  'anies',
#  'jgn',
#  'rusak',
#  'citra',
#  'smart',
#  'kalo',
#  'nya',
#  'bodoh',
#  'anies',
#  'bodoh',
#  'banget',
#  'yah',
#  'matematika',
#  'nya',
#  'pinteran',
#  'waitress',
#  'resto',
#  'boss',
#  'walo',
#  'tamat',
#  'fakta',
#  'celaka',
#  'triwul82',
#  'officialinewstv',
#  'orang',
#  'bodoh',
#  'percaya',
#  'anies',
#  'bantar',
#  'gebang',
#  'ngomong',
#  'sampah',
#  'salah',
#  'kelola',
#  'anies',
#  'janji',
#  'warga',
#  'kjp',
#  'kip',
#  'bagi',
#  'sama',
#  'ahok',
#  'pjzwuwksfd',
#  'anies',
#  'pintar',
#  'bodoh',
#  'anies',
#  'pintar',
#  'koq',
#  'pintar2',
#  'bodoh',
#  'duluuu',
#  'rakyat',
#  'kagum',
#  'aniesbaswedan',
#  'tau',
#  'belang',
#  '5fkypzlgev',
#  'tanya',
#  'bodoh',
#  'gitu',
#  'bpk',
#  'anies',
#  'congrats',
#  'temanahok',
#  'bodoh',
#  'cerdas',
#  '5zydrfdtgs',
#  'kompascom',
#  'anies',
#  'jadi',
#  'kolong',
#  'tol',
#  'wadah',
#  'ekspres',
#  'tirwtqbb1p',
#  'ide',
#  'bodoh',
#  'anies',
#  'bodoh',
#  'tau',
#  'apa2',
#  'pantes',
#  'pecat',
#  'xn7vnaeer5',
#  'gunromli',
#  'panca66',
#  'bodoh',
#  'pikir',
#  'org2',
#  'milih',
#  'anies',
#  'pks',
#  'picik',
#  'bro',
#  'org',
#  'milih',
#  'agus',
#  'anies',
#  'krn',
#  'udah',
#  'eneg',
#  'liat',
#  'idola',
#  'kes',
#  'bias',
#  'krn',
#  'scr',
#  'buka',
#  'dukung',
#  'ahok',
#  'serius',
#  'deh',
#  'knp',
#  'anies',
#  'agus',
#  'srg',
#  'ngeluarin',
#  'statement',
#  'bodoh',
#  'sih',
#  'gubernur',
#  'dki',
#  '2012',
#  '2016',
#  'versi',
#  'hti',
#  'fpi',
#  'brizieq',
#  'dukung',
#  'anies',
#  'sandi',
#  'moga',
#  'bodoh',
#  'sefaham',
#  'dgn',
#  'shxb9dgkzs',
#  'warga',
#  'kristen',
#  'protestan',
#  'amp',
#  'katholik',
#  'anies',
#  'sandi',
#  'agus',
#  'sylvi',
#  'bodoh',
#  'muslim',
#  'pilih',
#  'muslim',
#  'anggap',
#  'sara',
#  'rsephf9yct',
#  'dear',
#  'anies',
#  'didik',
#  'tolong',
#  'deh',
#  'anies',
#  'bodoh',
#  'maju',
#  '6potzigwvh',
#  'permutindo',
#  'kubu',
#  'anies',
#  'incumbent',
#  'sentuh',
#  'ekonomi',
#  'tim',
#  'ahok',
#  'buka',
#  'mata',
#  'kgbbsxylze',
#  'bodoh',
#  'anies',
#  'aniesbaswedan',
#  'anies',
#  'tri',
#  'bpk',
#  'istimewa',
#  'tnyata',
#  'pecat',
#  'bodoh',
#  'jakarta',
#  'butuh',
#  'pimpin',
#  'tdk',
#  'kasar',
#  'visioner',
#  'tdk',
#  'bilg',
#  'org',
#  'bodoh',
#  'responsif',
#  'tdk',
#  'babi',
#  'buta',
#  'anies',
#  'sandiagafordki1',
#  'republikaonline',
#  'anies',
#  'posko',
#  'menang',
#  'smakin',
#  'o2azpx5ath',
#  'nyata',
#  'bodoh',
#  'posko',
#  'tdk',
#  'ikut',
#  'anies',
#  'gagal',
#  'menteri',
#  'brani2an',
#  'nyalon',
#  'dki1',
#  'warga',
#  'dki',
#  'bodoh',
#  'liat',
#  'hsl',
#  'pilkada',
#  'dki',
#  '4r9vumoysz',
#  'ahmaddhaniprast',
#  'salah',
#  'nya',
#  'anies',
#  'kali',
#  'gagal',
#  'cerdas',
#  'bangsa',
#  'bodoh',
#  'gampang',
#  'hasut',
#  'agama',
#  'alat',
#  'politik',
#  'hehe',
#  'syihabrizieq',
#  'byk',
#  'org2',
#  'bodoh',
#  'dgn',
#  'mdh',
#  'hasut',
#  'msh',
#  'byk',
#  'org',
#  'cerdas',
#  'pantesan',
#  'anies',
#  'cukup',
#  'jokowi',
#  'pling',
#  'malas',
#  'dgn',
#  'org',
#  'ria',
#  'bodoh',
#  'beritasatu',
#  'anies',
#  'cendikiawan',
#  'knapa',
#  'skrg',
#  'bodoh',
#  'usung',
#  'cagub',
#  'partai',
#  'yahh',
#  'mohmahfudmd',
#  'silkybiru',
#  'anies',
#  'rada2',
#  'bodoh',
#  'massa',
#  'jujur',
#  'realita',
#  'gendeng',
#  'tribunnews',
#  'aniesbaswedan',
#  'anies',
#  'kawan',
#  'politis',
#  'omong',
#  'kosong',
#  'spt',
#  'syrf',
#  'hbb',
#  'dkk',
#  'ikut',
#  'bodoh',
#  'guoblok',
#  'anies',
#  'liat',
#  'bodoh',
#  'ivan23683770',
#  'aniesbaswedan',
#  'batalin',
#  'krn',
#  'murka',
#  'anies',
#  'bkn',
#  'org',
#  'bodoh',
#  'kali',
#  'keblinger',
#  '2hr',
#  'pikir',
#  'pftee',
#  'ych7168',
#  'alex',
#  'hunter146',
#  'bamsbulaksumur4',
#  'aniesbaswedan',
#  'nyata',
#  'bodoh',
#  'elektabilitas',
#  'anies',
#  'langsung',
#  'drop',
#  'pintar',
#  'apa',
#  'anies',
#  'baswedan',
#  'ketemu',
#  'sapi',
#  'kuda',
#  'pikir',
#  'sempit',
#  'bodoh',
#  'kasihan',
#  'ahauwlim',
#  'bloon',
#  'kalo',
#  'anies',
#  'menang',
#  'goceng',
#  'udah',
#  'angkot',
#  'subsidi',
#  'angkot',
#  '3500',
#  'tolol',
#  'pelihara',
#  'hahahaha',
#  'kompascom',
#  'anies',
#  'tolol',
#  'kayak',
#  'gitu',
#  'teukuarie',
#  'komplain',
#  'tim',
#  'sukses',
#  'ato',
#  'buzzer',
#  'ahok',
#  'ngata2in',
#  'anies',
#  'tolol',
#  'goblok',
#  'risih',
#  'jengah',
#  'baca',
#  'sam',
#  'arif',
#  'kalo',
#  'orang',
#  'bego',
#  'tolol',
#  'milih',
#  'ahy',
#  'anies',
#  'kompascom',
#  's4k1rr4',
#  'anies',
#  'tolol',
#  'sdh',
#  'anak',
#  'putus',
#  'sekolah',
#  'mki',
#  'dpt',
#  'kjp',
#  'kjp',
#  'utk',
#  'anak',
#  'sekolah',
#  'paham',
#  'kompascom',
#  'anies',
#  'mah',
#  'emank',
#  'munafik',
#  'sungai',
#  'jkt',
#  'bersih',
#  'aja',
#  'bilang',
#  'karna',
#  'foke',
#  'orng',
#  'pinter',
#  'tolol',
#  'pilkada',
#  'rawa',
#  'cagub',
#  'dodol',
#  'tolol',
#  'loe',
#  'anies',
#  'halojakarta',
#  'anies',
#  'goblok',
#  'tolol',
#  'org',
#  'tinggal',
#  'kolong',
#  'tol',
#  'wajib',
#  'gusur',
#  'tanah',
#  'kompascom',
#  'anies',
#  'mnusia',
#  'tolol',
#  'anies',
#  'sandi',
#  'cerdas',
#  'integritas',
#  'kontributif',
#  'sesal',
#  'orang',
#  'cerdas',
#  'spt',
#  'habibie',
#  'sebab',
#  'tolol',
#  'kangdede78',
#  'arif253162',
#  'org',
#  'stres',
#  'yah',
#  'kyk',
#  'gitu',
#  'anies',
#  'jawa',
#  'ahy',
#  'jawa',
#  'tolol',
#  'pelihara',
#  'igonious',
#  'maya',
#  'arifin',
#  'bernadetamurnip',
#  'aniesbaswedan',
#  'sosmedbw',
#  'pandji',
#  'ignosius',
#  'idiot',
#  'tolol',
#  'partai',
#  'dukung',
#  'goblog',
#  'anies',
#  'partai',
#  'aniesbaswedan',
#  'piye',
#  'anies',
#  'bergbung',
#  'amamafi2',
#  'tolol',
#  'bajigurceleng',
#  'amorricon',
#  'jaychou881',
#  'arifin',
#  'henry',
#  'gpp',
#  'deh',
#  'tolol',
#  'tinggal',
#  'cari',
#  'program',
#  'anies',
#  'agus',
#  'jaychou881',
#  'bajigurceleng',
#  'franstone888',
#  'kangsemproel',
#  'arifin',
#  'henry',
#  'yup',
#  'anies',
#  'jamin',
#  'tdk',
#  'gusur',
#  'tahu',
#  'pndukung',
#  'tolol',
#  'tolol',
#  'jaman',
#  'skrg',
#  'info',
#  'potong',
#  'khuhus',
#  'pilih',
#  'anies',
#  'agus',
#  'parah',
#  'pakai',
#  'sara',
#  'dtsjgdocq6',
#  'triwul82',
#  'merdekadotcom',
#  'dasar',
#  'tolol',
#  'tinggal',
#  'tiru2',
#  'langkah',
#  'mega',
#  'klo',
#  'anies',
#  'uno',
#  'bner2',
#  'tukang',
#  'copy',
#  'doang',
#  'tbayupatti',
#  'merdekadotcom',
#  'agus',
#  'aja',
#  'kencing',
#  'lurus',
#  'anies',
#  'bekas',
#  'tri',
#  'pect',
#  'tolol',
#  'uno',
#  'sapi',
#  'otak',
#  'ed',
#  'tirta',
#  'yudh4sampurna',
#  'tonywibowo12',
#  'zulemo15',
#  'donywenas',
#  'mlmkabeh',
#  'fariz1234',
#  'emang',
#  'agus',
#  'amp',
#  'anies',
#  'wewenang',
#  'ektp',
#  'iih',
#  'tolol',
#  'banget',
#  'aniesbaswedan',
#  'rinjanijb',
#  'dukung',
#  'anies',
#  'wis',
#  'wedan',
#  'sdh',
#  'tolol',
#  'koplak',
#  'sekolah',
#  'amrik',
#  'tukang',
#  'fitnah',
#  'waljamaah',
#  'jonru',
#  'fadlizon',
#  'fahrihamzah',
#  'dpp',
#  'fpi',
#  'halus24',
#  'ratnaspaet',
#  ...]

# %%
# Melakukan proses perhitungan dari setiap kemunculan isi content tweet
from nltk.probability import FreqDist
fqdist_content = FreqDist(word_tokenize_content)
fqdist_content
# Out:
# FreqDist({'jokowi': 450, 'bodoh': 384, 'bego': 293, 'fadlizon': 220, 'orang': 115, 'anies': 88, 'tolol': 86, 'rakyat': 74, 'org': 71, 'ahok': 68, ...})

# %%
# Menampilkan isi content tweet yang sering muncul sebanyak 500 kata
fqdist_content.most_common(500)
# Out:
# [('jokowi', 450),
#  ('bodoh', 384),
#  ('bego', 293),
#  ('fadlizon', 220),
#  ('orang', 115),
#  ('anies', 88),
#  ('tolol', 86),
#  ('rakyat', 74),
#  ('org', 71),
#  ('ahok', 68),
#  ('aja', 60),
#  ('presiden', 58),
#  ('amp', 42),
#  ('dpr', 42),
#  ('gak', 38),
#  ('dukung', 36),
#  ('fahrihamzah', 35),
#  ('tau', 34),
#  ('ri', 32),
#  ('klo', 31),
#  ('demo', 31),
#  ('pura', 29),
#  ('bilang', 28),
#  ('nya', 27),
#  ('emang', 26),
#  ('jgn', 26),
#  ('kalo', 25),
#  ('divhumaspolri', 24),
#  ('liat', 23),
#  ('fpi', 23),
#  ('basuki', 23),
#  ('btp', 23),
#  ('pura2', 22),
#  ('krn', 22),
#  ('tdk', 21),
#  ('sih', 20),
#  ('hukum', 20),
#  ('islam', 20),
#  ('pikir', 19),
#  ('bkn', 19),
#  ('indonesia', 19),
#  ('salah', 18),
#  ('kompascom', 18),
#  ('dgn', 18),
#  ('loe', 17),
#  ('pake', 17),
#  ('otak', 17),
#  ('sdh', 17),
#  ('nih', 16),
#  ('pintar', 16),
#  ('kerja', 16),
#  ('wakil', 16),
#  ('agus', 15),
#  ('provokator', 15),
#  ('sara', 15),
#  ('biar', 15),
#  ('kau', 15),
#  ('utk', 15),
#  ('pilih', 15),
#  ('pinter', 15),
#  ('dasar', 15),
#  ('zon', 15),
#  ('negara', 15),
#  ('udah', 14),
#  ('agama', 14),
#  ('goblok', 14),
#  ('bikin', 14),
#  ('aniesbaswedan', 13),
#  ('zonk', 13),
#  ('sugi', 13),
#  ('cerdas', 12),
#  ('gitu', 12),
#  ('org2', 12),
#  ('nyata', 12),
#  ('ahmaddhaniprast', 12),
#  ('bukti', 12),
#  ('jk', 12),
#  ('cina', 12),
#  ('0706', 12),
#  ('bpk', 11),
#  ('anggap', 11),
#  ('politik', 11),
#  ('dpp', 11),
#  ('ratnaspaet', 11),
#  ('fahiraidris', 11),
#  ('sahal', 11),
#  ('nkri', 11),
#  ('metro', 11),
#  ('tv', 11),
#  ('menang', 10),
#  ('baswedan', 10),
#  ('warga', 10),
#  ('republikaonline', 10),
#  ('banget', 10),
#  ('dki', 10),
#  ('pelihara', 10),
#  ('kayak', 10),
#  ('pakai', 10),
#  ('ente', 10),
#  ('ngerti', 10),
#  ('sbyudhoyono', 10),
#  ('ubah', 10),
#  ('milih', 9),
#  ('masuk', 9),
#  ('bener', 9),
#  ('percaya', 9),
#  ('yah', 9),
#  ('gagal', 9),
#  ('aksi', 9),
#  ('ikut', 9),
#  ('skrg', 9),
#  ('gerindra', 9),
#  ('tuh', 9),
#  ('puisi', 9),
#  ('lihat', 9),
#  ('as', 9),
#  ('dlm', 9),
#  ('polisi', 9),
#  ('turun', 9),
#  ('prabowo', 9),
#  ('isu', 9),
#  ('hati', 9),
#  ('monas', 9),
#  ('wahhabicc', 8),
#  ('orng', 8),
#  ('msh', 8),
#  ('elu', 8),
#  ('bangsa', 8),
#  ('adil', 8),
#  ('detikcom', 8),
#  ('ngomong', 8),
#  ('mata', 8),
#  ('jakarta', 8),
#  ('buta', 8),
#  ('syihabrizieq', 8),
#  ('makan', 8),
#  ('kaya', 8),
#  ('tvonenews', 8),
#  ('iya', 8),
#  ('beda', 8),
#  ('provokasi', 8),
#  ('proses', 8),
#  ('orang2', 8),
#  ('oon', 8),
#  ('sok', 8),
#  ('hadir', 8),
#  ('mulut', 8),
#  ('alih', 8),
#  ('perintah', 8),
#  ('212', 8),
#  ('manusia', 8),
#  ('nadir', 8),
#  ('monash', 8),
#  ('piara', 7),
#  ('jkt', 7),
#  ('gunromli', 7),
#  ('takut', 7),
#  ('bang', 7),
#  ('temanahok', 7),
#  ('knp', 7),
#  ('muslim', 7),
#  ('gampang', 7),
#  ('halojakarta', 7),
#  ('kyk', 7),
#  ('hina', 7),
#  ('nista', 7),
#  ('ulama', 7),
#  ('mudah', 7),
#  ('gua', 7),
#  ('dhani', 7),
#  ('ama', 7),
#  ('malu', 7),
#  ('berita', 7),
#  ('gin', 7),
#  ('beliau', 7),
#  ('maaf', 7),
#  ('debat', 6),
#  ('jkw', 6),
#  ('dana', 6),
#  ('jalan', 6),
#  ('mantan', 6),
#  ('pimpin', 6),
#  ('pilkada', 6),
#  ('tegak', 6),
#  ('koq', 6),
#  ('bro', 6),
#  ('gubernur', 6),
#  ('maju', 6),
#  ('hasut', 6),
#  ('massa', 6),
#  ('anak', 6),
#  ('sekolah', 6),
#  ('paham', 6),
#  ('fitnah', 6),
#  ('jls', 6),
#  ('dah', 6),
#  ('hahaha', 6),
#  ('fadjroel', 6),
#  ('ketua', 6),
#  ('temu', 6),
#  ('jabat', 6),
#  ('bijak', 6),
#  ('tindak', 6),
#  ('istana', 6),
#  ('makar', 6),
#  ('kaga', 6),
#  ('anggota', 6),
#  ('masyarakat', 6),
#  ('bangga', 6),
#  ('kpd', 6),
#  ('ustadtengku', 6),
#  ('umat', 6),
#  ('era', 6),
#  ('ngapain', 6),
#  ('ras', 6),
#  ('laku', 6),
#  ('urus', 6),
#  ('tolak', 6),
#  ('mending', 5),
#  ('kali', 5),
#  ('kalah', 5),
#  ('sandi', 5),
#  ('pakar', 5),
#  ('kritis', 5),
#  ('bicara', 5),
#  ('dengar', 5),
#  ('apa2', 5),
#  ('akn', 5),
#  ('partaisocmed', 5),
#  ('spt', 5),
#  ('citra', 5),
#  ('fakta', 5),
#  ('panca66', 5),
#  ('buka', 5),
#  ('menteri', 5),
#  ('byk', 5),
#  ('partai', 5),
#  ('langsung', 5),
#  ('hahahaha', 5),
#  ('baca', 5),
#  ('rawa', 5),
#  ('tukang', 5),
#  ('mui', 5),
#  ('penting', 5),
#  ('kuasa', 5),
#  ('trump', 5),
#  ('udh', 5),
#  ('blg', 5),
#  ('jdi', 5),
#  ('bin', 5),
#  ('maksud', 5),
#  ('id', 5),
#  ('belah', 5),
#  ('badut', 5),
#  ('milik', 5),
#  ('bantu', 5),
#  ('mati', 5),
#  ('bela', 5),
#  ('sadar', 5),
#  ('media', 5),
#  ('kritik', 5),
#  ('msih', 5),
#  ('maklum', 5),
#  ('fadli', 5),
#  ('bohong', 5),
#  ('sby', 5),
#  ('sbg', 5),
#  ('suruh', 5),
#  ('damai', 5),
#  ('ngarang', 5),
#  ('berat', 5),
#  ('uang', 5),
#  ('kpk', 5),
#  ('bunuh', 5),
#  ('lindung', 5),
#  ('youtube', 5),
#  ('vivacoid', 5),
#  ('smua', 5),
#  ('gimana', 5),
#  ('tangkap', 5),
#  ('proamdalrtb', 5),
#  ('kementerianlhk', 5),
#  ('bngt', 4),
#  ('pantes', 4),
#  ('iwan', 4),
#  ('apbd', 4),
#  ('anis', 4),
#  ('edo', 4),
#  ('macho', 4),
#  ('pandji', 4),
#  ('takviri', 4),
#  ('survei', 4),
#  ('didik', 4),
#  ('huahaha', 4),
#  ('akal', 4),
#  ('bgt', 4),
#  ('rusak', 4),
#  ('sampah', 4),
#  ('statement', 4),
#  ('moga', 4),
#  ('tolong', 4),
#  ('nyalon', 4),
#  ('beritasatu', 4),
#  ('cagub', 4),
#  ('omong', 4),
#  ('bloon', 4),
#  ('karna', 4),
#  ('gusur', 4),
#  ('arifin', 4),
#  ('doang', 4),
#  ('tbayupatti', 4),
#  ('mlmkabeh', 4),
#  ('rinjanijb', 4),
#  ('fatwa', 4),
#  ('lawan', 4),
#  ('yunartowijaya', 4),
#  ('emg', 4),
#  ('coba', 4),
#  ('realdonaldtrump', 4),
#  ('stop', 4),
#  ('awas', 4),
#  ('situ', 4),
#  ('ferrymaitimu', 4),
#  ('pedoman', 4),
#  ('undang', 4),
#  ('junjung', 4),
#  ('lapor', 4),
#  ('kader', 4),
#  ('harga', 4),
#  ('elo', 4),
#  ('allah', 4),
#  ('edit', 4),
#  ('dengki', 4),
#  ('lbh', 4),
#  ('b0sss', 4),
#  ('politikus', 4),
#  ('negeri', 4),
#  ('pancasila', 4),
#  ('isi', 4),
#  ('mutu', 4),
#  ('muka', 4),
#  ('maspiyungan', 4),
#  ('asepapit', 4),
#  ('mikir', 4),
#  ('indo', 4),
#  ('amin', 4),
#  ('ajar', 4),
#  ('komunis', 4),
#  ('mau', 4),
#  ('pki', 4),
#  ('ganggu', 4),
#  ('gemacan70', 4),
#  ('hrs', 4),
#  ('tito', 4),
#  ('rizieq', 4),
#  ('tang', 4),
#  ('china', 4),
#  ('gm', 4),
#  ('cinta', 4),
#  ('wkt', 4),
#  ('hancur', 4),
#  ('sprti', 4),
#  ('umnia77', 4),
#  ('kasih', 3),
#  ('hebat', 3),
#  ('uno', 3),
#  ('pecat', 3),
#  ('proyek', 3),
#  ('arif', 3),
#  ('ahy', 3),
#  ('csr', 3),
#  ('swasta', 3),
#  ('rngsupzbaj', 3),
#  ('kaki', 3),
#  ('hasil', 3),
#  ('kampanye', 3),
#  ('zuhairimisrawi', 3),
#  ('untung', 3),
#  ('sengaja', 3),
#  ('triwul82', 3),
#  ('kjp', 3),
#  ('pks', 3),
#  ('deh', 3),
#  ('ekonomi', 3),
#  ('tim', 3),
#  ('mohmahfudmd', 3),
#  ('pftee', 3),
#  ('ych7168', 3),
#  ('elektabilitas', 3),
#  ('apa', 3),
#  ('ketemu', 3),
#  ('buzzer', 3),
#  ('mah', 3),
#  ('munafik', 3),
#  ('tinggal', 3),
#  ('jawa', 3),
#  ('idiot', 3),
#  ('jaychou881', 3),
#  ('henry', 3),
#  ('gpp', 3),
#  ('program', 3),
#  ('tahu', 3),
#  ('ed', 3),
#  ('tirta', 3),
#  ('uda', 3),
#  ('gih', 3),
#  ('pinter2', 3),
#  ('cagubnyinyir', 3),
#  ('semiaji', 3),
#  ('w', 3),
#  ('kapolri', 3),
#  ('foto', 3),
#  ('lgsg', 3),
#  ('muak', 3),
#  ('ferrykoto', 3),
#  ('hmskaban', 3),
#  ('azissubekti', 3),
#  ('him', 3),
#  ('nk', 3),
#  ('ideas', 3),
#  ('masawep', 3),
#  ('jajah', 3),
#  ('klu', 3),
#  ('belakang', 3),
#  ('klw', 3),
#  ('bisik', 3),
#  ('sirik', 3),
#  ('iri', 3),
#  ('nama', 3),
#  ('dikit', 3),
#  ('hei', 3),
#  ('polri', 3),
#  ('aparat', 3),
#  ('sejarah', 3),
#  ('mrk', 3),
#  ('gedung', 3),
#  ('negri', 3),
#  ('news', 3),
#  ('tuk', 3),
#  ('kagak', 3),
#  ('akun', 3),
#  ('pln', 3),
#  ('emak', 3),
#  ('terima', 3),
#  ('pilpres', 3),
#  ('gue', 3),
#  ('ngeles', 3),
#  ('aseng', 3),
#  ('super', 3),
#  ('ormas', 3),
#  ('kata2', 3),
#  ('kadang', 3),
#  ('ttg', 3),
#  ('anti', 3),
#  ('mantap', 3),
#  ('gembok', 3),
#  ('aneh', 3),
#  ('president', 3),
#  ('09', 3),
#  ('sendok', 3),
#  ('bayar', 3),
#  ('pegang', 3),
#  ('utama', 3),
#  ('ummat', 3),
#  ('buruk', 3),
#  ('negatif', 3),
#  ('kek', 3),
#  ('tulis', 3),
#  ('kepala', 3),
#  ('nanya', 3),
#  ('nga', 3),
#  ('kabinet', 3),
#  ('ngakak', 3),
#  ('2019', 3),
#  ('ssirah', 3),
#  ('grand', 3),
#  ('light88', 3),
#  ('arifinp76', 3),
#  ('sono', 3),
#  ('orasi', 3),
#  ('twitter', 3),
#  ('buat', 3),
#  ('jepang', 3),
#  ('lho', 3),
#  ('sindir', 3),
#  ('depan', 3),
#  ('quran', 3),
#  ('tuju', 3),
#  ('nov', 3),
#  ('koar', 3),
#  ('sibonekakayu', 3),
#  ('kampret', 3),
#  ('thdp', 3),
#  ('pny', 3),
#  ('kuat', 3),
#  ('pres', 3),
#  ('ryesties', 3),
#  ('loh', 3),
#  ('mayoritas', 3),
#  ('daizlaode', 3)]

# %%
# Membuat visualisasi tweet berdasarkan isi tweet yang sering muncul sebanyak 30 kata yang sering digunakan
from cycler import cycler

plt.figure(figsize=(10, 7))
plt.title("Visualisasi Kata Yang Sering Dipakai Di Dalam Tweet", fontdict={"fontsize":15}, pad=15)
plt.rc("axes", prop_cycle=(cycler("color", ["g"])))
fqdist_content.plot(30, cumulative=False)
plt.show()

# %% [markdown]
# ## 4. Visualisasi Dengan Wordclouds

# %% [markdown]
# ### Semua Label (Positif & Negatif)

# %%
# Menampilkan sekaligus memvisualisasikan kata menggunakan wordcloud dari DataFrame "data_2016" dari kolom "content_bersih"  
all_tweet_post = " ".join(word for word in data_2016["content_bersih"])
wordcloud = WordCloud(colormap="BuGn", width=700, height=300, 
                      mode="RGBA", background_color="lightgrey").generate(all_tweet_post)
plt.figure(figsize=(17,10))
plt.title("Menampilkan Semua Isi Content Tweet Dari Kolom 'content_bersih'", fontdict={"fontsize":15}, pad = 15);
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# Jika dilihat dari visualisasi diatas tampilan tersebut merupakan visualisasi dari wordcloud yang bertujuan untuk mendapatkan insight pemahaman secara utuh tentang suatu ide atau gagasan dari seseorang atau tulisan seseorang dalam suatu waktu tertentu. Visualsasi ini banyak sekali digunakan dalam pengujian analisa sentimen karena untuk melihat setiap kata-kata yang telah diketikkan oleh masyarakat.
#
# Namun tampilan visualisasi diatas masih mencakup semua label (positif & negatif) yang membuat kita kesulitan untuk mengetahui kata-kata mana yang bernilai positif/negatif. Maka dari itu kami akan membuatnya secara terpisah antara visualisasi wordcloud yang bernilai positif dan wordcloud yang bernilai negatif.

# %% [markdown]
# ### Label Positif

# %%
# Memisahkan semua data yang memiliki label positif yang disesuaikan dari kolom "label"
data_2016_label_positif = data_2016[data_2016.label == "positif"]
data_2016_label_positif.head()
# Out:
#                      tanggal  \
# 1  2016-12-19 19:20:46+00:00
# 3  2016-11-24 21:22:09+00:00
# 5  2016-11-13 17:45:54+00:00
# 6  2016-10-29 17:42:11+00:00
# 7  2016-10-29 17:40:58+00:00
#
#                                              content    label  \
# 1   kaskus apa anies itu dipikir bego ahok jauh l...  positif
# 3  bego bngt asu anies sandi uno itu pantes aja d...  positif
# 5   percetakanku iwanfals kalo polling anies mena...  positif
# 6  anies akan masukan dana csr apbd anis bego itu...  positif
# 7  anies akan masukan dana csr apbd anis bego itu...  positif
#
#                                   content_tokenizing  \
# 1  [kaskus, apa, anies, itu, dipikir, bego, ahok,...
# 3  [bego, bngt, asu, anies, sandi, uno, itu, pant...
# 5  [percetakanku, iwanfals, kalo, polling, anies,...
# 6  [anies, akan, masukan, dana, csr, apbd, anis, ...
# 7  [anies, akan, masukan, dana, csr, apbd, anis, ...
#
#                                    content_stopwords  \
# 1     [kaskus, anies, dipikir, bego, ahok, loe, hok]
# 3  [bego, bngt, asu, anies, sandi, uno, pantes, a...
# 5  [percetakanku, iwanfals, kalo, polling, anies,...
# 6  [anies, masukan, dana, csr, apbd, anis, bego, ...
# 7  [anies, masukan, dana, csr, apbd, anis, bego, ...
#
#                                     content_stemming  \
# 1       [kaskus, anies, pikir, bego, ahok, loe, hok]
# 3  [bego, bngt, asu, anies, sandi, uno, pantes, a...
# 5  [cetak, iwanfals, kalo, polling, anies, menang...
# 6  [anies, masuk, dana, csr, apbd, anis, bego, da...
# 7  [anies, masuk, dana, csr, apbd, anis, bego, da...
#
#                                       content_bersih
# 1               kaskus anies pikir bego ahok loe hok
# 3  bego bngt asu anies sandi uno pantes aja pecat...
# 5  cetak iwanfals kalo polling anies menang iwan ...
# 6  anies masuk dana csr apbd anis bego dana swast...
# 7  anies masuk dana csr apbd anis bego dana swast...

# %%
# Memvisualisasikan menggunakan wordcloud dari DataFrame "data_2016_label_positif" dari kolom "content_bersih"  
all_content_positive = " ".join(word for word in data_2016_label_positif["content_bersih"])
wordcloud = WordCloud(colormap="winter", width=700, height=300, 
                      mode="RGBA", background_color="lightgrey").generate(all_content_positive)
plt.figure(figsize=(17,10))
plt.title("Menampilkan Semua Isi Content Yang Bersifat Positif Dari Kolom 'content_bersih'", 
          fontdict={"fontsize":15}, pad = 15);
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# ### Label Negatif

# %%
# Memisahkan semua data yang memiliki label negatif yang disesuaikan dari kolom "label"
data_2016_label_negatif = data_2016[data_2016.label == "negatif"]
data_2016_label_negatif.head()
# Out:
#                       tanggal  \
# 0   2016-12-21 04:36:51+00:00
# 2   2016-12-09 11:21:17+00:00
# 4   2016-11-18 17:40:30+00:00
# 12  2016-10-09 09:38:35+00:00
# 20  2016-12-29 10:04:37+00:00
#
#                                               content    label  \
# 0   jakartans bego mending kalo anies ini agus htt...  negatif
# 2   mau debatnya klo bertempat petamburan kali klo...  negatif
# 4    sam arif  kalo orang tidak bego dan tidak tol...  negatif
# 12  anies bener naik angkutan umum jkt itu mahal k...  negatif
# 20   takviri gunromli hanya orng bodoh yang percay...  negatif
#
#                                    content_tokenizing  \
# 0   [jakartans, bego, mending, kalo, anies, ini, a...
# 2   [mau, debatnya, klo, bertempat, petamburan, ka...
# 4   [sam, arif, kalo, orang, tidak, bego, dan, tid...
# 12  [anies, bener, naik, angkutan, umum, jkt, itu,...
# 20  [takviri, gunromli, hanya, orng, bodoh, yang, ...
#
#                                     content_stopwords  \
# 0   [jakartans, bego, mending, kalo, anies, agus, ...
# 2   [debatnya, klo, bertempat, petamburan, kali, k...
# 4   [sam, arif, kalo, orang, bego, tolol, milih, a...
# 12  [anies, bener, angkutan, jkt, mahal, kalo, tau...
# 20  [takviri, gunromli, orng, bodoh, percaya, agus...
#
#                                      content_stemming  \
# 0   [jakartans, bego, mending, kalo, anies, agus, ...
# 2   [debat, klo, tempat, tambur, kali, klo, kalah,...
# 4   [sam, arif, kalo, orang, bego, tolol, milih, a...
# 12  [anies, bener, angkut, jkt, mahal, kalo, tau, ...
# 20  [takviri, gunromli, orng, bodoh, percaya, agus...
#
#                                        content_bersih
# 0   jakartans bego mending kalo anies agus c66jtx7qoz
# 2   debat klo tempat tambur kali klo kalah debat k...
# 4      sam arif kalo orang bego tolol milih ahy anies
# 12  anies bener angkut jkt mahal kalo tau bego aja...
# 20  takviri gunromli orng bodoh percaya agus pimpi...

# %%
# Membuat Tampilan Visualisasi menggunakan wordcloud dari DataFrame "data_2016_label_negatif" dari kolom "content_bersih" 
all_content_negative = " ".join(word for word in data_2016_label_negatif["content_bersih"])
wordcloud = WordCloud(colormap="Reds", width=700, height=300, 
                      mode="RGBA", background_color="lightgrey").generate(all_content_negative)
plt.figure(figsize=(17,10))
plt.title("Menampilkan Semua Isi Tweet Yang Bersifat Netral Dari Kolom Tweet_Bersih", 
          fontdict={"fontsize":15}, pad = 15);
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# ## 5. Melakukan Pemodelan Dengan Model Machine Learning

# %%
# Menampilkan keseluruhan data dari DataFrame "data_2016"
data_2016.head()
# Out:
#                      tanggal  \
# 0  2016-12-21 04:36:51+00:00
# 1  2016-12-19 19:20:46+00:00
# 2  2016-12-09 11:21:17+00:00
# 3  2016-11-24 21:22:09+00:00
# 4  2016-11-18 17:40:30+00:00
#
#                                              content    label  \
# 0  jakartans bego mending kalo anies ini agus htt...  negatif
# 1   kaskus apa anies itu dipikir bego ahok jauh l...  positif
# 2  mau debatnya klo bertempat petamburan kali klo...  negatif
# 3  bego bngt asu anies sandi uno itu pantes aja d...  positif
# 4   sam arif  kalo orang tidak bego dan tidak tol...  negatif
#
#                                   content_tokenizing  \
# 0  [jakartans, bego, mending, kalo, anies, ini, a...
# 1  [kaskus, apa, anies, itu, dipikir, bego, ahok,...
# 2  [mau, debatnya, klo, bertempat, petamburan, ka...
# 3  [bego, bngt, asu, anies, sandi, uno, itu, pant...
# 4  [sam, arif, kalo, orang, tidak, bego, dan, tid...
#
#                                    content_stopwords  \
# 0  [jakartans, bego, mending, kalo, anies, agus, ...
# 1     [kaskus, anies, dipikir, bego, ahok, loe, hok]
# 2  [debatnya, klo, bertempat, petamburan, kali, k...
# 3  [bego, bngt, asu, anies, sandi, uno, pantes, a...
# 4  [sam, arif, kalo, orang, bego, tolol, milih, a...
#
#                                     content_stemming  \
# 0  [jakartans, bego, mending, kalo, anies, agus, ...
# 1       [kaskus, anies, pikir, bego, ahok, loe, hok]
# 2  [debat, klo, tempat, tambur, kali, klo, kalah,...
# 3  [bego, bngt, asu, anies, sandi, uno, pantes, a...
# 4  [sam, arif, kalo, orang, bego, tolol, milih, a...
#
#                                       content_bersih
# 0  jakartans bego mending kalo anies agus c66jtx7qoz
# 1               kaskus anies pikir bego ahok loe hok
# 2  debat klo tempat tambur kali klo kalah debat k...
# 3  bego bngt asu anies sandi uno pantes aja pecat...
# 4     sam arif kalo orang bego tolol milih ahy anies

# %% [markdown]
# Karena pada pengujian kali ini data yang bersifat lebih dominan terhadap data dokumen maka kami akan menggunakan sebuah pembobotan nilai yang bernama TF-IDF (term frequency-inverse document frequency). Pembobotan dengan TF-IDF  merupakan salah satu faktor pembobotan yang sering digunakan dalam konteks penambangan data yang bersifat full text. Selain itu TF-IDF juga dapat dapat digunakan untuk menganalisa hubungan antara sebuah frase/kalimat dengan sekumpulan dokumen. Teknik ini akan melakukan perhitungan dari sebuah kata kunci terhadap masing-masing dokumen.

# %%
# Melakukan proses pembobotan nilai dengan TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
data_2016_tfidf = tfidf.fit_transform(data_2016["content_bersih"].astype("U"))
data_2016_tfidf
# Out:
# <695x2925 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8094 stored elements in Compressed Sparse Row format>

# %%
# Melakukan pembagian data menjadi 2 bagian (data train & data test) menggunakan train_test_split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(data_2016_tfidf, data_2016["label"], test_size=0.2, random_state=20)

# %% [markdown]
# Penjelasan dari proses pemisahan data menjadi 2 variabel dan fungsi train_test_split:
#
# 1. data_2016_tfidf: merupakan sebuah fungsi yang berisi nilai pembobotan dari kolom "content_bersih"
# 2. data_2016: merupakan sebuah fungsi untuk mendeklarasikan/memanggil kolom "label" dari masing-masing nilai sentimen
# 3. test_size: Nilai presentase dari sebuah ukuran untuk membagi data test. Dalam pengujian ini saya memakai nilai test_size = 0.3 yang dimana ukuran dari data test mencapai 30% dan data train mencapai 70%.
# 4. random_state: Menetapkan nilai. Jika nilainya sama maka fungsi train_test_split akan menghasilkan pemisahan nilai yang sama persis di setiap waktunya. Namun jika ditentukan nilai random_statenya maka data akan diacak (random).

# %% [markdown]
# Setelah melakukan proses split yaitu membagi keutuhan data menjadi 2 bagian (data test & data train) langkah selanjutnya adalah melakukan pemodelan dengan menggunakan model multinomial naive bayes atau yang biasa dikenal sebagai MultinomialNB. Multinomial naive bayes merupakan sebuah teknik turunan dari naive bayes yang menggunakan teknik yang bernama conditional probability yaitu sebuah teknik yang dapat dilakukan dengan menggunakan frekuensi kemunculan suatu kata pada suatu kelas.

# %%
# Pemanggilan model Multinomial Naive Bayes (MultinomialNB) beserta parameternya
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV

model_mnb_train = MultinomialNB()

parameters = {
    "alpha": [6.5],
    "fit_prior": [False]
    
}

grid_search_mnb_train = GridSearchCV(model_mnb_train, parameters, cv=25) # CV = Cross Validation

grid_search_mnb_train.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=25, estimator=MultinomialNB(),
#              param_grid={'alpha': [6.5], 'fit_prior': [False]})

# %% [markdown]
# Penjelasan dari poin-poin yang ada di codingan diatas:
# 1. Parameters merupakan sebuah teknik pemanggilan fungsi-fungsi yang menjadi bagian dari sebuah model itu sendiri. Untuk mengecek parameter dari setiap model bisa dicek pada website sckit-learn. Pada codingan diatas, fungsi alpha dan fit_prior merupakan bagian dari parameter MultinomialNB.
# 2. GridSearchCV merupakan sebuah teknik untuk mencari best paramater/parameter terbaik untuk kasus klasifikasi. Pada codingan diatas, teknik GridSearchCV saya gunakan untuk memanggil variabel model dari MultinomialNB (model_mnb), fungsi serta nilai dari paramater model MultinomialNB, dan fungsi cross validation yang bernilai 30.
# 3. Cross Validation merupakan sebuah metode yang biasa dipakai dalam pengujian data mining yang bertujuan untuk memperoleh hasil akhir yang optimal. Metode ini akan menilai dengan cara mengestimasi rotasi yang hasil statistik analisisnya akan menggeneralisasi kumpulan data yang bersifat independen.
# 4. .fit merupakan sebuah fungsi yang bertujuan untuk melatih model dengan data training.

# %% [markdown]
# Namun setelah melakukan proses pemodelan untuk data train, saya juga akan melakukan pemodelan untuk data latih (test) supaya hasil akurasi yang di dapatkan tidak mengalami overfitting.

# %%
"""
Karena pada langkah sebelumnya sudah melakukan pemanggilan model Multinomial Naive Bayes terhadap data train (latih) selanjutnya
adalah melakukan pemanggilan model Multinomial Naive Bayes untuk data latih
"""
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV

model_mnb_test = MultinomialNB()

parameters = {
    "alpha": [6.5],
    "fit_prior": [False]
}

grid_search_mnb_test = GridSearchCV(model_mnb_test, parameters, cv=30) # CV = Cross Validation

grid_search_mnb_test.fit(x_test, y_test) # Melatih model MultinomialNB dengan data test supaya tidak terjadi imbalanced
# Out:
# GridSearchCV(cv=30, estimator=MultinomialNB(),
#              param_grid={'alpha': [6.5], 'fit_prior': [False]})

# %%
# Melakukan pengujian untuk variabel test & varibael train
print("----------------------------Prediksi Dari Data Uji---------------------------------")
prediction_test = grid_search_mnb_train.predict(x_test)
print(prediction_test)

print()

print("--------------------------Prediksi Dari Data Latih----------------------------------")
prediction_train = grid_search_mnb_test.predict(x_train)
print(prediction_train)
# Out:
# ----------------------------Prediksi Dari Data Uji---------------------------------
# ['positif' 'positif' 'positif' 'positif' 'negatif' 'negatif' 'positif'
#  'negatif' 'negatif' 'negatif' 'negatif' 'negatif' 'negatif' 'positif'
#  'positif' 'negatif' 'positif' 'negatif' 'positif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'negatif' 'negatif' 'positif' 'negatif'
#  'negatif' 'positif' 'negatif' 'positif' 'positif' 'negatif' 'negatif'
#  'negatif' 'positif' 'negatif' 'negatif' 'positif' 'negatif' 'negatif'
#  'negatif' 'negatif' 'negatif' 'negatif' 'negatif' 'negatif' 'positif'
#  'negatif' 'negatif' 'negatif' 'positif' 'negatif' 'negatif' 'positif'
#  'negatif' 'positif' 'negatif' 'negatif' 'negatif' 'positif' 'negatif'
#  'positif' 'positif' 'positif' 'negatif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'negatif' 'positif' 'negatif' 'negatif'
#  'positif' 'negatif' 'negatif' 'positif' 'negatif' 'positif' 'positif'
#  'negatif' 'positif' 'negatif' 'positif' 'positif' 'positif' 'negatif'
#  'positif' 'negatif' 'positif' 'positif' 'positif' 'positif' 'negatif'
#  'negatif' 'negatif' 'negatif' 'negatif' 'negatif' 'negatif' 'positif'
#  'positif' 'positif' 'negatif' 'positif' 'positif' 'positif' 'positif'
#  'negatif' 'negatif' 'negatif' 'negatif' 'negatif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'negatif'
#  'negatif' 'negatif' 'positif' 'negatif' 'negatif' 'positif']
#
# --------------------------Prediksi Dari Data Latih----------------------------------
# ['negatif' 'positif' 'positif' 'negatif' 'negatif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'negatif' 'negatif' 'negatif' 'positif'
#  'positif' 'negatif' 'negatif' 'negatif' 'positif' 'positif' 'negatif'
#  'negatif' 'negatif' 'negatif' 'positif' 'positif' 'positif' 'negatif'
#  'positif' 'positif' 'negatif' 'positif' 'positif' 'negatif' 'positif'
#  'positif' 'negatif' 'positif' 'positif' 'negatif' 'positif' 'negatif'
#  'positif' 'negatif' 'negatif' 'positif' 'negatif' 'positif' 'negatif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'negatif' 'negatif'
#  'positif' 'negatif' 'negatif' 'positif' 'positif' 'positif' 'negatif'
#  'negatif' 'negatif' 'positif' 'negatif' 'negatif' 'positif' 'positif'
#  'positif' 'negatif' 'negatif' 'negatif' 'positif' 'positif' 'positif'
#  'positif' 'negatif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'negatif' 'negatif' 'positif' 'positif' 'negatif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'negatif'
#  'negatif' 'positif' 'positif' 'positif' 'negatif' 'negatif' 'positif'
#  'positif' 'positif' 'negatif' 'negatif' 'positif' 'negatif' 'negatif'
#  'positif' 'negatif' 'positif' 'negatif' 'positif' 'negatif' 'positif'
#  'positif' 'positif' 'negatif' 'positif' 'positif' 'negatif' 'positif'
#  'negatif' 'negatif' 'negatif' 'positif' 'negatif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'negatif' 'negatif' 'positif' 'negatif'
#  'negatif' 'positif' 'negatif' 'positif' 'negatif' 'positif' 'negatif'
#  'positif' 'positif' 'positif' 'negatif' 'negatif' 'negatif' 'negatif'
#  'negatif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'negatif' 'negatif' 'positif' 'negatif' 'positif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'positif' 'negatif' 'negatif' 'negatif'
#  'positif' 'negatif' 'positif' 'negatif' 'negatif' 'positif' 'negatif'
#  'positif' 'negatif' 'negatif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'negatif'
#  'negatif' 'negatif' 'negatif' 'negatif' 'negatif' 'negatif' 'negatif'
#  'negatif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'negatif' 'positif' 'positif' 'negatif'
#  'positif' 'positif' 'negatif' 'positif' 'positif' 'negatif' 'positif'
#  'negatif' 'positif' 'positif' 'negatif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'negatif' 'negatif' 'negatif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'positif' 'positif' 'negatif' 'positif'
#  'negatif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'negatif'
#  'negatif' 'negatif' 'positif' 'positif' 'negatif' 'negatif' 'negatif'
#  'positif' 'positif' 'positif' 'negatif' 'positif' 'positif' 'positif'
#  'negatif' 'positif' 'negatif' 'negatif' 'positif' 'negatif' 'negatif'
#  'positif' 'positif' 'positif' 'negatif' 'positif' 'negatif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'negatif' 'negatif' 'negatif' 'positif' 'negatif' 'positif'
#  'positif' 'positif' 'positif' 'negatif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'negatif' 'positif'
#  'positif' 'negatif' 'positif' 'negatif' 'positif' 'positif' 'positif'
#  'positif' 'negatif' 'positif' 'positif' 'negatif' 'positif' 'negatif'
#  'positif' 'positif' 'negatif' 'positif' 'positif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'negatif' 'negatif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'negatif' 'positif' 'positif' 'positif' 'positif' 'negatif'
#  'positif' 'positif' 'positif' 'negatif' 'positif' 'negatif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'negatif' 'positif' 'negatif' 'positif' 'negatif' 'positif'
#  'positif' 'positif' 'negatif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'negatif'
#  'positif' 'negatif' 'positif' 'positif' 'negatif' 'negatif' 'negatif'
#  'positif' 'positif' 'positif' 'negatif' 'positif' 'positif' 'negatif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'negatif' 'positif' 'negatif' 'negatif' 'positif' 'negatif' 'negatif'
#  'positif' 'negatif' 'positif' 'positif' 'negatif' 'positif' 'positif'
#  'positif' 'negatif' 'positif' 'negatif' 'positif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'negatif' 'positif' 'positif' 'negatif'
#  'negatif' 'positif' 'negatif' 'negatif' 'positif' 'negatif' 'positif'
#  'positif' 'positif' 'positif' 'negatif' 'positif' 'positif' 'negatif'
#  'positif' 'positif' 'negatif' 'positif' 'positif' 'positif' 'negatif'
#  'negatif' 'positif' 'positif' 'positif' 'positif' 'negatif' 'negatif'
#  'positif' 'negatif' 'positif' 'positif' 'negatif' 'negatif' 'positif'
#  'positif' 'positif' 'positif' 'negatif' 'negatif' 'positif' 'positif'
#  'positif' 'positif' 'negatif' 'positif' 'positif' 'negatif' 'negatif'
#  'negatif' 'negatif' 'positif' 'positif' 'negatif' 'positif' 'negatif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'negatif'
#  'positif' 'positif' 'positif' 'negatif' 'negatif' 'positif' 'negatif'
#  'negatif' 'negatif' 'positif' 'negatif' 'negatif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'negatif' 'negatif' 'negatif' 'positif'
#  'negatif' 'positif' 'negatif' 'positif' 'positif' 'positif' 'negatif'
#  'negatif' 'negatif' 'negatif' 'negatif' 'positif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'negatif'
#  'positif' 'positif' 'negatif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'negatif' 'negatif']

# %%
# Membuat visualisasi untuk menampilkan pengukuran performa dari hasil prediksi pada variabel uji & latih

f, ax = plt.subplots(figsize=(9, 4))
sns.heatmap(confusion_matrix(y_test, prediction_test), annot=True, cmap="RdYlBu", fmt=".0f", ax=ax)
plt.xlabel("Prediksi")
plt.ylabel("Aktual")
plt.title("Pengukuran Performa Hasil Klasifikasi Dari Variabel Uji", fontdict={"fontsize":13}, pad=13)
plt.show()

f, ax = plt.subplots(figsize=(9, 4))
sns.heatmap(confusion_matrix(y_train, prediction_train), annot=True, cmap="RdYlBu", fmt=".0f", ax=ax)
plt.xlabel("Nilai Prediksi")
plt.ylabel("Nilai Aktual")
plt.title("Pengukuran Performa Hasil Klasifikasi Dari Variabel Latih", fontdict={"fontsize":13}, pad=13)
plt.show()

# %% [markdown]
# Penjelasan dari visualisasi pada confusion matrix:
# - Data Test
# 1. True Positive pada data test memiliki nilai sejumlah 48. True Positive merupakan data yang bernilai positif yang diprediksi tepat.
# 2. True Negative pada data test memiliki nilai sejumlah 52. True Negative sendiri merupakan data yang bernilai negatif yang diprediksi secara tepat.
# 3. False Positive pada data test memiliki nilai sejumlah 16. False Positive sendiri merupakan data yang bernilai negatif namun pada saat diprediksi terhitung sebagai data positif.
# 4. False Negative pada data test memiliki nilai sejumlah 23. False Negative sendiri merupakan data yang bernilai positif namun pada saat diprediksi terhitung sebagai data yang negatif.
#
# - Data Train
# 1. True Positive pada data train memiliki nilai sejumlah 150. True Positive merupakan data yang bernilai positif yang diprediksi tepat.
# 2. True Negative pada data train memiliki nilai sejumlah 221. True Negative sendiri merupakan data yang bernilai negatif yang diprediksi secara tepat.
# 3. False Positive pada data train memiliki nilai sejumlah 123. False Positive sendiri merupakan data yang bernilai negatif namun pada saat diprediksi terhitung sebagai data positif.
# 4. False Negative pada data train memiliki nilai sejumlah 62. False Negative sendiri merupakan data yang bernilai positif namun pada saat diprediksi terhitung sebagai data yang negatif.

# %%
# Menampilkan tingkat akurasi, precision, recall & f1-score dari model Multonimial Naive Bayes

print("------------------------Prediksi Dari Variabel Uji-------------------------------")
cr_test = classification_report(y_test, prediction_test)
print(cr_test)

print("------------------------Prediksi Dari Variabel Latih-------------------------------")
cr_train = classification_report(y_train, prediction_train)
print(cr_train)
# Out:
# ------------------------Prediksi Dari Variabel Uji-------------------------------
#               precision    recall  f1-score   support
#
#      negatif       0.68      0.75      0.71        64
#      positif       0.76      0.69      0.73        75
#
#     accuracy                           0.72       139
#    macro avg       0.72      0.72      0.72       139
# weighted avg       0.72      0.72      0.72       139
#
# ------------------------Prediksi Dari Variabel Latih-------------------------------
#               precision    recall  f1-score   support
#
#      negatif       0.70      0.55      0.62       273
#      positif       0.64      0.78      0.70       283
#
#     accuracy                           0.67       556
#    macro avg       0.67      0.66      0.66       556
# weighted avg       0.67      0.67      0.66       556

# %% [markdown]
# ## 6. Membuat Prediksi Akhir & Visualisasi Tahap Akhir

# %%
# Membuat variabel baru yang dihasilkan dari prediksi label content sentimen pada data test
content_output_test_2016 = pd.DataFrame({"label": prediction_test})
content_output_test_2016.head()
# Out:
#      label
# 0  positif
# 1  positif
# 2  positif
# 3  positif
# 4  negatif

# %%
# Membuat variabel yang dihasilkan dari prediksi label content sentimen pada data train
content_output_train_2016 = pd.DataFrame({"label": prediction_train})
content_output_train_2016.head()
# Out:
#      label
# 0  negatif
# 1  positif
# 2  positif
# 3  negatif
# 4  negatif

# %%
# Visualisasi untuk melihat sekaligus membandingkan hasil sentimen dari data test & data train
plt.figure(figsize=(15, 5))

# Visualiasi dari hasil prediksi pada variabel test/uji
plt.subplot(1, 2, 1)
sns.countplot(x="label", hue="label", data=content_output_test_2016)
plt.title("Visualisasi Label Sentimen Pada Data Uji Setelah Di Prediksi (Tahun 2016)", fontdict={"fontsize":13}, pad=13)
plt.xlabel("Label Sentimen Pada Data Uji")
plt.ylabel("Jumlah Tweet")
plt.legend()

# Visualiasi dari hasil prediksi pada variabel train/latih
plt.subplot(1, 2, 2)
sns.countplot(x="label", hue="label", data=content_output_train_2016)
plt.title("Visualisasi Label Sentimen Pada Data Latih Setelah Di Prediksi (Tahun 2016)", fontdict={"fontsize":13}, pad=13)
plt.xlabel("Label Sentimen Pada Data Latih")
plt.ylabel("Jumlah Tweet")
plt.show()

# %% [markdown]
# Penjelasan dari bar plot sebagai berikut:
# - Variabel content_output_test_2016
# 1. Pada variabel content_output_test_2016 dengan nilai label "positif" memiliki jumlah akhir isi content tweet sebanyak 68. Sedangkan pada nilai label "negatif" di variabel content_output_test_2016 memiliki jumlah nilai isi content tweet sebanyak 71. Jadi dapat disimpulkan bahwasanya jumlah akhir setelah dilakukan klasifikasi nilai label "negatif" lebih banyak daripada nilai label "positif" walaupun hanya memiliki selisih nilai yaitu 3.
#
# - Variabel content_ouutput_train_2016
# 1. Pada variabel content_ouutput_train_2016 dengan nilai label "positif" memiliki jumlah akhir isi content tweet sebanyak 343. Sedangkan pada nilai label "negatif" di variabel content_ouutput_train_2016 memiliki jumlah nilai isi content tweet sebanyak 213. Jadi dapat disimpulkan bahwasanya jumlah akhir setelah dilakukan klasifikasi nilai label "positif" lebih banyak daripada nilai label "negatif" yang memiliki selisih nilai sebanyak 130 nilai.
