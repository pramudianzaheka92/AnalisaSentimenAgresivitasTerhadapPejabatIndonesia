# %% [markdown]
# # Analisa Sentimen Dari Media Sosial Twitter Tentang Agresivitas Kepada Para Pejabat Indonesia Di Tahun 2020

# %% [markdown]
# ## 1. Import Library & Load Dataset Dari Local Device

# %%
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
from sklearn.metrics import confusion_matrix, classification_report

# %%
data_2020 = pd.read_excel("Data Tahun 2020.xlsx")
data_2020.head()
# Out:
#                         date  \
# 0  2020-12-29 23:16:16+00:00
# 1  2020-12-29 07:49:59+00:00
# 2  2020-12-28 14:52:49+00:00
# 3  2020-12-28 07:19:18+00:00
# 4  2020-12-27 16:42:18+00:00
#
#                                              content     label
# 0  @BieSpartacus @Da_yangqu @aniesbaswedan Owh ka...   positif
# 1  Beda pk anies, dengan pejabat publik lainnya, ...  negatif
# 2  @PeriSyantik @MerryAnjani19 @CNNIndonesia Situ...   positif
# 3  @OposisiCerdas Pokoknya klo pak anies jd calon...  negatif
# 4  @detikcom Mnding mikir buat 2022 dulu Bang. 20...  negatif

# %%
# Mengecek tipe data dan juga apakah di dalam DataFrame "data_2020" memiliki nilai NaN/tidak
data_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     1800 non-null   object
#  1   content  1800 non-null   object
#  2   label    1800 non-null   object
# dtypes: object(3)
# memory usage: 42.3+ KB

# %%
# Melakukan visualisasi untuk kolom "label"

plt.style.use("seaborn")
plt.title("Perhitungan Label Sentimen Secara Manual")
sns.countplot(x="label", hue="label", data=data_2020)
plt.figure(figsize=(10, 10))
plt.show()

# %%
# Menghitung sekaligus mengurutkan jumlah label terbanyak berdasarkan tweet
jumlah_content = data_2020.groupby("label").count()["content"].reset_index().sort_values(by="content", ascending=False)
jumlah_content.style.background_gradient(cmap="Wistia")
# Out:
# <style  type="text/css" >
# #T_3d5225e1_fb27_11eb_b067_8a52637b5ce0row0_col1{
#             background-color:  #fc7f00;
#             color:  #000000;
#         }#T_3d5225e1_fb27_11eb_b067_8a52637b5ce0row1_col1{
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }</style><table id="T_3d5225e1_fb27_11eb_b067_8a52637b5ce0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >label</th>        <th class="col_heading level0 col1" >content</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3d5225e1_fb27_11eb_b067_8a52637b5ce0level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_3d5225e1_fb27_11eb_b067_8a52637b5ce0row0_col0" class="data row0 col0" >positif</td>
#                         <td id="T_3d5225e1_fb27_11eb_b067_8a52637b5ce0row0_col1" class="data row0 col1" >1098</td>
#             </tr>
#             <tr>
#                         <th id="T_3d5225e1_fb27_11eb_b067_8a52637b5ce0level0_row1" class="row_heading level0 row1" >0</th>
#                         <td id="T_3d5225e1_fb27_11eb_b067_8a52637b5ce0row1_col0" class="data row1 col0" >negatif </td>
#                         <td id="T_3d5225e1_fb27_11eb_b067_8a52637b5ce0row1_col1" class="data row1 col1" >702</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Dapat dilihat dari perhitungan diatas, dari 1800 jumlah data netizen twitter di tahun 2020 ketika melakukan tweet tentang topik para pejabat di Indonesia mendapatkan label positif yang sangat tinggi daripada label negatif yang memiliki jumlah sentimen sebanyak 1098 tweet sedangkan label negatif memiliki jumlah sentimen sebanyak 702.

# %% [markdown]
# ## 2. Text Preprocessing (Cleansing, Case Folding, Tokenizing, Stopwords & Stemming)

# %% [markdown]
# ### Cleansing

# %%
# Menghilangkan dari kalimat-kalimat, simbol-simbol, emoticon yang tidak dibutuhkan selama pengujian pada kolom content
def bersih_text(text):
    text = re.sub(r'[^a-zA-z0-9]',' ', str(text))
    text = re.sub(r'\b\w{1,2}\b','', text)
    text = re.sub(r'\s\s+',' ', text)
    text = re.sub(r'https?:\/\/\S+', '', text)  
    text = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text)
    return text

data_2020["content"] = data_2020["content"].apply(bersih_text)

data_2020.head()
# Out:
#                         date  \
# 0  2020-12-29 23:16:16+00:00
# 1  2020-12-29 07:49:59+00:00
# 2  2020-12-28 14:52:49+00:00
# 3  2020-12-28 07:19:18+00:00
# 4  2020-12-27 16:42:18+00:00
#
#                                              content     label
# 0   BieSpartacus Da yangqu aniesbaswedan Owh kalo...   positif
# 1  Beda anies dengan pejabat publik lainnya pak a...  negatif
# 2   PeriSyantik MerryAnjani19 CNNIndonesia Situ b...   positif
# 3   OposisiCerdas Pokoknya klo pak anies calon pr...  negatif
# 4   detikcom Mnding mikir buat 2022 dulu Bang 202...  negatif

# %%
# Menghapus spasi pada kolom "label"
data_2020.label = list(map(lambda x: x.strip(), data_2020.label))
data_2020.head()
# Out:
#                         date  \
# 0  2020-12-29 23:16:16+00:00
# 1  2020-12-29 07:49:59+00:00
# 2  2020-12-28 14:52:49+00:00
# 3  2020-12-28 07:19:18+00:00
# 4  2020-12-27 16:42:18+00:00
#
#                                              content    label
# 0   BieSpartacus Da yangqu aniesbaswedan Owh kalo...  positif
# 1  Beda anies dengan pejabat publik lainnya pak a...  negatif
# 2   PeriSyantik MerryAnjani19 CNNIndonesia Situ b...  positif
# 3   OposisiCerdas Pokoknya klo pak anies calon pr...  negatif
# 4   detikcom Mnding mikir buat 2022 dulu Bang 202...  negatif

# %% [markdown]
# Setelah melakukan proses cleansing teks yaitu menghapus beberapa simbol/karakter-karakter yang tidak dipentingkan dalam kolom content tweet, langkah selanjutnya adalah case folding. Case folding merupakan sebuah tahapan untuk mengubah huruf-huruf kapital menjadi huruf-huruf kecil.

# %% [markdown]
# ### Case Folding

# %%
# Mengubah ukuran setiap kalimat yang ada di kolom "content" menjadi huruf kecil
data_2020["content"] = data_2020["content"].str.lower()

data_2020.head()
# Out:
#                         date  \
# 0  2020-12-29 23:16:16+00:00
# 1  2020-12-29 07:49:59+00:00
# 2  2020-12-28 14:52:49+00:00
# 3  2020-12-28 07:19:18+00:00
# 4  2020-12-27 16:42:18+00:00
#
#                                              content    label
# 0   biespartacus da yangqu aniesbaswedan owh kalo...  positif
# 1  beda anies dengan pejabat publik lainnya pak a...  negatif
# 2   perisyantik merryanjani19 cnnindonesia situ b...  positif
# 3   oposisicerdas pokoknya klo pak anies calon pr...  negatif
# 4   detikcom mnding mikir buat 2022 dulu bang 202...  negatif

# %% [markdown]
# Setelah melakukan proses case folding, langkah selanjutnya adalah tokenizing/tokenisasi. Tahap tokenizing merupakan tahap pemotongan teks ke dalam satuan kata.

# %% [markdown]
# ### Tokenizing

# %%
# Melakukan Tahapan Tokenisasi. 
# Tokenisasi adalah tahapan prepocessing data yang digunakan untuk membagi kalimat menjadi perkata
def tokennization(text):
    return word_tokenize(text)

data_2020["content_tokenizing"] = data_2020["content"].apply(tokennization)
data_2020.head()
# Out:
#                         date  \
# 0  2020-12-29 23:16:16+00:00
# 1  2020-12-29 07:49:59+00:00
# 2  2020-12-28 14:52:49+00:00
# 3  2020-12-28 07:19:18+00:00
# 4  2020-12-27 16:42:18+00:00
#
#                                              content    label  \
# 0   biespartacus da yangqu aniesbaswedan owh kalo...  positif
# 1  beda anies dengan pejabat publik lainnya pak a...  negatif
# 2   perisyantik merryanjani19 cnnindonesia situ b...  positif
# 3   oposisicerdas pokoknya klo pak anies calon pr...  negatif
# 4   detikcom mnding mikir buat 2022 dulu bang 202...  negatif
#
#                                   content_tokenizing
# 0  [biespartacus, da, yangqu, aniesbaswedan, owh,...
# 1  [beda, anies, dengan, pejabat, publik, lainnya...
# 2  [perisyantik, merryanjani19, cnnindonesia, sit...
# 3  [oposisicerdas, pokoknya, klo, pak, anies, cal...
# 4  [detikcom, mnding, mikir, buat, 2022, dulu, ba...

# %% [markdown]
# Setelah melakukan tahapan tokenisasi, selanjutnya saya akan melakukan proses filtering (stowords). Proses stopwords ini merupakan tahapan mengambil kata-kata dari tahapan tokenisasi. Stopword merupakan sebuah tahapan yang dimana bertujuan untuk membuang kata-kata yang tidak deskriptif dalam melakukan pendekatan bag-of-words.

# %% [markdown]
# ### Stopwords

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
 
factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()
print(stopwords)
# Out:
# ['yang', 'untuk', 'pada', 'ke', 'para', 'namun', 'menurut', 'antara', 'dia', 'dua', 'ia', 'seperti', 'jika', 'jika', 'sehingga', 'kembali', 'dan', 'tidak', 'ini', 'karena', 'kepada', 'oleh', 'saat', 'harus', 'sementara', 'setelah', 'belum', 'kami', 'sekitar', 'bagi', 'serta', 'di', 'dari', 'telah', 'sebagai', 'masih', 'hal', 'ketika', 'adalah', 'itu', 'dalam', 'bisa', 'bahwa', 'atau', 'hanya', 'kita', 'dengan', 'akan', 'juga', 'ada', 'mereka', 'sudah', 'saya', 'terhadap', 'secara', 'agar', 'lain', 'anda', 'begitu', 'mengapa', 'kenapa', 'yaitu', 'yakni', 'daripada', 'itulah', 'lagi', 'maka', 'tentang', 'demi', 'dimana', 'kemana', 'pula', 'sambil', 'sebelum', 'sesudah', 'supaya', 'guna', 'kah', 'pun', 'sampai', 'sedangkan', 'selagi', 'sementara', 'tetapi', 'apakah', 'kecuali', 'sebab', 'selain', 'seolah', 'seraya', 'seterusnya', 'tanpa', 'agak', 'boleh', 'dapat', 'dsb', 'dst', 'dll', 'dahulu', 'dulunya', 'anu', 'demikian', 'tapi', 'ingin', 'juga', 'nggak', 'mari', 'nanti', 'melainkan', 'oh', 'ok', 'seharusnya', 'sebetulnya', 'setiap', 'setidaknya', 'sesuatu', 'pasti', 'saja', 'toh', 'ya', 'walau', 'tolong', 'tentu', 'amat', 'apalagi', 'bagaimanapun']

# %% [markdown]
# Proses stopwords saya lakukan dengan mengambil nilai-nilai yang ada diatas yang sudah ditentukan oleh library Sastrawi. Kata-kata diatas boleh digunakan secara keseluruhan/diambil hanya beberapa saja.

# %%
# Proses Filtering dari kolom "content_tokenizing"
nltk.download("stopwords")
from nltk.corpus import stopwords

list_delete = ["yang", "untuk", "pada", "ke", "antara", "dua", "ia", "seperti", "antara", "dia", "seperti", "jika",
               "tidak", "oleh", "saat", "harus", "sementara", "mereka", "sudah", "terhadap", "sehingga",
               "secara", "agar", "lain", "begitu", "mengapa", "kenapa", "yaitu", "yakni", "daripada",
               "sekitar", "serta", "di", "dari", "telah", "sebagai", "masih", 'setidaknya', "sesuatu", "pasti", 
               "saja", "toh", "ya", "walau", "hal", "bahwa", "atau", "hanya", "ada", "mereka", "agar", "lain", 
               "anda", "begitu", "yaitu", "yakni", "itulah", "demi", "dimana", "pula", "sambil", "sebelum", 
               "sesudah", "guna", "ia", "dengan", "https", "supaya", "kah", "pun", "sampai", "seraya", "seterusnya", 
               "tanpa", "agak", "boleh", "dapat", "dsb", "dst", "nggak", "mari", "nanti", "melainkan", "oh", "ok",
               "sedangkan", "selagi", "seharusnya", "sebetulnya", "setiap", "apakah", "kecuali", "sebab", "selain"]

list_stopwords = stopwords.words("indonesian")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Mendeklarasikan fungsi untuk list_stopwords
def stopword(text):
    return [word for word in text if word not in list_stopwords]

data_2020["content_stopwords"] = data_2020["content_tokenizing"].apply(stopword)

# %%
# Mendeklarasikan fungsi untuk list_delete
def stopwords_removal(text):
    return [word for word in text if word not in list_delete]

data_2020["content_stopwords"] = data_2020["content_stopwords"].apply(stopwords_removal)
data_2020.head()
# Out:
#                         date  \
# 0  2020-12-29 23:16:16+00:00
# 1  2020-12-29 07:49:59+00:00
# 2  2020-12-28 14:52:49+00:00
# 3  2020-12-28 07:19:18+00:00
# 4  2020-12-27 16:42:18+00:00
#
#                                              content    label  \
# 0   biespartacus da yangqu aniesbaswedan owh kalo...  positif
# 1  beda anies dengan pejabat publik lainnya pak a...  negatif
# 2   perisyantik merryanjani19 cnnindonesia situ b...  positif
# 3   oposisicerdas pokoknya klo pak anies calon pr...  negatif
# 4   detikcom mnding mikir buat 2022 dulu bang 202...  negatif
#
#                                   content_tokenizing  \
# 0  [biespartacus, da, yangqu, aniesbaswedan, owh,...
# 1  [beda, anies, dengan, pejabat, publik, lainnya...
# 2  [perisyantik, merryanjani19, cnnindonesia, sit...
# 3  [oposisicerdas, pokoknya, klo, pak, anies, cal...
# 4  [detikcom, mnding, mikir, buat, 2022, dulu, ba...
#
#                                    content_stopwords
# 0  [biespartacus, da, yangqu, aniesbaswedan, owh,...
# 1  [beda, anies, pejabat, publik, anies, kerja, b...
# 2  [perisyantik, merryanjani19, cnnindonesia, sit...
# 3  [oposisicerdas, pokoknya, klo, anies, calon, p...
# 4  [detikcom, mnding, mikir, 2022, bang, 2022, aj...

# %% [markdown]
# Tahapan terakhir dalam text processing adalah proses stemming. Teknik Stemming merupakan sebuah tahapan kegiatan text preprocessing untuk memperkecil jumlah indeks yang berbeda dari suatu data dan juga untuk melakukan pengelompokan kata-kata lain yang memiliki kata dasar dan arti yang serupa namun memiliki bentuk yang berbeda karena mendapatkan imbuhan yang berbeda pula.

# %% [markdown]
# ### Stemming

# %%
# Proses Stemming dibantu dengan bantuan swifter
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter # Swifter berfungsi untuk mempercepat froses stemming pada Dataframe dengan menjalankan task secara parallel

# Membuat Stemmer dari sastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Membuat fungsi stemming
def stemming(text):
    return stemmer.stem(text)

term_dict = {}

# Menghitung ada berapa kata/words di dalam kolom "content_stopwords"
for document in data_2020["content_stopwords"]:
    for text in document:
        if text not in term_dict:
            term_dict[text] = " "
            
print(len(term_dict))
print("------------------------")

# Menampilkan isi kata/words yang telah dilakukan proses stemming
for text in term_dict:
    term_dict[text] = stemming(text)
    print(text,":" ,term_dict[text])
    
print(term_dict)
print("------------------------")

# Membuat fungsi baru untuk proses stemming
def stemming_word(document):
    return [term_dict[text] for text in document]

data_2020["content_stemming"] = data_2020["content_stopwords"].swifter.apply(stemming_word)
# Out:
# 8609
# ------------------------
# biespartacus : biespartacus
# da : da
# yangqu : yangqu
# aniesbaswedan : aniesbaswedan
# owh : owh
# kalo : kalo
# anies : anies
# kerja : kerja
# risma : risma
# pencitraan : citra
# bego : bego
# bie : bie
# bilangin : bilangin
# beda : beda
# pejabat : jabat
# publik : publik
# beritanya : berita
# kerjanya : kerja
# pemanis : man
# ginihari : ginihari
# begoin : begoin
# rakyat : rakyat
# aja : aja
# dgn : dgn
# pemberitaan : berita
# dosa : dosa
# tau : tau
# v2lghm9pdx : v2lghm9pdx
# perisyantik : perisyantik
# merryanjani19 : merryanjani19
# cnnindonesia : cnnindonesia
# situ : situ
# beneran : beneran
# modal : modal
# adu : adu
# argumentasi : argumentasi
# coba : coba
# meme : meme
# ginian : ginian
# latihan : latih
# deh : deh
# pembina : bina
# bikin : bikin
# malu : malu
# disuruh : suruh
# suruh : suruh
# saingan : saing
# sdh : sdh
# repot2 : repot2
# diangkat : angkat
# mensos : mensos
# downgrade : downgrade
# pndukung : pndukung
# bgini : bgini
# mentri : tri
# oposisicerdas : oposisicerdas
# pokoknya : pokok
# klo : klo
# calon : calon
# presiden : presiden
# org : org
# pilih : pilih
# beliau : beliau
# udah : udah
# terpampang : pampang
# nyata : nyata
# kinerjanya : kerja
# detikcom : detikcom
# mnding : mnding
# mikir : mikir
# 2022 : 2022
# bang : bang
# blum : blum
# menang : menang
# gatau : gatau
# dibangun : bangun
# anggaran : anggar
# ampir : ampir
# 100t : 100t
# setahun : tahun
# dipakai : pakai
# baca : baca
# emng : emng
# dikerjain : dikerjain
# doncorleone : doncorleone
# 78 : 78
# yak : yak
# bener : bener
# ngomong : ngomong
# bego2in : bego2in
# orang : orang
# nich : nich
# suka : suka
# bega : bega
# hasmisahar : hasmisahar
# lisaamartatara3 : lisaamartatara3
# tolong : tolong
# nasihatin : nasihatin
# dokter : dokter
# narasi : narasi
# kebencian : benci
# permusuhan : musuh
# sebar : sebar
# dukung : dukung
# kuat : kuat
# kohesi : kohesi
# fans : fans
# tpi : tpi
# gak : gak
# nambah : nambah
# fansnya : fansnya
# mw17714668 : mw17714668
# emg : emg
# kudu : kudu
# laporan : lapor
# elu : elu
# kasih : kasih
# penghargaan : harga
# terheran2 : terheran2
# ferdinandhaean3 : ferdinandhaean3
# skrg : skrg
# jilat : jilat
# pemerintah : perintah
# berharap : harap
# ngajak : ngajak
# gada : gada
# kasian : kasi
# ngejek : ngejek
# pintarnya : pintar
# gimana : gimana
# mas : mas
# hayang : hayang
# milih : milih
# kolor : kolor
# merah : merah
# drpd : drpd
# gertak : gertak
# klrg : klrg
# gemetaran : gemetar
# szmpe : szmpe
# bulu : bulu
# jembutnya : jembut
# rontok : rontok
# retweet : retweet
# gaes : gaes
# biar : biar
# cebong : cebong
# stalking : stalking
# twit : twit
# prestasi : prestasi
# dongo : dongo
# jakartajuaramelulu : jakartajuaramelulu
# 3wus7fiy4v : 3wus7fiy4v
# pemerhatibangs4 : pemerhatibangs4
# selalubergerakk : selalubergerakk
# korupsi : korupsi
# siluman : siluman
# amp : amp
# dki : dki
# mingkem : mingkem
# drun : drun
# emang : emang
# pendukung : dukung
# rizqmuhammad3 : rizqmuhammad3
# joedynto : joedynto
# krn : krn
# gabener : gabener
# didukung : dukung
# aman2 : aman2
# gubernur : gubernur
# tdk : tdk
# kadrun : kadrun
# bisa2 : bisa2
# abis : abis
# tuh : tuh
# orbanamen : orbanamen
# natal : natal
# jngn : jngn
# belagak : bagak
# yah : yah
# ama : ama
# temen : temen
# gub : gub
# lho : lho
# ijinin : ijinin
# christmas : christmas
# carol : carol
# taon : taon
# kemaren : kemaren
# aman : aman
# pdahal : pdahal
# fpi : fpi
# bully : bully
# habis2an : habis2an
# giliran : gilir
# luhut : luhut
# pura : pura
# budeg : budeg
# dasar : dasar
# batu : batu
# giok : giok
# kompastv : kompastv
# namanya : nama
# jgn : jgn
# atw : atw
# mega : mega
# tsamaradki : tsamaradki
# bloon : bloon
# banggaka : banggaka
# partai : partai
# penuh : penuh
# terima : terima
# kali : kali
# baswedan : baswedan
# gubenur : gubenur
# pilihan : pilih
# kecurangan : curang
# kotak : kotak
# suara : suara
# kardus : kardus
# kompascom : kompascom
# pandji : pandji
# kmn : kmn
# pas : pas
# ahok : ahok
# digituin : digituin
# tutup : tutup
# mata : mata
# richardjknight8 : richardjknight8
# alfaomega0110 : alfaomega0110
# emon : emon
# lucu : lucu
# fadlizon : fadlizon
# elo : elo
# laki2 : laki2
# pake : pake
# ava : ava
# perempuan : perempuan
# bencong : bencong
# dah : dah
# kalimat : kalimat
# nuduh : nuduh
# tuntut : tuntut
# marlina : marlina
# idha : idha
# diijinkan : diijinkan
# hrs : hrs
# ditetapkan : tetap
# tersangka : sangka
# bidik : bidik
# mengijinkan : mengijinkan
# paham : paham
# republikaonline : republikaonline
# dilarang : larang
# protes : protes
# ntar : ntar
# diizinkan : izin
# covid : covid
# disalahkan : salah
# dipidana : pidana
# banteng : banteng
# beli : beli
# vaksin : vaksin
# ketahui : tahu
# efektifitasnya : efektifitasnya
# efektif : efektif
# nya : nya
# buang : buang
# dikembalikan : kembali
# hmmm : hmmm
# disalahin : disalahin
# diuber : uber
# uber : uber
# aparat : aparat
# cejetqa9et : cejetqa9et
# andidrz : andidrz
# buchronik : buchronik
# nkrisaklawase : nkrisaklawase
# maspiyuo : maspiyuo
# jkt : jkt
# barometer : barometer
# ekonomi : ekonomi
# nasional : nasional
# eko : eko
# bln : bln
# tolol : tolol
# dunia : dunia
# hadapi : hadap
# pandemi : pandemi
# msh : msh
# batasi : batas
# aktivitas : aktivitas
# usaha : usaha
# blm : blm
# demo2 : demo2
# manusia : manusia
# minus : minus
# otak : otak
# takut : takut
# investor : investor
# esemka : esemka
# dijual : jual
# duit : duit
# ggk : ggk
# don : don
# rahmad : rahmad
# peduli : peduli
# krja : krja
# cmn : cmn
# ngurusin : ngurusin
# jakarta : jakarta
# pengen : ken
# meroket : roket
# smk : smk
# release : release
# ibukota : ibukota
# cpt : cpt
# pindah : pindah
# lapangan : lapang
# pkerjaan : pkerjaan
# jutaan : juta
# korup : korup
# hukum : hukum
# mati : mati
# borneo : borneo
# digarap : garap
# suku : suku
# pribumi : pribumi
# papua : papua
# damai : damai
# ttp : ttp
# nkri : nkri
# kga : kga
# ganti : ganti
# haji : haji
# bolot : bolot
# ajah : ajah
# panembahan : panembahan
# alit : alit
# sanksi : sanksi
# tertinggi : tinggi
# sebanding : banding
# dampak : dampak
# timbulkan : timbul
# akibat : akibat
# kebungulan : kebungulan
# junjungan : junjung
# kapolda : kapolda
# kapolsek : kapolsek
# walkot : walkot
# jakpus : jakpus
# korban2 : korban2
# tertular : tular
# iyaiyaamaafin : iyaiyaamaafin
# ndptr21 : ndptr21
# pulg4rr : pulg4rr
# ch : ch
# chotlmah : chotlmah
# divhumas : divhumas
# polri : polri
# paltiwest3 : paltiwest3
# kangdede78 : kangdede78
# p3nj3l4j4h : p3nj3l4j4h
# id : id
# izin : izin
# persilahkan : silah
# teman2 : teman2
# urusan : urus
# cctv : cctv
# bawahi : bawah
# berkaitan : kait
# pemda : pemda
# lgsg : lgsg
# tanggung : tanggung
# kerjaan : kerja
# bawahannya : bawah
# gini : gin
# ngerti : ngerti
# kalin : kalin
# sampah : sampah
# akmalbariq : akmalbariq
# markadenson : markadenson
# qodoxngorex : qodoxngorex
# sahal : sahal
# as : as
# kpk : kpk
# kgk : kgk
# pandang : pandang
# menteri : menteri
# ajh : ajh
# ciduk : ciduk
# andrydevry : andrydevry
# widiast46559533 : widiast46559533
# dennysiregar7 : dennysiregar7
# ri : ri
# novel : novel
# doang : doang
# curigai : curiga
# gabisa : gabisa
# nangkep : nangkep
# mikirnya : mikirnya
# terbukti : bukti
# mah : mah
# njr : njr
# antojagad3 : antojagad3
# nanyo : nanyo
# 5 : 5
# pembela : bela
# rata2 : rata2
# org2 : org2
# nerima : nerima
# kenyataan : nyata
# penghargaannya : harga
# hasil : hasil
# program : program
# jokowi : jokowi
# wkwkwkwk : wkwkwkwk
# gamalu : gamalu
# klaim2 : klaim2
# orangpi46254193 : orangpi46254193
# loe : loe
# kate : kate
# dimakan : makan
# sekolah : sekolah
# dikatain : dikatain
# sat : sat
# pinayungan : payung
# mr : mr
# cosanostra : cosanostra
# songong : songong
# jgo : jgo
# itung2 : itung2
# klompoknya : klompoknya
# muchlis : muchlis
# ar : ar
# kek : kek
# aga : aga
# komen : komen
# petugas : tugas
# ngeswab : ngeswab
# masker : masker
# swab : swab
# conge : conge
# kuping : kuping
# anakodok2009 : anakodok2009
# hellosyalala : hellosyalala
# ainunnajib : ainunnajib
# hahahaha : hahahaha
# pantesan : pantesan
# dapet : dapet
# pemimpin : pimpin
# modelan : model
# wisma : wisma
# atlet : atlet
# juha : juha
# darurat : darurat
# hotel : hotel
# barak : barak
# tentara : tentara
# rumah : rumah
# dinas : dinas
# pasien : pasien
# covidnya : covidnya
# wajib : wajib
# protokol : protokol
# 2sznxvjxm2 : 2sznxvjxm2
# memanfaatkan : manfaat
# pde : pde
# islam : islam
# dijadikan : jadi
# politik : politik
# sebelah : belah
# bhinneka : bhinneka
# tunggal : tunggal
# ika : ika
# negara : negara
# bro : bro
# dprddkijakarta : dprddkijakarta
# uang : uang
# pdi : pdi
# perjuangan : juang
# diam : diam
# prasetyoedi : prasetyoedi
# dlm : dlm
# dng : dng
# basuki : basuki
# btp : btp
# serang : serang
# habis : habis
# habisan : habis
# menkopolhukam : menkopolhukam
# pdhl : pdhl
# berkuasa : kuasa
# level : level
# pusat : pusat
# dilangkahi : langkah
# sekelas : kelas
# bawa : bawa
# negri : negri
# banget : banget
# logikanya : logika
# qitn06oigm : qitn06oigm
# adearmando1 : adearmando1
# ketawain : ketawain
# anak : anak
# stm : stm
# cuk : cuk
# bohong : bohong
# positif : positif
# bilangnya : bilang
# negatif : negatif
# ntu : ntu
# namenye : namenye
# jangan2 : jangan2
# sadar : sadar
# goodbener : goodbener
# c19 : c19
# makasih : makasih
# mudinarl : mudinarl
# purba : purba
# desmo : desmo
# prabowo : prabowo
# larinya : lari
# bahas : bahas
# kelompok : kelompok
# provokator : provokator
# wajar : wajar
# sih : sih
# natural : natural
# klau : klau
# deni : den
# mantaap : mantaap
# bilang : bilang
# pdip : pdip
# loyo : loyo
# kbyakan : kbyakan
# kbijakan : kbijakan
# membeoo : membeoo
# imadya : imadya
# ttg : ttg
# formula : formula
# kritisx : kritisx
# andotulong : andotulong
# kamalbukankemal : kamalbukankemal
# intoleransi : intoleransi
# bani : bani
# togog : togog
# penasaran : penasaran
# comberan : comberan
# keok : keok
# jualan : jual
# ayat : ayat
# mayat : mayat
# cuman : cuman
# sulut : sulut
# ntt : ntt
# gubernurnya : gubernur
# muslim : muslim
# nyinyir : nyinyir
# kayak : kayak
# ulitrisnani : ulitrisnani
# psi : psi
# julidin : julidin
# nyinyirin : nyinyirin
# berhasil : hasil
# julid : julid
# kliatan : kliatan
# andy : andy
# budiman : budiman
# seputar : putar
# pengikutnya : ikut
# matian : mati
# menjatuhkan : jatuh
# terliha : terliha
# amatiran : amatir
# adhydault : adhydault
# halah : halah
# hti : hti
# manfaatin : manfaatin
# ikur12 : ikur12
# iwan : iwan
# 03 : 03
# nakula : nakula
# canputtt : canputtt
# haniafiair : haniafiair
# firzahusain : firzahusain
# nadjib : nadjib
# 178 : 178
# ewidi79 : ewidi79
# warsanawoko : warsanawoko
# vita : vita
# avp : avp
# nikilo2512 : nikilo2512
# pro : pro
# pilpres : pilpres
# 2024 : 2024
# poros : poros
# rizieq : rizieq
# tersandung : sandung
# prokes : prokes
# pusaran : pusar
# puting : puting
# beliung : beliung
# triliun : triliun
# subianto : subianto
# dicapit : capit
# benur : benur
# lobster : lobster
# minumlah : minum
# jamu : jamu
# maju : maju
# sembah : sembah
# muja : muja
# baliho : baliho
# bkn : bkn
# sirik : sirik
# bolakbalikkata : bolakbalikkata
# dadszzjioy : dadszzjioy
# tolakbigotnkri : tolakbigotnkri
# aryprasetyo85 : aryprasetyo85
# radenano : radenano
# kesittt : kesittt
# ririjreeng : ririjreeng
# rlanang : rlanang
# gitariiii : gitariiii
# paltiwest : paltiwest
# miduk17 : miduk17
# kenhans03 : kenhans03
# sangkutin : sangkutin
# cari : cari
# noh : noh
# harun : harun
# masiku : mas
# m : m
# asmara1701 : asmara1701
# democrazy : democrazy
# gengsi : gengsi
# hahahahaha : hahahahaha
# k : k
# h : h
# a : a
# i : i
# r : r
# t3htjemplung : t3htjemplung
# orang2 : orang2
# dungu : dungu
# menyalahkan : salah
# misi : misi
# kepentingan : penting
# jegal : jegal
# plus : plus
# plusnya : plus
# nakes : nakes
# kinerja : kerja
# pemprov : pemprov
# lsg : lsg
# dbls : dbls
# buzzer : buzzer
# hidup : hidup
# kebanyakan : banyak
# ijazah : ijazah
# dbanding : dbanding
# inget : inget
# bejibun : bejibun
# nih : nih
# arteria : arteria
# muhamma87797215 : muhamma87797215
# jurus : jurus
# jebak : jebak
# sgt : sgt
# dirugikan : rugi
# pempus : pempus
# biarkan : biar
# melanggar : langgar
# komoditi : komoditi
# rugi : rugi
# petamburan : tambur
# diselamatkan : selamat
# kebodohan : bodoh
# mrk : mrk
# msaid : msaid
# didu : didu
# wkwkwkw : wkwkwkw
# ngelawan : ngelawan
# pens : pens
# merarau : merarau
# temlen : temlen
# ngatain : ngatain
# goblok : goblok
# bijimana : bijimana
# isi : isi
# otaknya : otak
# redywanjames : redywanjames
# yeee : yeee
# gara2 : gara2
# ip2 : ip2
# corona : corona
# masuk : masuk
# indonesia : indonesia
# waspada : waspada
# masukin : masukin
# tka : tka
# cina : cina
# udh : udh
# parah : parah
# penyakit : sakit
# menyebar : sebar
# nyalahin : nyalahin
# a1yt0vfd7h : a1yt0vfd7h
# tempodotco : tempodotco
# keliatan : liat
# rezim : rezim
# panik : panik
# mantau : mantau
# asenkaldo : asenkaldo
# anda60986081 : anda60986081
# kritisi : kritisi
# statement : statement
# terkait : kait
# imbas : imbas
# psbb : psbb
# angka : angka
# kemiskinan : miskin
# kebijakan : bijak
# populis : populis
# blunder : blunder
# ambil : ambil
# tsb : tsb
# bahasa : bahasa
# sederhananya : sederhana
# bunuh : bunuh
# galihholic : galihholic
# 23 : 23
# abdulka56150343 : abdulka56150343
# enggalpmt : enggalpmt
# bong : bong
# darah : darah
# arabnya : arab
# emangnya : emang
# lahir : lahir
# mekkah : mek
# segitunya : segitunya
# hrrygnwn : hrrygnwn
# kiputkingg : kiputkingg
# nilotica2 : nilotica2
# tni : tni
# langkah : langkah
# gakbener : gakbener
# wkwk : wkwk
# sowan : sowan
# menertibkan : tertib
# satpol : satpol
# buah : buah
# fisabillah : fisabillah
# cerdas : cerdas
# smart : smart
# sederhana : sederhana
# davidtdmx : davidtdmx
# bytriantono : bytriantono
# na : na
# dirs : dirs
# buku : buku
# kepanasan : panas
# dibilang : bilang
# aniesnya : aniesnya
# oia : oia
# jarang : jarang
# walikota : walikota
# periode : periode
# grafik : grafik
# neh : neh
# qvlia1tpsh : qvlia1tpsh
# dinaslhdki : dinaslhdki
# yaelah : yaelah
# dengki : dengki
# gitu : gitu
# pikiran : pikir
# jernih : jernih
# napa : napa
# pesan : pesan
# mengisi : isi
# luang : luang
# membaca : baca
# ilmu : ilmu
# ampun : ampun
# daddydigitalzzz : daddydigitalzzz
# mutyaltfn : mutyaltfn
# photo : photo
# judul : judul
# utk : utk
# menyindir : sindir
# baper : baper
# sukses : sukses
# gag : gag
# mustahil : mustahil
# bodoh : bodoh
# kepancing : pancing
# mantan : mantan
# demokrat : demokrat
# menangin : menangin
# pemilih : pilih
# numpek : numpek
# blek : blek
# ahy : ahy
# mikih : mikih
# yunartowijaya : yunartowijaya
# faham : faham
# foto : foto
# belaga : belaga
# fenomena : fenomena
# demokrasi : demokrasi
# dibunuh : bunuh
# perlahan : perlahan
# rifqizuhdi281 : rifqizuhdi281
# fpi87932287 : fpi87932287
# sigitwid : sigitwid
# milliyya : milliyya
# dkijakarta : dkijakarta
# dibahas : bahas
# ngomongin : ngomongin
# berita : berita
# 2015 : 2015
# piara : piara
# ngga : ngga
# domba : domba
# kawan2 : kawan2
# pecah : pecah
# belah : belah
# provokasi : provokasi
# gstvxsqovu : gstvxsqovu
# n4t4li3 : n4t4li3
# cr1st1 : cr1st1
# amggap : amggap
# belajar : ajar
# sejarah : sejarah
# cabut : cabut
# pribimi : pribimi
# kog : kog
# sok : sok
# ngaku : ngaku
# femgerin : femgerin
# senyum : senyum
# nhetawain : nhetawain
# anis : anis
# benernya : benernya
# absolutia : absolutia
# riziq : riziq
# bertaburan : tabur
# 2020 : 2020
# cont : cont
# cukml4gfkg : cukml4gfkg
# intruksimendagri : intruksimendagri
# kaum : kaum
# bin : bin
# belegug : belegug
# abu : abu
# janda : janda
# goblog : goblog
# gorong : gorong
# dajjal : dajjal
# fitnah : fitnah
# kamibersamahrsdananies : kamibersamahrsdananies
# a9okwyre3l : a9okwyre3l
# irdatnh : irdatnh
# sanguan0709 : sanguan0709
# sebenernya : sebenernya
# gua : gua
# cil : cil
# kang : kang
# emil : emil
# periksa : periksa
# polisi : polisi
# congor : congor
# diem : diem
# bae : bae
# akting : akting
# sakit : sakit
# ngejilat : ngejilat
# lubang : lubang
# pantat : pantat
# habib : habib
# kelakuan : laku
# kyk : kyk
# orgil : orgil
# haikal : haikal
# hassan : hassan
# kmrn2 : kmrn2
# kemana : mana
# lihat : lihat
# ndk : ndk
# kepemimpinan : pimpin
# pny : pny
# banggakan : bangga
# hny : hny
# melanjutkan : lanjut
# merusak : rusak
# bisanya : bisa
# matanya : mata
# eloo : eloo
# pasang : pasang
# hnurwahid : hnurwahid
# tijabar : tijabar
# lama2 : lama2
# ikutan : ikut
# dipanggil : panggil
# polda : polda
# metro : metro
# jabar : jabar
# bareskrim : bareskrim
# manggil : manggil
# senjautama18 : senjautama18
# jnrhrd : jnrhrd
# 2014 : 2014
# kalender : kalender
# rmh : rmh
# nyapres : nyapres
# kebiadaban : biadab
# kolam : kolam
# jan : jan
# dibawa : bawa
# darat : darat
# nulis : nulis
# panjang2 : panjang2
# nyambung : nyambung
# kodok : kodok
# bmttthh : bmttthh
# adriansyahyasin : adriansyahyasin
# buruk : buruk
# sampe : sampe
# ketua2nye : ketua2nye
# nye : nye
# complain : complain
# bendera : bendera
# aje : aje
# dppfpi : dppfpi
# cebonk : cebonk
# kejang2 : kejang2
# fotonya : foto
# nyolong : nyolong
# maklum : maklum
# cebongers : cebongers
# hhh : hhh
# dpt : dpt
# bayar : bayar
# juta : juta
# prestasinya : prestasi
# timnya : tim
# batalkanomnibusuklaw : batalkanomnibusuklaw
# fjdu0aagxj : fjdu0aagxj
# triwul82 : triwul82
# adlh : adlh
# penguasa : kuasa
# sesungguhnya : sungguh
# jalan : jalan
# milik : milik
# rakyatpun : rakyat
# dikuasai : asai
# melepaskan : lepas
# mengayomi : ayom
# melindungi : lindung
# warganya : warga
# warga : warga
# lbh : lbh
# mengatur : atur
# enczpyv65x : enczpyv65x
# mohamadmaskur5 : mohamadmaskur5
# yaniarsim : yaniarsim
# karyanya : karya
# dinikmati : nikmat
# masyarakat : masyarakat
# basis : basis
# frontal : frontal
# tebet : tebet
# kampung : kampung
# pulo : pulo
# puaskah : puas
# postingan : postingan
# dihapus : hapus
# masing2 : masing2
# kota : kota
# emosi : emosi
# super : super
# orgnya : orgnya
# over : over
# pede : pede
# aturan : atur
# brsinergi : brsinergi
# polkis : polkis
# karantina : karantina
# diterapkan : terap
# cetefotber : cetefotber
# notaslimboy : notaslimboy
# mengahalangi : mengahalangi
# total : total
# membuka : buka
# airport : airport
# diskon : diskon
# tiket : tiket
# menimbulkan : timbul
# keramaian : ramai
# baretanovri : baretanovri
# detahida : detahida
# anistrianaanis : anistrianaanis
# jimlyas : jimlyas
# gabung : gabung
# anaklolina2 : anaklolina2
# galih : galih
# akek : akek
# nyamain : nyamain
# sejajarin : sejajarin
# awam : awam
# sayang : sayang
# kadang : kadang
# gelar : gelar
# bbmrachel : bbmrachel
# bisma : bisma
# haryana : haryana
# dalang : dalang
# demonya : demo
# ditangkepin : ditangkepin
# gituloh : gituloh
# jumhur : jumhur
# dll : dll
# kerumunan : kerumun
# nikahan : nikah
# dalangnya : dalang
# rijiek : rijiek
# pembiaran : biar
# masak : masak
# ribuan : ribu
# dipanggilin : dipanggilin
# satu2 : satu2
# abisin : abisin
# penyidiknya : sidik
# mayoritas : mayoritas
# bsinuhajie : bsinuhajie
# boecharikarim : boecharikarim
# spt : spt
# kenyang : kenyang
# laper : laper
# ngamuk : ngamuk
# liat : liat
# wkt : wkt
# jaman : jaman
# ngamukan : ngamukan
# anteng : anteng
# pade : pade
# moh : moh
# effendie : effendie
# fahrihamzah : fahrihamzah
# lha : lha
# knpa : knpa
# pesawat : pesawat
# wilayah : wilayah
# ngizinin : ngizinin
# kuasa : kuasa
# mencegah : cegah
# isinya : isi
# dikarantina : karantina
# nanggung : nanggung
# wkwkkw : wkwkkw
# bgt : bgt
# tumbal : tumbal
# kmarin : kmarin
# acara : acara
# munculnya : muncul
# klaster : klaster
# keluarga : keluarga
# pascalibur : pascalibur
# memper : memper
# inwz8uuglq : inwz8uuglq
# ar01pangeran : ar01pangeran
# lopesketan : lopesketan
# setuju : tuju
# hajar : hajar
# berlian : berlian
# idris : idris
# fakta : fakta
# pulang : pulang
# kerumunanan : kerumunanan
# bandara : bandara
# bogor : bogor
# kecam : kecam
# bacot : bacot
# gede : gede
# taekkkk : taekkkk
# suddend01990860 : suddend01990860
# galihontoseno : galihontoseno
# jakprogroup : jakprogroup
# persija : persija
# infokomjakmania : infokomjakmania
# jakintstadium : jakintstadium
# dihujat : hujat
# pelanggarannya : langgar
# ganjar : ganjar
# akalnya : akal
# idamancapres : idamancapres
# timeline : timeline
# bnpb : bnpb
# kena : kena
# gila : gila
# jann40260260 : jann40260260
# za : za
# vitri : vitri
# musniumar : musniumar
# dukungan : dukung
# ente : ente
# kritik : kritik
# mang : mang
# kampanye : kampanye
# kumpulin : kumpulin
# larang : larang
# siape : siape
# perintah : perintah
# jongkok : jongkok
# hatinya : hati
# demo : demo
# diiyain : diiyain
# akad : akad
# nikah : nikah
# sohib : sohib
# amburadul : amburadul
# e2kmqork8i : e2kmqork8i
# wkkkkkkk : wkkkkkkk
# ngerjain : ngerjain
# buzer : buzer
# buser : buser
# jazililmustofa1 : jazililmustofa1
# hadiantobroer : hadiantobroer
# permadiaktivis1 : permadiaktivis1
# nikitamirzani : nikitamirzani
# ustadzmaaher : ustadzmaaher
# sengsara : sengsara
# lgi : lgi
# jdi : jdi
# diusir : usir
# nnti : nnti
# afrika : afrika
# sprti : sprti
# cynthiaellenna : cynthiaellenna
# iw4n : iw4n
# kurni4w4n : kurni4w4n
# iri : iri
# keberhasilan : hasil
# memimpin : pimpin
# buzzerrp : buzzerrp
# abdulka92071154 : abdulka92071154
# munafik : munafik
# dibiarkan : biar
# jr : jr
# kw19 : kw19
# ali : ali
# alisalim98 : alisalim98
# bngun : bngun
# krl : krl
# jalanin : jalanin
# busway : busway
# ngebangun : ngebangun
# mrt : mrt
# kenape : kenape
# bangga : bangga
# maruk : maruk
# bos : bos
# mrsrachelin : mrsrachelin
# pengecut : kecut
# cakklowor1 : cakklowor1
# sensus : sensus
# 888 : 888
# lptq : lptq
# heran : heran
# kebalikannya : balik
# dri : dri
# fira : fira
# sakit2an : sakit2an
# idiot : idiot
# buka : buka
# dikit : dikit
# dipecat : pecat
# rekomendasi : rekomendasi
# ompung : ompung
# kumis : kumis
# bondol : bondol
# potensi : potensi
# menakutkan : takut
# di2019 : di2019
# tko : tko
# ngadepin : ngadepin
# wowo : wowo
# blingsatan : blingsatan
# ngeluarin : ngeluarin
# energi : energi
# ngos2an : ngos2an
# wokwokwok : wokwokwok
# u : u
# y : y
# o : o
# tukang : tukang
# pemakamannya : makam
# urusin : urusin
# bijak : bijak
# 3zaf6adqtz : 3zaf6adqtz
# jumpai : jumpa
# membawa : bawa
# caplin : caplin
# pilkada : pilkada
# menjumpai : jumpa
# deportasi : deportasi
# 4v99kuv3gb : 4v99kuv3gb
# hapeproperti : hapeproperti
# mochamadarip : mochamadarip
# cieee : cieee
# nyaaa : nyaaa
# ngebandingin : ngebandingin
# vumanult : vumanult
# jamban : jamban
# kagak : kagak
# ryanmbojas : ryanmbojas
# janji : janji
# christien : christien
# meity : meity
# anisbaswedan : anisbaswedan
# aslinya : asli
# konteks : konteks
# pengangguran : anggur
# blok : blok
# koordinasi : koordinasi
# jng : jng
# salahin : salahin
# anjing : anjing
# 6ei1ydeau4 : 6ei1ydeau4
# nilain : nilain
# inggris : inggris
# pembantunya : bantu
# wkwkwk : wkwkwk
# bangun : bangun
# atlit : atlit
# ngapain2 : ngapain2
# junisoehardjo : junisoehardjo
# ipk : ipk
# dibawah : bawah
# belepotan : belepotan
# ditanyain : ditanyain
# wartawan : wartawan
# plonga : plonga
# plongo : plongo
# ujung2nya : ujung2nya
# public : public
# speaking : speaking
# teks : teks
# sssttt : sssttt
# kabarnya : kabar
# 100 : 100
# siapa2 : siapa2
# makan : makan
# yaa : yaa
# kebangetan : banget
# pilkadamasihlama : pilkadamasihlama
# ahoksudahtidakbisaditolong : ahoksudahtidakbisaditolong
# terimakasihaniesbaswedan : terimakasihaniesbaswedan
# puluhan : puluh
# massa : massa
# balai : balai
# tuding : tuding
# dalangi : dalang
# buruh : buruh
# mahasiswa : mahasiswa
# maczhpuwjw : maczhpuwjw
# egadjusu : egadjusu
# vivacoid : vivacoid
# iye : iye
# mewakili : wakil
# nyesel : nyesel
# luh : luh
# jawabarat : jawabarat
# jawa : jawa
# kementar : tar
# gue : gue
# robert : robert
# moses2 : moses2
# ikan : ikan
# hiu : hiu
# bau : bau
# tomat : tomat
# amis : amis
# klu : klu
# ngk : ngk
# ajak2 : ajak2
# lawan : lawan
# kelas : kelas
# angge50131004 : angge50131004
# gegara : gegara
# sang : sang
# ahokers : ahokers
# taikers : taikers
# nongol : nongol
# nyerang : nyerang
# membabi : babi
# buta : buta
# gagal : gagal
# mulu : mulu
# follower : follower
# satupun : satu
# banjir : banjir
# rame2 : rame2
# junjungannya : junjung
# dicatut : catut
# catutin : catutin
# diborong : borong
# menyukai : suka
# hati : hati
# akut : akut
# senang : senang
# soebektisoehar5 : soebektisoehar5
# joe : joe
# francmohede : francmohede
# fadjroel : fadjroel
# terkorup : korup
# knp : knp
# smpe : smpe
# skrng : skrng
# dipnnggil : dipnnggil
# dipake : dipake
# blg : blg
# krna : krna
# slma : slma
# non : non
# rosdiananemo : rosdiananemo
# nazi : nazi
# 8303 : 8303
# orangwaras : orangwaras
# d : d
# militan : militan
# ciri : ciri
# khas : khas
# kalah : kalah
# telak : telak
# mlh : mlh
# ngamuk2 : ngamuk2
# nyebong : nyebong
# kumbara14467594 : kumbara14467594
# bosen : bosen
# duduk : duduk
# fasyam7 : fasyam7
# fagtng : fagtng
# heniunique : heniunique
# harum : harum
# ikhlas : ikhlas
# hadeee : hadeee
# susah : susah
# turunan : turun
# dajal : dajal
# pernh : pernh
# adem : adem
# ati : ati
# orng : orng
# bahagia : bahagia
# musni : musni
# umar : umar
# orangnya : orang
# klw : klw
# ditwitter : ditwitter
# upload : upload
# mukanya : muka
# banci : banci
# tampil : tampil
# teel : teel
# ohhh : ohhh
# rektor : rektor
# jabatan : jabat
# jkw : jkw
# bikinin : bikinin
# vivattt : vivattt
# beruntung : untung
# buahnya : buah
# lemah : lemah
# pengawasan : awas
# perusahaan2 : perusahaan2
# terdampak : dampak
# konyol : konyol
# peraturan : atur
# bener2 : bener2
# 4nt1 : 4nt1
# pk1 : pk1
# waras : waras
# benaran : benar
# bicara : bicara
# banjiiii : banjiiii
# ciliwung : ciliwung
# kmpg : kmpg
# mending : mending
# cuci : cuci
# kaki : kaki
# trus : trus
# tidur : tidur
# kompres : kompres
# pinter : pinter
# yagro00 : yagro00
# tofatofa : tofatofa
# berminat : minat
# capres : capres
# cawapres : cawapres
# sandi : sandi
# dicawapresin : dicawapresin
# urus : urus
# budiawan1985 : budiawan1985
# geiszchalifah : geiszchalifah
# selesai : selesai
# dipenjara : penjara
# bpk : bpk
# nurulai14459911 : nurulai14459911
# contoh : contoh
# menjilat : jilat
# apanya : apa
# lupa : lupa
# tengok : tengok
# toyv4h2igi : toyv4h2igi
# wkwkwkwkwk : wkwkwkwkwk
# pikir : pikir
# dibegoin : dibegoin
# akhir2 : akhir2
# keras : keras
# 2orang : 2orang
# bisa2nya : bisa2nya
# sbg : sbg
# sumber : sumber
# klan : klan
# kasta : kasta
# luarbiasa : luarbiasa
# sustainable : sustainable
# transport : transport
# award : award
# sta : sta
# ajang : ajang
# tahunan : tahun
# menilai : nilai
# perbaikan : baik
# mobilitas : mobilitas
# inovasi : inovasi
# sistem : sistem
# transportasi : transportasi
# dinilai : nilai
# terbaik : baik
# bedain : bedain
# permainan : main
# kata2 : kata2
# 53zchhemwa : 53zchhemwa
# surya : surya
# aditya10 : aditya10
# batalin : batalin
# undang2 : undang2
# wkwkw : wkwkw
# maniak : maniak
# bahan : bahan
# memalukan : malu
# ahmadmubarok019 : ahmadmubarok019
# proyek : proyek
# lrt : lrt
# pokoke : pokoke
# slogan : slogan
# sekolam : kolam
# butek : butek
# wkwkwkkw : wkwkwkkw
# klaupun : klaupun
# predikat : predikat
# trbaik : trbaik
# pembangunan : bangun
# trlihat : trlihat
# thn : thn
# objektif : objektif
# taik : taik
# alwan47176872 : alwan47176872
# zumazafin1 : zumazafin1
# bus : bus
# masi : mas
# bagus : bagus
# dibuang : buang
# ir4lolb1jc : ir4lolb1jc
# pekok : kok
# bahlul : bahlul
# pendemo : demo
# bayaran : bayar
# nyuruh : nyuruh
# cukong : cukong
# lengser : lengser
# tentram : tentram
# ape : ape
# loo : loo
# jcolzcgbda : jcolzcgbda
# ituudh : ituudh
# zyezykia : zyezykia
# hahahahha : hahahahha
# bajer : bajer
# gocengan : gocengan
# langsung : langsung
# tante : tante
# keknya : kek
# ketakutan : takut
# video : video
# beredar : edar
# sendirilah : sendiri
# kesian : kesi
# sembarangan : sembarang
# nuding : nuding
# salah : salah
# main : main
# fljm7ytkg8 : fljm7ytkg8
# swaswa : swaswa
# nyari : nyari
# beruang : beruang
# ragunan : ragunan
# ilang : ilang
# koko : koko
# kru : kru
# fkadrun : fkadrun
# kab : kab
# bekasi : bekas
# merugikan : rugi
# bocil : bocil
# triajaaa : triajaaa
# mudeng : mudeng
# faktanya : fakta
# halte : halte
# bunderan : bunderan
# renovasi : renovasi
# pasca : pasca
# bombastis : bombastis
# 65milyard : 65milyard
# blom : blom
# penjelasan : jelas
# transparansinya : transparansi
# sigmahalim : sigmahalim
# jancuk : jancuk
# asu : asu
# koen : koen
# iku : iku
# ancene : ancene
# akui : aku
# ngelesmu : ngelesmu
# mengalahkan : kalah
# wis : wis
# jwb : jwb
# maksud : maksud
# meubel : meubel
# ngibul : ngibul
# anggap : anggap
# kibulin : kibulin
# clear : clear
# mlipir : mlipir
# wynorusia20 : wynorusia20
# malunya : malu
# moon : moon
# back : back
# bolbal : bolbal
# zahrah40291660 : zahrah40291660
# viantytjp : viantytjp
# tagarnya : tagar
# pelan2 : pelan2
# merasakan : rasa
# kebenaran : benar
# tagar : tagar
# muka : muka
# bacanya : baca
# zahra : zahra
# dimdimas24 : dimdimas24
# fyi : fyi
# suci : suci
# hannah18877852 : hannah18877852
# ngeliat : ngeliat
# nyebutin : nyebutin
# pekingers : pekingers
# langung : langung
# ferdinand : ferdinand
# ibnu : ibnu
# chaldun : chaldun
# p3e3gfbf6q : p3e3gfbf6q
# maunya : mau
# slalu : slalu
# panggung : panggung
# pinang : pinang
# bahasanya : bahasa
# berbobot : bobot
# ferdinan : ferdinan
# 4lf4ris : 4lf4ris
# mawisevendry : mawisevendry
# ryandirhamsyah : ryandirhamsyah
# takviri : takviri
# blsan : blsan
# satire : satire
# mknya : mknya
# bls : bls
# bgtu : bgtu
# nyindir : nyindir
# bhs : bhs
# jago : jago
# doank : doank
# ngmng : ngmng
# hestek : hestek
# huruf : huruf
# dicela : cela
# cela : cela
# dihestek : dihestek
# aneh2 : aneh2
# netizen : netizen
# qj4bkzxgl9 : qj4bkzxgl9
# haram : haram
# najis : najis
# mahluk : mahluk
# jimmysimbar4 : jimmysimbar4
# akuanak95595151 : akuanak95595151
# tololgoblog : tololgoblog
# tinggal : tinggal
# dipapua : dipapua
# gubnur : gubnur
# fraksi : fraksi
# moncong : moncong
# putih : putih
# pimpin : pimpin
# raih : raih
# bnyak : bnyak
# oon : oon
# ubun2 : ubun2
# diperoleh : oleh
# sso : sso
# bukti : bukti
# mengikuti : ikut
# pendidikan : didik
# kesimpulannya : simpul
# pintar : pintar
# mengambil : ambil
# keputusan : putus
# rawayan212 : rawayan212
# kaga : kaga
# ditepati : tepat
# dilis : dil
# persatu : satu
# janjinya : janji
# chek : chek
# imaginasi : imaginasi
# tnp : tnp
# mmg : mmg
# mudah : mudah
# berhadapan : hadap
# otakdikit : otakdikit
# pecundang : cundang
# dewantara : dewantara
# adjie : adjie
# bangariza : bangariza
# tenang : tenang
# ohowwwwhhhh : ohowwwwhhhh
# wan : wan
# abut : abut
# jokodok : jokodok
# bint4ng211 : bint4ng211
# retno : retno
# setyowat : setyowat
# berilmu : beril
# hitung : hitung
# ilmunya : ilmu
# nasi : nasi
# bungkus : bungkus
# ketangkep : ketangkep
# berurusan : urus
# cair : cair
# hudattamini : hudattamini
# dimata : mata
# baginda : baginda
# smua : smua
# rab : rab
# singkatannya : singkat
# rancangan : rancang
# bebas : bebas
# blaasssss : blaasssss
# narkosun : narkosun
# binamargadki : binamargadki
# tamanhutandki : tamanhutandki
# pt : pt
# transjakarta : transjakarta
# dishubdki : dishubdki
# humasjakfire : humasjakfire
# dinassdajakarta : dinassdajakarta
# mrtjakarta : mrtjakarta
# pribahasa : pribahasa
# dipamerin : dipamerin
# syarat : syarat
# buzzerp : buzzerp
# kayanya : kaya
# sosmed : sosmed
# menulis : tulis
# benci : benci
# njir : njir
# teryata : teryata
# ngebolehin : ngebolehin
# bakar : bakar
# haltenya : halte
# udang : udang
# maki2 : maki2
# tong : tong
# raynoldsurbakti : raynoldsurbakti
# r0t17yuyda : r0t17yuyda
# love : love
# ag4ever : ag4ever
# apbd : apbd
# ngutang : ngutang
# berpikiran : pikir
# syukurlah : syukur
# tgupp : tgupp
# berasa : asa
# ironman : ironman
# ustadtengkuzul : ustadtengkuzul
# jagoan : jago
# zul : zul
# sprt : sprt
# nvinwnzzwd : nvinwnzzwd
# negasin : negasin
# terusan : terus
# nungguin : nungguin
# engga : engga
# wasting : wasting
# time : time
# really : really
# but : but
# more : more
# bahagiaku : bahagia
# 3tenuk : 3tenuk
# mamiedcool34 : mamiedcool34
# mainnya : main
# gih : gih
# merapikan : rapi
# fasilitas : fasilitas
# publil : publil
# dirusak : rusak
# angkanya : angka
# ribut : ribut
# gelontorin : gelontorin
# jiwasraya : jiwasraya
# dirampok : rampok
# dikasih : kasih
# ono : ono
# planga : planga
# rismaayunur : rismaayunur
# ardymbalembout1 : ardymbalembout1
# bujug : bujug
# membela : bela
# bangsa : bangsa
# ketinggian : tinggi
# halunya : halunya
# kuntiiiii : kuntiiiii
# begono : begono
# kmrn : kmrn
# protes2 : protes2
# tnyt : tnyt
# jawabannya : jawab
# anakkolong : anakkolong
# wiliam : wiliam
# runturambi : runturambi
# suporter : suporter
# fanatik : fanatik
# nama : nama
# keren : keren
# ditunjang : tunjang
# memadai : pada
# pepatah : pepatah
# mozambiq : mozambiq
# busung : busung
# nalar : nalar
# penipu : tipu
# mengacungkan : acung
# jempol : jempol
# untuknya : untuk
# berprestasi : prestasi
# kobe : kobe
# komunitas : komunitas
# wkkkkkk : wkkkkkk
# kakak : kakak
# pembinanya : bina
# zoo : zoo
# lfikafir : lfikafir
# gubernr : gubernr
# katua : katua
# appsi : appsi
# asosiasi : asosiasi
# propinsi : propinsi
# aneis : aneis
# pnya : pnya
# wewenang : wewenang
# mngatur : mngatur
# sngaja : sngaja
# ditonton : tonton
# wm9nm4ikqq : wm9nm4ikqq
# w : w
# mentang2 : mentang2
# gratis : gratis
# borong : borong
# boro2 : boro2
# lanjutkan : lanjut
# druun : druun
# berat : berat
# sanggup : sanggup
# sandiaga : sandiaga
# uno : uno
# seberang : seberang
# keretasirkus : keretasirkus
# banjirnya : banjir
# karna : karna
# pohon : pohon
# tebang : tebang
# kapal : kapal
# nabi : nabi
# nuh : nuh
# je : je
# ly : ly
# payah : payah
# mak : mak
# sekolahin : sekolahin
# dengkul : dengkul
# setan : setan
# bali : bal
# sucirhmds : sucirhmds
# sheknowshoney : sheknowshoney
# oramg : oramg
# kacau : kacau
# tggal : tggal
# cebong2 : cebong2
# sekjen : sekjen
# pbb : pbb
# gayakin : gayakin
# asli : asli
# cadar : cadar
# bgtbgtbgt : bgtbgtbgt
# tweet : tweet
# memperkeruh : keruh
# suasana : suasana
# hina : hina
# sindir2 : sindir2
# sumpah : sumpah
# dpr : dpr
# kabur : kabur
# a1yl8dlihz : a1yl8dlihz
# nurtono8 : nurtono8
# ngebuzzeein : ngebuzzeein
# cilaka : cilaka
# penghambat : hambat
# investasi : investasi
# birokrasi : birokrasi
# digencet : gencet
# males : males
# debat : debat
# gond : gond
# rong : rong
# syng : syng
# nganu2 : nganu2
# puji : puji
# rangorang : rangorang
# fer : fer
# dikit2 : dikit2
# squidwardd : squidwardd
# bambang : bambang
# turun : turun
# nenangin : nenangin
# gabakal : gabakal
# tbtb : tbtb
# nnya : nnya
# pliara : pliara
# panggil : panggil
# liatin : liatin
# itik : itik
# diplihara : diplihara
# kewajiban : wajib
# ngawasin : ngawasin
# daherahnya : daherahnya
# aline : aline
# yoana : yoana
# tan : tan
# penyusunan : susun
# jadwal : jadwal
# terjadwal : jadwal
# jual : jual
# cocot : cocot
# amies : amies
# memancing : pancing
# air : air
# keruh : keruh
# ujung : ujung
# ujungnya : ujung
# salahamin : salahamin
# fitnahan : fitnah
# 25m : 25m
# boy : boy
# hutang : hutang
# aldidoeet : aldidoeet
# membedakan : beda
# rakyatnya : rakyat
# fulus : fulus
# lumayan : lumayan
# miliar : miliar
# oktayudhi : oktayudhi
# dicari : cari
# dprnya : dprnya
# hadehhh : hadehhh
# mass : mass
# pst : pst
# kritis : kritis
# ipnswm9y4f : ipnswm9y4f
# ekyrmdhy : ekyrmdhy
# arab : arab
# kalimantan : kalimantan
# ketemuibpara : ketemuibpara
# tumuin : tumuin
# rusak : rusak
# cuan : cuan
# ntijamet : ntijamet
# cupu : cupu
# wulan87718522 : wulan87718522
# noerwhyd : noerwhyd
# anomharya : anomharya
# el : el
# ahmadripani : ahmadripani
# ulil : ulil
# akun : akun
# netes : netes
# hebatnya : hebat
# apa2nya : apa2nya
# ortu : ortu
# nyekolahin : nyekolahin
# mahal2 : mahal2
# hasilnya : hasil
# bedanya : beda
# sama2 : sama2
# peler : peler
# kuda : kuda
# gasekalian : gasekalian
# sutiyoso : sutiyoso
# ancur : ancur
# penjarahan : jarah
# trauma : trauma
# mendingan : mending
# rendeman : rendeman
# ngapain : ngapain
# nge : nge
# twitin : twitin
# make : make
# your : your
# degree : degree
# useful : useful
# not : not
# useless : useless
# woi : woi
# tusuk : tusuk
# sate : sate
# jagan : jagan
# bertanggung : tanggung
# ngurus : ngurus
# seenggaknya : enggak
# tuan : tuan
# nyali : nyali
# menemui : temu
# demonstran : demonstran
# ridwan : ridwan
# kamil : kamil
# 6iojx2heq2 : 6iojx2heq2
# hilmi28 : hilmi28
# wow : wow
# gaada : gaada
# haha : haha
# yaaa : yaaa
# sehat : sehat
# tuhan : tuhan
# berpikir : pikir
# johanslo1 : johanslo1
# anggota : anggota
# dewan : dewan
# pdipeh : pdipeh
# dianggap : anggap
# pamer : pamer
# andil : andil
# regar : regar
# oposisi : oposisi
# kafir : kafir
# kemarahan : marah
# allah : allah
# teguran : tegur
# salahkan : salah
# dibenci : benci
# bandang : bandang
# adibabahira : adibabahira
# kakekhalal : kakekhalal
# analisa : analisa
# adl : adl
# asumsi : asumsi
# bhw : bhw
# beralih : alih
# pikirnya : pikir
# gobloknya : goblok
# bersih : bersih
# irisan : iris
# ideologis : ideologis
# hendryx691 : hendryx691
# maspiyu4 : maspiyu4
# lingkaran : lingkar
# menolak : tolak
# mnjadi : mnjadi
# jujur : jujur
# resikonya : resiko
# hrus : hrus
# dikeluarkan : keluar
# ngiri : ngiri
# kangsemproel : kangsemproel
# terselubung : selubung
# habisi : habis
# next : next
# model : model
# dieksalsa : dieksalsa
# risyadfardy : risyadfardy
# fuhrer : fuhrer
# e100ss : e100ss
# gelandangan : gelandang
# provinsi : provinsi
# khofifah : khofifah
# luntang : luntang
# lantung : lantung
# daerah : daerah
# mreka : mreka
# hub : hub
# banyakny : banyakny
# miskin : miskin
# mulut : mulut
# kasar : kasar
# gelndangan : gelndangan
# ditangkap : tangkap
# prijanti1 : prijanti1
# piliangyoesoef : piliangyoesoef
# buktinya : bukti
# tunggu : tunggu
# mainin : mainin
# doyan : doyan
# hoax : hoax
# giltanto : giltanto
# neilotraidub : neilotraidub
# savage : savage
# trakhir : trakhir
# tua : tua
# lahirin : lahirin
# ituh : ituh
# kenal : kenal
# topik : topik
# apapun : apa
# alihkan : alih
# mmbagikan : mmbagikan
# infografis : infografis
# murahan : murah
# berulang : ulang
# data : data
# reliable : reliable
# sdg : sdg
# mrendahkan : mrendahkan
# dibela : bela
# mnganggap : mnganggap
# ngara : ngara
# setara : tara
# iya : iya
# mba : mba
# ras : ras
# anyway : anyway
# angkat : angkat
# syg : syg
# eek : eek
# dibayar : bayar
# pajak : pajak
# dsr : dsr
# bangke : bangke
# teddygusnaidi : teddygusnaidi
# pergaulan : gaul
# pakar : pakar
# disitu : situ
# mainan : main
# berkomentar : komentar
# menyerang : serang
# sesuai : sesuai
# pesanan : pesan
# kesalahan : salah
# mutkak : mutkak
# peragu : ragu
# dibolak : bolak
# pikirannya : pikir
# penanggung : tanggung
# semoga : moga
# cepat : cepat
# sembuh : sembuh
# perbanyak : banyak
# zikir : zikir
# istighfar : istighfar
# dilanjutkan : lanjut
# senen : senen
# 2021 : 2021
# diresmikan : resmi
# tmpt : tmpt
# flyover : flyover
# tapal : tapal
# lenteng : lenteng
# agung : agung
# tanjung : tanjung
# barat : barat
# sma : sma
# jaksel : jaksel
# bersuaralah : suara
# pernyataan : nyata
# komentator : komentator
# dipelihara : pelihara
# coretsajadeh : coretsajadeh
# anna : anna
# masue3 : masue3
# senyumin : senyumin
# ketipu : tipu
# akal2an : akal2an
# busuk : busuk
# politisi : politis
# menurutku : turut
# hinduantahir : hinduantahir
# memuja : puja
# mimpi : mimpi
# siang : siang
# bolong : bolong
# halu : halu
# penyidikan : sidi
# felix : felix
# siauw : siauw
# bosennya : bosennya
# percaya : percaya
# sepdhan1 : sepdhan1
# chahrulirawan : chahrulirawan
# dongok : dongok
# sungguh : sungguh
# september : september
# 19 : 19
# order : order
# peti : peti
# lipat : lipat
# dnjq9frkhl : dnjq9frkhl
# korang : korang
# xbyftaayr3 : xbyftaayr3
# harua : harua
# foto2 : foto2
# ditempat : tempat
# sinetron : sinetron
# detikinet : detikinet
# contohnya : contoh
# nyok : nyok
# kumpul : kumpul
# barisan : baris
# bareng : bareng
# sono : sono
# taat : taat
# isoman : isoman
# rqlhqwruyc : rqlhqwruyc
# diisolasi : isolasi
# lantaran : lantar
# terpapar : papar
# virus : virus
# istri : istri
# fery : fery
# farhati : farhati
# anaknya : anak
# menjenguk : jenguk
# muhsambodo : muhsambodo
# ferdyanalf3 : ferdyanalf3
# jumawa : jumawa
# hiburan : hibur
# malam : malam
# kamis : kamis
# menghibur : hibur
# mbok : mbok
# yao : yao
# dik : dik
# ridwankamil : ridwankamil
# sorot : sorot
# mencari : cari
# mush4r : mush4r
# ben : ben
# muhyiddin : muhyiddin
# tampang : tampang
# paulus : paulus
# willy : willy
# bohonglah : bohong
# spontan : spontan
# diejek : ejek
# dibalik : balik
# lgian : lgian
# ajalah : aja
# ngelesnya : ngelesnya
# guru : guru
# trmsk : trmsk
# ind : ind
# konotasinya : konotasi
# tokoh : tokoh
# manegement : manegement
# emosinya : emosi
# jauhh : jauhh
# tarik : tarik
# rem : rem
# buzzerp2 : buzzerp2
# koar2 : koar2
# macem2 : macem2
# layu : layu
# patuhi : patuh
# maha : maha
# firmannya : firman
# dv2hpynz9x : dv2hpynz9x
# jumianto : jumianto
# rk : rk
# curut : curut
# perusak : usak
# memilih : pilih
# ranah : ranah
# syahwat : syahwat
# kekuasaan : kuasa
# penjahat : jahat
# kelakuannya : laku
# bersebrangan : bersebrangan
# aneh : aneh
# gamau : gamau
# bising : bising
# twitter : twitter
# rerata : rerata
# sarjana : sarjana
# doktor : doktor
# sekian : sekian
# nampak : nampak
# sisanya : sisa
# sorak : sorak
# udeh : udeh
# nasib : nasib
# gobernoor : gobernoor
# licik : licik
# seiman : iman
# pelajaran : ajar
# kapan2 : kapan2
# carilah : cari
# cakap : cakap
# wcckrq0iyp : wcckrq0iyp
# mohmahfudmd : mohmahfudmd
# polhukamri : polhukamri
# koar : koar
# bawak : bawak
# tugas : tugas
# ucapan : ucap
# belasungkawa : belasungkawa
# korban : korban
# kadernya : kader
# kader : kader
# otakmu : otak
# kepala : kepala
# meninggal : tinggal
# tulisan : tulis
# m6zrxnvacb : m6zrxnvacb
# jusuf : jusuf
# kalla : kalla
# ehh : ehh
# dilanggar : langgar
# kebijakannya : bijak
# amnesia : amnesia
# 4y4nkz : 4y4nkz
# hahahahahahaha : hahahahahahaha
# membasmi : basmi
# maling : maling
# 11t : 11t
# pertamina : pertamina
# diembat : embat
# beritajakarta : beritajakarta
# rasyid : rasyid
# sluruh : sluruh
# perangkat : perangkat
# sampai2 : sampai2
# terkagum2 : terkagum2
# knapa : knapa
# hei : hei
# sah : sah
# dipilih : pilih
# lantik : lantik
# tjukan : tjukan
# bswedan : bswedan
# hnya : hnya
# pandai : pandai
# ber : ber
# retorika : retorika
# jahat : jahat
# kumpulnya : kumpul
# kepiawaianya : kepiawaianya
# bnding : bnding
# merubah : rubah
# tatanan : tatanan
# sombong : sombong
# tlh : tlh
# merusaknya : rusak
# putriiyuliani : putriiyuliani
# tatakujiyati : tatakujiyati
# berani : berani
# berstatmen : berstatmen
# tanyain : tanyain
# belom : bom
# jaga : jaga
# nanyain : nanyain
# samudra68752553 : samudra68752553
# istilah : istilah
# memanggil : panggil
# rela : rela
# pant : pant
# dok : dok
# dengar : dengar
# moto : moto
# cam : cam
# enjin : enjin
# bunyi : bunyi
# nak : nak
# angin : angin
# camtu : camtu
# leklok : leklok
# kau : kau
# azwareko : azwareko
# elfaani : elfaani
# bicarakan : bicara
# membahas : bahas
# penyadapan : sadap
# koruptor : koruptor
# ketularan : tular
# nangkap : nangkap
# tvonenews : tvonenews
# kepilih : pilih
# adearmando : adearmando
# kaya : kaya
# hutahaen : hutahaen
# ade : ade
# armando : armando
# mempermasalahkan : masalah
# pov : pov
# buset : buset
# fokus : fokus
# disalah : salah
# artikan : arti
# gaexmudo : gaexmudo
# innoy : innoy
# akuu : akuu
# tutupautoklaf : tutupautoklaf
# paman : paman
# plisss : plisss
# apa2 : apa2
# ajeh : ajeh
# yee : yee
# donal : donal
# trump : trump
# plis : plis
# kedokteran : dokter
# mncari : mncari
# pembenaran : benar
# alasannya : alas
# mmbuat : mmbuat
# tmbh : tmbh
# sbb : sbb
# dkter : dkter
# bliau : bliau
# trsenyum : trsenyum
# terinfeksi : infeksi
# smg : smg
# cepet : cepet
# nmn : nmn
# mksud : mksud
# mkutjlragv : mkutjlragv
# ariefsulaiman02 : ariefsulaiman02
# hahaha : hahaha
# sempit : sempit
# nalarnya : nalar
# loh : loh
# terusin : terusin
# definisinya : definisi
# sisi : sisi
# hrsnya : hrsnya
# cek : cek
# istana : istana
# diumbar : umbar
# 2ekm0xnr5e : 2ekm0xnr5e
# fucekrii : fucekrii
# diahaiiu8 : diahaiiu8
# bagassetywnn : bagassetywnn
# aro : aro
# franky : franky
# kessek : kessek
# mbaknya : mbak
# ngebela : ngebela
# inyongmanise : inyongmanise
# naikin : naikin
# gaji : gaji
# dprd : dprd
# berdo : berdo
# dijauhkan : jauh
# mara : mara
# bahaya : bahaya
# muehehehe : muehehehe
# olietamami : olietamami
# isolasi : isolasi
# mandiri : mandiri
# dinasnya : dinas
# otg : otg
# ketua : ketua
# edi : edi
# prasetio : prasetio
# kenaikan : naik
# membodohkan : bodoh
# tuk : tuk
# bancakan : bancak
# maaf : maaf
# kln : kln
# enak : enak
# royal : royal
# sll : sll
# cin : cin
# cai : cai
# airrtjnvvi : airrtjnvvi
# ixndheso : ixndheso
# pinternya : pinternya
# komentar : komentar
# woy : woy
# please : please
# tbak : tbak
# brpa : brpa
# mjbat : mjbat
# sjk : sjk
# bner : bner
# sepeda : sepeda
# bsa : bsa
# bntu : bntu
# jwab : jwab
# kshan : kshan
# prlu : prlu
# bnyk : bnyk
# pngthuan : pngthuan
# zoepr406 : zoepr406
# putratahuna : putratahuna
# pengamat : amat
# memprediksi : prediksi
# menghormati : hormat
# kesepakatan : sepakat
# gerindra : gerindra
# kabinet : kabinet
# politikus : politikus
# 2wq0uk9fyw : 2wq0uk9fyw
# cengengesan : cengengesan
# disruptivesigna : disruptivesigna
# dasarkita : dasarkita
# loi30st : loi30st
# kh : kh
# notodiputro : notodiputro
# zoelfick : zoelfick
# mna : mna
# dtanjung15 : dtanjung15
# sngat : sngat
# brharap : brharap
# slamet : slamet
# sobri : sobri
# munarwan : munarwan
# tengku : tengku
# menyusul : susul
# sibinatang : sibinatang
# tersiksa : siksa
# sekarat : sekarat
# modarrrr : modarrrr
# mampus : mampus
# caleg : caleg
# zl06vodx97 : zl06vodx97
# alhamdulillah : alhamdulillah
# swt : swt
# prtolongn : prtolongn
# penegak : tegak
# aplgi : aplgi
# sosok : sosok
# dicintai : cinta
# ulama : ulama
# rkyatny : rkyatny
# bathil : bathil
# pra : pra
# pembenci : benci
# kopong : kopong
# shingga : shingga
# smangkin : smangkin
# menampakn : menampakn
# watak : watak
# iblisan : iblis
# rkyat : rkyat
# kasat : kasat
# candraasmara85 : candraasmara85
# koq : koq
# alasan : alas
# ngawur : ngawur
# polll : polll
# ter : ter
# tracking : tracking
# wakil : wakil
# gulseey : gulseey
# hubungannya : hubung
# ummi : ummi
# ariestariico : ariestariico
# pcr : pcr
# rutin : rutin
# bis : bis
# jelas2 : jelas2
# berbuat : buat
# kutil : kutil
# babi : babi
# erikamelfa : erikamelfa
# karma : karma
# tahayul : tahayul
# tahyul : tahyul
# persetan : persetan
# ajaran : ajar
# pelebur : lebur
# xyusltdwms : xyusltdwms
# haaaaaa : haaaaaa
# pantes : pantes
# hancur : hancur
# pikirin : pikirin
# balau : balau
# wagub : wagub
# caper : caper
# nemuin : nemuin
# transisi : transisi
# berjalan : jalan
# dibiarin : dibiarin
# semprul : semprul
# dipeliara : dipeliara
# vjiygyb1dp : vjiygyb1dp
# asrie : asrie
# 12022021 : 12022021
# kelonjotan : kelonjotan
# kontraksi : kontraksi
# pengadu : adu
# radikal : radikal
# intolerant : intolerant
# keberuntungan : untung
# kebodohannya : bodoh
# pembodohan : bodoh
# disebar : sebar
# tim : tim
# dipercaya : percaya
# pengelolaan : kelola
# outputnya : outputnya
# plts : plts
# 2016 : 2016
# dianggarkan : anggar
# sxa792ybac : sxa792ybac
# ia31ajk2zn : ia31ajk2zn
# deddyw : deddyw
# intrik : intrik
# menguasai : kuasa
# paramadina : paramadina
# tepatnya : tepat
# democrazymedia : democrazymedia
# target : target
# rkyt : rkyt
# becik : becik
# ketitik : titik
# olo : olo
# ketoro : toro
# nngecopot : nngecopot
# datangin : datangin
# bib : bib
# brizieq : brizieq
# hadeuh : hadeuh
# ketulungan : ketulungan
# lainnx : lainnx
# coz : coz
# kegiring : giring
# opini : opini
# media : media
# bwat : bwat
# jdie : jdie
# mlm : mlm
# sbaliknx : sbaliknx
# papa : papa
# sie : sie
# cumak : cumak
# apelo : apelo
# maklambeturah : maklambeturah
# tetep : tetep
# berlagak : lagak
# kslimat : kslimat
# ramai : ramai
# dobol : dobol
# dungunya : dungu
# selangit : langit
# normal : normal
# ngumpul : ngumpul
# orgznisasi : orgznisasi
# piaraanya : piaraanya
# sejenisnya : jenis
# picik : picik
# dirumah : rumah
# jngan : jngan
# klh : klh
# brani : brani
# kmbing : kmbing
# hitam : hitam
# spy : spy
# ngak : ngak
# dislhkan : dislhkan
# rizirq : rizirq
# sehrusnya : sehrusnya
# bodooh : bodooh
# uul2yhca7c : uul2yhca7c
# kesel : kesel
# hajat : hajat
# ribet : ribet
# 6cdo2giffu : 6cdo2giffu
# 4rchang3l : 4rchang3l
# sertai : serta
# datanya : data
# mangap : mangap
# berkesan : kesan
# lapor : lapor
# 200jt : 200jt
# dilaporin : dilaporin
# shoping : shoping
# bini : bini
# jatuhin : jatuhin
# konspirasi : konspirasi
# hawa : hawa
# nafsu : nafsu
# gema : gema
# jak : jak
# tangkap : tangkap
# xxl5c2hwei : xxl5c2hwei
# raisyaelbix1 : raisyaelbix1
# dipamerkan : pamer
# persis : persis
# sendysuwanto : sendysuwanto
# ansor : ansor
# noeruzzaman : noeruzzaman
# yelah : yelah
# mgkn : mgkn
# ide : ide
# nasionalisreli2 : nasionalisreli2
# diskusi : diskusi
# bule : bule
# slangkangan : slangkangan
# item : item
# septictank : septictank
# sllu : sllu
# taiker : taiker
# mengkritik : kritik
# sanjung : sanjung
# pekerjaan : kerja
# sulit : sulit
# bejad : bejad
# kritiknya : kritik
# pendukungnya : dukung
# kita2 : kita2
# dzakylove1 : dzakylove1
# rbiasa2aja : rbiasa2aja
# putaran : putar
# ahoker : ahoker
# njelek2in : njelek2in
# akibatnya : akibat
# bongo : bongo
# en538474n6 : en538474n6
# hatersnya : hatersnya
# ngotot : ngotot
# sentimen : sentimen
# emosional : emosional
# dasarnya : dasar
# tertipu : tipu
# rajin : rajin
# semu : semu
# berdebat : debat
# muter2 : muter2
# ngegas : ngegas
# absurd : absurd
# panas2 : panas2
# kat : kat
# luaq : luaq
# rwol9f6muv : rwol9f6muv
# karni : karni
# ilyas : ilyas
# bemper : bemper
# menjebak : jebak
# jwbanx : jwbanx
# dibubarkan : bubar
# karniilyas : karniilyas
# kartikaicha18 : kartikaicha18
# ahli : ahli
# membantu : bantu
# pengambilan : ambil
# bandingkan : banding
# penegakkan : tegak
# kesehatan : sehat
# pembanding : banding
# hutahaean : hutahaean
# cjtj4ev1a5 : cjtj4ev1a5
# svkujvixev : svkujvixev
# kesiangan : siang
# kesubuhan : subuh
# viral : viral
# gara : gara
# bisniscom : bisniscom
# dlu : dlu
# biarpun : biarpun
# iyaa : iyaa
# mengkritisi : kritisi
# kejang : kejang
# quran : quran
# panas : panas
# 2phlvsoa7f : 2phlvsoa7f
# ilctv1 : ilctv1
# seolah2 : seolah2
# urutan : urut
# peristiwa : peristiwa
# utuh : utuh
# cut : cut
# fadli : fadli
# zon : zon
# pengamatnya : amat
# hehehehehe : hehehehehe
# cermati : cermat
# dibaca : baca
# 2002 : 2002
# kurawa : rawa
# ngetop : ngetop
# sensasi : sensasi
# sensasilah : sensasi
# jgnkan : jgnkan
# odading : odading
# suek : suek
# sosiolog : sosiolog
# tren : tren
# cok : cok
# jalur : jalur
# olah : olah
# raga : raga
# dibikin : bikin
# track : track
# bersepeda : sepeda
# trnyta : trnyta
# prof : prof
# memamerkan : pamer
# langkah2nya : langkah2nya
# slnjtnya : slnjtnya
# rachland : rachland
# membocorkan : bocor
# strateginya : strategi
# komik : komik
# yusuf : yusuf
# dumdum : dumdum
# nurut : nurut
# kesadaran : sadar
# terhinfar : terhinfar
# covid19 : covid19
# utm : utm
# sibelajar : sibelajar
# mbojosamsul : mbojosamsul
# mencela : cela
# keep : keep
# calm : calm
# dihina : hina
# berotak : otak
# satunya : satu
# mengganggu : ganggu
# zutkzcc8qu : zutkzcc8qu
# powerxbr88 : powerxbr88
# segi : segi
# kepimpinan : pimpin
# omongannya : omong
# dipegang : pegang
# sore : sore
# keputusannya : putus
# dikoreksi : koreksi
# plogo : plogo
# serius : serius
# umarchelsea75 : umarchelsea75
# selamat : selamat
# menikmati : nikmat
# minggu : minggu
# pagi : pagi
# jam : jam
# seh : seh
# santai : santai
# ketus : ketus
# tsamara : tsamara
# framing : framing
# norak : norak
# jijik : jijik
# ikuti : ikut
# berfikir : berfikir
# positip : positip
# tanpailkan : tanpailkan
# kecerdasan : cerdas
# kebaikan : baik
# berkatalah : kata
# unggah : unggah
# how : how
# democracies : democracies
# die : die
# diseret : seret
# 2ksnl9z6gl : 2ksnl9z6gl
# dipnggil : dipnggil
# riza : riza
# drama : drama
# kelihtn : kelihtn
# kubu : kubu
# nyari2 : nyari2
# masalh : masalh
# seprti : seprti
# dibenarkan : benar
# dipikirnya : pikir
# reflyhz : reflyhz
# andiarief : andiarief
# haris : haris
# azhar : azhar
# rachlannashidik : rachlannashidik
# menambah : tambah
# bersuara : suara
# tanda : tanda
# centang : centang
# biru : biru
# cuitan2 : cuitan2
# nehi : nehi
# t : t
# jail : jail
# kemakan : makan
# posting : posting
# nynyir : nynyir
# cetek : cetek
# pigur : pigur
# golkar : golkar
# perhatian : perhati
# id6pvu9p3d : id6pvu9p3d
# wanglydia90 : wanglydia90
# kitogrrapo : kitogrrapo
# otib62487461 : otib62487461
# faizalassegaf : faizalassegaf
# pelihara : pelihara
# pangdam : pangdam
# dipindahkan : pindah
# sindiran : sindir
# elegan : elegan
# tampa : tampa
# bangsat : bangsat
# literasi : literasi
# jendela : jendela
# fikiran : fikiran
# ...
# bm : bm
# pegi : pegi
# xbole : xbole
# pegar : pegar
# statementnya : statementnya
# dikemudian : kemudi
# kwalitasnya : kwalitasnya
# setingkat : tingkat
# kecamatan : camat
# mngkin : mngkin
# kasihkan : kasih
# wiku : wiku
# satgas : satgas
# rilis : rilis
# maret : maret
# asu9dm6htq : asu9dm6htq
# chicohakim : chicohakim
# kemdikbud : kemdikbud
# tunda : tunda
# kpn : kpn
# khidupan : khidupan
# skolah : skolah
# lwt : lwt
# gurunya : guru
# nganggur : nganggur
# digaji : gaji
# naahh : naahh
# gemparazha : gemparazha
# aswinazha1 : aswinazha1
# rsudjasmin : rsudjasmin
# kkpunasional : kkpunasional
# santoso09579056 : santoso09579056
# sutarmanw : sutarmanw
# ombudsmanri137 : ombudsmanri137
# sila : sila
# pemilik : milik
# shgb : shgb
# setwapres : setwapres
# nyatakan : nyata
# hgb : hgb
# malay : malay
# apah : apah
# yahh : yahh
# jjur : jjur
# prasaan : prasaan
# lecehkan : leceh
# sihh : sihh
# jancok : jancok
# nasirajo : nasirajo
# yakim : yakim
# dsn : dsn
# menujukkan : menujukkan
# indonesiabersatu : indonesiabersatu
# lawankorupsi : lawankorupsi
# brantaskorupsi : brantaskorupsi
# tiktok : tiktok
# facebook : facebook
# makassarinfo : makassarinfo
# jakartainfo : jakartainfo
# td9nrgynqp : td9nrgynqp
# menyesat : sesat
# berati : berat
# usa : usa
# gaduh : gaduh
# kadali : kadal
# memaafkan : maaf
# respect : respect
# for : for
# songs : songs
# indonesian : indonesian
# homeland : homeland
# indonesiaraya : indonesiaraya
# 7uff3ateoz : 7uff3ateoz
# cape : cape
# refreshing : refreshing
# kuliner : kuliner
# misinformasi : misinformasi
# terstruktur : struktur
# menguntungkan : untung
# statistik : statistik
# menyatukan : satu
# ibdlbrcrhb : ibdlbrcrhb
# 85albasrihasan : 85albasrihasan
# nasihat : nasihat
# rahasia : rahasia
# trhadap : trhadap
# rnjae16 : rnjae16
# pecintankri45 : pecintankri45
# kayu : kayu
# hutan : hutan
# bennykeef : bennykeef
# y5iy5ejegt : y5iy5ejegt
# mengenal : kenal
# influencer : influencer
# pemikir : pikir
# tipe : tipe
# medekati : medekati
# suruhan : suruh
# melototi : melotot
# pulutik : pulutik
# pejuang01733866 : pejuang01733866
# usulan : usul
# ataurn : ataurn
# slamanya : slamanya
# eben : eben
# haizer : haizer
# cemerlang : cemerlang
# ncuhiriwo : ncuhiriwo
# rrc : rrc
# transfer : transfer
# teknologi : teknologi
# inj : inj
# terulang : ulang
# iamthebestiii1 : iamthebestiii1
# arif2702daulay : arif2702daulay
# ohh : ohh
# gituuu : gituuu
# 2019 : 2019
# sebutannya : sebut
# harta : harta
# hilang : hilang
# bendungan : bendung
# aliran : alir
# kereta : kereta
# api : api
# homb : homb
# dktkanlah : dktkanlah
# hatimu : hati
# goblokanmu : goblok
# tertutpi : tertutpi
# amal : amal
# baikmu : baik
# butu : butu
# minietweets2 : minietweets2
# taliban : talib
# jefri : jefri
# justeru : justeru
# kkn : kkn
# dahsyat : dahsyat
# molor : molor
# berendam : rendam
# sangkuni : sangkuni
# uzur : uzur
# diskriminasi : diskriminasi
# 6pemkfopil : 6pemkfopil
# bwvwqyl19j : bwvwqyl19j
# yusufmansurnew : yusufmansurnew
# sinkretisme : sinkretisme
# gusyaqut : gusyaqut
# syiah : syiah
# ahmadiyah : ahmadiyah
# iqbalkita : iqbalkita
# repkertanegara : repkertanegara
# kbnaran : kbnaran
# bersanding : sanding
# ktdk : ktdk
# tradisi : tradisi
# prinsip : prinsip
# sngguh2 : sngguh2
# pamreh : pamreh
# intropeksi : intropeksi
# maat : maat
# pndidikan : pndidikan
# biarlah : biar
# sulitlah : sulit
# dijamin : jamin
# prilakunya : prilakunya
# pokok : pokok
# eeee : eeee
# radenkerto : radenkerto
# jln : jln
# toll : toll
# panca66 : panca66
# sarapn : sarapn
# jafi : jafi
# sialan : sial
# mengantikan : anti
# ular : ular
# ditelan : tel
# astaga : astaga
# lemes : lemes
# disekeliling : keliling
# praktisi : praktisi
# sewaktu2 : sewaktu2
# menyalahi : salah
# prosedur : prosedur
# manang : manang
# disembah : sembah
# belio : belio
# berlapis : lap
# menggenjot : genjot
# pariwisata : pariwisata
# penyebaran : sebar
# heheheheheheheheheh : heheheheheheheheheh
# tambang : tambang
# susi : sus
# pudjiastuti : pudjiastuti
# wtscitrzmk : wtscitrzmk
# sekulerkan : sekuler
# sukarno : sukarno
# membubarkan : bubar
# masumi : masumi
# asutan : asutan
# fpiandhrsnotguilty : fpiandhrsnotguilty
# b2ml0ewbt6 : b2ml0ewbt6
# bhcyl901zm : bhcyl901zm
# myh34rtf0ry0u : myh34rtf0ry0u
# gonkcil : gonkcil
# rimal : rimal
# rizky : rizky
# pengaruh : pengaruh
# suri : suri
# tauladan : tauladan
# lakunya : laku
# berpengaruh : pengaruh
# pagrqxozdh : pagrqxozdh
# penafsiran : tafsir
# mengatasnamakan : mengatasnamakan
# 3ghhqt7evt : 3ghhqt7evt
# maksa : maksa
# muhamma45899654 : muhamma45899654
# ridwans38612261 : ridwans38612261
# tugasnya : tugas
# ngajakin : ngajakin
# foliowernya : foliowernya
# block : block
# ngelayani : ngelayani
# bye : bye
# azhim : azhim
# prince : prince
# mainkan : main
# meres : meres
# mengarah : arah
# pidana : pidana
# ngedukungnya : ngedukungnya
# sbnya : sbnya
# ente2 : ente2
# kdepanny : kdepanny
# pilpros : pilpros
# endingny : endingny
# mengkhiantai : mengkhiantai
# pendkung : pendkung
# mendkung : mendkung
# msuk : msuk
# sangguru2471 : sangguru2471
# nyantai : nyantai
# perusahan : usah
# hujat2 : hujat2
# pengajian : aji
# bersyukur : syukur
# perduli : duli
# pengorbanan : korban
# rocy : rocy
# perngorbanan : perngorbanan
# cetak : cetak
# tariiiik : tariiiik
# gerangan : gerangan
# astagfirullahalazim : astagfirullahalazim
# pertunjukan : tunjuk
# peliharaan : pelihara
# kimh7jtwdo : kimh7jtwdo
# sarti : sarti
# cantik : cantik
# memberitahu : memberitahu
# gagasan : gagas
# meningkatkan : tingkat
# penerimaan : terima
# ngurangi : ngurangi
# dilaksanakan : laksana
# neng : neng
# marga : marga
# bengek : bengek
# juliari : juliari
# stimulan : stimulan
# kontroversi : kontroversi
# rekonsiliasi : rekonsiliasi
# anggaplah : anggap
# ppn : ppn
# npwp : npwp
# pph : pph
# kupahami : paham
# misahin : misahin
# pengelola : kelola
# dayung : dayung
# yudikatif : yudikatif
# penghasilan : hasil
# wawanii2 : wawanii2
# satugunung : satugunung
# bigdad : bigdad
# membandingkan : banding
# orde : orde
# runtuh : runtuh
# gerakan : gera
# ngaco : ngaco
# bnr2 : bnr2
# penghambaan : hamba
# jls2 : jls2
# akn : akn
# terjd : terjd
# rivalitas : rivalitas
# keniscayaan : niscaya
# nurkhamidah : nurkhamidah
# gagall : gagall
# pandaiii : pandaiii
# olehh : olehh
# peraturannn : peraturannn
# memyulitkan : memyulitkan
# nienazka : nienazka
# untk : untk
# seruuu : seruuu
# pantunj2p : pantunj2p
# msih : msih
# menggonggong : gonggong
# insyaf : insyaf
# diakomodir : diakomodir
# agusyudhoyono : agusyudhoyono
# enaugh : enaugh
# xzod8qkb8s : xzod8qkb8s
# katzefaule : katzefaule
# propil : propil
# ditambah : tambah
# ijtima : ijtima
# mrka : mrka
# berkilah : kilah
# munarman : munarman
# individu : individu
# gus : gus
# yaqut : yaqut
# amunisi : amunisi
# menghantam : hantam
# radikalisme : radikalisme
# qudari : qudari
# sujud2 : sujud2
# ngingetin : ngingetin
# diurus : urus
# merapat : rapat
# meninggalkan : tinggal
# nan : nan
# dhanis96 : dhanis96
# omiccakra : omiccakra
# pakguruhonorer : pakguruhonorer
# reaksi : reaksi
# lingkungan : lingkung
# atm : atm
# belanja : belanja
# rizmaya : rizmaya
# nusantara : nusantara
# patih : patih
# gajah : gajah
# mada : mada
# rung : rung
# onar : onar
# konslet : konslet
# dibeneri : dibeneri
# oplgsinkcv : oplgsinkcv
# muhabisy : muhabisy
# biasalah : biasa
# dianginanjar177 : dianginanjar177
# candi : candi
# borobudur : borobudur
# pakdhe : pakdhe
# checkmate : checkmate
# salute : salute
# hadeh : hadeh
# budaya : budaya
# alquran : alquran
# sunnah : sunnah
# penjarakan : penjara
# agungkan : agung
# abaikan : abai
# menaati : taat
# santi11irma : santi11irma
# keluarganya : keluarga
# membiarkn : membiarkn
# menyebarkan : sebar
# mendasar : dasar
# sangar : sangar
# esok : esok
# menantu : menantu
# bodok : bodok
# otu : otu
# irfan : irfan
# sukoco : sukoco
# yeeeee : yeeeee
# pelit : pelit
# felixsiauw : felixsiauw
# anime : anime
# lix : lix
# ngutip : ngutip
# hadeh2 : hadeh2
# hubungan : hubung
# tii : tii
# ufqbk2lrll : ufqbk2lrll
# narayana909 : narayana909
# ketik : ketik
# yutub : yutub
# muafiq : muafiq
# aduh : aduh
# bedirikan : bedirikan
# nara : nara
# mana2 : mana2
# desi : desi
# mbuzzer : mbuzzer
# cuplikan : cuplik
# 2menit : 2menit
# sutiknoprayogo : sutiknoprayogo
# kaifiatsenja : kaifiatsenja
# sungkem : sungkem
# jembut : jembut
# khilaf : khilaf
# ngebikin : ngebikin
# xg13bdolmm : xg13bdolmm
# klepon : klepon
# hindu : hindu
# budha : budha
# asalnya : asal
# india : india
# asia : asia
# terhapus : hapus
# tenggara : tenggara
# moyang : moyang
# animisme : animisme
# indonesianegarahukum : indonesianegarahukum
# selamatkan : selamat
# sihhhh : sihhhh
# braman : braman
# kotzen : kotzen
# ghifary : ghifary
# aby : aby
# jsuryop1 : jsuryop1
# stafsuscolonial : stafsuscolonial
# kedepanya : depa
# menelusuri : telusur
# saudaraku : saudara
# gampangnya : gampang
# saudra2ku : saudra2ku
# ngawang2 : ngawang2
# terjitu : jitu
# menghadapi : hadap
# syok : syok
# faldomaldini : faldomaldini
# dinamis : dinamis
# tertawaan : tertawa
# ramah : ramah
# musyawahkan : musyawahkan
# markas : markas
# dikelabuin : dikelabuin
# hihihih : hihihih
# mansurarif5 : mansurarif5
# yaqin : yaqin
# radioelshinta : radioelshinta
# pertanyanya : tanya
# menggantikan : ganti
# rekrut : rekrut
# legion : legion
# rjydpt : rjydpt
# banna : banna
# bamgat : bamgat
# lantang : lantang
# terang2an : terang2an
# pendirian : diri
# maklumi : maklum
# plin : plin
# bodohmu : bodoh
# ktolongan : ktolongan
# ibumu : ibu
# musibah : musibah
# sajatemenmu : sajatemenmu
# dikasihani : kasihan
# saw : saw
# fiqih : fiqih
# syari : syar
# dipermainkan : main
# ulamaan : ulama
# imamuhum : imamuhum
# amplopihim : amplopihim
# imanya : imanya
# tergantung : gantung
# amplop : amplop
# am6enai3mp : am6enai3mp
# slama : slama
# gencar : gencar
# suarakan : suara
# reshufflekabinet : reshufflekabinet
# moga : moga
# nempatkan : nempatkan
# kiriteria : kiriteria
# komunikatif : komunikatif
# pekerja : kerja
# ulet : ulet
# temperamen : temperamen
# fpiteroris : fpiteroris
# s72royhgvn : s72royhgvn
# comrhwdpmj : comrhwdpmj
# terungkap : ungkap
# g : g
# nikki : nikki
# atik15279533 : atik15279533
# sepaham : paham
# nyuruh2 : nyuruh2
# ngakunya : ngakunya
# toleran : toleran
# usir : usir
# angingmamiri25 : angingmamiri25
# ayralubis : ayralubis
# setnegri : setnegri
# elhurrykorn : elhurrykorn
# moeldoko : moeldoko
# prajurit : prajurit
# jenderalnya : jenderal
# patrick : patrick
# hip : hip
# ijin : ijin
# duta : duta
# shameger : shameger
# difoto : foto
# usahakan : usaha
# shameonyougermany : shameonyougermany
# bodohkah : bodoh
# bgs : bgs
# hlxbecmw0c : hlxbecmw0c
# woii : woii
# asuh : asuh
# statementmu : statementmu
# mengambarkan : ambar
# terbongkar : bongkar
# 0fv3bmgg2o : 0fv3bmgg2o
# terdidik : didik
# realita : realita
# unjuk : unjuk
# ototnya : otot
# batasnya : batas
# yansrakyatb42u : yansrakyatb42u
# kompas : kompas
# ngajari : ngajari
# pembaca : baca
# ditarik : tarik
# tas : tas
# infrastruktur : infrastruktur
# 2yvs07akkc : 2yvs07akkc
# dijatuhkan : jatuh
# cia : cia
# best : best
# merusuh : rusuh
# suriah : suriah
# menonjolkan : tonjol
# justri : justri
# indah : indah
# menunggu : tunggu
# pembuktian : bukti
# mengungkap : ungkap
# 1kyekibdcd : 1kyekibdcd
# geetracker : geetracker
# bullfront : bullfront
# politis : politis
# dubesnya : dubes
# etika : etika
# layak : layak
# dipulangkan : pulang
# habitatnya : habitat
# memeka : peka
# ketegasan : tegas
# termudahnya : mudah
# panasin : panasin
# mencintai : cinta
# bangsanya : bangsa
# jirrrrrrr : jirrrrrrr
# nujukan : nujukan
# force : force
# majeure : majeure
# digoreng : goreng
# petinggi : petinggi
# ditinggalkan : tinggal
# kader2 : kader2
# alexstefanus : alexstefanus
# komisiyudisial : komisiyudisial
# banyolan : banyol
# mojokin : mojokin
# kepalanya : kepala
# kardun : kardun
# agustus : agustus
# kaltara : kaltara
# desember : desember
# ditunjukin : ditunjukin
# menjemur : jemur
# bukit : bukit
# seandai : anda
# mempermalukan : malu
# diprotes : protes
# mencoreng : coreng
# mitra : mitra
# diplomat : diplomat
# dingenyek : ngenyek
# bohir2 : bohir2
# piaraannya : piara
# metong : metong
# tuwoe4khnf : tuwoe4khnf
# aa2a6c062b3c4b6 : aa2a6c062b3c4b6
# iq7ujuh : iq7ujuh
# indanusdidikke1 : indanusdidikke1
# bangat : bangat
# tuntaskan : tuntas
# buly : buly
# sebenar : benar
# ketolalan : ketolalan
# akurat : akurat
# c4h : c4h
# mengkonsumsi : konsumsi
# berita2 : berita2
# dtebak : dtebak
# arah : arah
# siapkn : siapkn
# jwbn : jwbn
# srta : srta
# egois : egois
# mndahulukan : mndahulukan
# kantongin : kantongin
# arnoldy1230 : arnoldy1230
# bobby77h : bobby77h
# qnz1dwzbhq : qnz1dwzbhq
# 27mile03 : 27mile03
# dadangrusian : dadangrusian
# presidenku : presiden
# winardhi : winardhi
# resuffle : resuffle
# disadari : sadar
# nurani : nurani
# kesal : kesal
# diarahkan : arah
# gacwkk3ngh : gacwkk3ngh
# asdiputraiwan : asdiputraiwan
# isna : isna
# j : j
# ajril48 : ajril48
# dkusdedi : dkusdedi
# {'biespartacus': 'biespartacus', 'da': 'da', 'yangqu': 'yangqu', 'aniesbaswedan': 'aniesbaswedan', 'owh': 'owh', 'kalo': 'kalo', 'anies': 'anies', 'kerja': 'kerja', 'risma': 'risma', 'pencitraan': 'citra', 'bego': 'bego', 'bie': 'bie', 'bilangin': 'bilangin', 'beda': 'beda', 'pejabat': 'jabat', 'publik': 'publik', 'beritanya': 'berita', 'kerjanya': 'kerja', 'pemanis': 'man', 'ginihari': 'ginihari', 'begoin': 'begoin', 'rakyat': 'rakyat', 'aja': 'aja', 'dgn': 'dgn', 'pemberitaan': 'berita', 'dosa': 'dosa', 'tau': 'tau', 'v2lghm9pdx': 'v2lghm9pdx', 'perisyantik': 'perisyantik', 'merryanjani19': 'merryanjani19', 'cnnindonesia': 'cnnindonesia', 'situ': 'situ', 'beneran': 'beneran', 'modal': 'modal', 'adu': 'adu', 'argumentasi': 'argumentasi', 'coba': 'coba', 'meme': 'meme', 'ginian': 'ginian', 'latihan': 'latih', 'deh': 'deh', 'pembina': 'bina', 'bikin': 'bikin', 'malu': 'malu', 'disuruh': 'suruh', 'suruh': 'suruh', 'saingan': 'saing', 'sdh': 'sdh', 'repot2': 'repot2', 'diangkat': 'angkat', 'mensos': 'mensos', 'downgrade': 'downgrade', 'pndukung': 'pndukung', 'bgini': 'bgini', 'mentri': 'tri', 'oposisicerdas': 'oposisicerdas', 'pokoknya': 'pokok', 'klo': 'klo', 'calon': 'calon', 'presiden': 'presiden', 'org': 'org', 'pilih': 'pilih', 'beliau': 'beliau', 'udah': 'udah', 'terpampang': 'pampang', 'nyata': 'nyata', 'kinerjanya': 'kerja', 'detikcom': 'detikcom', 'mnding': 'mnding', 'mikir': 'mikir', '2022': '2022', 'bang': 'bang', 'blum': 'blum', 'menang': 'menang', 'gatau': 'gatau', 'dibangun': 'bangun', 'anggaran': 'anggar', 'ampir': 'ampir', '100t': '100t', 'setahun': 'tahun', 'dipakai': 'pakai', 'baca': 'baca', 'emng': 'emng', 'dikerjain': 'dikerjain', 'doncorleone': 'doncorleone', '78': '78', 'yak': 'yak', 'bener': 'bener', 'ngomong': 'ngomong', 'bego2in': 'bego2in', 'orang': 'orang', 'nich': 'nich', 'suka': 'suka', 'bega': 'bega', 'hasmisahar': 'hasmisahar', 'lisaamartatara3': 'lisaamartatara3', 'tolong': 'tolong', 'nasihatin': 'nasihatin', 'dokter': 'dokter', 'narasi': 'narasi', 'kebencian': 'benci', 'permusuhan': 'musuh', 'sebar': 'sebar', 'dukung': 'dukung', 'kuat': 'kuat', 'kohesi': 'kohesi', 'fans': 'fans', 'tpi': 'tpi', 'gak': 'gak', 'nambah': 'nambah', 'fansnya': 'fansnya', 'mw17714668': 'mw17714668', 'emg': 'emg', 'kudu': 'kudu', 'laporan': 'lapor', 'elu': 'elu', 'kasih': 'kasih', 'penghargaan': 'harga', 'terheran2': 'terheran2', 'ferdinandhaean3': 'ferdinandhaean3', 'skrg': 'skrg', 'jilat': 'jilat', 'pemerintah': 'perintah', 'berharap': 'harap', 'ngajak': 'ngajak', 'gada': 'gada', 'kasian': 'kasi', 'ngejek': 'ngejek', 'pintarnya': 'pintar', 'gimana': 'gimana', 'mas': 'mas', 'hayang': 'hayang', 'milih': 'milih', 'kolor': 'kolor', 'merah': 'merah', 'drpd': 'drpd', 'gertak': 'gertak', 'klrg': 'klrg', 'gemetaran': 'gemetar', 'szmpe': 'szmpe', 'bulu': 'bulu', 'jembutnya': 'jembut', 'rontok': 'rontok', 'retweet': 'retweet', 'gaes': 'gaes', 'biar': 'biar', 'cebong': 'cebong', 'stalking': 'stalking', 'twit': 'twit', 'prestasi': 'prestasi', 'dongo': 'dongo', 'jakartajuaramelulu': 'jakartajuaramelulu', '3wus7fiy4v': '3wus7fiy4v', 'pemerhatibangs4': 'pemerhatibangs4', 'selalubergerakk': 'selalubergerakk', 'korupsi': 'korupsi', 'siluman': 'siluman', 'amp': 'amp', 'dki': 'dki', 'mingkem': 'mingkem', 'drun': 'drun', 'emang': 'emang', 'pendukung': 'dukung', 'rizqmuhammad3': 'rizqmuhammad3', 'joedynto': 'joedynto', 'krn': 'krn', 'gabener': 'gabener', 'didukung': 'dukung', 'aman2': 'aman2', 'gubernur': 'gubernur', 'tdk': 'tdk', 'kadrun': 'kadrun', 'bisa2': 'bisa2', 'abis': 'abis', 'tuh': 'tuh', 'orbanamen': 'orbanamen', 'natal': 'natal', 'jngn': 'jngn', 'belagak': 'bagak', 'yah': 'yah', 'ama': 'ama', 'temen': 'temen', 'gub': 'gub', 'lho': 'lho', 'ijinin': 'ijinin', 'christmas': 'christmas', 'carol': 'carol', 'taon': 'taon', 'kemaren': 'kemaren', 'aman': 'aman', 'pdahal': 'pdahal', 'fpi': 'fpi', 'bully': 'bully', 'habis2an': 'habis2an', 'giliran': 'gilir', 'luhut': 'luhut', 'pura': 'pura', 'budeg': 'budeg', 'dasar': 'dasar', 'batu': 'batu ...
# ------------------------
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=1800.0), HTML(value='')))

# %%
# Membuat kolom yang bernama "content_bersih" pada DataFrame "data_2020" yang telah selesai dilakukan proses text preprocessing
data_2020["content_bersih"] = [" ".join(map(str, i)) for i in data_2020["content_stemming"]]
data_2020.head()
# Out:
#                         date  \
# 0  2020-12-29 23:16:16+00:00
# 1  2020-12-29 07:49:59+00:00
# 2  2020-12-28 14:52:49+00:00
# 3  2020-12-28 07:19:18+00:00
# 4  2020-12-27 16:42:18+00:00
#
#                                              content    label  \
# 0   biespartacus da yangqu aniesbaswedan owh kalo...  positif
# 1  beda anies dengan pejabat publik lainnya pak a...  negatif
# 2   perisyantik merryanjani19 cnnindonesia situ b...  positif
# 3   oposisicerdas pokoknya klo pak anies calon pr...  negatif
# 4   detikcom mnding mikir buat 2022 dulu bang 202...  negatif
#
#                                   content_tokenizing  \
# 0  [biespartacus, da, yangqu, aniesbaswedan, owh,...
# 1  [beda, anies, dengan, pejabat, publik, lainnya...
# 2  [perisyantik, merryanjani19, cnnindonesia, sit...
# 3  [oposisicerdas, pokoknya, klo, pak, anies, cal...
# 4  [detikcom, mnding, mikir, buat, 2022, dulu, ba...
#
#                                    content_stopwords  \
# 0  [biespartacus, da, yangqu, aniesbaswedan, owh,...
# 1  [beda, anies, pejabat, publik, anies, kerja, b...
# 2  [perisyantik, merryanjani19, cnnindonesia, sit...
# 3  [oposisicerdas, pokoknya, klo, anies, calon, p...
# 4  [detikcom, mnding, mikir, 2022, bang, 2022, aj...
#
#                                     content_stemming  \
# 0  [biespartacus, da, yangqu, aniesbaswedan, owh,...
# 1  [beda, anies, jabat, publik, anies, kerja, ber...
# 2  [perisyantik, merryanjani19, cnnindonesia, sit...
# 3  [oposisicerdas, pokok, klo, anies, calon, pres...
# 4  [detikcom, mnding, mikir, 2022, bang, 2022, aj...
#
#                                       content_bersih
# 0  biespartacus da yangqu aniesbaswedan owh kalo ...
# 1  beda anies jabat publik anies kerja berita jab...
# 2  perisyantik merryanjani19 cnnindonesia situ be...
# 3  oposisicerdas pokok klo anies calon presiden o...
# 4  detikcom mnding mikir 2022 bang 2022 aja blum ...

# %% [markdown]
# ## 3. Mengambil Isi Kolom "content_bersih"

# %%
# Mengeluarkan isi tweet bersih dari DataFrame "data"
ekstraksi_data_content = " ".join(str(c) for c in data_2020["content_bersih"])
ekstraksi_data_content
# Out:
# 'biespartacus da yangqu aniesbaswedan owh kalo anies kerja kalo risma citra bego bie bilangin beda anies jabat publik anies kerja berita jabat kerja man berita ginihari bego begoin rakyat aja dgn berita dosa tau v2lghm9pdx perisyantik merryanjani19 cnnindonesia situ beneran modal adu argumentasi coba meme ginian coba latih deh bina bikin malu risma aja suruh suruh saing anies sdh repot2 angkat mensos downgrade pndukung bego bgini bikin malu tri oposisicerdas pokok klo anies calon presiden org bego aja pilih beliau udah pampang nyata kerja detikcom mnding mikir 2022 bang 2022 aja blum menang kerja anies nyata gatau bangun anggar ampir 100t tahun gatau pakai bego baca emng dikerjain doncorleone 78 yak bener kalo ngomong bego2in orang anies nich orang suka ngomong bega bego hasmisahar lisaamartatara3 aniesbaswedan coba tolong nasihatin dokter bego narasi narasi benci musuh sebar dukung anies kuat kohesi fans anies tpi beliau gak nambah fans fansnya aja mw17714668 detikcom kalo anies kerja emg kudu lapor elu kasih harga orang bego orang terheran2 ferdinandhaean3 skrg jilat perintah harap ngajak gada kasi skrg ngejek aniesbaswedan pintar gimana mas anies hayang orang bego milih kolor merah drpd anies gertak klrg gemetar szmpe bulu jembut rontok retweet gaes biar cebong bego suka stalking twit prestasi anies dongo jakartajuaramelulu 3wus7fiy4v pemerhatibangs4 selalubergerakk korupsi anggar siluman amp dki mingkem drun bego emang dukung anies rizqmuhammad3 joedynto cnnindonesia krn anies gabener dukung aman2 aja coba kalo gubernur tdk dukung kadrun bisa2 abis tuh orbanamen natal jngn bagak bego yah malu ama temen temen kadrun joedynto cnnindonesia gub anies lho ijinin christmas carol taon kemaren aman aman aja pdahal gubernur dukung ama fpi lho jngn bagak bego yah malu ama temen temen kalo ngomong anies situ bully habis2an gilir luhut ngomong situ pura pura bego budeg dasar batu giok kompastv bego aja bikin coba nama jgn anies atw mega orang tsamaradki bikin narasi aja bloon banggaka partai dongo penuh benci terima kali anies baswedan gubenur pilih rakyat curang kotak suara kardus bego kompascom pandji kmn aja bego pas ahok digituin elu tutup mata krn dukung anies richardjknight8 alfaomega0110 emon lucu fadlizon elo laki2 pake ava perempuan bencong dah kalimat elo nuduh anies tuntut anies bego marlina idha bego bener kalo diijinkan hrs tetap sangka anies bidik kalo mengijinkan paham republikaonline larang protes ntar izin covid anies salah pidana dasar banteng bego beli vaksin tahu efektifitasnya kalo tdk efektif vaksin nya buang kembali bego hmmm disalahin anies uber uber aparat hrs cejetqa9et andidrz buchronik nkrisaklawase maspiyuo bego jkt barometer ekonomi nasional eko bln tolol dunia hadap pandemi anies msh batas aktivitas usaha blm demo2 manusia minus otak bikin takut investor esemka sdh jual tuh duit ggk don rahmad buchronik nkrisaklawase maspiyuo bego peduli anies krja cmn ngurusin jakarta ken ekonomi roket smk release beli ibukota cpt pindah lapang pkerjaan juta korup hukum mati borneo garap suku pribumi papua damai ttp nkri kga ganti haji bolot ajah panembahan alit ferdinandhaean3 sanksi tinggi gak banding dampak timbul akibat kebungulan junjung elu kapolda kapolsek walkot jakpus korban2 bego tular covid anies iyaiyaamaafin ndptr21 pulg4rr ch chotlmah divhumas polri paltiwest3 kangdede78 p3nj3l4j4h id tuh izin anies anies silah teman2 urus anies cctv teman2 bego pulg4rr ndptr21 ch chotlmah divhumas polri paltiwest3 kangdede78 p3nj3l4j4h id kadrun bego anies gubernur bawah kait pemda dki gubernur gak kerja lgsg tanggung kerja bawah gin aja gak ngerti krn otak kalin sampah akmalbariq markadenson qodoxngorex sahal as bego kpk kgk pandang bulu menteri ajh ciduk anies andrydevry widiast46559533 dennysiregar7 kpk ri kpk novel baswedan doang novel curiga gabisa nangkep anies baswedan hrs mikirnya orang nangkep anies klo bukti korupsi kerja kpk novel baswedan cebong mah bego njr antojagad3 nanyo 5 widiast46559533 dennysiregar7 kpk ...

# %%
# Melihat isi tweet per kata yang telah dilakukan proses ekstraksi menggunakan word_tokenize dari library nltk
word_tokenize_content = word_tokenize(ekstraksi_data_content)
word_tokenize_content
# Out:
# ['biespartacus',
#  'da',
#  'yangqu',
#  'aniesbaswedan',
#  'owh',
#  'kalo',
#  'anies',
#  'kerja',
#  'kalo',
#  'risma',
#  'citra',
#  'bego',
#  'bie',
#  'bilangin',
#  'beda',
#  'anies',
#  'jabat',
#  'publik',
#  'anies',
#  'kerja',
#  'berita',
#  'jabat',
#  'kerja',
#  'man',
#  'berita',
#  'ginihari',
#  'bego',
#  'begoin',
#  'rakyat',
#  'aja',
#  'dgn',
#  'berita',
#  'dosa',
#  'tau',
#  'v2lghm9pdx',
#  'perisyantik',
#  'merryanjani19',
#  'cnnindonesia',
#  'situ',
#  'beneran',
#  'modal',
#  'adu',
#  'argumentasi',
#  'coba',
#  'meme',
#  'ginian',
#  'coba',
#  'latih',
#  'deh',
#  'bina',
#  'bikin',
#  'malu',
#  'risma',
#  'aja',
#  'suruh',
#  'suruh',
#  'saing',
#  'anies',
#  'sdh',
#  'repot2',
#  'angkat',
#  'mensos',
#  'downgrade',
#  'pndukung',
#  'bego',
#  'bgini',
#  'bikin',
#  'malu',
#  'tri',
#  'oposisicerdas',
#  'pokok',
#  'klo',
#  'anies',
#  'calon',
#  'presiden',
#  'org',
#  'bego',
#  'aja',
#  'pilih',
#  'beliau',
#  'udah',
#  'pampang',
#  'nyata',
#  'kerja',
#  'detikcom',
#  'mnding',
#  'mikir',
#  '2022',
#  'bang',
#  '2022',
#  'aja',
#  'blum',
#  'menang',
#  'kerja',
#  'anies',
#  'nyata',
#  'gatau',
#  'bangun',
#  'anggar',
#  'ampir',
#  '100t',
#  'tahun',
#  'gatau',
#  'pakai',
#  'bego',
#  'baca',
#  'emng',
#  'dikerjain',
#  'doncorleone',
#  '78',
#  'yak',
#  'bener',
#  'kalo',
#  'ngomong',
#  'bego2in',
#  'orang',
#  'anies',
#  'nich',
#  'orang',
#  'suka',
#  'ngomong',
#  'bega',
#  'bego',
#  'hasmisahar',
#  'lisaamartatara3',
#  'aniesbaswedan',
#  'coba',
#  'tolong',
#  'nasihatin',
#  'dokter',
#  'bego',
#  'narasi',
#  'narasi',
#  'benci',
#  'musuh',
#  'sebar',
#  'dukung',
#  'anies',
#  'kuat',
#  'kohesi',
#  'fans',
#  'anies',
#  'tpi',
#  'beliau',
#  'gak',
#  'nambah',
#  'fans',
#  'fansnya',
#  'aja',
#  'mw17714668',
#  'detikcom',
#  'kalo',
#  'anies',
#  'kerja',
#  'emg',
#  'kudu',
#  'lapor',
#  'elu',
#  'kasih',
#  'harga',
#  'orang',
#  'bego',
#  'orang',
#  'terheran2',
#  'ferdinandhaean3',
#  'skrg',
#  'jilat',
#  'perintah',
#  'harap',
#  'ngajak',
#  'gada',
#  'kasi',
#  'skrg',
#  'ngejek',
#  'aniesbaswedan',
#  'pintar',
#  'gimana',
#  'mas',
#  'anies',
#  'hayang',
#  'orang',
#  'bego',
#  'milih',
#  'kolor',
#  'merah',
#  'drpd',
#  'anies',
#  'gertak',
#  'klrg',
#  'gemetar',
#  'szmpe',
#  'bulu',
#  'jembut',
#  'rontok',
#  'retweet',
#  'gaes',
#  'biar',
#  'cebong',
#  'bego',
#  'suka',
#  'stalking',
#  'twit',
#  'prestasi',
#  'anies',
#  'dongo',
#  'jakartajuaramelulu',
#  '3wus7fiy4v',
#  'pemerhatibangs4',
#  'selalubergerakk',
#  'korupsi',
#  'anggar',
#  'siluman',
#  'amp',
#  'dki',
#  'mingkem',
#  'drun',
#  'bego',
#  'emang',
#  'dukung',
#  'anies',
#  'rizqmuhammad3',
#  'joedynto',
#  'cnnindonesia',
#  'krn',
#  'anies',
#  'gabener',
#  'dukung',
#  'aman2',
#  'aja',
#  'coba',
#  'kalo',
#  'gubernur',
#  'tdk',
#  'dukung',
#  'kadrun',
#  'bisa2',
#  'abis',
#  'tuh',
#  'orbanamen',
#  'natal',
#  'jngn',
#  'bagak',
#  'bego',
#  'yah',
#  'malu',
#  'ama',
#  'temen',
#  'temen',
#  'kadrun',
#  'joedynto',
#  'cnnindonesia',
#  'gub',
#  'anies',
#  'lho',
#  'ijinin',
#  'christmas',
#  'carol',
#  'taon',
#  'kemaren',
#  'aman',
#  'aman',
#  'aja',
#  'pdahal',
#  'gubernur',
#  'dukung',
#  'ama',
#  'fpi',
#  'lho',
#  'jngn',
#  'bagak',
#  'bego',
#  'yah',
#  'malu',
#  'ama',
#  'temen',
#  'temen',
#  'kalo',
#  'ngomong',
#  'anies',
#  'situ',
#  'bully',
#  'habis2an',
#  'gilir',
#  'luhut',
#  'ngomong',
#  'situ',
#  'pura',
#  'pura',
#  'bego',
#  'budeg',
#  'dasar',
#  'batu',
#  'giok',
#  'kompastv',
#  'bego',
#  'aja',
#  'bikin',
#  'coba',
#  'nama',
#  'jgn',
#  'anies',
#  'atw',
#  'mega',
#  'orang',
#  'tsamaradki',
#  'bikin',
#  'narasi',
#  'aja',
#  'bloon',
#  'banggaka',
#  'partai',
#  'dongo',
#  'penuh',
#  'benci',
#  'terima',
#  'kali',
#  'anies',
#  'baswedan',
#  'gubenur',
#  'pilih',
#  'rakyat',
#  'curang',
#  'kotak',
#  'suara',
#  'kardus',
#  'bego',
#  'kompascom',
#  'pandji',
#  'kmn',
#  'aja',
#  'bego',
#  'pas',
#  'ahok',
#  'digituin',
#  'elu',
#  'tutup',
#  'mata',
#  'krn',
#  'dukung',
#  'anies',
#  'richardjknight8',
#  'alfaomega0110',
#  'emon',
#  'lucu',
#  'fadlizon',
#  'elo',
#  'laki2',
#  'pake',
#  'ava',
#  'perempuan',
#  'bencong',
#  'dah',
#  'kalimat',
#  'elo',
#  'nuduh',
#  'anies',
#  'tuntut',
#  'anies',
#  'bego',
#  'marlina',
#  'idha',
#  'bego',
#  'bener',
#  'kalo',
#  'diijinkan',
#  'hrs',
#  'tetap',
#  'sangka',
#  'anies',
#  'bidik',
#  'kalo',
#  'mengijinkan',
#  'paham',
#  'republikaonline',
#  'larang',
#  'protes',
#  'ntar',
#  'izin',
#  'covid',
#  'anies',
#  'salah',
#  'pidana',
#  'dasar',
#  'banteng',
#  'bego',
#  'beli',
#  'vaksin',
#  'tahu',
#  'efektifitasnya',
#  'kalo',
#  'tdk',
#  'efektif',
#  'vaksin',
#  'nya',
#  'buang',
#  'kembali',
#  'bego',
#  'hmmm',
#  'disalahin',
#  'anies',
#  'uber',
#  'uber',
#  'aparat',
#  'hrs',
#  'cejetqa9et',
#  'andidrz',
#  'buchronik',
#  'nkrisaklawase',
#  'maspiyuo',
#  'bego',
#  'jkt',
#  'barometer',
#  'ekonomi',
#  'nasional',
#  'eko',
#  'bln',
#  'tolol',
#  'dunia',
#  'hadap',
#  'pandemi',
#  'anies',
#  'msh',
#  'batas',
#  'aktivitas',
#  'usaha',
#  'blm',
#  'demo2',
#  'manusia',
#  'minus',
#  'otak',
#  'bikin',
#  'takut',
#  'investor',
#  'esemka',
#  'sdh',
#  'jual',
#  'tuh',
#  'duit',
#  'ggk',
#  'don',
#  'rahmad',
#  'buchronik',
#  'nkrisaklawase',
#  'maspiyuo',
#  'bego',
#  'peduli',
#  'anies',
#  'krja',
#  'cmn',
#  'ngurusin',
#  'jakarta',
#  'ken',
#  'ekonomi',
#  'roket',
#  'smk',
#  'release',
#  'beli',
#  'ibukota',
#  'cpt',
#  'pindah',
#  'lapang',
#  'pkerjaan',
#  'juta',
#  'korup',
#  'hukum',
#  'mati',
#  'borneo',
#  'garap',
#  'suku',
#  'pribumi',
#  'papua',
#  'damai',
#  'ttp',
#  'nkri',
#  'kga',
#  'ganti',
#  'haji',
#  'bolot',
#  'ajah',
#  'panembahan',
#  'alit',
#  'ferdinandhaean3',
#  'sanksi',
#  'tinggi',
#  'gak',
#  'banding',
#  'dampak',
#  'timbul',
#  'akibat',
#  'kebungulan',
#  'junjung',
#  'elu',
#  'kapolda',
#  'kapolsek',
#  'walkot',
#  'jakpus',
#  'korban2',
#  'bego',
#  'tular',
#  'covid',
#  'anies',
#  'iyaiyaamaafin',
#  'ndptr21',
#  'pulg4rr',
#  'ch',
#  'chotlmah',
#  'divhumas',
#  'polri',
#  'paltiwest3',
#  'kangdede78',
#  'p3nj3l4j4h',
#  'id',
#  'tuh',
#  'izin',
#  'anies',
#  'anies',
#  'silah',
#  'teman2',
#  'urus',
#  'anies',
#  'cctv',
#  'teman2',
#  'bego',
#  'pulg4rr',
#  'ndptr21',
#  'ch',
#  'chotlmah',
#  'divhumas',
#  'polri',
#  'paltiwest3',
#  'kangdede78',
#  'p3nj3l4j4h',
#  'id',
#  'kadrun',
#  'bego',
#  'anies',
#  'gubernur',
#  'bawah',
#  'kait',
#  'pemda',
#  'dki',
#  'gubernur',
#  'gak',
#  'kerja',
#  'lgsg',
#  'tanggung',
#  'kerja',
#  'bawah',
#  'gin',
#  'aja',
#  'gak',
#  'ngerti',
#  'krn',
#  'otak',
#  'kalin',
#  'sampah',
#  'akmalbariq',
#  'markadenson',
#  'qodoxngorex',
#  'sahal',
#  'as',
#  'bego',
#  'kpk',
#  'kgk',
#  'pandang',
#  'bulu',
#  'menteri',
#  'ajh',
#  'ciduk',
#  'anies',
#  'andrydevry',
#  'widiast46559533',
#  'dennysiregar7',
#  'kpk',
#  'ri',
#  'kpk',
#  'novel',
#  'baswedan',
#  'doang',
#  'novel',
#  'curiga',
#  'gabisa',
#  'nangkep',
#  'anies',
#  'baswedan',
#  'hrs',
#  'mikirnya',
#  'orang',
#  'nangkep',
#  'anies',
#  'klo',
#  'bukti',
#  'korupsi',
#  'kerja',
#  'kpk',
#  'novel',
#  'baswedan',
#  'cebong',
#  'mah',
#  'bego',
#  'njr',
#  'antojagad3',
#  'nanyo',
#  '5',
#  'widiast46559533',
#  'dennysiregar7',
#  'kpk',
#  'ri',
#  'udah',
#  'deh',
#  'tau',
#  'bela',
#  'anies',
#  'rata2',
#  'org2',
#  'bego',
#  'gabisa',
#  'nerima',
#  'nyata',
#  'kalo',
#  'emg',
#  'kerja',
#  'kalo',
#  'emg',
#  'kerja',
#  'harga',
#  'hasil',
#  'program',
#  'jokowi',
#  'ahok',
#  'msh',
#  'gubernur',
#  'wkwkwkwk',
#  'pake',
#  'gamalu',
#  'klaim2',
#  'orangpi46254193',
#  'loe',
#  'kate',
#  'makan',
#  'anies',
#  'sekolah',
#  'biar',
#  'dikatain',
#  'bego',
#  'lisaamartatara3',
#  'sat',
#  'payung',
#  'mr',
#  'cosanostra',
#  'partai',
#  'songong',
#  'jgo',
#  'itung2',
#  'anies',
#  'tpi',
#  'bego',
#  'klo',
#  'klompoknya',
#  'muchlis',
#  'ar',
#  'kek',
#  'aga',
#  'bego',
#  'dah',
#  'komen',
#  'tugas',
#  'ngeswab',
#  'anies',
#  'anies',
#  'pake',
#  'masker',
#  'swab',
#  'conge',
#  'kuping',
#  'anakodok2009',
#  'hellosyalala',
#  'ainunnajib',
#  'hahahaha',
#  'bego',
#  'pantesan',
#  'dapet',
#  'pimpin',
#  'model',
#  'jokowi',
#  'anies',
#  'wisma',
#  'atlet',
#  'juha',
#  'darurat',
#  'kek',
#  'hotel',
#  'kek',
#  'barak',
#  'tentara',
#  'kek',
#  'rumah',
#  'dinas',
#  'kek',
#  'pokok',
#  'pasien',
#  'covidnya',
#  'wajib',
#  'protokol',
#  '2sznxvjxm2',
#  'cnnindonesia',
#  'anies',
#  'manfaat',
#  'pde',
#  'bego',
#  'islam',
#  'jadi',
#  'politik',
#  'belah',
#  'bhinneka',
#  'tunggal',
#  'ika',
#  'negara',
#  'bro',
#  'dennysiregar7',
#  'dprddkijakarta',
#  'kalo',
#  'urus',
#  'uang',
#  'pdi',
#  'juang',
#  'diam',
#  'prasetyoedi',
#  'pura',
#  'bego',
#  'anies',
#  'aman',
#  'dlm',
#  'beda',
#  'dng',
#  'basuki',
#  'btp',
#  'serang',
#  'habis',
#  'habis',
#  'jokowi',
#  'menkopolhukam',
#  'pdhl',
#  'bagak',
#  'kuasa',
#  'level',
#  'pusat',
#  'langkah',
#  'anies',
#  'yak',
#  'kelas',
#  'gubernur',
#  'doang',
#  'bawa',
#  'bawa',
#  'org',
#  'negri',
#  'bego',
#  'banget',
#  'logika',
#  'qitn06oigm',
#  'adearmando1',
#  'bego',
#  'ketawain',
#  'anak',
#  'stm',
#  'cuk',
#  'adearmando1',
#  'nama',
#  'bohong',
#  'anies',
#  'positif',
#  'bilang',
#  'negatif',
#  'ntu',
#  'bohong',
#  'namenye',
#  'jangan2',
#  'sadar',
#  'harap',
#  'goodbener',
#  'negatif',
#  'c19',
#  'makasih',
#  'cuk',
#  'mudinarl',
#  'purba',
#  'desmo',
#  'prabowo',
#  'lari',
#  'anies',
#  'bahas',
#  'kelompok',
#  'provokator',
#  'wajar',
#  'sih',
#  'kadrun',
#  'bego',
#  'natural',
#  'dennysiregar7',
#  'dprddkijakarta',
#  'klau',
#  'dukung',
#  'den',
#  'mantaap',
#  'bilang',
#  'aja',
#  'pdip',
#  'loyo',
#  'kbyakan',
#  'diam',
#  'klau',
#  'urus',
#  'anggar',
#  'kbijakan',
#  'anies',
#  'membeoo',
#  'suara',
#  'imadya',
#  'ttg',
#  'anggar',
#  'formula',
#  'kritisx',
#  'pdip',
#  'partai',
#  'bego',
#  'andotulong',
#  'kamalbukankemal',
#  'intoleransi',
#  'elo',
#  'bani',
#  'togog',
#  'anies',
#  'baswedan',
#  'menang',
#  'terima',
#  'penasaran',
#  'comberan',
#  'suruh',
#  'udah',
#  'keok',
#  'bilang',
#  'jual',
#  'ayat',
#  'mayat',
#  'jual',
#  'ayat',
#  'cuman',
#  'bego',
#  'sulut',
#  'ntt',
#  'gubernur',
#  'muslim',
#  'wajar',
#  'gak',
#  'nyinyir',
#  'kayak',
#  'elo',
#  'marlina',
#  'idha',
#  'ulitrisnani',
#  'kerja',
#  'psi',
#  'julidin',
#  'nyinyirin',
#  'anies',
#  'hasil',
#  'gak',
#  'hasil',
#  'gak',
#  'julid',
#  'kliatan',
#  'bego',
#  'andy',
#  'budiman',
#  'psi',
#  'id',
#  'partai',
#  'putar',
#  'ibukota',
#  'ikut',
#  'mati',
#  'mati',
#  'jatuh',
#  'anies',
#  'terliha',
#  'bego',
#  'amatir',
#  'adhydault',
#  'aniesbaswedan',
#  'halah',
#  'dasar',
#  'hti',
#  'anies',
#  'bego',
#  'manfaatin',
#  'hti',
#  'ikur12',
#  'iwan',
#  'dennysiregar7',
#  '03',
#  'nakula',
#  'canputtt',
#  'haniafiair',
#  'firzahusain',
#  'nadjib',
#  '178',
#  'ewidi79',
#  'warsanawoko',
#  'vita',
#  'avp',
#  'nikilo2512',
#  'pro',
#  'anies',
#  'aja',
#  'kadrun',
#  'bego',
#  'pilpres',
#  '2024',
#  'poros',
#  'anies',
#  'rizieq',
#  'sandung',
#  'prokes',
#  'amp',
#  'pusar',
#  'puting',
#  'beliung',
#  'mega',
#  'korup',
#  'triliun',
#  'poros',
#  'prabowo',
#  'subianto',
#  'capit',
#  'benur',
#  'lobster',
#  'minum',
#  'jamu',
#  'klo',
#  'maju',
#  'pilpres',
#  'biar',
#  'kuat',
#  'jgn',
#  'sembah',
#  'muja',
#  'baliho',
#  'bkn',
#  'sirik',
#  'bego',
#  'bolakbalikkata',
#  'dadszzjioy',
#  'tolakbigotnkri',
#  'aryprasetyo85',
#  'radenano',
#  'kesittt',
#  '03',
#  'nakula',
#  'ririjreeng',
#  'rlanang',
#  'gitariiii',
#  'paltiwest',
#  'miduk17',
#  'kenhans03',
#  'cebong',
#  'bego',
#  'aja',
#  'sangkutin',
#  'anies',
#  'cari',
#  'noh',
#  'harun',
#  'mas',
#  'm',
#  'asmara1701',
#  'democrazy',
#  'id',
#  'fadlizon',
#  'ken',
#  'anies',
#  'gengsi',
#  'hahahahaha',
#  'bego',
#  'k',
#  'h',
#  'a',
#  'i',
#  'r',
#  'a',
#  'aniesbaswedan',
#  'lisaamartatara3',
#  'marlina',
#  'idha',
#  't3htjemplung',
#  'orang2',
#  'bego',
#  'dungu',
#  'abis',
#  'salah',
#  ...]

# %%
# Melakukan proses perhitungan dari setiap kemunculan isi content tweet
from nltk.probability import FreqDist
fqdist_content = FreqDist(word_tokenize_content)
fqdist_content
# Out:
# FreqDist({'bodoh': 778, 'tolol': 746, 'jokowi': 728, 'anies': 697, 'bego': 675, 'fadlizon': 645, 'orang': 304, 'gak': 216, 'aja': 215, 'nya': 188, ...})

# %%
# Menampilkan isi content tweet yang sering muncul sebanyak 500 kata
fqdist_content.most_common(500)
# Out:
# [('bodoh', 778),
#  ('tolol', 746),
#  ('jokowi', 728),
#  ('anies', 697),
#  ('bego', 675),
#  ('fadlizon', 645),
#  ('orang', 304),
#  ('gak', 216),
#  ('aja', 215),
#  ('nya', 188),
#  ('rachlannashidik', 147),
#  ('org', 131),
#  ('tau', 127),
#  ('rakyat', 126),
#  ('cebong', 122),
#  ('emang', 120),
#  ('klo', 117),
#  ('kalo', 116),
#  ('aniesbaswedan', 111),
#  ('otak', 108),
#  ('baca', 107),
#  ('salah', 106),
#  ('goblok', 106),
#  ('dennysiregar7', 104),
#  ('kau', 102),
#  ('amp', 99),
#  ('udah', 98),
#  ('sih', 95),
#  ('gubernur', 94),
#  ('bilang', 89),
#  ('tdk', 86),
#  ('kadrun', 86),
#  ('indonesia', 86),
#  ('loe', 78),
#  ('negara', 78),
#  ('presiden', 77),
#  ('kerja', 74),
#  ('bikin', 74),
#  ('jgn', 73),
#  ('komnasham', 73),
#  ('pilih', 70),
#  ('perintah', 70),
#  ('krn', 70),
#  ('polri', 70),
#  ('dukung', 69),
#  ('tuh', 68),
#  ('mardanialisera', 68),
#  ('hrs', 67),
#  ('jakarta', 65),
#  ('dgn', 64),
#  ('dki', 64),
#  ('prabowo', 64),
#  ('bin', 64),
#  ('anak', 63),
#  ('divhumas', 62),
#  ('sdh', 61),
#  ('fpi', 60),
#  ('dasar', 60),
#  ('banget', 58),
#  ('sinkbadher', 57),
#  ('biar', 55),
#  ('dungu', 54),
#  ('pimpin', 53),
#  ('utk', 53),
#  ('pinter', 51),
#  ('pikir', 50),
#  ('pura', 48),
#  ('baswedan', 48),
#  ('gitu', 47),
#  ('benci', 46),
#  ('bang', 45),
#  ('liat', 45),
#  ('politik', 44),
#  ('hnurwahid', 44),
#  ('nama', 43),
#  ('manusia', 43),
#  ('berita', 41),
#  ('pake', 41),
#  ('mati', 41),
#  ('didu', 41),
#  ('nih', 40),
#  ('cerdas', 40),
#  ('percaya', 40),
#  ('coba', 39),
#  ('malu', 39),
#  ('pintar', 39),
#  ('partai', 39),
#  ('ajar', 39),
#  ('hati', 39),
#  ('mohmahfudmd', 39),
#  ('beda', 38),
#  ('harga', 38),
#  ('dah', 38),
#  ('sakit', 38),
#  ('sandiuno', 38),
#  ('lisaamartatara3', 37),
#  ('kasih', 37),
#  ('kali', 37),
#  ('islam', 37),
#  ('kuasa', 37),
#  ('warga', 37),
#  ('anggap', 37),
#  ('elu', 36),
#  ('ferdinandhaean3', 36),
#  ('hukum', 36),
#  ('makan', 36),
#  ('bkn', 36),
#  ('msaid', 36),
#  ('ente', 36),
#  ('suka', 35),
#  ('ri', 35),
#  ('mas', 34),
#  ('paham', 34),
#  ('bukti', 34),
#  ('udh', 34),
#  ('bong', 34),
#  ('agama', 34),
#  ('urus', 33),
#  ('mah', 33),
#  ('main', 33),
#  ('hoax', 33),
#  ('menteri', 32),
#  ('orang2', 32),
#  ('hidup', 32),
#  ('fahrihamzah', 32),
#  ('skrg', 31),
#  ('ahok', 31),
#  ('jual', 31),
#  ('kek', 31),
#  ('bawa', 31),
#  ('tambur', 31),
#  ('demo', 31),
#  ('prestasi', 30),
#  ('doang', 30),
#  ('hasil', 30),
#  ('komen', 30),
#  ('cari', 30),
#  ('masyarakat', 30),
#  ('permadiaktivis1', 30),
#  ('fadjroel', 30),
#  ('ngomong', 29),
#  ('korupsi', 29),
#  ('terima', 29),
#  ('gin', 29),
#  ('kayak', 29),
#  ('geiszchalifah', 29),
#  ('kaya', 29),
#  ('bangun', 28),
#  ('vaksin', 28),
#  ('sampah', 28),
#  ('tempodotco', 28),
#  ('gue', 28),
#  ('sehat', 28),
#  ('ikut', 27),
#  ('atur', 27),
#  ('tetep', 27),
#  ('gimana', 26),
#  ('fitnah', 26),
#  ('spt', 26),
#  ('kena', 26),
#  ('dpr', 26),
#  ('zon', 26),
#  ('detikcom', 25),
#  ('bener', 25),
#  ('ama', 25),
#  ('id', 25),
#  ('ngerti', 25),
#  ('kpk', 25),
#  ('dlm', 25),
#  ('rezim', 25),
#  ('sok', 25),
#  ('gua', 25),
#  ('anjing', 25),
#  ('bantu', 25),
#  ('korban', 25),
#  ('official', 25),
#  ('jabat', 24),
#  ('suruh', 24),
#  ('elo', 24),
#  ('bohong', 24),
#  ('kaum', 24),
#  ('lihat', 24),
#  ('apa', 24),
#  ('bangsa', 24),
#  ('ridwankamil', 24),
#  ('dunia', 23),
#  ('ch', 23),
#  ('bela', 23),
#  ('buku', 23),
#  ('polisi', 23),
#  ('kalah', 23),
#  ('jansen', 23),
#  ('jsp', 23),
#  ('nyata', 22),
#  ('covid', 22),
#  ('junjung', 22),
#  ('rizieq', 22),
#  ('ngga', 22),
#  ('haikal', 22),
#  ('lawan', 22),
#  ('knp', 22),
#  ('contoh', 22),
#  ('ustadtengkuzul', 22),
#  ('ormas', 22),
#  ('cnnindonesia', 21),
#  ('gub', 21),
#  ('diam', 21),
#  ('langgar', 21),
#  ('bijak', 21),
#  ('laku', 21),
#  ('sampe', 21),
#  ('bayar', 21),
#  ('bicara', 21),
#  ('mmg', 21),
#  ('allah', 21),
#  ('iya', 21),
#  ('pelihara', 21),
#  ('radikal', 21),
#  ('pura2', 21),
#  ('situ', 20),
#  ('emg', 20),
#  ('habis', 20),
#  ('mrk', 20),
#  ('isi', 20),
#  ('tni', 20),
#  ('ngaku', 20),
#  ('jaman', 20),
#  ('fadli', 20),
#  ('tri', 19),
#  ('beliau', 19),
#  ('narasi', 19),
#  ('yah', 19),
#  ('jkt', 19),
#  ('chotlmah', 19),
#  ('wajar', 19),
#  ('masuk', 19),
#  ('foto', 19),
#  ('jdi', 19),
#  ('turun', 19),
#  ('langsung', 19),
#  ('jahat', 19),
#  ('surga', 19),
#  ('kelompok', 18),
#  ('psbb', 18),
#  ('hassan', 18),
#  ('aje', 18),
#  ('buka', 18),
#  ('keluarga', 18),
#  ('musniumar', 18),
#  ('buta', 18),
#  ('sandi', 18),
#  ('tinggal', 18),
#  ('mimpi', 18),
#  ('pakai', 17),
#  ('milih', 17),
#  ('msh', 17),
#  ('sekolah', 17),
#  ('pilpres', 17),
#  ('buzzer', 17),
#  ('wkwk', 17),
#  ('goblog', 17),
#  ('bangga', 17),
#  ('jalan', 17),
#  ('kerumun', 17),
#  ('asli', 17),
#  ('wakil', 17),
#  ('baik', 17),
#  ('anggota', 17),
#  ('hahaha', 17),
#  ('teroris', 17),
#  ('publik', 16),
#  ('deh', 16),
#  ('mikir', 16),
#  ('takut', 16),
#  ('duit', 16),
#  ('sahal', 16),
#  ('as', 16),
#  ('hahahaha', 16),
#  ('bro', 16),
#  ('pusat', 16),
#  ('nyinyir', 16),
#  ('ambil', 16),
#  ('piara', 16),
#  ('rusak', 16),
#  ('panggil', 16),
#  ('nyambung', 16),
#  ('milik', 16),
#  ('bgt', 16),
#  ('tuju', 16),
#  ('kritik', 16),
#  ('benar', 16),
#  ('trus', 16),
#  ('debat', 16),
#  ('oposisi', 16),
#  ('umat', 16),
#  ('tanah', 16),
#  ('zonk', 16),
#  ('andi', 16),
#  ('angkat', 15),
#  ('jilat', 15),
#  ('marlina', 15),
#  ('idha', 15),
#  ('beli', 15),
#  ('blm', 15),
#  ('jadi', 15),
#  ('serang', 15),
#  ('maju', 15),
#  ('banyak', 15),
#  ('bacot', 15),
#  ('pilkada', 15),
#  ('mending', 15),
#  ('hina', 15),
#  ('ngapain', 15),
#  ('cinta', 15),
#  ('sharif', 15),
#  ('sebar', 14),
#  ('aman', 14),
#  ('suara', 14),
#  ('uber', 14),
#  ('rumah', 14),
#  ('uang', 14),
#  ('bahas', 14),
#  ('arab', 14),
#  ('kyk', 14),
#  ('kota', 14),
#  ('wilayah', 14),
#  ('acara', 14),
#  ('inggris', 14),
#  ('klu', 14),
#  ('banjir', 14),
#  ('blg', 14),
#  ('tweet', 14),
#  ('daerah', 14),
#  ('mulut', 14),
#  ('tangkap', 14),
#  ('tua', 14),
#  ('moga', 14),
#  ('ulama', 14),
#  ('dlu', 14),
#  ('tambah', 14),
#  ('gampang', 14),
#  ('era', 14),
#  ('bansos', 14),
#  ('kemenkeuri', 14),
#  ('menang', 13),
#  ('kasi', 13),
#  ('mata', 13),
#  ('lucu', 13),
#  ('republikaonline', 13),
#  ('nkri', 13),
#  ('tugas', 13),
#  ('2024', 13),
#  ('rugi', 13),
#  ('nyalahin', 13),
#  ('bahasa', 13),
#  ('dengki', 13),
#  ('ilmu', 13),
#  ('kolam', 13),
#  ('dpt', 13),
#  ('sungguh', 13),
#  ('fakta', 13),
#  ('jann40260260', 13),
#  ('blok', 13),
#  ('yaa', 13),
#  ('vivacoid', 13),
#  ('kata2', 13),
#  ('kok', 13),
#  ('gratis', 13),
#  ('tuhan', 13),
#  ('pamer', 13),
#  ('data', 13),
#  ('dengar', 13),
#  ('alas', 13),
#  ('maaf', 13),
#  ('nafsu', 13),
#  ('omong', 13),
#  ('guoblok', 13),
#  ('putri', 13),
#  ('pki', 13),
#  ('gunromli', 13),
#  ('sibuk', 13),
#  ('twitt', 13),
#  ('puspen', 13),
#  ('ccicpolri', 13),
#  ('pdemokrat', 13),
#  ('kiyai', 13),
#  ('marufamin', 13),
#  ('lapor', 12),
#  ('harap', 12),
#  ('drun', 12),
#  ('tsamaradki', 12),
#  ('penuh', 12),
#  ('pas', 12),
#  ('tutup', 12),
#  ('banding', 12),
#  ('bawah', 12),
#  ('tanggung', 12),
#  ('juang', 12),
#  ('basuki', 12),
#  ('btp', 12),
#  ('sadar', 12),
#  ('penting', 12),
#  ('buah', 12),
#  ('photo', 12),
#  ('dkijakarta', 12),
#  ('anis', 12),
#  ('akal', 12),
#  ('kampanye', 12),
#  ('lgi', 12),
#  ('dri', 12),
#  ('dikit', 12),
#  ('tukang', 12),
#  ('kagak', 12),
#  ('salahin', 12),
#  ('wkwkwk', 12),
#  ('jawa', 12),
#  ('satu', 12),
#  ('susah', 12),
#  ('untung', 12),
#  ('lupa', 12),
#  ('maksud', 12),
#  ('didik', 12),
#  ('kaga', 12),
#  ('tulis', 12),
#  ('tipu', 12),
#  ('akun', 12),
#  ('kumpul', 12),
#  ('kader', 12),
#  ('koq', 12),
#  ('hancur', 12),
#  ('media', 12),
#  ('ngak', 12),
#  ('raisyaelbix1', 12),
#  ('ansor', 12),
#  ('sengaja', 12),
#  ('212', 12),
#  ('tempo', 12),
#  ('hak', 12),
#  ('butuh', 12),
#  ('ham', 12),
#  ('melayu02', 12),
#  ('widizay115', 12),
#  ('djoenbaela', 12),
#  ('syamsul344r1f', 12),
#  ('viant', 12),
#  ('terorisme', 12),
#  ('risma', 11),
#  ('beneran', 11),
#  ('mensos', 11),
#  ('tolong', 11),
#  ('lho', 11),
#  ('maspiyuo', 11),
#  ('ngurusin', 11),
#  ('ken', 11),
#  ('dikatain', 11),
#  ('pdi', 11),
#  ('cuman', 11),
#  ('bunuh', 11),
#  ('periode', 11),
#  ('demokrasi', 11),
#  ('gila', 11),
#  ('bos', 11),
#  ('luh', 11),
#  ('babi', 11),
#  ('gagal', 11),
#  ('borong', 11),
#  ('akut', 11),
#  ('bagus', 11),
#  ('mudah', 11),
#  ('retno', 11),
#  ('tonton', 11),
#  ('karna', 11),
#  ('hebat', 11),
#  ('koruptor', 11),
#  ('tuk', 11),
#  ('gerindra', 11),
#  ('jaya', 11),
#  ('adil', 11),
#  ('ganjarpranowo', 11),
#  ('hukumdan', 11),
#  ('utang', 11),
#  ('tahan', 11),
#  ('nakulas85315847', 11),
#  ('pao', 11),
#  ('restyresseh', 11),
#  ('nunukan', 11),
#  ('jodhigawa', 11),
#  ('adu', 10),
#  ('tpi', 10),
#  ('twit', 10),
#  ('tahu', 10),
#  ('juta', 10),
#  ('akibat', 10),
#  ('wkwkwkwk', 10),
#  ('mr', 10),
#  ('manfaat', 10),
#  ('logika', 10),
#  ('pdip', 10),
#  ('ayat', 10),
#  ('psi', 10)]

# %%
# Membuat visualisasi tweet berdasarkan isi tweet yang sering muncul sebanyak 30 kata yang sering digunakan
from cycler import cycler

plt.figure(figsize=(10, 7))
plt.title("Visualisasi Kata Yang Sering Dipakai Di Dalam Tweet", fontdict={"fontsize":15}, pad=15)
plt.rc("axes", prop_cycle=(cycler("color", ["b"])))
fqdist_content.plot(30, cumulative=False)
plt.show()

# %% [markdown]
# ## 4. Visualisasi Dengan Wordclouds

# %% [markdown]
# ### Semua Label (Positif & Negatif)

# %%
# Menampilkan sekaligus memvisualisasikan kata menggunakan wordcloud dari DataFrame "data_2020" dari kolom "content_bersih"  
all_tweet_post = " ".join(word for word in data_2020["content_bersih"])
wordcloud = WordCloud(colormap="CMRmap", width=700, height=300, 
                      mode="RGBA", background_color="lightgrey").generate(all_tweet_post)
plt.figure(figsize=(17,10))
plt.title("Menampilkan Semua Isi Content Tweet Dari Kolom 'content_bersih'", fontdict={"fontsize":15}, pad = 15);
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# Jika dilihat dari visualisasi diatas tampilan tersebut merupakan visualisasi dari wordcloud yang bertujuan untuk mendapatkan insight pemahaman secara utuh tentang suatu ide atau gagasan dari seseorang atau tulisan seseorang dalam suatu waktu tertentu. Visualsasi ini banyak sekali digunakan dalam pengujian analisa sentimen karena untuk melihat setiap kata-kata yang telah diketikkan oleh masyarakat.
#
# Namun tampilan visualisasi diatas masih mencakup semua label (positif & negatif) yang membuat kita kesulitan untuk mengetahui kata-kata mana yang bernilai positif/negatif. Maka dari itu kami akan membuatnya secara terpisah antara visualisasi wordcloud yang bernilai positif dan wordcloud yang bernilai negatif.

# %% [markdown]
# ### Label Positif

# %%
# Memisahkan semua data yang memiliki label positif yang disesuaikan dari kolom "label"
data_2020_label_positif = data_2020[data_2020.label == "positif"]
data_2020_label_positif.head()
# Out:
#                          date  \
# 0   2020-12-29 23:16:16+00:00
# 2   2020-12-28 14:52:49+00:00
# 6   2020-12-25 05:05:50+00:00
# 8   2020-12-24 14:08:33+00:00
# 10  2020-12-22 06:11:46+00:00
#
#                                               content    label  \
# 0    biespartacus da yangqu aniesbaswedan owh kalo...  positif
# 2    perisyantik merryanjani19 cnnindonesia situ b...  positif
# 6    hasmisahar lisaamartatara3 aniesbaswedan coba...  positif
# 8    ferdinandhaean3 skrg sedang jilat pemerintah ...  positif
# 10   pemerhatibangs4 selalubergerakk korupsi angga...  positif
#
#                                    content_tokenizing  \
# 0   [biespartacus, da, yangqu, aniesbaswedan, owh,...
# 2   [perisyantik, merryanjani19, cnnindonesia, sit...
# 6   [hasmisahar, lisaamartatara3, aniesbaswedan, c...
# 8   [ferdinandhaean3, skrg, sedang, jilat, pemerin...
# 10  [pemerhatibangs4, selalubergerakk, korupsi, an...
#
#                                     content_stopwords  \
# 0   [biespartacus, da, yangqu, aniesbaswedan, owh,...
# 2   [perisyantik, merryanjani19, cnnindonesia, sit...
# 6   [hasmisahar, lisaamartatara3, aniesbaswedan, c...
# 8   [ferdinandhaean3, skrg, jilat, pemerintah, ber...
# 10  [pemerhatibangs4, selalubergerakk, korupsi, an...
#
#                                      content_stemming  \
# 0   [biespartacus, da, yangqu, aniesbaswedan, owh,...
# 2   [perisyantik, merryanjani19, cnnindonesia, sit...
# 6   [hasmisahar, lisaamartatara3, aniesbaswedan, c...
# 8   [ferdinandhaean3, skrg, jilat, perintah, harap...
# 10  [pemerhatibangs4, selalubergerakk, korupsi, an...
#
#                                        content_bersih
# 0   biespartacus da yangqu aniesbaswedan owh kalo ...
# 2   perisyantik merryanjani19 cnnindonesia situ be...
# 6   hasmisahar lisaamartatara3 aniesbaswedan coba ...
# 8   ferdinandhaean3 skrg jilat perintah harap ngaj...
# 10  pemerhatibangs4 selalubergerakk korupsi anggar...

# %%
# Memvisualisasikan menggunakan wordcloud dari DataFrame "data_2020_label_positif" dari kolom "content_bersih"  
all_content_positive = " ".join(word for word in data_2020_label_positif["content_bersih"])
wordcloud = WordCloud(colormap="ocean", width=700, height=300, 
                      mode="RGBA", background_color="lightgrey").generate(all_content_positive)
plt.figure(figsize=(17,10))
plt.title("Menampilkan Semua Isi Content Yang Bersifat Positif Dari Kolom 'content_bersih'", 
          fontdict={"fontsize":15}, pad = 15);
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# ### Label Negatif

# %%
# Memisahkan semua data yang memiliki label negatif yang disesuaikan dari kolom "label"
data_2020_label_negatif = data_2020[data_2020.label == "negatif"]
data_2020_label_negatif.head()
# Out:
#                         date  \
# 1  2020-12-29 07:49:59+00:00
# 3  2020-12-28 07:19:18+00:00
# 4  2020-12-27 16:42:18+00:00
# 5  2020-12-26 22:53:17+00:00
# 7  2020-12-25 01:50:34+00:00
#
#                                              content    label  \
# 1  beda anies dengan pejabat publik lainnya pak a...  negatif
# 3   oposisicerdas pokoknya klo pak anies calon pr...  negatif
# 4   detikcom mnding mikir buat 2022 dulu bang 202...  negatif
# 5    doncorleone 78 yak bener kalo ngomong bego2i...  negatif
# 7   mw17714668 detikcom kalo anies kerja emg kudu...  negatif
#
#                                   content_tokenizing  \
# 1  [beda, anies, dengan, pejabat, publik, lainnya...
# 3  [oposisicerdas, pokoknya, klo, pak, anies, cal...
# 4  [detikcom, mnding, mikir, buat, 2022, dulu, ba...
# 5  [doncorleone, 78, yak, bener, kalo, ngomong, b...
# 7  [mw17714668, detikcom, kalo, anies, kerja, emg...
#
#                                    content_stopwords  \
# 1  [beda, anies, pejabat, publik, anies, kerja, b...
# 3  [oposisicerdas, pokoknya, klo, anies, calon, p...
# 4  [detikcom, mnding, mikir, 2022, bang, 2022, aj...
# 5  [doncorleone, 78, yak, bener, kalo, ngomong, b...
# 7  [mw17714668, detikcom, kalo, anies, kerja, emg...
#
#                                     content_stemming  \
# 1  [beda, anies, jabat, publik, anies, kerja, ber...
# 3  [oposisicerdas, pokok, klo, anies, calon, pres...
# 4  [detikcom, mnding, mikir, 2022, bang, 2022, aj...
# 5  [doncorleone, 78, yak, bener, kalo, ngomong, b...
# 7  [mw17714668, detikcom, kalo, anies, kerja, emg...
#
#                                       content_bersih
# 1  beda anies jabat publik anies kerja berita jab...
# 3  oposisicerdas pokok klo anies calon presiden o...
# 4  detikcom mnding mikir 2022 bang 2022 aja blum ...
# 5  doncorleone 78 yak bener kalo ngomong bego2in ...
# 7  mw17714668 detikcom kalo anies kerja emg kudu ...

# %%
# Membuat Tampilan Visualisasi menggunakan wordcloud dari DataFrame "data_2020_label_negatif" dari kolom "content_bersih" 
all_content_negative = " ".join(word for word in data_2020_label_negatif["content_bersih"])
wordcloud = WordCloud(colormap="ocean", width=700, height=300, 
                      mode="RGBA", background_color="lightgrey").generate(all_content_negative)
plt.figure(figsize=(17,10))
plt.title("Menampilkan Semua Isi Tweet Yang Bersifat Netral Dari Kolom Tweet_Bersih", 
          fontdict={"fontsize":15}, pad = 15);
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# ## 5. Melakukan Pemodelan Dengan Model Machine Learning

# %%
# Menampilkan keseluruhan data dari DataFrame "data_2020"
data_2020.head()
# Out:
#                         date  \
# 0  2020-12-29 23:16:16+00:00
# 1  2020-12-29 07:49:59+00:00
# 2  2020-12-28 14:52:49+00:00
# 3  2020-12-28 07:19:18+00:00
# 4  2020-12-27 16:42:18+00:00
#
#                                              content    label  \
# 0   biespartacus da yangqu aniesbaswedan owh kalo...  positif
# 1  beda anies dengan pejabat publik lainnya pak a...  negatif
# 2   perisyantik merryanjani19 cnnindonesia situ b...  positif
# 3   oposisicerdas pokoknya klo pak anies calon pr...  negatif
# 4   detikcom mnding mikir buat 2022 dulu bang 202...  negatif
#
#                                   content_tokenizing  \
# 0  [biespartacus, da, yangqu, aniesbaswedan, owh,...
# 1  [beda, anies, dengan, pejabat, publik, lainnya...
# 2  [perisyantik, merryanjani19, cnnindonesia, sit...
# 3  [oposisicerdas, pokoknya, klo, pak, anies, cal...
# 4  [detikcom, mnding, mikir, buat, 2022, dulu, ba...
#
#                                    content_stopwords  \
# 0  [biespartacus, da, yangqu, aniesbaswedan, owh,...
# 1  [beda, anies, pejabat, publik, anies, kerja, b...
# 2  [perisyantik, merryanjani19, cnnindonesia, sit...
# 3  [oposisicerdas, pokoknya, klo, anies, calon, p...
# 4  [detikcom, mnding, mikir, 2022, bang, 2022, aj...
#
#                                     content_stemming  \
# 0  [biespartacus, da, yangqu, aniesbaswedan, owh,...
# 1  [beda, anies, jabat, publik, anies, kerja, ber...
# 2  [perisyantik, merryanjani19, cnnindonesia, sit...
# 3  [oposisicerdas, pokok, klo, anies, calon, pres...
# 4  [detikcom, mnding, mikir, 2022, bang, 2022, aj...
#
#                                       content_bersih
# 0  biespartacus da yangqu aniesbaswedan owh kalo ...
# 1  beda anies jabat publik anies kerja berita jab...
# 2  perisyantik merryanjani19 cnnindonesia situ be...
# 3  oposisicerdas pokok klo anies calon presiden o...
# 4  detikcom mnding mikir 2022 bang 2022 aja blum ...

# %% [markdown]
# Karena pada pengujian kali ini data yang bersifat lebih dominan terhadap data dokumen maka kami akan menggunakan sebuah pembobotan nilai yang bernama TF-IDF (term frequency-inverse document frequency). Pembobotan dengan TF-IDF merupakan salah satu faktor pembobotan yang sering digunakan dalam konteks penambangan data yang bersifat full text. Selain itu TF-IDF juga dapat dapat digunakan untuk menganalisa hubungan antara sebuah frase/kalimat dengan sekumpulan dokumen. Teknik ini akan melakukan perhitungan dari sebuah kata kunci terhadap masing-masing dokumen.

# %%
# Melakukan proses pembobotan nilai dengan TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
data_2020_tfidf = tfidf.fit_transform(data_2020["content_bersih"].astype("U"))
data_2020_tfidf
# Out:
# <1800x7294 sparse matrix of type '<class 'numpy.float64'>'
# 	with 29130 stored elements in Compressed Sparse Row format>

# %%
# Melakukan pembagian data menjadi 2 bagian (data train & data test) menggunakan train_test_split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(data_2020_tfidf, data_2020["label"], test_size=0.2, random_state=20)

# %% [markdown]
# Penjelasan dari proses pemisahan data menjadi 2 variabel dan fungsi train_test_split:
#
# 1. data_2020_tfidf: merupakan sebuah fungsi yang berisi nilai pembobotan dari kolom "content_bersih"
# 2. data_2020: merupakan sebuah fungsi untuk mendeklarasikan/memanggil kolom "label" dari masing-masing nilai sentimen
# 3. test_size: Nilai presentase dari sebuah ukuran untuk membagi data test. Dalam pengujian ini saya memakai nilai test_size = 0.2 yang dimana ukuran dari data test mencapai 20% dan data train mencapai 80%.
# 4. random_state: Menetapkan nilai. Jika nilainya sama maka fungsi train_test_split akan menghasilkan pemisahan nilai yang sama persis di setiap waktunya. Namun jika ditentukan nilai random_statenya maka data akan diacak (random).

# %% [markdown]
# Setelah melakukan proses split yaitu membagi keutuhan data menjadi 2 bagian (data test & data train) langkah selanjutnya adalah melakukan pemodelan dengan menggunakan model multinomial naive bayes atau yang biasa dikenal sebagai MultinomialNB. Multinomial naive bayes merupakan sebuah teknik turunan dari naive bayes yang menggunakan teknik yang bernama conditional probability yaitu sebuah teknik yang dapat dilakukan dengan menggunakan frekuensi kemunculan suatu kata pada suatu kelas.

# %%
# Pemanggilan model Multinomial Naive Bayes (MultinomialNB) beserta parameternya
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV

model_mnb_train = MultinomialNB()

parameters = {
    "alpha": [6.5],
    "fit_prior": [False]
    
}

grid_search_mnb_train = GridSearchCV(model_mnb_train, parameters, cv=30) # CV = Cross Validation

grid_search_mnb_train.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=30, estimator=MultinomialNB(),
#              param_grid={'alpha': [6.5], 'fit_prior': [False]})

# %% [markdown]
# Penjelasan dari poin-poin yang ada di codingan diatas:
# 1. Parameters merupakan sebuah teknik pemanggilan fungsi-fungsi yang menjadi bagian dari sebuah model itu sendiri. Untuk mengecek parameter dari setiap model bisa dicek pada website sckit-learn. Pada codingan diatas, fungsi alpha dan fit_prior merupakan bagian dari parameter MultinomialNB.
# 2. GridSearchCV merupakan sebuah teknik untuk mencari best paramater/parameter terbaik untuk kasus klasifikasi. Pada codingan diatas, teknik GridSearchCV saya gunakan untuk memanggil variabel model dari MultinomialNB (model_mnb), fungsi serta nilai dari paramater model MultinomialNB, dan fungsi cross validation yang bernilai 30.
# 3. Cross Validation merupakan sebuah metode yang biasa dipakai dalam pengujian data mining yang bertujuan untuk memperoleh hasil akhir yang optimal. Metode ini akan menilai dengan cara mengestimasi rotasi yang hasil statistik analisisnya akan menggeneralisasi kumpulan data yang bersifat independen.
# 4. .fit merupakan sebuah fungsi yang bertujuan untuk melatih model dengan data training.

# %% [markdown]
# Namun setelah melakukan proses pemodelan untuk data train, saya juga akan melakukan pemodelan untuk data latih (test) supaya hasil akurasi yang di dapatkan tidak mengalami overfitting.

# %%
"""
Karena pada langkah sebelumnya sudah melakukan pemanggilan model Multinomial Naive Bayes terhadap data train (latih) selanjutnya
adalah melakukan pemanggilan model Multinomial Naive Bayes untuk data latih
"""
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV

model_mnb_test = MultinomialNB()

parameters = {
    "alpha": [6.5],
    "fit_prior": [False]
}

grid_search_mnb_test = GridSearchCV(model_mnb_test, parameters, cv=30) # CV = Cross Validation

grid_search_mnb_test.fit(x_test, y_test) # Melatih model MultinomialNB dengan data test supaya tidak terjadi imbalanced
# Out:
# GridSearchCV(cv=30, estimator=MultinomialNB(),
#              param_grid={'alpha': [6.5], 'fit_prior': [False]})

# %%
# Melakukan pengujian untuk variabel test & varibael train
print("------------------------Prediksi Dari Data Uji---------------------------------")
prediction_test = grid_search_mnb_train.predict(x_test)
print(prediction_test)

print()

print("----------------------Prediksi Dari Data Latih---------------------------------")
prediction_train = grid_search_mnb_test.predict(x_train)
print(prediction_train)
# Out:
# ------------------------Prediksi Dari Data Uji---------------------------------
# ['positif' 'positif' 'positif' 'negatif' 'negatif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'negatif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'negatif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'negatif' 'positif' 'positif' 'positif' 'negatif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'negatif'
#  'negatif' 'negatif' 'positif' 'positif' 'negatif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'negatif' 'positif'
#  'positif' 'negatif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'negatif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'negatif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'negatif' 'positif'
#  'positif' 'negatif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'negatif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'negatif' 'positif' 'negatif' 'positif' 'positif' 'negatif'
#  'negatif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'negatif' 'positif' 'positif' 'negatif' 'positif' 'negatif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'negatif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'negatif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'negatif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'negatif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'positif' 'negatif' 'negatif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'negatif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif']
#
# ----------------------Prediksi Dari Data Latih---------------------------------
# ['positif' 'positif' 'positif' ... 'positif' 'positif' 'positif']

# %%
# Membuat visualisasi untuk menampilkan pengukuran performa dari hasil prediksi pada variabel uji & latih

f, ax = plt.subplots(figsize=(9, 4))
sns.heatmap(confusion_matrix(y_test, prediction_test), annot=True, cmap="coolwarm", fmt=".0f", ax=ax)
plt.xlabel("Prediksi")
plt.ylabel("Aktual")
plt.title("Pengukuran Performa Hasil Klasifikasi Dari Variabel Uji", fontdict={"fontsize":13}, pad=13)
plt.show()

f, ax = plt.subplots(figsize=(9, 4))
sns.heatmap(confusion_matrix(y_train, prediction_train), annot=True, cmap="coolwarm", fmt=".0f", ax=ax)
plt.xlabel("Nilai Prediksi")
plt.ylabel("Nilai Aktual")
plt.title("Pengukuran Performa Hasil Klasifikasi Dari Variabel Latih", fontdict={"fontsize":13}, pad=13)
plt.show()

# %% [markdown]
# Penjelasan dari visualisasi pada confusion matrix:
# - Data Test
# 1. True Positive pada data test memiliki nilai sejumlah 28. True Positive merupakan data yang bernilai positif yang diprediksi tepat.
# 2. True Negative pada data test memiliki nilai sejumlah 222. True Negative sendiri merupakan data yang bernilai negatif yang diprediksi secara tepat.
# 3. False Positive pada data test memiliki nilai sejumlah 99. False Positive sendiri merupakan data yang bernilai negatif namun pada saat diprediksi terhitung sebagai data positif.
# 4. False Negative pada data test memiliki nilai sejumlah 11. False Negative sendiri merupakan data yang bernilai positif namun pada saat diprediksi terhitung sebagai data yang negatif.
#
# - Data Train
# 1. True Positive pada data train memiliki nilai sejumlah 80. True Positive merupakan data yang bernilai positif yang diprediksi tepat.
# 2. True Negative pada data train memiliki nilai sejumlah 826. True Negative sendiri merupakan data yang bernilai negatif yang diprediksi secara tepat.
# 3. False Positive pada data train memiliki nilai sejumlah 495. False Positive sendiri merupakan data yang bernilai negatif namun pada saat diprediksi terhitung sebagai data positif.
# 4. False Negative pada data train memiliki nilai sejumlah 39. False Negative sendiri merupakan data yang bernilai positif namun pada saat diprediksi terhitung sebagai data yang negatif.

# %%
# Menampilkan tingkat akurasi, precision, recall & f1-score dari model Multonimial Naive Bayes

print("------------------------Prediksi Dari Variabel Uji-------------------------------")
cr_test = classification_report(y_test, prediction_test)
print(cr_test)

print("------------------------Prediksi Dari Variabel Latih-------------------------------")
cr_train = classification_report(y_train, prediction_train)
print(cr_train)
# Out:
# ------------------------Prediksi Dari Variabel Uji-------------------------------
#               precision    recall  f1-score   support
#
#      negatif       0.72      0.22      0.34       127
#      positif       0.69      0.95      0.80       233
#
#     accuracy                           0.69       360
#    macro avg       0.70      0.59      0.57       360
# weighted avg       0.70      0.69      0.64       360
#
# ------------------------Prediksi Dari Variabel Latih-------------------------------
#               precision    recall  f1-score   support
#
#      negatif       0.67      0.14      0.23       575
#      positif       0.63      0.95      0.76       865
#
#     accuracy                           0.63      1440
#    macro avg       0.65      0.55      0.49      1440
# weighted avg       0.64      0.63      0.55      1440

# %% [markdown]
# ## 6. Membuat Prediksi Akhir & Visualisasi Tahap Akhir

# %%
# Membuat variabel baru yang dihasilkan dari prediksi label content sentimen terhadap data test
content_output_test_2020 = pd.DataFrame({"label": prediction_test})
content_output_test_2020.head()
# Out:
#      label
# 0  positif
# 1  positif
# 2  positif
# 3  negatif
# 4  negatif

# %%
# Membuat variabel yang dihasilkan dari prediksi label content sentimen terhadap data train
content_output_train_2020 = pd.DataFrame({"label": prediction_train})
content_output_train_2020.head()
# Out:
#      label
# 0  positif
# 1  positif
# 2  positif
# 3  positif
# 4  positif

# %%
# Visualisasi untuk melihat sekaligus membandingkan hasil sentimen dari data test & data train
plt.figure(figsize=(15, 5))

# Visualiasi dari hasil prediksi pada variabel test/uji
plt.subplot(1, 2, 1)
sns.countplot(x="label", hue="label", data=content_output_test_2020)
plt.title("Visualisasi Label Sentimen Pada Data Uji Setelah Di Prediksi (Tahun 2020)", fontdict={"fontsize":13}, pad=13)
plt.xlabel("Label Sentimen Pada Data Uji")
plt.ylabel("Jumlah Tweet")
plt.legend()

# Visualiasi dari hasil prediksi pada variabel train/latih
plt.subplot(1, 2, 2)
sns.countplot(x="label", hue="label", data=content_output_train_2020)
plt.title("Visualisasi Label Sentimen Pada Data Latih Setelah Di Prediksi (Tahun 2020)", fontdict={"fontsize":13}, pad=13)
plt.xlabel("Label Sentimen Pada Data Latih")
plt.ylabel("Jumlah Tweet")
plt.show()

# %% [markdown]
# Penjelasan dari bar plot sebagai berikut:
#
#  - Variabel content_output_test_2020
# 1. Pada variabel content_output_test_2020 dengan nilai label "positif" memiliki jumlah akhir isi content tweet sebanyak 321. Sedangkan pada nilai label "negatif" di variabel content_output_test_2020 memiliki jumlah nilai isi content tweet sebanyak 39 Jadi dapat disimpulkan bahwasanya jumlah akhir setelah dilakukan klasifikasi nilai label "positif" lebih banyak daripada nilai label "negatif" yang memiliki selisih nilai sebanyak 282 nilai.
#
# - Variabel content_ouutput_train_2020
# 1. Pada variabel content_output_train_2020 dengan nilai label "positif" memiliki jumlah akhir isi content tweet sebanyak 1321. Sedangkan pada nilai label "negatif" di variabel content_output_train_2020 memiliki jumlah nilai isi content tweet sebanyak 119. Jadi dapat disimpulkan bahwasanya jumlah akhir setelah dilakukan klasifikasi nilai label "positif" lebih banyak daripada nilai label "negatif" yang memiliki selisih nilai sebanyak 1202 nilai.
