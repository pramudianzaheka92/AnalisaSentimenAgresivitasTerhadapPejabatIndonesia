# %% [markdown]
# # Analisa Sentimen Dari Media Sosial Twitter Tentang Agresivitas Kepada Para Pejabat Indonesia Di Tahun 2017

# %% [markdown]
# ## 1. Import Library & Load Dataset Dari Local Device

# %%
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
from sklearn.metrics import confusion_matrix, classification_report

# %%
data_2017 = pd.read_excel("Data Tahun 2017.xlsx")
data_2017.head()
# Out:
#                         date  \
# 0  2017-12-29 08:09:29+00:00
# 1  2017-12-28 02:12:13+00:00
# 2  2017-12-27 12:32:16+00:00
# 3  2017-12-26 13:01:10+00:00
# 4  2017-12-26 08:29:32+00:00
#
#                                              content    label
# 0  @PenDjaca @herditiya1 berharap menkeu meralat ...  negatif
# 1  @tonywibowo12 @Michael24007966 @triwul82 @semi...  positif
# 2  @detikfinance Aduh anies jng mgeliatin bego ny...  positif
# 3  Emangnya Anies lakukan kmpanye hitam.Dmn.Apa m...  positif
# 4  @Dahnilanzar Anies itu toleran kalau menguntun...  positif

# %%
# Mengecek tipe data dan juga apakah di dalam data memiliki nilai NaN/tidak
data_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     1800 non-null   object
#  1   content  1800 non-null   object
#  2   label    1800 non-null   object
# dtypes: object(3)
# memory usage: 42.3+ KB

# %%
# Melakukan visualisasi untuk kolom "Sentimen"

plt.style.use("seaborn")
plt.title("Perhitungan Label Sentimen Secara Manual")
sns.countplot(x="label", hue="label", data=data_2017)
plt.figure(figsize=(10, 10))
plt.show()

# %%
# Menghitung sekaligus mengurutkan jumlah label terbanyak berdasarkan tweet
jumlah_content = data_2017.groupby("label").count()["content"].reset_index().sort_values(by="content", ascending=False)
jumlah_content.style.background_gradient(cmap="summer")
# Out:
# <style  type="text/css" >
# #T_6abdf94f_fb18_11eb_a3f6_8a52637b5ce0row0_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_6abdf94f_fb18_11eb_a3f6_8a52637b5ce0row1_col1{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_6abdf94f_fb18_11eb_a3f6_8a52637b5ce0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >label</th>        <th class="col_heading level0 col1" >content</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6abdf94f_fb18_11eb_a3f6_8a52637b5ce0level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_6abdf94f_fb18_11eb_a3f6_8a52637b5ce0row0_col0" class="data row0 col0" >positif</td>
#                         <td id="T_6abdf94f_fb18_11eb_a3f6_8a52637b5ce0row0_col1" class="data row0 col1" >1062</td>
#             </tr>
#             <tr>
#                         <th id="T_6abdf94f_fb18_11eb_a3f6_8a52637b5ce0level0_row1" class="row_heading level0 row1" >0</th>
#                         <td id="T_6abdf94f_fb18_11eb_a3f6_8a52637b5ce0row1_col0" class="data row1 col0" >negatif</td>
#                         <td id="T_6abdf94f_fb18_11eb_a3f6_8a52637b5ce0row1_col1" class="data row1 col1" >738</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Dapat dilihat dari perhitungan diatas, dari 1800 jumlah data netizen twitter ketika melakukan tweet tentang topik para pejabat di Indonesia mendapatkan label positif yang sangat tinggi daripada label negatif yang memiliki jumlah sentimen sebanyak 1062 tweet sedangkan label negatif memiliki jumlah sentimen sebanyak 738.

# %% [markdown]
# ## 2. Text Processing (Cleansing, Case Folding, Tokenizing, Stopwords & Stemming)

# %% [markdown]
# ### Cleansing Teks

# %%
# Menghilangkan tweet dan username dari kalimat-kalimat, simbol-simbol, emoticon yang tidak dibutuhkan selama pengujian
def bersih_text(text):
    text = re.sub(r'[^a-zA-z0-9]',' ', str(text))
    text = re.sub(r'\b\w{1,2}\b','', text)
    text = re.sub(r'\s\s+',' ', text)
    text = re.sub(r'https?:\/\/\S+', '', text)  
    text = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text)
    return text

data_2017["content"] = data_2017["content"].apply(bersih_text)

data_2017.head()
# Out:
#                         date  \
# 0  2017-12-29 08:09:29+00:00
# 1  2017-12-28 02:12:13+00:00
# 2  2017-12-27 12:32:16+00:00
# 3  2017-12-26 13:01:10+00:00
# 4  2017-12-26 08:29:32+00:00
#
#                                              content    label
# 0   PenDjaca herditiya1 berharap menkeu meralat p...  negatif
# 1   tonywibowo12 Michael24007966 triwul82 semiaji...  positif
# 2   detikfinance Aduh anies jng mgeliatin bego ny...  positif
# 3  Emangnya Anies lakukan kmpanye hitam Dmn Apa m...  positif
# 4   Dahnilanzar Anies itu toleran kalau menguntun...  positif

# %%
# Menghapus spasi pada kolom "label"
data_2017.label = list(map(lambda x: x.strip(), data_2017.label))
data_2017.head()
# Out:
#                         date  \
# 0  2017-12-29 08:09:29+00:00
# 1  2017-12-28 02:12:13+00:00
# 2  2017-12-27 12:32:16+00:00
# 3  2017-12-26 13:01:10+00:00
# 4  2017-12-26 08:29:32+00:00
#
#                                              content    label
# 0   PenDjaca herditiya1 berharap menkeu meralat p...  negatif
# 1   tonywibowo12 Michael24007966 triwul82 semiaji...  positif
# 2   detikfinance Aduh anies jng mgeliatin bego ny...  positif
# 3  Emangnya Anies lakukan kmpanye hitam Dmn Apa m...  positif
# 4   Dahnilanzar Anies itu toleran kalau menguntun...  positif

# %% [markdown]
# Setelah melakukan proses cleansing teks yaitu menghapus beberapa simbol/karakter-karakter yang tidak dipentingkan dalam kolom content tweet, langkah selanjutnya adalah case folding. Case folding merupakan sebuah tahapan untuk mengubah huruf-huruf kapital menjadi huruf-huruf kecil.

# %% [markdown]
# ### Case Folding

# %%
# Mengubah ukuran setiap kalimat yang ada di kolom "content" menjadi huruf kecil
data_2017["content"] = data_2017["content"].str.lower()

data_2017.head()
# Out:
#                         date  \
# 0  2017-12-29 08:09:29+00:00
# 1  2017-12-28 02:12:13+00:00
# 2  2017-12-27 12:32:16+00:00
# 3  2017-12-26 13:01:10+00:00
# 4  2017-12-26 08:29:32+00:00
#
#                                              content    label
# 0   pendjaca herditiya1 berharap menkeu meralat p...  negatif
# 1   tonywibowo12 michael24007966 triwul82 semiaji...  positif
# 2   detikfinance aduh anies jng mgeliatin bego ny...  positif
# 3  emangnya anies lakukan kmpanye hitam dmn apa m...  positif
# 4   dahnilanzar anies itu toleran kalau menguntun...  positif

# %% [markdown]
# Setelah melakukan proses case folding, langkah selanjutnya adalah tokenizing/tokenisasi. Tahap tokenizing merupakan tahap pemotongan teks ke dalam satuan kata.

# %% [markdown]
# ### Tokenizing

# %%
# Melakukan Tahapan Tokenisasi. 
# Tokenisasi adalah tahapan prepocessing data yang digunakan untuk membagi kalimat menjadi perkata
def tokennization(text):
    return word_tokenize(text)

data_2017["content_tokenizing"] = data_2017["content"].apply(tokennization)
data_2017.head()
# Out:
#                         date  \
# 0  2017-12-29 08:09:29+00:00
# 1  2017-12-28 02:12:13+00:00
# 2  2017-12-27 12:32:16+00:00
# 3  2017-12-26 13:01:10+00:00
# 4  2017-12-26 08:29:32+00:00
#
#                                              content    label  \
# 0   pendjaca herditiya1 berharap menkeu meralat p...  negatif
# 1   tonywibowo12 michael24007966 triwul82 semiaji...  positif
# 2   detikfinance aduh anies jng mgeliatin bego ny...  positif
# 3  emangnya anies lakukan kmpanye hitam dmn apa m...  positif
# 4   dahnilanzar anies itu toleran kalau menguntun...  positif
#
#                                   content_tokenizing
# 0  [pendjaca, herditiya1, berharap, menkeu, meral...
# 1  [tonywibowo12, michael24007966, triwul82, semi...
# 2  [detikfinance, aduh, anies, jng, mgeliatin, be...
# 3  [emangnya, anies, lakukan, kmpanye, hitam, dmn...
# 4  [dahnilanzar, anies, itu, toleran, kalau, meng...

# %% [markdown]
# Setelah melakukan tahapan tokenisasi, selanjutnya saya akan melakukan proses filtering (stowords). Proses stopwords ini merupakan tahapan mengambil kata-kata dari tahapan tokenisasi. Stopword merupakan sebuah tahapan yang dimana bertujuan untuk membuang kata-kata yang tidak deskriptif dalam melakukan pendekatan bag-of-words.

# %% [markdown]
# ### Stopwords

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
 
factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()
print(stopwords)
# Out:
# ['yang', 'untuk', 'pada', 'ke', 'para', 'namun', 'menurut', 'antara', 'dia', 'dua', 'ia', 'seperti', 'jika', 'jika', 'sehingga', 'kembali', 'dan', 'tidak', 'ini', 'karena', 'kepada', 'oleh', 'saat', 'harus', 'sementara', 'setelah', 'belum', 'kami', 'sekitar', 'bagi', 'serta', 'di', 'dari', 'telah', 'sebagai', 'masih', 'hal', 'ketika', 'adalah', 'itu', 'dalam', 'bisa', 'bahwa', 'atau', 'hanya', 'kita', 'dengan', 'akan', 'juga', 'ada', 'mereka', 'sudah', 'saya', 'terhadap', 'secara', 'agar', 'lain', 'anda', 'begitu', 'mengapa', 'kenapa', 'yaitu', 'yakni', 'daripada', 'itulah', 'lagi', 'maka', 'tentang', 'demi', 'dimana', 'kemana', 'pula', 'sambil', 'sebelum', 'sesudah', 'supaya', 'guna', 'kah', 'pun', 'sampai', 'sedangkan', 'selagi', 'sementara', 'tetapi', 'apakah', 'kecuali', 'sebab', 'selain', 'seolah', 'seraya', 'seterusnya', 'tanpa', 'agak', 'boleh', 'dapat', 'dsb', 'dst', 'dll', 'dahulu', 'dulunya', 'anu', 'demikian', 'tapi', 'ingin', 'juga', 'nggak', 'mari', 'nanti', 'melainkan', 'oh', 'ok', 'seharusnya', 'sebetulnya', 'setiap', 'setidaknya', 'sesuatu', 'pasti', 'saja', 'toh', 'ya', 'walau', 'tolong', 'tentu', 'amat', 'apalagi', 'bagaimanapun']

# %% [markdown]
# Proses stopwords saya lakukan dengan mengambil nilai-nilai yang ada diatas yang sudah ditentukan oleh library Sastrawi. Kata-kata diatas boleh digunakan secara keseluruhan/diambil hanya beberapa saja.

# %%
# Proses Filtering dari kolom "Tweet_Tokenizing"
nltk.download("stopwords")
from nltk.corpus import stopwords

list_delete = ["yang", "untuk", "pada", "ke", "antara", "dua", "ia", "seperti", "antara", "dia", "seperti", "jika",
               "tidak", "oleh", "saat", "harus", "sementara", "mereka", "sudah", "terhadap", "sehingga",
               "secara", "agar", "lain", "begitu", "mengapa", "kenapa", "yaitu", "yakni", "daripada",
               "sekitar", "serta", "di", "dari", "telah", "sebagai", "masih", 'setidaknya', "sesuatu", "pasti", 
               "saja", "toh", "ya", "walau", "hal", "bahwa", "atau", "hanya", "ada", "mereka", "agar", "lain", 
               "anda", "begitu", "yaitu", "yakni", "itulah", "demi", "dimana", "pula", "sambil", "sebelum", 
               "sesudah", "guna", "ia", "dengan", "https", "supaya", "kah", "pun", "sampai", "seraya", "seterusnya", 
               "tanpa", "agak", "boleh", "dapat", "dsb", "dst", "nggak", "mari", "nanti", "melainkan", "oh", "ok",
               "sedangkan", "selagi", "seharusnya", "sebetulnya", "setiap", "apakah", "kecuali", "sebab", "selain"]

list_stopwords = stopwords.words("indonesian")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Mendeklarasikan fungsi untuk list_stopwords
def stopword(text):
    return [word for word in text if word not in list_stopwords]

data_2017["content_stopwords"] = data_2017["content_tokenizing"].apply(stopword)

# %%
# Mendeklarasikan fungsi untuk list_delete
def stopwords_removal(text):
    return [word for word in text if word not in list_delete]

data_2017["content_stopwords"] = data_2017["content_stopwords"].apply(stopwords_removal)
data_2017.head()
# Out:
#                         date  \
# 0  2017-12-29 08:09:29+00:00
# 1  2017-12-28 02:12:13+00:00
# 2  2017-12-27 12:32:16+00:00
# 3  2017-12-26 13:01:10+00:00
# 4  2017-12-26 08:29:32+00:00
#
#                                              content    label  \
# 0   pendjaca herditiya1 berharap menkeu meralat p...  negatif
# 1   tonywibowo12 michael24007966 triwul82 semiaji...  positif
# 2   detikfinance aduh anies jng mgeliatin bego ny...  positif
# 3  emangnya anies lakukan kmpanye hitam dmn apa m...  positif
# 4   dahnilanzar anies itu toleran kalau menguntun...  positif
#
#                                   content_tokenizing  \
# 0  [pendjaca, herditiya1, berharap, menkeu, meral...
# 1  [tonywibowo12, michael24007966, triwul82, semi...
# 2  [detikfinance, aduh, anies, jng, mgeliatin, be...
# 3  [emangnya, anies, lakukan, kmpanye, hitam, dmn...
# 4  [dahnilanzar, anies, itu, toleran, kalau, meng...
#
#                                    content_stopwords
# 0  [pendjaca, herditiya1, berharap, menkeu, meral...
# 1  [tonywibowo12, michael24007966, triwul82, semi...
# 2  [detikfinance, aduh, anies, jng, mgeliatin, be...
# 3  [emangnya, anies, lakukan, kmpanye, hitam, dmn...
# 4  [dahnilanzar, anies, toleran, menguntungkan, e...

# %% [markdown]
# Tahapan terakhir dalam text processing adalah proses stemming. Teknik Stemming merupakan sebuah tahapan kegiatan text preprocessing untuk memperkecil jumlah indeks yang berbeda dari suatu data dan juga untuk melakukan pengelompokan kata-kata lain yang memiliki kata dasar dan arti yang serupa namun memiliki bentuk yang berbeda karena mendapatkan imbuhan yang berbeda pula.

# %% [markdown]
# ### Stemming

# %%
# Proses Stemming dibantu dengan bantuan swifter
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter # Swifter berfungsi untuk mempercepat froses stemming pada Dataframe dengan menjalankan task secara parallel

# Membuat Stemmer dari sastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Membuat fungsi stemming
def stemming(text):
    return stemmer.stem(text)

term_dict = {}

# Menghitung ada berapa kata/words di dalam kolom "content_stopwords"
for document in data_2017["content_stopwords"]:
    for text in document:
        if text not in term_dict:
            term_dict[text] = " "
            
print(len(term_dict))
print("------------------------")

# Menampilkan isi kata/words yang telah dilakukan proses stemming
for text in term_dict:
    term_dict[text] = stemming(text)
    print(text,":" ,term_dict[text])
    
print(term_dict)
print("------------------------")

# Membuat fungsi baru untuk proses stemming
def stemming_word(document):
    return [term_dict[text] for text in document]

data_2017["content_stemming"] = data_2017["content_stopwords"].swifter.apply(stemming_word)
# Out:
# 8462
# ------------------------
# pendjaca : pendjaca
# herditiya1 : herditiya1
# berharap : harap
# menkeu : menkeu
# meralat : ralat
# pernyataannya : nyata
# pembenci : benci
# anies : anies
# sandi : sandi
# keliatan : liat
# bego : bego
# tonywibowo12 : tonywibowo12
# michael24007966 : michael24007966
# triwul82 : triwul82
# semiaji : semiaji
# w : w
# tetapahokdjarot : tetapahokdjarot
# aniesbaswedan : aniesbaswedan
# suaraanies : suaraanies
# kpk : kpk
# ri : ri
# jokowi : jokowi
# ruhutsitompul : ruhutsitompul
# tjahjo : tjahjo
# kumolo : kumolo
# anti : anti
# sdh : sdh
# salah : salah
# baca : baca
# berita : berita
# gak : gak
# dasar : dasar
# guoblok : guoblok
# tinggal : tinggal
# dijakarta : dijakarta
# kalo : kalo
# berani : berani
# langsung : langsung
# datengin : datengin
# napa : napa
# kritik : kritik
# hebat : hebat
# bicara : bicara
# medsos : medsos
# haha : haha
# jkrta : jkrta
# mikiiirrr : mikiiirrr
# tong : tong
# detikfinance : detikfinance
# aduh : aduh
# jng : jng
# mgeliatin : mgeliatin
# nya : nya
# elo : elo
# srimulyani : srimulyani
# udh : udh
# manajer : manajer
# world : world
# bank : bank
# ngasal : ngasal
# bkin : bkin
# anggaran : anggar
# enak : enak
# bngt : bngt
# pejabat : jabat
# abis2in : abis2in
# uang : uang
# rakyat : rakyat
# sarap : sarap
# nyiiiing : nyiiiing
# sia : sia
# mah : mah
# emangnya : emang
# lakukan : laku
# kmpanye : kmpanye
# hitam : hitam
# dmn : dmn
# materinya : materi
# tunjukkan : tunjuk
# pengamat : amat
# pngamat : pngamat
# pro : pro
# ahoker : ahoker
# korantempo : korantempo
# xphgcuqfwg : xphgcuqfwg
# dahnilanzar : dahnilanzar
# toleran : toleran
# menguntungkan : untung
# ente : ente
# pura2 : pura2
# baswedan : baswedan
# gubernur : gubernur
# dimiliki : milik
# jakarta : jakarta
# mantan : mantan
# rektor : rektor
# paham : paham
# beda : beda
# pasar : pasar
# jalan : jalan
# senyum : senyum
# kekecewaan : kecewa
# pkl : pkl
# penataan : tata
# tanah : tanah
# abang : abang
# ala : ala
# 1oix5sl6p6 : 1oix5sl6p6
# ve4zsksvrt : ve4zsksvrt
# arab : arab
# bodoh : bodoh
# bin : bin
# tolol : tolol
# bangsat : bangsat
# perseteruan : seteru
# kemendagri : kemendagri
# tgupp : tgupp
# aag3qz8crr : aag3qz8crr
# jeg : jeg
# likte : likte
# youtube : youtube
# video : video
# fyojwcreia : fyojwcreia
# mendagri : mendagri
# cagubnyinyir : cagubnyinyir
# lulung : lulung
# sempet2nya : sempet2nya
# jenius : jenius
# menata : tata
# lawan : lawan
# ombudsman : ombudsman
# thdp : thdp
# cara2 : cara2
# dicoret : coret
# des : des
# yovnmiqdep : yovnmiqdep
# reyarton : reyarton
# ridwan : ridwan
# ayaaya : ayaaya
# kangdede78 : kangdede78
# fanatik : fanatik
# blh : blh
# jgn : jgn
# tuh : tuh
# pct : pct
# krn : krn
# kerja : kerja
# apalg : apalg
# ngurus : ngurus
# 23t : 23t
# ampir : ampir
# lolos : lolos
# untung : untung
# ketahuan : tahu
# gabener : gabener
# jualan : jual
# sara : sara
# menunjukan : tunjuk
# amp : amp
# dki : dki
# diabisin : diabisin
# peruntukannya : untuk
# ngaku : ngaku
# jonan : jonan
# pinter : pinter
# msh : msh
# banget : banget
# lahh : lahh
# gausah : gausah
# twitter : twitter
# gabakal : gabakal
# denger : denger
# doi : doi
# cuy : cuy
# ketemu : ketemu
# sms : sms
# wkwk : wkwk
# gabisa : gabisa
# doain : doain
# aja : aja
# allah : allah
# ngerubah : ngerubah
# perilaku : perilaku
# vento : vento
# melvin : melvin
# dsimbol1 : dsimbol1
# tjakdny : tjakdny
# republikaonline : republikaonline
# oon : oon
# move : move
# nerima : nerima
# kenyataan : nyata
# ngehabur : ngehabur
# hamburin : hamburin
# apbd : apbd
# cmiww : cmiww
# tolong : tolong
# garis : garis
# bawahi : bawah
# kalimat : kalimat
# demit : demit
# gue : gue
# percaya : percaya
# taeeeeeee : taeeeeeee
# kompascom : kompascom
# tdk : tdk
# karuan : karuan
# menganggap : anggap
# warga : warga
# jaman : jaman
# ahok : ahok
# digaji : gaji
# pakai : pakai
# dana : dana
# operasional : operasional
# anien : anien
# bedanya : beda
# perbedaan : beda
# dianggarkan : anggar
# waras : waras
# muter2 : muter2
# hidahidaan : hidahidaan
# mas : mas
# hida : hida
# orang : orang
# berpikir : pikir
# kritis : kritis
# data : data
# bikin : bikin
# berubah : ubah
# pendirian : diri
# taun : taun
# inkonsisten : inkonsisten
# petualangan : tualang
# pemikiran : pikir
# tukangkoprol : tukangkoprol
# omongannya : omong
# wkt : wkt
# debat : debat
# dlu : dlu
# bilang : bilang
# putus : putus
# asa : asa
# skrg : skrg
# pake : pake
# smua : smua
# program : program
# utk : utk
# lansia : lansia
# kali : kali
# sih : sih
# doank : doank
# prinsip : prinsip
# terpilih : pilih
# janji : janji
# masyarakat : masyarakat
# termakan : makan
# omongan : omong
# kebencian : benci
# sandy : sandy
# kecebong : kecebong
# permanen : permanen
# kampanye : kampanye
# ngomong : ngomong
# rekamannya : rekam
# solusi : solusi
# banjir : banjir
# versi : versi
# koq : koq
# pbgdawgqly : pbgdawgqly
# pembodohan : bodoh
# dibodohin : dibodohin
# sllu : sllu
# berusaha : usaha
# lepas : lepas
# bayang2 : bayang2
# klo : klo
# idenya : ide
# judulnya : judul
# lwt : lwt
# permainan : main
# kata2 : kata2
# sensng : sensng
# sengaja : sengaja
# menang : menang
# biar : biar
# congor : congor
# teriak : teriak
# negara : negara
# kondusif : kondusif
# indonesia : indonesia
# hancur : hancur
# perang : perang
# agama : agama
# tau : tau
# politik : politik
# taunya : tau
# demo : demo
# makan : makan
# nasbus : nasbus
# berak : berak
# kencing : kencing
# pohon : pohon
# hihihi : hihihi
# ucpxtgez5r : ucpxtgez5r
# santai : santai
# karna : karna
# milih : milih
# elu : elu
# pilih : pilih
# tipu : tipu
# kasihan : kasihan
# deh : deh
# nasib : nasib
# mikir : mikir
# piara : piara
# gewfltxfec : gewfltxfec
# krizz39907724 : krizz39907724
# ngoceh : ngoceh
# bani : bani
# cabul : cabul
# idiot : idiot
# anak : anak
# didik : didik
# rizieq : rizieq
# mabur : mabur
# pulang : pulang
# kebanyakan : banyak
# bacot : bacot
# persis : persis
# kek : kek
# mulut : mulut
# jefrinaldi : jefrinaldi
# anandasukarlan : anandasukarlan
# lukmansaifuddin : lukmansaifuddin
# jelas2 : jelas2
# sukrlala : sukrlala
# pidato : pidato
# berkarap : karap
# koh : koh
# hok : hok
# disitu : situ
# naah : naah
# monas : monas
# adlh : adlh
# muslim : muslim
# kecewa : kecewa
# dgn : dgn
# menterinya : menteri
# udah : udah
# cebong : cebong
# suara : suara
# satubkolam : satubkolam
# butek : butek
# kawal : kawal
# jkt : jkt
# halah : halah
# loe : loe
# org : org
# jawabannya : jawab
# ngak : ngak
# pendukungnya : dukung
# dicekoki : cekok
# doang : doang
# ngecek : ngecek
# kyk : kyk
# ngeles : ngeles
# emang : emang
# kgk : kgk
# bantuan : bantu
# partai : partai
# lipat : lipat
# sdbbx8wgxj : sdbbx8wgxj
# tvonenews : tvonenews
# ayo : ayo
# vangke : vangke
# takviri : takviri
# nyinyirin : nyinyirin
# lahhh : lahhh
# otak : otak
# kaya : kaya
# kebo : kebo
# y0rbun8fyi : y0rbun8fyi
# bang : bang
# udin19 : udin19
# ferryh19 : ferryh19
# tsamaradki : tsamaradki
# wooyyyy : wooyyyy
# berpikirk : berpikirk
# taon : taon
# milik : milik
# djarot : djarot
# bkn : bkn
# dpn : dpn
# tanggung : tanggung
# jwb : jwb
# ush : ush
# bagi2 : bagi2
# jamban : jamban
# gemacan70 : gemacan70
# fwhhn5k6pg : fwhhn5k6pg
# cnnindonesia : cnnindonesia
# hehehe : hehehe
# nomer : nomer
# mengganggu : ganggu
# tenabang : tenabang
# ttp : ttp
# gpp : gpp
# menimbulkan : timbul
# kemacetan : macet
# doel2 : doel2
# sisi : sisi
# seolah2 : seolah2
# disisi : sisi
# laen : laen
# setiawan87iwan : setiawan87iwan
# lilianbih : lilianbih
# mastbp : mastbp
# mbok : mbok
# ngerti : ngerti
# siklus : siklus
# hidrologi : hidrologi
# sok : sok
# pinteerr : pinteerr
# kliahatan : kliahatan
# ian : ian
# andrearya15 : andrearya15
# awanmrs : awanmrs
# sandiuno : sandiuno
# cba : cba
# test : test
# disidang : sidang
# nama : nama
# sudirman : sudirman
# said : said
# taikviri : taikviri
# jawapos : jawapos
# poling : poling
# mengharumkan : harum
# menjatuhkan : jatuh
# dinaayu73107460 : dinaayu73107460
# susah : susah
# klw : klw
# bru : bru
# 2bln : 2bln
# jabat : jabat
# gub : gub
# salahin : salahin
# samain : samain
# 5thn : 5thn
# shrus : shrus
# junjungan : junjung
# brhasil : brhasil
# ngtasin : ngtasin
# zaman : zaman
# gad : gad
# scra : scra
# lsng : lsng
# napi : napi
# gagal : gagal
# bnyak : bnyak
# muka : muka
# cantik : cantik
# cerdas : cerdas
# retjapentung : retjapentung
# rapi : rapi
# proyek : proyek
# masak : masak
# bangunan : bangun
# isfraktruktur : isfraktruktur
# bangun : bangun
# candi : candi
# boro : boro
# budur : budur
# jin : jin
# asu : asu
# aing : aing
# phantom : phantom
# gyoucancallme : gyoucancallme
# detikcom : detikcom
# nalar : nalar
# top : top
# komunikasi : komunikasi
# bagus : bagus
# awemany : awemany
# wkwkwkwk : wkwkwkwk
# kagak : kagak
# lha : lha
# kmr : kmr
# fitnah : fitnah
# melonjak : lonjak
# jarot : jarot
# pdhal : pdhal
# bengkakin : bengkakin
# nudingnya : nudingnya
# fix : fix
# dah : dah
# apa2 : apa2
# bong : bong
# dengerin : dengerin
# buruan : buru
# hoax : hoax
# liatdknopd : liatdknopd
# heroe : heroe
# bad : bad
# tempodotco : tempodotco
# mdh : mdh
# oct : oct
# tdtgn : tdtgn
# silahkan : silah
# tunjukin : tunjukin
# tgl : tgl
# dokumen : dokumen
# asli : asli
# knp : knp
# dok : dok
# tanda : tanda
# tgnnya : tgnnya
# gampang : gampang
# buktiinnya : buktiinnya
# sesbangpol : sesbangpol
# diajuin : diajuin
# netizen : netizen
# dikit : dikit
# taikers : taikers
# naikan : naik
# parpol : parpol
# menabrak : tabrak
# peraturan : atur
# daerah : daerah
# dijalanan : jalan
# diganti : ganti
# sembarangan : sembarang
# suruh : suruh
# bersihin : bersihin
# and : and
# cebokin : cebokin
# substansial : substansial
# mengkritisi : kritisi
# ngga : ngga
# bahan : bahan
# nih : nih
# lupa : lupa
# gun : gun
# romli : romli
# gunromli : gunromli
# nanda : nanda
# tanganin : tanganin
# perda : perda
# orgnya : orgnya
# nyalahin : nyalahin
# dipelihara : pelihara
# pg6izq3otj : pg6izq3otj
# linden : linden
# dollar : dollar
# policybermoz : policybermoz
# mbahuyok : mbahuyok
# lusihq : lusihq
# woooi : woooi
# peninggalan : tinggal
# tanggul2 : tanggul2
# jebol : jebol
# coba : coba
# dongo : dongo
# tunggu : tunggu
# parah : parah
# ikutan : ikut
# ngebully : ngebully
# meme : meme
# mengalahkan : kalah
# pergub : pergub
# detik : detik
# kedepan : depan
# memahami : paham
# uno : uno
# kasih : kasih
# juragantahu : juragantahu
# 99 : 99
# john : john
# nelwan : nelwan
# yusejahtera : yusejahtera
# oke : oke
# jauhhhhh : jauhhhhh
# sblm : sblm
# sepakat : sepakat
# wa : wa
# subarkah : subarkah
# menangani : tangan
# ditangani : tangan
# abadi : abadi
# banjr : banjr
# kota : kota
# bener2 : bener2
# diapungkan : apung
# pompa : pompa
# dinyalain : dinyalain
# tetep : tetep
# menggenang : genang
# airnya : air
# alat : alat
# ngapa2in : ngapa2in
# addiems : addiems
# benar2 : benar2
# wagebener : wagebener
# pemimpin : pimpin
# dipilih : pilih
# paksa : paksa
# batu : batu
# kalah : kalah
# negara2 : negara2
# asia : asia
# kerberooz : kerberooz
# bullfront : bullfront
# partaisocmed : partaisocmed
# teretam : teretam
# sahal : sahal
# as : as
# gisellauci : gisellauci
# perisyantik : perisyantik
# mutia : mutia
# raaaaa : raaaaa
# penumpang : tumpang
# gelap : gelap
# auroraspruit : auroraspruit
# rianernesto : rianernesto
# likninpakr : likninpakr
# giewahyudi : giewahyudi
# gubernurnya : gubernur
# yah : yah
# nagih : nagih
# mope : mope
# taeee : taeee
# permintaan : minta
# tim : tim
# transisi : transisi
# embah72 : embah72
# celah : celah
# korupsinya : korupsi
# aspek : aspek
# tar : tar
# rayain : rayain
# cina : cina
# milyar : milyar
# toleransi : toleransi
# 67b102feabf5471 : 67b102feabf5471
# sunar : sunar
# fni : fni
# kangmeirza : kangmeirza
# lucky : lucky
# hs : hs
# napipks : napipks
# jojorivai : jojorivai
# sutomoagus92 : sutomoagus92
# sammisoh : sammisoh
# ezkisuyanto : ezkisuyanto
# temen2 : temen2
# twit2 : twit2
# twit : twit
# pantesan : pantesan
# pilkada : pilkada
# kalahnya : kalah
# tertelak : telak
# sejarah : sejarah
# gini : gin
# daya : daya
# tangkepnya : tangkepnya
# survey : survey
# benarnya : benar
# nifm1isa4f : nifm1isa4f
# rachmayanto : rachmayanto
# digembok : gembok
# duitnya : duit
# gonggon52608112 : gonggon52608112
# mcanocebong : mcanocebong
# apanya : apa
# faktanya : fakta
# kirim : kirim
# marbut : marbut
# umrah : umrah
# cebong2 : cebong2
# nyinyier : nyinyier
# zebua : zebua
# aro06 : aro06
# mitzuo : mitzuo
# sembara : sembara
# 1980 : 1980
# shintashi2 : shintashi2
# menjabat : jabat
# 2018 : 2018
# itukan : itu
# kerjaan : kerja
# china : china
# kafir : kafir
# penjara : penjara
# mako : mako
# brimob : brimob
# sekolah : sekolah
# apbn : apbn
# orang2an : orang2an
# ono : ono
# kesambet : kesambet
# setan : setan
# budeg : budeg
# ronavioleta : ronavioleta
# eneg : eneg
# edit : edit
# please : please
# bersebrangan : bersebrangan
# murahan : murah
# edit2 : edit2
# canda : canda
# lucu : lucu
# tujuan : tuju
# media2 : media2
# spt : spt
# tempo : tempo
# kompas : kompas
# cnn : cnn
# mecah : mecah
# belah : belah
# umat : umat
# islam : islam
# menjunjung : junjung
# kmudian : kmudian
# dijatuhkan : jatuh
# namaya : namaya
# memimpin : pimpin
# tuntas : tuntas
# 2019 : 2019
# jkw : jkw
# yzvleqylfr : yzvleqylfr
# kemaren : kemaren
# usmar : usmar
# bawa : bawa
# bit : bit
# crowdnya : crowdnya
# kebelah : belah
# pokoknya : pokok
# kesel : kesel
# dilakuin : dilakuin
# majelislucu : majelislucu
# uncensored : uncensored
# wwqxywk4ym : wwqxywk4ym
# p3nj3l4j4h : p3nj3l4j4h
# chilli : chilli
# pari : pari
# kaesangp : kaesangp
# ambarwatirexy : ambarwatirexy
# 4y4nkz : 4y4nkz
# aryprasetyo85 : aryprasetyo85
# djanchoek : djanchoek
# wahhabicc : wahhabicc
# jabar : jabar
# adtaufiq : adtaufiq
# rizmawidiono : rizmawidiono
# badjanuswantara : badjanuswantara
# presiden : presiden
# orng : orng
# dya : dya
# pintar : pintar
# pecat : pecat
# permanent : permanent
# ketulung : ketulung
# cvakgnix8t : cvakgnix8t
# pas : pas
# dapet : dapet
# model : model
# azab : azab
# ganjaran : ganjar
# ketololan : tolol
# menyakitkan : sakit
# alamat : alamat
# fiktif : fiktif
# kale : kale
# kompastv : kompastv
# menilai : nilai
# kesalahan : salah
# penulisan : tulis
# ditoleransi : toleransi
# jep9os3zop : jep9os3zop
# mad : mad
# duit : duit
# dijadikan : jadi
# wakil : wakil
# disuruh : suruh
# bumper : bumper
# maju : maju
# gegara : gegara
# nebeng : nebeng
# bayar : bayar
# ongkos : ongkos
# hoi : hoi
# dipakai : pakai
# mrlvrfrtwf : mrlvrfrtwf
# kwanlung : kwanlung
# thedufresne : thedufresne
# batasnya : batas
# super : super
# unlimited : unlimited
# dipecat : pecat
# menteri : menteri
# pendidikan : didik
# rakyatnya : rakyat
# antonbagaspati : antonbagaspati
# jh : jh
# talk : talk
# 2 : 2
# u : u
# trico : trico
# saputro : saputro
# serdadulangit4 : serdadulangit4
# link : link
# kasi : kasi
# kate : kate
# masuk : masuk
# usulan : usul
# musrembang : musrembang
# hrs : hrs
# dprd : dprd
# njing : njing
# jago : jago
# statement : statement
# bully : bully
# publik : publik
# ahokers : ahokers
# gratis : gratis
# blusukan : blusukan
# juliany03189821 : juliany03189821
# metro : metro
# tv : tv
# nooo : nooo
# pelototin : pelototin
# nyee : nyee
# april : april
# pelantikan : lantik
# kpn : kpn
# pelihara : pelihara
# x2klyuawq9 : x2klyuawq9
# demen3 : demen3
# tstsp71 : tstsp71
# koruptor : koruptor
# dipenjara : penjara
# kesempatan : sempat
# memenjarakan : penjara
# mumpung : mumpung
# berkuasa : kuasa
# iya : iya
# emg : emg
# dirancang : rancang
# boneka : boneka
# nipu : nipu
# jakarta58 : jakarta58
# ngigau : ngigau
# dipercaya : percaya
# uda : uda
# dpt : dpt
# kavling : kavling
# sorga : sorga
# tertipu : tipu
# a4guzmkxpb : a4guzmkxpb
# lihong2307 : lihong2307
# dendeng88 : dendeng88
# cumarachel : cumarachel
# penies : penies
# pendukung : dukung
# lihat : lihat
# ngeh : ngeh
# debrisss2 : debrisss2
# brisikzone : brisikzone
# maklambeturah : maklambeturah
# ruang : ruang
# tidur : tidur
# lenyapkan : lenyap
# ngerti2 : ngerti2
# akipfirmanshah : akipfirmanshah
# jkt58 : jkt58
# ama : ama
# manis : manis
# kasian : kasi
# mrk : mrk
# dikibulin : dikibulin
# suka : suka
# bangga : bangga
# dipiara : piara
# byr : byr
# kemarin : kemarin
# gimanaaa : gimanaaa
# gitu : gitu
# adek : adek
# termauk : termauk
# blg : blg
# kemakan : makan
# isu : isu
# nyesel : nyesel
# amal : amal
# perbuatan : buat
# nilai : nilai
# manusia : manusia
# bhaaak : bhaaak
# falahfajar : falahfajar
# hahaha : hahaha
# kaum : kaum
# bodat : bodat
# banggain : banggain
# berhasil : hasil
# tutup : tutup
# alexis : alexis
# yos : yos
# status : status
# mak : mak
# lambe : lambe
# turah : turah
# ahokdjarot : ahokdjarot
# hilangkan : hilang
# ngotot : ngotot
# ayugalax : ayugalax
# hahahaha : hahahaha
# gotu : gotu
# repot : repot
# dilantik : lantik
# draft : draft
# diajukan : aju
# ngejawab : ngejawab
# ndgwbdjvjw : ndgwbdjvjw
# rhijayanto : rhijayanto
# irma : irma
# indo : indo
# ub : ub
# hidayat : hidayat
# laahhh : laahhh
# angkat : angkat
# mentri : tri
# hahahahahah : hahahahahah
# sayang : sayang
# saidbasalim : saidbasalim
# menolak : tolak
# tolak : tolak
# mentah2 : mentah2
# nakei : nakei
# zahwa : zahwa
# bohong : bohong
# situ : situ
# pantes : pantes
# seh : seh
# dibohongin : dibohongin
# ekoph18 : ekoph18
# tribunnews : tribunnews
# otaknya : otak
# dengkul : dengkul
# rancang : rancang
# trus : trus
# lngsung : lngsung
# tandatangan : tandatangan
# edz9iiq6i5 : edz9iiq6i5
# bgt : bgt
# ngapain : ngapain
# ops : ops
# dibikin : bikin
# gaji : gaji
# staff : staff
# ujung2nya : ujung2nya
# dibui : bui
# aman : aman
# halalan : halal
# toyiban : toyiban
# mayan : mayan
# beli : beli
# nasbung : nasbung
# karung : karung
# beneran : beneran
# yaaa : yaaa
# nies : nies
# buktikan : bukti
# wkwkwkk : wkwkwkk
# gila : gila
# pretasi : pretasi
# terbaik : baik
# mohammadelakbar : mohammadelakbar
# sebenernya : sebenernya
# curiga : curiga
# jelek : jelek
# doktor : doktor
# dijadiin : dijadiin
# narasumber : narasumber
# sebego : bego
# agenda : agenda
# tersembunyi : sembunyi
# berlagak : lagak
# hydrangea0710 : hydrangea0710
# revansianturi1 : revansianturi1
# natonatnat : natonatnat
# nara : nara
# sumber : sumber
# buta : buta
# ksh : ksh
# delegasi : delegasi
# lurah : lurah
# dibriefing : dibriefing
# org2 : org2
# lho : lho
# blum : blum
# camatnya : camat
# syifni : syifni
# dibilang : bilang
# distop : stop
# dianggarin : dianggarin
# kko : kko
# urusan : urus
# selesai : selesai
# kecamatan : camat
# balaikota : balaikota
# males : males
# jogyeskarta1 : jogyeskarta1
# dennysiregar7 : dennysiregar7
# orangnya : orang
# zbmloxtm1k : zbmloxtm1k
# bisa2 : bisa2
# bodohi : bodoh
# malu : malu
# beliau : beliau
# minarihirai : minarihirai
# direkturnya : direktur
# walk : walk
# out : out
# rame : rame
# dll : dll
# ngajak : ngajak
# uninstall : uninstall
# traveloka : traveloka
# berjamaah : jamaah
# pandji : pandji
# sori : sori
# nji : nji
# dititik : titik
# gua : gua
# terbukti : bukti
# sekelas : kelas
# modal : modal
# omong : omong
# butuh : butuh
# kayak : kayak
# ezgb8enxhe : ezgb8enxhe
# nay : nay
# shihab : shihab
# 1bulan : 1bulan
# admin : admin
# imanuel20171 : imanuel20171
# kurawa : rawa
# laah : laah
# undang : undang
# kanisius : kanisius
# dateng : dateng
# sbg : sbg
# pimpinan : pimpin
# diundang : undang
# bloon : bloon
# blm : blm
# stlh : stlh
# piye : piye
# vir : vir
# maryadi03351859 : maryadi03351859
# yunartowijaya : yunartowijaya
# brita : brita
# diusir : usir
# smpt : smpt
# shalt : shalt
# jumat : jumat
# shalat : shalat
# msjd : msjd
# pikir : pikir
# wartawan : wartawan
# lgian : lgian
# pjabat : pjabat
# kunker : kunker
# persekusi : persekusi
# sajam : sajam
# lbh : lbh
# gawat : gawat
# asik : asik
# comberan : comberan
# secuil : cuil
# akut : akut
# ngeruk : ngeruk
# got : got
# pikiran : pikir
# rutofivevo : rutofivevo
# william60118 : william60118
# andika : andika
# 211216 : 211216
# arifinpribadi : arifinpribadi
# eliya : eliya
# mkom : mkom
# aldhiraaa : aldhiraaa
# panca66 : panca66
# playingasvictim : playingasvictim
# kubu : kubu
# penistaagama : penistaagama
# standar : standar
# gurih : gurih
# segurih : gurih
# mecin : mecin
# akuin : akuin
# kelompok : kelompok
# ngusir : ngusir
# balasannya : balas
# walkout : walkout
# maha : maha
# adil : adil
# berkerja : kerja
# gubenur : gubenur
# fs6kzb1qqx : fs6kzb1qqx
# naznasir1 : naznasir1
# green : green
# garden : garden
# taonan : taonan
# skg : skg
# kau : kau
# idola : idola
# barusan : barusan
# oktober : oktober
# visi : visi
# misi : misi
# tercover : tercover
# mba : mba
# berjalannya : jalan
# nzpp46o0ui : nzpp46o0ui
# heran : heran
# sinyal : sinyal
# kepulauan : pulau
# seribu : ribu
# 6d53mrshef : 6d53mrshef
# operator : operator
# celuler : celuler
# gampangkan : gampang
# wan : wan
# abud : abud
# mel2cents : mel2cents
# irawan : irawan
# tee1 : tee1
# bca : bca
# faham : faham
# replay : replay
# awam : awam
# acara : acara
# penghargaan : harga
# alumni : alumni
# kmpus : kmpus
# pesertanya : serta
# beradab : adab
# adab : adab
# ditolak : tolak
# dilempari : lempari
# botol : botol
# dialami : alami
# pedukung : dukung
# teriakananak : teriakananak
# realabikatrader : realabikatrader
# karniilyas : karniilyas
# akal : akal
# kebangetan : banget
# nyet : nyet
# udang : udang
# logika : logika
# freestonereborn : freestonereborn
# hueheeheee : hueheeheee
# dukung : dukung
# nyinyir : nyinyir
# dungu : dungu
# ngalahin : ngalahin
# goblok : goblok
# dech : dech
# hahahaaahahaa : hahahaaahahaa
# ivonejcsc : ivonejcsc
# sorakin : sorakin
# kmrn : kmrn
# turun : turun
# bus : bus
# projo : projo
# reaksi : reaksi
# nyamalahan : nyamalahan
# maklum : maklum
# isi : isi
# nyaa : nyaa
# siscayulianti6 : siscayulianti6
# maspiyuuu : maspiyuuu
# pede : pede
# acaranya : acara
# panglima : panglima
# tertinggi : tinggi
# mengundang : undang
# relawan : rawan
# kotor : kotor
# suriaantono : suriaantono
# pekok : kok
# setuju : tuju
# hasil : hasil
# riset : riset
# tanya2 : tanya2
# klu : klu
# pjalan : pjalan
# kaki : kaki
# r7llsiknoq : r7llsiknoq
# fikridoank86 : fikridoank86
# mau2nya : mau2nya
# becus : becus
# pemikirannya : pikir
# ancurrrrr : ancurrrrr
# lollyschatzi : lollyschatzi
# pinteran : pinteran
# belagak : bagak
# aan123yes : aan123yes
# bosen : bosen
# ngomen : ngomen
# purbasr : purbasr
# thya : thya
# liem257 : liem257
# wkwkwkw : wkwkwkw
# panatik : panatik
# menindaklanjuti : menindaklanjuti
# memutuskannya : putus
# ilang : ilang
# hkbp : hkbp
# resmikan : resmi
# trharu : trharu
# jemaat : jemaat
# peluk2 : peluk2
# provokator : provokator
# alhamdulillah : alhamdulillah
# hotel : hotel
# alexix : alexix
# ditutup : tutup
# mantab : mantab
# pribumi : pribumi
# 2pna0ijcd4 : 2pna0ijcd4
# lumayan : lumayan
# pencitraan : citra
# sehari : hari
# malamnya : malam
# bos : bos
# telpon : telpon
# heh : heh
# ape : ape
# awas : awas
# bongkar : bongkar
# kedok : kedok
# qs1qgdbudm : qs1qgdbudm
# liat : liat
# tanggaldi : tanggaldi
# surat : surat
# donk : donk
# tanggal27 : tanggal27
# tagih : tagih
# ketua : ketua
# nolak : nolak
# gelar : gelar
# paripurna : paripurna
# sampeyan : sampeyan
# sehat : sehat
# norak : norak
# teafaco4pq : teafaco4pq
# dee : dee
# tyo : tyo
# siegeranwalt : siegeranwalt
# kejadian : jadi
# reputasinya : reputasi
# dipertaruhkan : taruh
# nyalon : nyalon
# refungsi : refungsi
# gimana : gimana
# sebentar : sebentar
# berdasarkan : dasar
# investasi : investasi
# mudah : mudah
# kalahkan : kalah
# dlm : dlm
# pengadilan : adil
# arbitrase : arbitrase
# btp : btp
# std : std
# appreciate : appreciate
# pura : pura
# cabut : cabut
# izin : izin
# kira2 : kira2
# themeikarta : themeikarta
# reklamasi : reklamasi
# keputusan : putus
# sbb : sbb
# intoleran : intoleran
# radikal : radikal
# rasis : ras
# dwmo : dwmo
# gih : gih
# nge : nge
# 9062eutilp : 9062eutilp
# profylh : profylh
# bacotnya : bacot
# benci : benci
# hayo : hayo
# usircinapki : usircinapki
# maradewi71 : maradewi71
# elisa : elisa
# beban : beban
# ikut2an : ikut2an
# menderita : derita
# bunu : bunu
# datar : datar
# aisyah : aisyah
# lrahman : lrahman
# topik : topik
# ngomongin : ngomongin
# hubungin : hubungin
# idup : idup
# dipake : dipake
# ngefitnah : ngefitnah
# jngn : jngn
# ktm : ktm
# pngmbng : pngmbng
# rmh : rmh
# prabowo : prabowo
# blng : blng
# prieyan1 : prieyan1
# abuupik1 : abuupik1
# localhost911 : localhost911
# boengparno : boengparno
# bersatu1 : bersatu1
# restycayah : restycayah
# rejentt : rejentt
# ipunglombok : ipunglombok
# pdemokrat : pdemokrat
# ndoro : ndoro
# putri : putri
# zarazettirazr : zarazettirazr
# mengajak : ajak
# mengejek : ejek
# merangkul : rangkul
# memukul : pukul
# over : over
# dosis : dosis
# bubuk : bubuk
# indomi : indomi
# 6szcpo2tzs : 6szcpo2tzs
# mustahil : mustahil
# berkat : berkat
# ngalah : ngalah
# sipenakecil : sipenakecil
# jokopujakesuma : jokopujakesuma
# qzfvr : qzfvr
# heru7310 : heru7310
# myshineray : myshineray
# yefta1899 : yefta1899
# caukepoo : caukepoo
# ganjarpranowo : ganjarpranowo
# gakononama : gakononama
# mengkritik : kritik
# ngatai : ngatai
# songong : songong
# ngeyel : ngeyel
# linguistic : linguistic
# histories : histories
# olisi : olisi
# terima : terima
# laporan : lapor
# sam : sam
# aliano : aliano
# hukumnya : hukum
# sekolahan : sekolah
# ketulungan : ketulungan
# iwanzaghi : iwanzaghi
# mampet : mampet
# diulang : ulang
# sugikawuloalit : sugikawuloalit
# gregory : gregory
# xu : xu
# erryfreakz : erryfreakz
# konsisten : konsisten
# dipenuhi : penuh
# silakan : sila
# pemilih : pilih
# rasisme : rasisme
# merebak : rebak
# pendukunga : pendukunga
# t6ohuri5im : t6ohuri5im
# dicuekin : dicuekin
# posting : posting
# ngetop : ngetop
# euuyiwlq75 : euuyiwlq75
# alfan06127157 : alfan06127157
# yahoo : yahoo
# id : id
# helloowww : helloowww
# ditulis : tulis
# ditopi : topi
# sihh : sihh
# adem : adem
# liatnya : liat
# taik : taik
# brengsek : brengsek
# pastinya : pasti
# ancaman : ancam
# sampe : sampe
# 1jam : 1jam
# bernegosiasi : negosiasi
# eyo64bnb9c : eyo64bnb9c
# liputan6dotcom : liputan6dotcom
# arus : arus
# dilawan : lawan
# ekoi : ekoi
# cl : cl
# bangzul : bangzul
# 1988 : 1988
# ustadtengkuzul : ustadtengkuzul
# terusin : terusin
# orang2 : orang2
# samsoegi : samsoegi
# udara : udara
# puncak : puncak
# blo : blo
# lokasi : lokasi
# polusinya : polusi
# berbeda : beda
# loh : loh
# sjaechu : sjaechu
# mamoharyatmo6 : mamoharyatmo6
# gepeng : gepeng
# kowi : kowi
# sapa : sapa
# ntu : ntu
# baleho : baleho
# anggawira : anggawira
# micin : micin
# ckck : ckck
# bajingan : bajing
# membongkar : bongkar
# menghambat : hambat
# mrt : mrt
# 1g2wtwwdja : 1g2wtwwdja
# 8jlojdxlhb : 8jlojdxlhb
# umnia77 : umnia77
# kecoa : kecoa
# a3zsmegrts : a3zsmegrts
# ernestkan : ernestkan
# hey2 : hey2
# ngamuk : ngamuk
# gara2 : gara2
# kena : kena
# macet : macet
# ramai2 : ramai2
# diserang : serang
# sebulan : bulan
# dianggap : anggap
# sampah : sampah
# belain : bain
# umihanif2 : umihanif2
# dgr : dgr
# non : non
# copas : copas
# disuapin : disuapin
# mengerti : erti
# sedikitpun : sedikit
# diomongi : omong
# lugu : lugu
# 7yb5hn9sl7 : 7yb5hn9sl7
# wkwkwkwkwkwk : wkwkwkwkwkwk
# maaf : maaf
# pelajaran : ajar
# duduk : duduk
# zwtxcjrpvj : zwtxcjrpvj
# haekalb : haekalb
# handokotjung : handokotjung
# ayam : ayam
# bebek : bebek
# ras : ras
# rudyno1 : rudyno1
# unilubis : unilubis
# hadeuh : hadeuh
# skrng : skrng
# dipengadilan : adil
# hub : hub
# penjajah : jajah
# dilap : lap
# polisi : polisi
# aliansi : aliansi
# korban : korban
# tuntut : tuntut
# sekda : sekda
# saefullah : saefullah
# plonga : plonga
# plongo : plongo
# balai : balai
# alfyan : alfyan
# justice : justice
# dhory : dhory
# hizkia : hizkia
# bukti : bukti
# media : media
# noh : noh
# buktinya : bukti
# aslimanusiabodoh : aslimanusiabodoh
# banikamvret : banikamvret
# veverdi : veverdi
# gmn : gmn
# nich : nich
# iwan : iwan
# fals : fals
# ckckck : ckckck
# hamur666 : hamur666
# cakbassoke : cakbassoke
# budimannainggo7 : budimannainggo7
# konteks : konteks
# bro : bro
# yaallah : yaallah
# keturunan : turun
# jahiliyah : jahiliyah
# orangtua : orangtua
# pesbuk : pesbuk
# guru : guru
# sma : sma
# huh : huh
# diem : diem
# peduli : peduli
# yaampun : yaampun
# gemes : gemes
# bahaya : bahaya
# mls : mls
# slordig : slordig
# budget : budget
# jauuuuuh : jauuuuuh
# memecah : pecah
# persatuan : satu
# oyahyaputr : oyahyaputr
# iyalah : iya
# mang : mang
# maksud : maksud
# teks : teks
# lapor : lapor
# sensi : sensi
# ronronn79 : ronronn79
# siih : siih
# mencalonkan : calon
# ngeshare : ngeshare
# kutipan : kutip
# sepenggal : penggal
# menangkanpancasila : menangkanpancasila
# kata2nya : kata2nya
# pecah : pecah
# arahkan : arah
# plintir : plintir
# arti : arti
# jagoannya : jago
# alex : alex
# hunter146 : hunter146
# darkalbatawi : darkalbatawi
# sriisnanih : sriisnanih
# hamka : hamka
# kdz : kdz
# budimandjatmiko : budimandjatmiko
# serius : serius
# cerita : cerita
# ttg : ttg
# pemisahan : pisah
# bumiputera : bumiputera
# zmn : zmn
# belanda : belanda
# mosok : mosok
# disandingkan : sanding
# retorika : retorika
# ulangi : ulang
# anis : anis
# kebangkitan : bangkit
# minus : minus
# rizieqsyihabfpi : rizieqsyihabfpi
# ixuk0pvf6x : ixuk0pvf6x
# senang : senang
# kumpulan : kumpul
# ngemeng : ngemeng
# fnz8xktg09 : fnz8xktg09
# okewaee : okewaee
# ruhut : ruhut
# okewae : okewae
# nonton : nonton
# upin : upin
# ipin : ipin
# somplak : somplak
# bawaan : bawa
# very : very
# start : start
# igmo0va5ck : igmo0va5ck
# ade : ade
# armando : armando
# mayoritas : mayoritas
# mahfud : mahfud
# nga : nga
# y1hzrmokys : y1hzrmokys
# gjv7wilydz : gjv7wilydz
# haaaa : haaaa
# mutu : mutu
# kelasnya : kelas
# ttd : ttd
# diciduk : ciduk
# doa : doa
# realita : realita
# ditipu : tipu
# 356 : 356
# jatuh : jatuh
# mencinta : cinta
# kadang : kadang
# semenyakitkan : sakit
# gur : gur
# terjerumus : jerumus
# rnmosmyhb3 : rnmosmyhb3
# ngerasa : ngerasa
# ndak : ndak
# yaa : yaa
# eddlfj57wg : eddlfj57wg
# razgriz910 : razgriz910
# lexx : lexx
# alexylex : alexylex
# 78meimei : 78meimei
# rainembleketek : rainembleketek
# dewituti : dewituti
# ana : ana
# temanjesus : temanjesus
# abasri : abasri
# 03 : 03
# manroeunited : manroeunited
# nanarosa4292 : nanarosa4292
# anth : anth
# bee : bee
# indragu78730991 : indragu78730991
# grand : grand
# light88 : light88
# poney : poney
# doo : doo
# tekukur : tekukur
# ys : ys
# inong911 : inong911
# parjo : parjo
# sutikno : sutikno
# terongkw : terongkw
# eandesla : eandesla
# nyamar : nyamar
# supermancemonk : supermancemonk
# arekgubeng2 : arekgubeng2
# anth83090816 : anth83090816
# plufduck : plufduck
# kuyawirya : kuyawirya
# adoramona : adoramona
# bee5ant : bee5ant
# hurry : hurry
# hansjedi671 : hansjedi671
# antbee005 : antbee005
# beequeensoun : beequeensoun
# kyaionline : kyaionline
# 174nd0 : 174nd0
# awathon : awathon
# jt : jt
# suryo : suryo
# savirahelmi : savirahelmi
# dsyamil3 : dsyamil3
# bemoljaya5 : bemoljaya5
# am0k4 : am0k4
# mallik02 : mallik02
# kraengmedicy : kraengmedicy
# aidah731103221 : aidah731103221
# paijoaryanto : paijoaryanto
# manusiabersay4p : manusiabersay4p
# gurutua7 : gurutua7
# gebuki : gebuk
# mca : mca
# andrilay007 : andrilay007
# nazta08 : nazta08
# ndeso : ndeso
# kristen : kristen
# chinese : chinese
# datanya : data
# paxrue5kan : paxrue5kan
# asboediono : asboediono
# romo : romo
# kotak : kotak
# memusuhi : musuh
# fpi : fpi
# miara : miara
# memilih : pilih
# kilas : kilas
# ngerangkul : ngerangkul
# muhammadiyah : muhammadiyah
# kaga : kaga
# bekas : bekas
# berhutang : hutang
# budi : budi
# wakadol2012 : wakadol2012
# magusset : magusset
# ch : ch
# chotimah : chotimah
# ghazalisil : ghazalisil
# gobloknya : goblok
# naga : naga
# keok : keok
# lidyasalaunaung : lidyasalaunaung
# gussumbogo : gussumbogo
# tipikal : tipikal
# ngomel2 : ngomel2
# voridjer : voridjer
# dikasih : kasih
# bales2 : bales2
# watson : watson
# katia : katia
# nyata : nyata
# hobi : hobi
# muh : muh
# zakii : zakii
# alergi : alergi
# dikritik : kritik
# mundur : mundur
# modelnya : model
# kebijakannya : bijak
# polemik : polemik
# bodohnya : bodoh
# sandiaga : sandiaga
# diutak : diutak
# atik : atik
# untk : untk
# menyelesaikan : selesai
# kebodohan : bodoh
# expoloitasi : expoloitasi
# laa : laa
# ax0dakdjcw : ax0dakdjcw
# temennya : temennya
# hahahahahaha : hahahahahaha
# laaa : laaa
# perut : perut
# gelak : gelak
# 1lx7dicyo7 : 1lx7dicyo7
# hudattamini : hudattamini
# mem : mem
# xyah : xyah
# bawak : bawak
# uber : uber
# quvvatt : quvvatt
# klop : klop
# ikut2 : ikut2
# dituduh : tuduh
# kwalitas : kwalitas
# segitu : segitu
# aturan : atur
# lgi : lgi
# ibadah : ibadah
# sholat : sholat
# idul : idul
# fitri : fitri
# bas : bas
# edan : edan
# pimpin : pimpin
# kusumahadi44 : kusumahadi44
# 100 : 100
# pernyataan : nyata
# dibodohi : bodoh
# menerus : terus
# akibat : akibat
# kebijakan : bijak
# tjqazabwx0 : tjqazabwx0
# chan : chan
# ricka : ricka
# menteri2 : menteri2
# murid : murid
# mahasiswa : mahasiswa
# gab : gab
# wakilnya : wakil
# jawan : jawan
# trotoar : trotoar
# wkwkwkwkkkkkk : wkwkwkwkkkkkk
# kog : kog
# diplihara : diplihara
# yooo : yooo
# melawanbodoh : melawanbodoh
# rinjanijb : rinjanijb
# kita2 : kita2
# sekilas : kilas
# penjelasan : jelas
# berat : berat
# membedakan : beda
# miliaran : miliar
# rupiah : rupiah
# dikorbankan : korban
# daviwans : daviwans
# airinetza : airinetza
# kepolisian : polisi
# sekelompok : kelompok
# anggota : anggota
# kepolisan : polis
# ter : ter
# sistem : sistem
# menyetujui : tuju
# harahapburhan : harahapburhan
# rita : rita
# tj : tj
# cukong : cukong
# hahahahaahahahahahaha : hahahahaahahahahahaha
# kdh : kdh
# miliar : miliar
# gubernur2 : gubernur2
# cari : cari
# info : info
# pilihan : pilih
# merusak : rusak
# berjualan : jual
# peruntukkannya : untuk
# menyingkirkan : singkir
# kepentingan : penting
# bedakan : beda
# diutamakan : utama
# copot : copot
# klaim : klaim
# ribut : ribut
# berantem : antem
# bacok : bacok
# bacokan : baco
# sikut : sikut
# palak : palak
# keberpihakan : pihak
# namanya : nama
# shame : shame
# bercita2 : bercita2
# menghapus : hapus
# kebijakan2 : kebijakan2
# hc8q3jnz4d : hc8q3jnz4d
# menilep : menilep
# memiliki : milik
# k629g70l0r : k629g70l0r
# era : era
# bop : bop
# sekrg : sekrg
# evaluasi : evaluasi
# sadarlah : sadar
# vuwb7xbqdv : vuwb7xbqdv
# marah : marah
# sensitif : sensitif
# memperkaya : kaya
# preman : preman
# sedih : sedih
# sayah : sayah
# dikhianati : khianat
# menghakimi : hakim
# hakim : hakim
# sebelah : belah
# becussss : becussss
# byk : byk
# kamera : kamera
# menyorot : sorot
# mjd : mjd
# wae : wae
# ribet : ribet
# urusin : urusin
# gubernurmu : gubernur
# konsen : konsen
# rkytdki : rkytdki
# diurus : urus
# maki2 : maki2
# mulu : mulu
# uhv3bprlo4 : uhv3bprlo4
# aw7eugfg08 : aw7eugfg08
# via : via
# poskotanews : poskotanews
# melanggar : langgar
# jln : jln
# menuntut : tuntut
# difasilitasi : fasilitas
# bgmn : bgmn
# pemilik : milik
# kios : kios
# pajak : pajak
# memenuhi : penuh
# mengkorbankan : korban
# merugikan : rugi
# pedagang : dagang
# fungsi : fungsi
# sedunia : dunia
# keberatan : berat
# ihfu0cnscv : ihfu0cnscv
# thn : thn
# wakli : wakli
# sadar : sadar
# ardi : ardi
# riau : riau
# upaya : upaya
# terang2an : terang2an
# dikiranya : kira
# masi : mas
# ckckckck : ckckckck
# pikirnya : pikir
# menghayal : menghayal
# aneh : aneh
# 68332ece2ec54e7 : 68332ece2ec54e7
# akun : akun
# kloningan : kloning
# keluyuran : keluyur
# bahas : bahas
# kualitas : kualitas
# terbatas : batas
# melawan : lawan
# periode : periode
# g2iuswdhwp : g2iuswdhwp
# timny : timny
# gie : gie
# nakayah : nakayah
# menyepelekan : sepele
# saking : saking
# puyengnya : puyeng
# jati : jati
# nueldelau : nueldelau
# mohmahfudmd : mohmahfudmd
# najwashihab : najwashihab
# iwanfals : iwanfals
# raffinagita1717 : raffinagita1717
# yasonalaoly : yasonalaoly
# dewiperssik12 : dewiperssik12
# capres : capres
# dunggu : dunggu
# bersih : bersih
# tertib : tertib
# semrawut : semrawut
# nikmatilah : nikmat
# votters : votters
# gaberners : gaberners
# resuffle : resuffle
# jokoanwar : jokoanwar
# cuman : cuman
# knapa : knapa
# kondisi : kondisi
# tanggul : tanggul
# eksisting : eksisting
# bantaran : bantaran
# pelebaran : lebar
# padang : padang
# ef14dkjyte : ef14dkjyte
# jonruzonk : jonruzonk
# gerombolan : gerombol
# bln : bln
# mlh : mlh
# sibuk : sibuk
# urus : urus
# pdhl : pdhl
# hadeuuhhh : hadeuuhhh
# wagaberner : wagaberner
# beny : beny
# ide : ide
# penggunaaan : penggunaaan
# mengamankan : aman
# natal : natal
# simpati : simpati
# edin : edin
# eae18 : eae18
# bantuin : bantuin
# culong : culong
# woles : woles
# s4ncai : s4ncai
# muhamma87797215 : muhamma87797215
# tribunstyle : tribunstyle
# basuki : basuki
# ehh : ehh
# belagu : belagu
# dibully : dibully
# kebodohannya : bodoh
# dicintai : cinta
# islamis : islamis
# drpd : drpd
# evcatzomhi : evcatzomhi
# seiman : iman
# faktor : faktor
# yunar : yunar
# ary : ary
# gaj : gaj
# hianati : hianati
# buruh : buruh
# aaja : aaja
# rasain : rasain
# halnya : hal
# jutaan : juta
# pemuja : puja
# trumph : trumph
# ane : ane
# 2012 : 2012
# 2017 : 2017
# mendukung : dukung
# diakhir : akhir
# hati : hati
# se2eucyzdb : se2eucyzdb
# iyai : iya
# toeni : toeni
# kumparan : kumpar
# dek : dek
# bersuara : suara
# disangka : sangka
# icw : icw
# sogok : sogok
# mendingan : mending
# dark : dark
# pecatan : pecat
# bermasalah : masalah
# uni : uni
# bahasa : bahasa
# ampuh : ampuh
# vw9s2pzixo : vw9s2pzixo
# kasat : kasat
# mata : mata
# mempolitisasi : politisasi
# katolik : katolik
# ditunggangi : tunggang
# gk1rilaayj : gk1rilaayj
# ancam : ancam
# mayat : mayat
# gakan : gakan
# disholati : disholati
# niat : niat
# nyumbang : nyumbang
# biaya : biaya
# diterima : terima
# terserah : serah
# masing2 : masing2
# sendiri2 : sendiri2
# baiknya : baik
# positive : positive
# thingking : thingking
# i5sihct8ef : i5sihct8ef
# putra : putra
# bisma12 : bisma12
# yusuf : yusuf
# dumdum : dumdum
# susipudjiastuti : susipudjiastuti
# melebar : lebar
# garisbawahi : garisbawahi
# hubungan : hubung
# susi : sus
# nyinyiran : nyinyir
# sdr : sdr
# fokus : fokus
# komentar : komentar
# reply : reply
# nyambung : nyambung
# rahmatan : rahmat
# lil : lil
# alamin : alamin
# mending : mending
# koprol : koprol
# jidat : jidat
# jedotin : jedotin
# tembok : tembok
# 27x : 27x
# ato : ato
# bantu : bantu
# sedot : sedot
# sedotan : sedot
# plastik : plastik
# pasukan : pasu
# langit : langit
# liatin : liatin
# atraksi : atraksi
# cmhbkwsbrm : cmhbkwsbrm
# s6zfd6e60t : s6zfd6e60t
# wagub : wagub
# traditional : traditional
# introvert : introvert
# tertutup : tutup
# betawi : betawi
# yuzwin : yuzwin
# menjelek2an : menjelek2an
# ahoax : ahoax
# tandanya : tanda
# old : old
# tll : tll
# bnyk : bnyk
# klian : klian
# ketipu : tipu
# wajar : wajar
# yai : yai
# kusam : kusam
# romlah : romlah
# sindir : sindir
# begok : begok
# betah : betah
# l6an7wyiyw : l6an7wyiyw
# fakta : fakta
# terbantahkan : bantah
# warga58 : warga58
# mmg : mmg
# nggedabrus : nggedabrus
# minggat : minggat
# digusur : gusur
# wh8mfjufug : wh8mfjufug
# opini : opini
# menyesatkan : sesat
# kepemimpinan : pimpin
# genap : genap
# menjalankan : jalan
# selebat : lebat
# apapun : apa
# hujan : hujan
# intinya : inti
# menyalahkan : salah
# swara : swara
# 212 : 212
# rokhimmoch : rokhimmoch
# maulano17 : maulano17
# hnurwahid : hnurwahid
# berfoto : foto
# berjejer : jejer
# foto : foto
# genangan : genang
# air : air
# diatasi : atas
# hasilnya : hasil
# yaaaa : yaaaa
# terkejut : kejut
# dinaikkan : naik
# sse2ayw0qa : sse2ayw0qa
# lempar : lempar
# harto : harto
# biadab : biadab
# teddygusnaidi : teddygusnaidi
# putih : putih
# dingin : dingin
# panas : panas
# nieside27 : nieside27
# rafara : rafara
# 14 : 14
# chicohakim : chicohakim
# tpi : tpi
# acak2 : acak2
# mnurut : mnurut
# goblook : goblook
# mendahului : dahulu
# keruan : keruan
# nunjukin : nunjukin
# gabung : gabung
# yaspayelunggam1 : yaspayelunggam1
# konconelin : konconelin
# amandagempita : amandagempita
# hapnyandryanti : hapnyandryanti
# el : el
# francs : francs
# pengikut : ikut
# wiro : wiro
# sableng : sableng
# jakartabanjir : jakartabanjir
# disalahin : disalahin
# kinerja : kerja
# alias : alias
# diberhentikan : henti
# mrahmatm212 : mrahmatm212
# mnctrijayafm : mnctrijayafm
# lilonard : lilonard
# amdal : amdal
# wkwkwk : wkwkwk
# sisca789 : sisca789
# alam : alam
# f : f
# ed : ed
# tirta : tirta
# bosstoukeeisa : bosstoukeeisa
# f24nk1 : f24nk1
# detere : detere
# re : re
# dssupriyady : dssupriyady
# badonci : badonci
# dedisagala24 : dedisagala24
# pandai : pandai
# pemilihnya : pilih
# memanfaatkan : manfaat
# manusia2 : manusia2
# dimobilisasi : mobilisasi
# dibalut : balut
# sebutan : sebut
# munafik : munafik
# iblis : iblis
# dajjal : dajjal
# licik : licik
# sombong : sombong
# disandangnya : sandang
# berdosa : dosa
# mentimoen : mentimoen
# olanhutabarat : olanhutabarat
# dibiyain : dibiyain
# nurani : nurani
# kemana : mana
# mempersatukam : mempersatukam
# dibiayaii : dibiayaii
# kamprett : kamprett
# ceo : ceo
# analysisri1 : analysisri1
# dyasviantiratna : dyasviantiratna
# taslimcoy : taslimcoy
# jojoel : jojoel
# bellanegoro : bellanegoro
# babeth3006 : babeth3006
# haryalfon : haryalfon
# sinthas5 : sinthas5
# wr200465 : wr200465
# lenyshintarani : lenyshintarani
# manusiabedebah : manusiabedebah
# badriyahsiti170 : badriyahsiti170
# cd : cd
# anggraini : anggraini
# chend : chend
# malaaanaim : malaaanaim
# liina : liina
# adja : adja
# cachanatasha1 : cachanatasha1
# p3n6h1n4ul4m4 : p3n6h1n4ul4m4
# demokrat : demokrat
# nyungsep : nyungsep
# pemilu : milu
# sby : sby
# kerjanya : kerja
# kebohongan : bohong
# tontonan : tonton
# fazvmhow4q : fazvmhow4q
# lidah : lidah
# tornado : tornado
# rhoudhotuli : rhoudhotuli
# zheeomega : zheeomega
# potensi : potensi
# dilengserkan : lengser
# sayangnya : sayang
# mendengar : dengar
# pembisiknya : bisik
# membuka : buka
# ucapan : ucap
# dipidana : pidana
# disikat : sikat
# buyungkiu : buyungkiu
# type : type
# pekerja : kerja
# konseptor : konseptor
# bkan : bkan
# utama : utama
# jga : jga
# rptra : rptra
# contohnya : contoh
# malas : malas
# konsep : konsep
# menonjol : tonjol
# slama : slama
# nothing : nothing
# hapus : hapus
# lpj : lpj
# menyederhanakannya : sederhana
# iaophaiupq : iaophaiupq
# sekian : sekian
# wagabener : wagabener
# fatal : fatal
# tinggalkan : tinggal
# pusing : pusing
# komen : komen
# peminpin : peminpin
# mecat : mecat
# diteruskan : terus
# ancur : ancur
# trump : trump
# taruhan : taruh
# ptwn8f51yv : ptwn8f51yv
# anggap : anggap
# warganya : warga
# rezim : rezim
# rezimnya : rezim
# dihapus : hapus
# fq1mhaypuv : fq1mhaypuv
# ketauan : tau
# sembako : sembako
# apkh : apkh
# disimpulkn : disimpulkn
# berkualitas : kualitas
# rpzjmcztow : rpzjmcztow
# noerh4yatie : noerh4yatie
# nomnomnom : nomnomnom
# 17 : 17
# alpha : alpha
# n : n
# rochland : rochland
# y : y
# liar : liar
# khmluqman : khmluqman
# dibelakang : belakang
# taipan : taipan
# mati2an : mati2an
# bela : bela
# pertarung : tarung
# gede : gede
# dimanfaatin : dimanfaatin
# aniesbaswedanid : aniesbaswedanid
# abwdotinfo : abwdotinfo
# infoabw : infoabw
# aniesbaswedan2 : aniesbaswedan2
# quotes : quotes
# aniesbaswedan1 : aniesbaswedan1
# nte : nte
# batin : batin
# bilangin : bilangin
# dalang : dalang
# hidup : hidup
# sesungguhnya : sungguh
# kematian : mati
# serakah : serakah
# pd2ioxairu : pd2ioxairu
# visinya : visi
# terang : terang
# miskin : miskin
# aguan : aguan
# ktmu : ktmu
# wqoqy5rhn2 : wqoqy5rhn2
# ambil : ambil
# hibah : hibah
# majelis : majelis
# taqlim : taqlim
# sctv : sctv
# tst : tst
# marsc1103 : marsc1103
# jngan : jngan
# ngelis : ngelis
# melek : melek
# aset : aset
# 10t : 10t
# bharga : bharga
# sumbangan : sumbang
# wkwkwkkkk : wkwkwkkkk
# tuan : tuan
# majikan : majikan
# sma2 : sma2
# jebak : jebak
# tercyduk : tercyduk
# ciri2 : ciri2
# jempol : jempol
# cepat : cepat
# pda : pda
# pocongtwit : pocongtwit
# farambrose : farambrose
# sergiohantoro : sergiohantoro
# novian : novian
# sp : sp
# malangpungki : malangpungki
# halus24 : halus24
# 9naga : 9naga
# cacing : cacing
# 9cacing : 9cacing
# jakowi : jakowi
# ktahuan : ktahuan
# cri2 : cri2
# ksalahan : ksalahan
# iq200sekolam : iq200sekolam
# aktivis : aktivis
# tionghoa : tionghoa
# speech : speech
# korelasi : korelasi
# counter : counter
# argumennya : argumen
# nol : nol
# harihariono1 : harihariono1
# ilc : ilc
# pahami : paham
# loyalitas : loyalitas
# bengong : bengong
# bhw : bhw
# kpd : kpd
# telinga : telinga
# terganggu : ganggu
# fans : fans
# haters : haters
# keras : keras
# tonton : tonton
# ilcrapbddki : ilcrapbddki
# odyiusjacare : odyiusjacare
# nkri : nkri
# nomor : nomor
# 1 : 1
# iyutvb : iyutvb
# semu : semu
# bunda : bunda
# paud : paud
# bener : bener
# paut : paut
# alokasikan : alokasi
# sdhada : sdhada
# pusat : pusat
# belajar : ajar
# sabar : sabar
# cebongers : cebongers
# jalankan : jalan
# dengarkan : dengar
# kalap : kalap
# kebagian : bagi
# stnclaqlby : stnclaqlby
# fahiraidris : fahiraidris
# gendut : gendut
# getol : getol
# nyerang : nyerang
# honest : honest
# dibodoh2i : dibodoh2i
# politikus : politikus
# embel2 : embel2
# membela : bela
# dicampur : campur
# mangut2 : mangut2
# nalarnya : nalar
# mati : mati
# anjjiiiingg : anjjiiiingg
# sbnrnx : sbnrnx
# emsi : emsi
# mrah : mrah
# krjnx : krjnx
# cma : cma
# komeni : komeni
# periksa : periksa
# olh : olh
# mnytakn : mnytakn
# tmukn : tmukn
# tndk : tndk
# pdna : pdna
# korupsi : korupsi
# smpe : smpe
# dtk : dtk
# bkti : bkti
# lpor : lpor
# agen : agen
# pamer : pamer
# ganggu : ganggu
# aranku : aranku
# ragamaya : ragamaya
# bsputra4 : bsputra4
# zaeffendy : zaeffendy
# zumpio : zumpio
# kristwianto : kristwianto
# haryostwitte : haryostwitte
# prijantorabbani : prijantorabbani
# hazpohan : hazpohan
# ndon08 : ndon08
# kopral : kopral
# tl : tl
# quvvat : quvvat
# brilliant : brilliant
# pemprov : pemprov
# doyan : doyan
# heuheuheu : heuheuheu
# mon : mon
# maap : maap
# 10jt : 10jt
# jiwa : jiwa
# tlg : tlg
# pls : pls
# surolado : surolado
# yth : yth
# kyanom : kyanom
# jangkaru : jangkaru
# hey : hey
# abpd : abpd
# rancangan : rancang
# rapbd2018 : rapbd2018
# sisir : sisir
# relevan : relevan
# tugas : tugas
# merevisi : revisi
# blunder : blunder
# dr : dr
# anggapk : anggapk
# affi : affi
# r : r
# alv : alv
# jktmajubersama : jktmajubersama
# seorg : seorg
# dokter : dokter
# otomatis : otomatis
# trgelitik : trgelitik
# krena : krena
# seagama : agama
# krna : krna
# programny : programny
# terangkan : terang
# bagan : bagan
# skpd : skpd
# sekretariat : sekretariat
# rapbd : rapbd
# kmarin : kmarin
# pembengkakan : bengkak
# pspjjhu0yp : pspjjhu0yp
# timomanullang : timomanullang
# horang : horang
# bentar : bentar
# onde : onde
# mande : mande
# ananda : ananda
# sukarlan : sukarlan
# kereta : kereta
# bandara : bandara
# prestasi : prestasi
# portal : portal
# hbjhdwvktq : hbjhdwvktq
# kutil : kutil
# babi : babi
# bisanya : bisa
# 6x3edmor5h : 6x3edmor5h
# doviaric : doviaric
# emerson : emerson
# yuntho : yuntho
# gm : gm
# mensejeniskan : jenis
# lain2 : lain2
# ngompol : ngompol
# malang : malang
# melintang : lintang
# dunia : dunia
# persilatan : silat
# manz8687 : manz8687
# beritanya : berita
# membuktikan : bukti
# jn7r3f4obm : jn7r3f4obm
# hliee6atqu : hliee6atqu
# 28rrihf7zd : 28rrihf7zd
# waoi0v64mx : waoi0v64mx
# czdnr4gls9 : czdnr4gls9
# 3486uyrdcz : 3486uyrdcz
# zlxhqp9uwv : zlxhqp9uwv
# x63zlvh2gy : x63zlvh2gy
# bantah : bantah
# sumarsono : sumarsono
# dibiayai : biaya
# swasta : swasta
# harianindo : harianindo
# nov : nov
# fadlizon : fadlizon
# habiburokhman : habiburokhman
# minterin : minterin
# mncerdaskan : mncerdaskan
# agamis : agam
# abis : abis
# no1 : no1
# iming2 : iming2
# plus : plus
# vmwo4cfclt : vmwo4cfclt
# ngelesnya : ngelesnya
# manies : manies
# gqlgnleg2p : gqlgnleg2p
# 8evujgh08i : 8evujgh08i
# jpnncom : jpnncom
# pembodoh : bodoh
# mencari : cari
# uji : uji
# manfaat : manfaat
# terbesar : besar
# sekeluarganya : keluarga
# lbd1gmunja : lbd1gmunja
# hamaro : hamaro
# abethcia : abethcia
# dipimpin : pimpin
# sarmawan : sarmawan
# pertantasn : pertantasn
# anggaean : anggaean
# bengkak : bengkak
# upah : upah
# penceramah : ceramah
# kafirin : kafirin
# pra : pra
# jakrta : jakrta
# yuk : yuk
# dipaparkan : papar
# now : now
# banyam : banyam
# membual : bual
# mampus : mampus
# kapok : kapok
# luh : luh
# merajalela : rajalela
# presidentweter : presidentweter
# donaturia : donaturia
# kjp : kjp
# cabutin : cabutin
# berengsek : berengsek
# nongkrong : nongkrong
# warung : warung
# ngisap : ngisap
# rokok : rokok
# bengal : bengal
# silmys : silmys
# eyelash : eyelash
# prettysprairie : prettysprairie
# redstudio : redstudio
# banding : banding
# pidana : pidana
# pembunuhan : bunuh
# hak : hak
# hukum : hukum
# perdata : perdata
# ngatain : ngatain
# epic : epic
# floananta : floananta
# njabat : njabat
# sebb : sebb
# pradilan : pradilan
# wrga : wrga
# bukit : bukit
# duri : duri
# duhh : duhh
# njelasin : njelasin
# memaklumi : maklum
# petang : petang
# seblmny : seblmny
# nasional : nasional
# mnyaksikn : mnyaksikn
# mmbodohi : mmbodohi
# mjaewm0em5 : mjaewm0em5
# rachdianto : rachdianto
# tenaga : tenaga
# pekerjaan : kerja
# dibayar : bayar
# najis : najis
# nyari : nyari
# popularitas : popularitas
# menolongnya : tolong
# mengandalkan : andal
# tawubalong : tawubalong
# hotradero : hotradero
# ngefans : ngefans
# alasannya : alas
# kekepin : pin
# diuntunglah : untung
# bla : bla
# giliran : gilir
# koit : koit
# hehe : hehe
# the : the
# schloss : schloss
# noteiqbal : noteiqbal
# thenbagoess : thenbagoess
# ingetin : ingetin
# hasyim : hasyim
# dkk : dkk
# rompi : rompi
# tahanan : tahan
# stoknya : stok
# memfitnah : fitnah
# sebatas : batas
# kemampuan : mampu
# merekam : rekam
# culas : culas
# berfikir : berfikir
# lainpun : lain
# menggaji : gaji
# staf : staf
# mentok : mentok
# setingkat : tingkat
# menutupi : tutup
# bentuk : bentuk
# keserakahan : serakah
# kelicikannya : kelici
# alihkan : alih
# pandangan : pandang
# phw1n8agt5 : phw1n8agt5
# mrsaris378 : mrsaris378
# sory : sory
# menuduh : tuduh
# naniksudaryanti : naniksudaryanti
# festival : festival
# pantun : pantun
# relawanjmb : relawanjmb
# jdi : jdi
# kehendak : hendak
# adakalanya : adakalanya
# kekerasan : keras
# kedegilan : degil
# keliwat : liwat
# pelit : pelit
# pemkot : pemkot
# papa : papa
# tlp : tlp
# puji : puji
# tuhan : tuhan
# thanks : thanks
# lord : lord
# mairie : mairie
# paris : paris
# teman2 : teman2
# pilihanmu : pilih
# seandainya : anda
# wni : wni
# wktu : wktu
# sorry : sorry
# bnde : bnde
# jenis : jenis
# nak : nak
# layan : layan
# kbai : kbai
# roedysetiadi : roedysetiadi
# dkijakarta : dkijakarta
# jsclounge : jsclounge
# kmu : kmu
# ngedukung : ngedukung
# mgkin : mgkin
# bodoh2 : bodoh2
# pndidikan : pndidikan
# bnar : bnar
# mabok : mabok
# jdilah : jdilah
# gmpang : gmpang
# juni : juni
# irene : irene
# repot2 : repot2
# berkerumun : kerumun
# menunggu : tunggu
# statemen : statemen
# dikomen : dikomen
# rame2 : rame2
# jsdeyz : jsdeyz
# dmuluk : dmuluk
# menggambarkan : gambar
# pendendam : dendam
# penuh : penuh
# kedengkian : dengki
# yakinlah : yakin
# keberhasilan : hasil
# menjelang : jelang
# posisi : posisi
# lahiran : lahir
# selasa : selasa
# ngadunya : ngadunya
# sabtu : sabtu
# berpura : pura
# rekayasa : rekayasa
# ibukota : ibukota
# mempermalukan : malu
# hrcgea7sw2 : hrcgea7sw2
# xboleh : xboleh
# brain : brain
# alasan : alas
# xnak : xnak
# dtg : dtg
# esok : esok
# haish : haish
# sis : sis
# carutkan : carut
# muji : muji
# sndiri : sndiri
# ketawain : ketawain
# password : password
# email : email
# still : still
# letak : letak
# heih : heih
# blom : blom
# apa2nya : apa2nya
# ahmaddhaniprast : ahmaddhaniprast
# abdurrahman : abdurrahman
# kakek : kakek
# pahlawan : pahlawan
# artis : artis
# keminter : keminter
# sing : sing
# iku : iku
# kowe : kowe
# ump : ump
# bnn : bnn
# tenang : tenang
# keuangan : uang
# spj : spj
# 8yhepfdsek : 8yhepfdsek
# amaliaamelcute2 : amaliaamelcute2
# assalamualaikum : assalamualaikum
# biarin : biarin
# persiapan : siap
# fazzukha : fazzukha
# hbhendro : hbhendro
# ardhatitus : ardhatitus
# mantriss : mantriss
# verdomd : verdomd
# vervelend : vervelend
# erg : erg
# menyebalkan : sebal
# bilik : bilik
# mengadu : adu
# bukak : bukak
# cite : cite
# bosan : bosan
# siot : siot
# mlm : mlm
# tgk : tgk
# demdam : demdam
# aurora : aurora
# episod : episod
# sengal : sengal
# nye : nye
# whatsapp : whatsapp
# bile : bile
# jumpe : jumpe
# rindu : rindu
# septiara : septiara
# sist : sist
# kabar : kabar
# ownernya : ownernya
# dikabarkan : kabar
# owner : owner
# hadir : hadir
# tsb : tsb
# sik : sik
# tolol2 : tolol2
# hhh : hhh
# cape : cape
# tingkah : tingkah
# kyknya : kyknya
# semboyannya : semboyan
# tenggelamkan : tenggelam
# penyebar : sebar
# hatinya : hati
# busuk : busuk
# langkah : langkah
# bersinar : sinar
# bintangku206 : bintangku206
# tuagemox : tuagemox
# kepengen : ken
# dibanding : banding
# sprt : sprt
# bumi : bumi
# panggung : panggung
# ...
# jpranata : jpranata
# guntur : guntur
# edwin : edwin
# analisa : analisa
# maklumi : maklum
# surut : surut
# tergiur : giur
# jdlah : jdlah
# pngikut : pngikut
# w8azzw36fy : w8azzw36fy
# menggantinya : ganti
# pinternya : pinternya
# sopan : sopan
# ngatasi : ngatasi
# haryatiiin : haryatiiin
# ngelantur : ngelantur
# pakurmatan : pakurmatan
# hukumdan : hukumdan
# nyadar : nyadar
# saingan : saing
# cntoh : cntoh
# jimlyas : jimlyas
# babpc5kuxf : babpc5kuxf
# indra : indra
# zaids : zaids
# smart : smart
# menanggapi : tanggap
# statemnt : statemnt
# nazib : nazib
# tiba2 : tiba2
# gagap : gagap
# alkausar5 : alkausar5
# film : film
# warkop : warkop
# katotoloyo : katotoloyo
# sunda : sunda
# nambahin : nambahin
# disiapkan : siap
# masjaksa : masjaksa
# jaksa : jaksa
# menjeblokkan : jeblok
# chellendah : chellendah
# kerna : kerna
# teori : teori
# mala : mala
# sebenar : benar
# victor : victor
# pol : pol
# mdzolimi : mdzolimi
# tampil : tampil
# dingunuya : dingunuya
# pdg : pdg
# bkt : bkt
# 1978 : 1978
# abidumarfaruq : abidumarfaruq
# bangat : bangat
# kult : kult
# woy : woy
# ngambil : ngambil
# nantang : nantang
# rd0kdvvi5n : rd0kdvvi5n
# sul5td : sul5td
# twitan : twitan
# android : android
# mengirim : kirim
# jebakan : jebak
# kantong : kantong
# kuras : kuras
# 0rsfhvqkym : 0rsfhvqkym
# hahahahaahahah : hahahahaahahah
# netas : netas
# neng : neng
# hahahahahahahahahahahah : hahahahahahahahahahahah
# masukan : masuk
# ite : ite
# hahahahahahahah : hahahahahahahah
# hahahahahahahahahaahhah : hahahahahahahahahaahhah
# hahahahahahahahah : hahahahahahahahah
# cotchungha : cotchungha
# ngakaaak : ngakaaak
# malumaluin : malumaluin
# gunadimardianto : gunadimardianto
# ccilviany : ccilviany
# 50rb : 50rb
# karet : karet
# olah : olah
# ban : ban
# mesin : mesin
# kedukun : dukun
# tolil : tolil
# tauu : tauu
# syirik : syirik
# adha : adha
# firdaus99 : firdaus99
# memerangi : rang
# diperangi : rang
# memangnya : memang
# mabuk : mabuk
# minuman : minum
# oplosan : oplos
# zionis : zionis
# dear : dear
# mundar : mundar
# mandir : mandir
# what : what
# cabutbebasvisauntukchina : cabutbebasvisauntukchina
# pjpscafask : pjpscafask
# proksi2000 : proksi2000
# hebatnya : hebat
# tumpah : tumpah
# ruah : ruah
# jalanan : jalan
# kenal : kenal
# relawanperak : relawanperak
# cadarmerah : cadarmerah
# trahkartasura : trahkartasura
# kafan : kafan
# anggoro : anggoro
# gampanglah : gampang
# trik : trik
# mentelengin : mentelengin
# appun : appun
# 0x0mtpocus : 0x0mtpocus
# bales : bales
# tantangan : tantang
# mnunjukkan : mnunjukkan
# dipecahkan : pecah
# ngetik : ngetik
# laki2 : laki2
# sejati : sejati
# penolak : tolak
# mksud : mksud
# argumen : argumen
# kgak : kgak
# nyolot : nyolot
# bngga : bngga
# unyikusrol : unyikusrol
# kbnykan : kbnykan
# mkin : mkin
# ngakunya : ngakunya
# cermah : cermah
# bhkan : bhkan
# hrus : hrus
# ajrn : ajrn
# aldidesri : aldidesri
# 7evenclothes : 7evenclothes
# dkarhita : dkarhita
# jimmyherdyansy2 : jimmyherdyansy2
# ngobush3 : ngobush3
# bacod : bacod
# flash : flash
# back : back
# pendahulumu : dahulu
# diikutin : diikutin
# pakde : pakde
# mengedepankan : depan
# slogan : slogan
# g8idah2bzk : g8idah2bzk
# hhhhahahahhaa : hhhhahahahhaa
# pntes : pntes
# nggk : nggk
# sntg : sntg
# prempuan : prempuan
# emk : emk
# hhhahahha : hhhahahha
# coyy : coyy
# hhhhahaha : hhhhahaha
# parlandungan : parlandungan
# damaiselalu86 : damaiselalu86
# zizig17 : zizig17
# hutangnya : hutang
# meroket : roket
# main2 : main2
# dung : dung
# kebawah : bawah
# premium : premium
# menghilang : hilang
# prestasinya : prestasi
# cahbagoes39 : cahbagoes39
# pelayanan : layan
# mentalitas : mentalitas
# massif : massif
# melampaui : lampau
# capaian : capai
# orde : orde
# belegug : belegug
# manpu : manpu
# robekin : robekin
# topi : topi
# panci : panci
# ngajedog : ngajedog
# jang : jang
# dahar : dahar
# jelema : jelema
# bencong : bencong
# jalanin : jalanin
# sejalan : jalan
# dikitlah : dikit
# iyah : iyah
# penjelasannya : jelas
# paspampres : paspampres
# eks : eks
# dirjen : dirjen
# hubla : hubla
# dbenarkan : dbenarkan
# disekolah : seko
# kalian2 : kalian2
# sukanya : suka
# urusin2 : urusin2
# ginian : ginian
# begerak : begerak
# diexpose : diexpose
# jiplak : jiplak
# 4o0atlytyi : 4o0atlytyi
# giat : giat
# mengejar : kejar
# ekonomi : ekonomi
# dijelasin : dijelasin
# gunromlahh : gunromlahh
# snorkeling12 : snorkeling12
# dibina : bina
# kamaru : kamaru
# 02 : 02
# rininz1972 : rininz1972
# 01 : 01
# 04 : 04
# 05 : 05
# 06 : 06
# 07 : 07
# egp13 : egp13
# dre : dre
# helllloooooooo : helllloooooooo
# lakinya : laki
# incarannya : incar
# sosok : sosok
# dijitak : jitak
# bindrawati : bindrawati
# struk : struk
# maen : maen
# waria : waria
# tampang : tampang
# dewasa : dewasa
# masukin : masukin
# gorong : gorong
# trans : trans
# bodohhhhhhh : bodohhhhhhh
# buahhahahahahhahahha : buahhahahahahhahahha
# jari : jari
# sentuh : sentuh
# lurus : lurus
# hadis : hadis
# hafal : hafal
# mempertontonkan : tonton
# kedunguanmu : dungu
# tersinggung : singgung
# nose : nose
# dilanggar : langgar
# kemunafikan : munafik
# membantahnya : bantah
# pntas : pntas
# mempermainkan : main
# bertuhan : tuhan
# bibir : bibir
# dijaga : jaga
# berhadapan : hadap
# kelak : kelak
# rupa : rupa
# diisi : isi
# khawandar : khawandar
# klonengan : klonengan
# andai2nya : andai2nya
# pasangan : pasang
# surveyor : surveyor
# klas : klas
# bwh : bwh
# asripeni3 : asripeni3
# berpendapat : dapat
# terorisme : terorisme
# yerusalem : yerusalem
# mencegah : cegah
# replynya : replynya
# poutmonz : poutmonz
# kedaibunda : kedaibunda
# sabrigo3 : sabrigo3
# dede318a : dede318a
# sabrigo : sabrigo
# kicep : kicep
# cemilan : cemilan
# bebel : bebel
# icamikil : icamikil
# prieyan : prieyan
# kemendag : kemendag
# wuasu : wuasu
# kabinetlenong : kabinetlenong
# solor : solor
# hapeproperti : hapeproperti
# alwayzrejoice : alwayzrejoice
# leonartorabono : leonartorabono
# jrvfk2s3nh : jrvfk2s3nh
# cebongkoleps : cebongkoleps
# insyaallah : insyaallah
# 3zdwriqawa : 3zdwriqawa
# d2nnizam : d2nnizam
# 04nakula : 04nakula
# ditipuin : ditipuin
# jazedw : jazedw
# ricky42471019 : ricky42471019
# dhemithmerapi : dhemithmerapi
# tjahjadijudono : tjahjadijudono
# habib : habib
# kimono : kimono
# mnghina : mnghina
# pmimpin : pmimpin
# kotanya : kota
# sblum2nya : sblum2nya
# halus : halus
# tauknya : tauknya
# esensi : esensi
# disoraki : sorak
# pir : pir
# kurang2 : kurang2
# terungkap : ungkap
# tuli : tuli
# goublog : goublog
# tuch : tuch
# falahmohamad30 : falahmohamad30
# krenteking : krenteking
# ati : ati
# hanestia : hanestia
# nahdlatululama : nahdlatululama
# asupan : asupan
# fulus : fulus
# rokdounhx7 : rokdounhx7
# ascha021 : ascha021
# iwanisti2 : iwanisti2
# tepati : tepat
# cacuganteng : cacuganteng
# menguat : kuat
# janjinya : janji
# penghuni : huni
# gobloooook : gobloooook
# emanuel97859971 : emanuel97859971
# ngeladenin : ngeladenin
# kykny : kykny
# buaya : buaya
# ngajak2 : ngajak2
# mosoooooooooooooooo : mosoooooooooooooooo
# nama2 : nama2
# persidangan : sidang
# hervasemil : hervasemil
# selenakoe : selenakoe
# bisikin : bisikin
# zonk59638945 : zonk59638945
# bandingin : bandingin
# fuihhh : fuihhh
# 7fys5hdcuj : 7fys5hdcuj
# endarto59769219 : endarto59769219
# nindyarti : nindyarti
# johny71989498 : johny71989498
# pramugaring : pramugaring
# camumpuni : camumpuni
# gpansor : gpansor
# ld : ld
# pbnu : pbnu
# cybernu : cybernu
# mensyen : mensyen
# jwab : jwab
# gusnadjib : gusnadjib
# berlipstik : lipstik
# gituan : gituan
# menghindari : hindar
# gruduk : gruduk
# massa : massa
# gerombolannya : gerombol
# psd : psd
# 313 : 313
# tedongborneo : tedongborneo
# oia : oia
# lukmansaiffudin : lukmansaiffudin
# tumbuh : tumbuh
# rian : rian
# jombang : jombang
# saipul : saipul
# jamil : jamil
# ditunggangin : ditunggangin
# koruptor2 : koruptor2
# nakut2in : nakut2in
# res : res
# bengak2 : bengak2
# smpai : smpai
# tanduk : tanduk
# nggag : nggag
# mahluk : mahluk
# sok2an : sok2an
# kepleset : kepleset
# maidah51 : maidah51
# murahanx : murahanx
# timur : timur
# dimasukin : dimasukin
# isti : isti
# astro : astro
# hotman49572384 : hotman49572384
# andreasgoeng : andreasgoeng
# w1n2017 : w1n2017
# rutucinta : rutucinta
# cekak : cekak
# proporsional : proporsional
# sangkutpautkan : sangkutpautkan
# sigabener : sigabener
# sutiyoso : sutiyoso
# polisiindiammgtolol : polisiindiammgtolol
# senoaji2772 : senoaji2772
# radenw46 : radenw46
# henrisalim1 : henrisalim1
# sayur : sayur
# ariepriambudi : ariepriambudi
# iwanaprawira : iwanaprawira
# amir : amir
# dibicarain : dibicarain
# jiah : jiah
# kue : kue
# kering : kering
# rebutan : rebut
# donasi : donasi
# 500rb : 500rb
# drone : drone
# bonus : bonus
# bayarannya : bayar
# solusinya : solusi
# husinshihab : husinshihab
# ncik : ncik
# ngih : ngih
# rest : rest
# wereng : wereng
# coklat : coklat
# kocak : kocak
# 17317dr4 : 17317dr4
# samanya : sama
# kepo : kepo
# klik : klik
# ketularan : tular
# rajo : rajo
# boed : boed
# bubarkanbanser : bubarkanbanser
# putrie : putrie
# guooblog : guooblog
# inramiana : inramiana
# duper : duper
# skali : skali
# tmbh : tmbh
# mjd2 : mjd2
# didarat : darat
# empang : empang
# alihaqqi : alihaqqi
# my23cr : my23cr
# jing : jing
# gmana : gmana
# objeknya : objek
# declare : declare
# buy : buy
# realisasikan : realisasi
# sbnrny : sbnrny
# butakan : buta
# bohongnya : bohong
# semenjak : semenjak
# 2periode : 2periode
# rusdira : rusdira
# uf : uf
# 5ydcx4125e : 5ydcx4125e
# hidayatabd : hidayatabd
# kerak : kerak
# ketan : ketan
# angus : angus
# merintah : merintah
# jaga : jaga
# intensitas : intensitas
# banyaknya : banyak
# ngungsi : ngungsi
# ajang : ajang
# badai : badai
# cempaka : cempaka
# dahlia : dahlia
# jatim : jatim
# nuntut : nuntut
# hid : hid
# kemampuannya : mampu
# masyaallah : masyaallah
# sumarsono80 : sumarsono80
# diragukan : ragu
# keoranganny : keoranganny
# pengumuman : umum
# omg : omg
# pembagian : bagi
# absen : absen
# evelin4mey : evelin4mey
# bzsoiy8r6r : bzsoiy8r6r
# ywho353tnu : ywho353tnu
# nurwahid : nurwahid
# berdiam : diam
# raya : raya
# help : help
# y9wv8zaw0n : y9wv8zaw0n
# laras88laras881 : laras88laras881
# bnjir : bnjir
# makhlumi : makhlumi
# bepikir : bepikir
# 29umwjodlq : 29umwjodlq
# amelia89597444 : amelia89597444
# kelompoknya : kelompok
# agamanya : agama
# lacurkan : lacur
# gundi : gundi
# jerami : jerami
# penanggulangan : tanggulang
# ekseskusinya : ekseskusinya
# tergantung : gantung
# hadapi : hadap
# janjimu : janji
# lko : lko
# dibawa2 : dibawa2
# haikal : haikal
# hassan : hassan
# etnzg5uuwo : etnzg5uuwo
# dbawa : dbawa
# ajee : ajee
# diborong : borong
# kaliiii : kaliiii
# ngomel : ngomel
# trio : trio
# lanjutin : lanjutin
# ngurangin : ngurangin
# ngibulin : ngibulin
# diresmikan : resmi
# vc7sxdfq6d : vc7sxdfq6d
# kaesang : kaesang
# katain : katain
# sangka : sangka
# qv68nlxywc : qv68nlxywc
# e6h15rmg7y : e6h15rmg7y
# sahkan : sahkan
# slb : slb
# ngibul : ngibul
# bertanggung : tanggung
# mengungkap : ungkap
# tirai : tirai
# diperparah : parah
# bancakan : bancak
# memudahkan : mudah
# penanganan : tangan
# dijajah : jajah
# memerdekakan : merdeka
# pindah : pindah
# bho50 : bho50
# dsni : dsni
# ermaperma : ermaperma
# parahnya : parah
# warbiyasah : warbiyasah
# katak : katak
# hmmm : hmmm
# setya1201 : setya1201
# kelangkaan : langka
# distributor : distributor
# mslh : mslh
# pngriman : pngriman
# mbah : mbah
# konteksnya : konteks
# ybs : ybs
# coz : coz
# tm2000back : tm2000back
# mf : mf
# yaman : yaman
# swarnadiva9 : swarnadiva9
# metrotvboxlies : metrotvboxlies
# kawuladusun : kawuladusun
# ninnocyber : ninnocyber
# lpi : lpi
# ha3x : ha3x
# ajah : ajah
# laskar : laskar
# front : front
# kroni2 : kroni2
# blomm : blomm
# trus2an : trus2an
# nyebarin : nyebarin
# hate : hate
# torak1920 : torak1920
# gilarbandoenx : gilarbandoenx
# auryn071 : auryn071
# nda : nda
# diberitain : diberitain
# eksis : eks
# thd : thd
# noch : noch
# mekanisme : mekanisme
# slametfebrian : slametfebrian
# kementerianesdm : kementerianesdm
# dibikinin : dibikinin
# 3kg : 3kg
# nonsubsidi : nonsubsidi
# gas3kg : gas3kg
# mention : mention
# rontokan : rontok
# rengginang : rengginang
# z4z7hptw92 : z4z7hptw92
# aiaidid : aiaidid
# hariankompas : hariankompas
# woiiiii : woiiiii
# kntl : kntl
# nyolong : nyolong
# nekad : nekad
# senonoh : senonoh
# berbalut : balut
# anticebongs : anticebongs
# gembel : gembel
# nikmatin : nikmatin
# nihil : nihil
# oerak : oerak
# trnsfr : trnsfr
# ssama : ssama
# ribetny : ribetny
# nunggu : nunggu
# 3hari : 3hari
# direksinya : direksi
# kontakbri : kontakbri
# bankmandiri : bankmandiri
# mayaapertiwii : mayaapertiwii
# rajesky : rajesky
# imamsupriadibpk : imamsupriadibpk
# buyut : buyut
# sofieborneo62 : sofieborneo62
# strategy : strategy
# niyh : niyh
# terpancing : pancing
# qta : qta
# negatif : negatif
# seputar : putar
# perjuangannya : juang
# gnns : gnns
# andeket : andeket
# herryzal : herryzal
# jue : jue
# jum : jum
# atan : atan
# ladeni : laden
# {'pendjaca': 'pendjaca', 'herditiya1': 'herditiya1', 'berharap': 'harap', 'menkeu': 'menkeu', 'meralat': 'ralat', 'pernyataannya': 'nyata', 'pembenci': 'benci', 'anies': 'anies', 'sandi': 'sandi', 'keliatan': 'liat', 'bego': 'bego', 'tonywibowo12': 'tonywibowo12', 'michael24007966': 'michael24007966', 'triwul82': 'triwul82', 'semiaji': 'semiaji', 'w': 'w', 'tetapahokdjarot': 'tetapahokdjarot', 'aniesbaswedan': 'aniesbaswedan', 'suaraanies': 'suaraanies', 'kpk': 'kpk', 'ri': 'ri', 'jokowi': 'jokowi', 'ruhutsitompul': 'ruhutsitompul', 'tjahjo': 'tjahjo', 'kumolo': 'kumolo', 'anti': 'anti', 'sdh': 'sdh', 'salah': 'salah', 'baca': 'baca', 'berita': 'berita', 'gak': 'gak', 'dasar': 'dasar', 'guoblok': 'guoblok', 'tinggal': 'tinggal', 'dijakarta': 'dijakarta', 'kalo': 'kalo', 'berani': 'berani', 'langsung': 'langsung', 'datengin': 'datengin', 'napa': 'napa', 'kritik': 'kritik', 'hebat': 'hebat', 'bicara': 'bicara', 'medsos': 'medsos', 'haha': 'haha', 'jkrta': 'jkrta', 'mikiiirrr': 'mikiiirrr', 'tong': 'tong', 'detikfinance': 'detikfinance', 'aduh': 'aduh', 'jng': 'jng', 'mgeliatin': 'mgeliatin', 'nya': 'nya', 'elo': 'elo', 'srimulyani': 'srimulyani', 'udh': 'udh', 'manajer': 'manajer', 'world': 'world', 'bank': 'bank', 'ngasal': 'ngasal', 'bkin': 'bkin', 'anggaran': 'anggar', 'enak': 'enak', 'bngt': 'bngt', 'pejabat': 'jabat', 'abis2in': 'abis2in', 'uang': 'uang', 'rakyat': 'rakyat', 'sarap': 'sarap', 'nyiiiing': 'nyiiiing', 'sia': 'sia', 'mah': 'mah', 'emangnya': 'emang', 'lakukan': 'laku', 'kmpanye': 'kmpanye', 'hitam': 'hitam', 'dmn': 'dmn', 'materinya': 'materi', 'tunjukkan': 'tunjuk', 'pengamat': 'amat', 'pngamat': 'pngamat', 'pro': 'pro', 'ahoker': 'ahoker', 'korantempo': 'korantempo', 'xphgcuqfwg': 'xphgcuqfwg', 'dahnilanzar': 'dahnilanzar', 'toleran': 'toleran', 'menguntungkan': 'untung', 'ente': 'ente', 'pura2': 'pura2', 'baswedan': 'baswedan', 'gubernur': 'gubernur', 'dimiliki': 'milik', 'jakarta': 'jakarta', 'mantan': 'mantan', 'rektor': 'rektor', 'paham': 'paham', 'beda': 'beda', 'pasar': 'pasar', 'jalan': 'jalan', 'senyum': 'senyum', 'kekecewaan': 'kecewa', 'pkl': 'pkl', 'penataan': 'tata', 'tanah': 'tanah', 'abang': 'abang', 'ala': 'ala', '1oix5sl6p6': '1oix5sl6p6', 've4zsksvrt': 've4zsksvrt', 'arab': 'arab', 'bodoh': 'bodoh', 'bin': 'bin', 'tolol': 'tolol', 'bangsat': 'bangsat', 'perseteruan': 'seteru', 'kemendagri': 'kemendagri', 'tgupp': 'tgupp', 'aag3qz8crr': 'aag3qz8crr', 'jeg': 'jeg', 'likte': 'likte', 'youtube': 'youtube', 'video': 'video', 'fyojwcreia': 'fyojwcreia', 'mendagri': 'mendagri', 'cagubnyinyir': 'cagubnyinyir', 'lulung': 'lulung', 'sempet2nya': 'sempet2nya', 'jenius': 'jenius', 'menata': 'tata', 'lawan': 'lawan', 'ombudsman': 'ombudsman', 'thdp': 'thdp', 'cara2': 'cara2', 'dicoret': 'coret', 'des': 'des', 'yovnmiqdep': 'yovnmiqdep', 'reyarton': 'reyarton', 'ridwan': 'ridwan', 'ayaaya': 'ayaaya', 'kangdede78': 'kangdede78', 'fanatik': 'fanatik', 'blh': 'blh', 'jgn': 'jgn', 'tuh': 'tuh', 'pct': 'pct', 'krn': 'krn', 'kerja': 'kerja', 'apalg': 'apalg', 'ngurus': 'ngurus', '23t': '23t', 'ampir': 'ampir', 'lolos': 'lolos', 'untung': 'untung', 'ketahuan': 'tahu', 'gabener': 'gabener', 'jualan': 'jual', 'sara': 'sara', 'menunjukan': 'tunjuk', 'amp': 'amp', 'dki': 'dki', 'diabisin': 'diabisin', 'peruntukannya': 'untuk', 'ngaku': 'ngaku', 'jonan': 'jonan', 'pinter': 'pinter', 'msh': 'msh', 'banget': 'banget', 'lahh': 'lahh', 'gausah': 'gausah', 'twitter': 'twitter', 'gabakal': 'gabakal', 'denger': 'denger', 'doi': 'doi', 'cuy': 'cuy', 'ketemu': 'ketemu', 'sms': 'sms', 'wkwk': 'wkwk', 'gabisa': 'gabisa', 'doain': 'doain', 'aja': 'aja', 'allah': 'allah', 'ngerubah': 'ngerubah', 'perilaku': 'perilaku', 'vento': 'vento', 'melvin': 'melvin', 'dsimbol1': 'dsimbol1', 'tjakdny': 'tjakdny', 'republikaonline': 'republikaonline', 'oon': 'oon', 'move': 'move', 'nerima': 'nerima', 'kenyataan': 'nyata', 'ngehabur': 'ngehabur', 'hamburin': 'hamburin', 'apbd': 'apbd', 'cmiww': 'cmiww', 'tolong': 'tolong', 'garis': 'garis', 'b ...
# ------------------------
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=1800.0), HTML(value='')))

# %%
# Membuat kolom yang bernama "content_bersih" pada DataFrame "data_2017" yang telah selesai dilakukan proses text preprocessing
data_2017["content_bersih"] = [" ".join(map(str, i)) for i in data_2017["content_stemming"]]
data_2017.head()
# Out:
#                         date  \
# 0  2017-12-29 08:09:29+00:00
# 1  2017-12-28 02:12:13+00:00
# 2  2017-12-27 12:32:16+00:00
# 3  2017-12-26 13:01:10+00:00
# 4  2017-12-26 08:29:32+00:00
#
#                                              content    label  \
# 0   pendjaca herditiya1 berharap menkeu meralat p...  negatif
# 1   tonywibowo12 michael24007966 triwul82 semiaji...  positif
# 2   detikfinance aduh anies jng mgeliatin bego ny...  positif
# 3  emangnya anies lakukan kmpanye hitam dmn apa m...  positif
# 4   dahnilanzar anies itu toleran kalau menguntun...  positif
#
#                                   content_tokenizing  \
# 0  [pendjaca, herditiya1, berharap, menkeu, meral...
# 1  [tonywibowo12, michael24007966, triwul82, semi...
# 2  [detikfinance, aduh, anies, jng, mgeliatin, be...
# 3  [emangnya, anies, lakukan, kmpanye, hitam, dmn...
# 4  [dahnilanzar, anies, itu, toleran, kalau, meng...
#
#                                    content_stopwords  \
# 0  [pendjaca, herditiya1, berharap, menkeu, meral...
# 1  [tonywibowo12, michael24007966, triwul82, semi...
# 2  [detikfinance, aduh, anies, jng, mgeliatin, be...
# 3  [emangnya, anies, lakukan, kmpanye, hitam, dmn...
# 4  [dahnilanzar, anies, toleran, menguntungkan, e...
#
#                                     content_stemming  \
# 0  [pendjaca, herditiya1, harap, menkeu, ralat, n...
# 1  [tonywibowo12, michael24007966, triwul82, semi...
# 2  [detikfinance, aduh, anies, jng, mgeliatin, be...
# 3  [emang, anies, laku, kmpanye, hitam, dmn, mate...
# 4  [dahnilanzar, anies, toleran, untung, ente, be...
#
#                                       content_bersih
# 0  pendjaca herditiya1 harap menkeu ralat nyata b...
# 1  tonywibowo12 michael24007966 triwul82 semiaji ...
# 2  detikfinance aduh anies jng mgeliatin bego nya...
# 3  emang anies laku kmpanye hitam dmn materi tunj...
# 4  dahnilanzar anies toleran untung ente bego pur...

# %% [markdown]
# ## 3. Mengambil Isi Kolom "content_bersih"

# %%
# Mengeluarkan isi tweet bersih dari DataFrame "data"
ekstraksi_data_content = " ".join(str(c) for c in data_2017["content_bersih"])
ekstraksi_data_content
# Out:
# 'pendjaca herditiya1 harap menkeu ralat nyata benci anies sandi liat bego tonywibowo12 michael24007966 triwul82 semiaji w tetapahokdjarot aniesbaswedan suaraanies kpk ri jokowi ruhutsitompul tjahjo kumolo anti anies sdh salah bego baca berita gak dasar guoblok tinggal dijakarta kalo berani langsung datengin langsung napa kritik hebat bicara medsos gak berani haha jkrta mikiiirrr tong detikfinance aduh anies jng mgeliatin bego nya elo napa srimulyani udh manajer world bank jng ngasal bkin anggar enak bngt jabat abis2in uang rakyat sarap nyiiiing sia mah emang anies laku kmpanye hitam dmn materi tunjuk amat bego pngamat pro ahoker korantempo xphgcuqfwg dahnilanzar anies toleran untung ente bego pura2 bego anies baswedan gubernur bego milik jakarta gubernur mantan rektor paham beda pasar jalan senyum kecewa pkl tata tanah abang ala anies sandi 1oix5sl6p6 ve4zsksvrt arab bodoh bin bego bin tolol bin bangsat seteru anies kemendagri tgupp aag3qz8crr jeg likte youtube video fyojwcreia anies sandi gubernur mendagri bego gubernur mendagri cagubnyinyir lulung sempet2nya anies jenius tata tanah abang jenius lawan bego lulung jenius ombudsman thdp cara2 anies anies sandi gubernur mendagri bego gubernur mendagri tgupp coret des yovnmiqdep reyarton ridwan ayaaya kangdede78 aniesbaswedan fanatik blh bego jgn anies tuh pct krn kerja apalg ngurus anggar 23t ampir lolos untung tahu anies gabener krn jual sara tunjuk amp anggar dki diabisin untuk ngaku jonan pinter msh bodoh kalo kritik jokowi anies sandi bego bego banget lahh gausah twitter gabakal denger doi cuy kalo langsung ketemu sms wkwk kalo gabisa doain aja allah ngerubah perilaku nya vento melvin dsimbol1 tjakdny republikaonline oon move bego nya gak nerima nyata kalo anies ngehabur hamburin apbd cmiww tolong garis bawah kalimat demit gue aja percaya kalo anies bego taeeeeeee kompascom tdk karuan anggap warga dki bego tgupp jaman ahok gaji pakai dana operasional anien pakai apbd beda anies beda anggar warga waras sdh paham jgn muter2 pakai dana operasional hidahidaan kangdede78 mas hida orang gak percaya pikir kritis gak data bikin ubah diri taun mah inkonsisten mas tualang pikir gue aja percaya kalo anies bego tukangkoprol aniesbaswedan omong anies wkt debat dlu bilang ahok gubernur putus asa skrg pake smua program ahok program utk lansia smua warga dki bego kali bego sih doank kompascom prinsip anies dlu pilih janji masyarakat bego makan omong benci anies sandy kecebong bego permanen kampanye ngomong sih anies ente rekam gak suaraanies solusi banjir versi baswedan koq bego gubernur jakarta pbgdawgqly kompascom bodoh dibodohin pura2 bego anies sllu usaha lepas bayang2 ahok klo ide judul sllu beda lwt main kata2 sensng anies sengaja bikin menang biar congor ente tdk teriak teriak biar negara kondusif indonesia hancur perang agama bego tau politik tau demo makan nasbus berak kencing pohon hihihi ucpxtgez5r gue mah santai aja karna gue gak milih anies sandi elu pilih anies sandi elu tipu kasihan deh nasib mikir bego piara gewfltxfec krizz39907724 ngoceh dasar bani cabul bego idiot anak didik rizieq cabul mabur gak pulang pulang anies banyak bacot persis kek mulut anies sandi jefrinaldi anandasukarlan aniesbaswedan lukmansaifuddin dasar bego jelas2 beda sukrlala krn gak pidato anies karap koh hok situ naah monas adlh muslim kecewa dgn menteri krn gak muslim udah paham dasar cebong suara satubkolam butek suaraanies kawal jkt halah pura2 bego aja loe org jawab loe org aja loe ngak dukung anies percaya omong loe krn cekok doang ngecek kyk aniesbaswedan ngeles krn emang kgk ngecek anies baswedan bantu dana partai kali lipat sdbbx8wgxj tvonenews ayo vangke ahoker bego takviri nyinyirin lahhh bego otak kaya kebo y0rbun8fyi bang udin19 ferryh19 tsamaradki wooyyyy berpikirk otak anggar taon msh milik djarot bkn anies klo taon dpn tanggung jwb anies klo bego ush bagi2 takviri jamban gemacan70 anies baswedan bantu dana partai kali lipat fwhhn5k6pg tvonenews ayo vangke ahoker bego takviri nyinyirin l ...

# %%
# Melihat isi tweet per kata yang telah dilakukan proses ekstraksi menggunakan word_tokenize dari library nltk
word_tokenize_content = word_tokenize(ekstraksi_data_content)
word_tokenize_content
# Out:
# ['pendjaca',
#  'herditiya1',
#  'harap',
#  'menkeu',
#  'ralat',
#  'nyata',
#  'benci',
#  'anies',
#  'sandi',
#  'liat',
#  'bego',
#  'tonywibowo12',
#  'michael24007966',
#  'triwul82',
#  'semiaji',
#  'w',
#  'tetapahokdjarot',
#  'aniesbaswedan',
#  'suaraanies',
#  'kpk',
#  'ri',
#  'jokowi',
#  'ruhutsitompul',
#  'tjahjo',
#  'kumolo',
#  'anti',
#  'anies',
#  'sdh',
#  'salah',
#  'bego',
#  'baca',
#  'berita',
#  'gak',
#  'dasar',
#  'guoblok',
#  'tinggal',
#  'dijakarta',
#  'kalo',
#  'berani',
#  'langsung',
#  'datengin',
#  'langsung',
#  'napa',
#  'kritik',
#  'hebat',
#  'bicara',
#  'medsos',
#  'gak',
#  'berani',
#  'haha',
#  'jkrta',
#  'mikiiirrr',
#  'tong',
#  'detikfinance',
#  'aduh',
#  'anies',
#  'jng',
#  'mgeliatin',
#  'bego',
#  'nya',
#  'elo',
#  'napa',
#  'srimulyani',
#  'udh',
#  'manajer',
#  'world',
#  'bank',
#  'jng',
#  'ngasal',
#  'bkin',
#  'anggar',
#  'enak',
#  'bngt',
#  'jabat',
#  'abis2in',
#  'uang',
#  'rakyat',
#  'sarap',
#  'nyiiiing',
#  'sia',
#  'mah',
#  'emang',
#  'anies',
#  'laku',
#  'kmpanye',
#  'hitam',
#  'dmn',
#  'materi',
#  'tunjuk',
#  'amat',
#  'bego',
#  'pngamat',
#  'pro',
#  'ahoker',
#  'korantempo',
#  'xphgcuqfwg',
#  'dahnilanzar',
#  'anies',
#  'toleran',
#  'untung',
#  'ente',
#  'bego',
#  'pura2',
#  'bego',
#  'anies',
#  'baswedan',
#  'gubernur',
#  'bego',
#  'milik',
#  'jakarta',
#  'gubernur',
#  'mantan',
#  'rektor',
#  'paham',
#  'beda',
#  'pasar',
#  'jalan',
#  'senyum',
#  'kecewa',
#  'pkl',
#  'tata',
#  'tanah',
#  'abang',
#  'ala',
#  'anies',
#  'sandi',
#  '1oix5sl6p6',
#  've4zsksvrt',
#  'arab',
#  'bodoh',
#  'bin',
#  'bego',
#  'bin',
#  'tolol',
#  'bin',
#  'bangsat',
#  'seteru',
#  'anies',
#  'kemendagri',
#  'tgupp',
#  'aag3qz8crr',
#  'jeg',
#  'likte',
#  'youtube',
#  'video',
#  'fyojwcreia',
#  'anies',
#  'sandi',
#  'gubernur',
#  'mendagri',
#  'bego',
#  'gubernur',
#  'mendagri',
#  'cagubnyinyir',
#  'lulung',
#  'sempet2nya',
#  'anies',
#  'jenius',
#  'tata',
#  'tanah',
#  'abang',
#  'jenius',
#  'lawan',
#  'bego',
#  'lulung',
#  'jenius',
#  'ombudsman',
#  'thdp',
#  'cara2',
#  'anies',
#  'anies',
#  'sandi',
#  'gubernur',
#  'mendagri',
#  'bego',
#  'gubernur',
#  'mendagri',
#  'tgupp',
#  'coret',
#  'des',
#  'yovnmiqdep',
#  'reyarton',
#  'ridwan',
#  'ayaaya',
#  'kangdede78',
#  'aniesbaswedan',
#  'fanatik',
#  'blh',
#  'bego',
#  'jgn',
#  'anies',
#  'tuh',
#  'pct',
#  'krn',
#  'kerja',
#  'apalg',
#  'ngurus',
#  'anggar',
#  '23t',
#  'ampir',
#  'lolos',
#  'untung',
#  'tahu',
#  'anies',
#  'gabener',
#  'krn',
#  'jual',
#  'sara',
#  'tunjuk',
#  'amp',
#  'anggar',
#  'dki',
#  'diabisin',
#  'untuk',
#  'ngaku',
#  'jonan',
#  'pinter',
#  'msh',
#  'bodoh',
#  'kalo',
#  'kritik',
#  'jokowi',
#  'anies',
#  'sandi',
#  'bego',
#  'bego',
#  'banget',
#  'lahh',
#  'gausah',
#  'twitter',
#  'gabakal',
#  'denger',
#  'doi',
#  'cuy',
#  'kalo',
#  'langsung',
#  'ketemu',
#  'sms',
#  'wkwk',
#  'kalo',
#  'gabisa',
#  'doain',
#  'aja',
#  'allah',
#  'ngerubah',
#  'perilaku',
#  'nya',
#  'vento',
#  'melvin',
#  'dsimbol1',
#  'tjakdny',
#  'republikaonline',
#  'oon',
#  'move',
#  'bego',
#  'nya',
#  'gak',
#  'nerima',
#  'nyata',
#  'kalo',
#  'anies',
#  'ngehabur',
#  'hamburin',
#  'apbd',
#  'cmiww',
#  'tolong',
#  'garis',
#  'bawah',
#  'kalimat',
#  'demit',
#  'gue',
#  'aja',
#  'percaya',
#  'kalo',
#  'anies',
#  'bego',
#  'taeeeeeee',
#  'kompascom',
#  'tdk',
#  'karuan',
#  'anggap',
#  'warga',
#  'dki',
#  'bego',
#  'tgupp',
#  'jaman',
#  'ahok',
#  'gaji',
#  'pakai',
#  'dana',
#  'operasional',
#  'anien',
#  'pakai',
#  'apbd',
#  'beda',
#  'anies',
#  'beda',
#  'anggar',
#  'warga',
#  'waras',
#  'sdh',
#  'paham',
#  'jgn',
#  'muter2',
#  'pakai',
#  'dana',
#  'operasional',
#  'hidahidaan',
#  'kangdede78',
#  'mas',
#  'hida',
#  'orang',
#  'gak',
#  'percaya',
#  'pikir',
#  'kritis',
#  'gak',
#  'data',
#  'bikin',
#  'ubah',
#  'diri',
#  'taun',
#  'mah',
#  'inkonsisten',
#  'mas',
#  'tualang',
#  'pikir',
#  'gue',
#  'aja',
#  'percaya',
#  'kalo',
#  'anies',
#  'bego',
#  'tukangkoprol',
#  'aniesbaswedan',
#  'omong',
#  'anies',
#  'wkt',
#  'debat',
#  'dlu',
#  'bilang',
#  'ahok',
#  'gubernur',
#  'putus',
#  'asa',
#  'skrg',
#  'pake',
#  'smua',
#  'program',
#  'ahok',
#  'program',
#  'utk',
#  'lansia',
#  'smua',
#  'warga',
#  'dki',
#  'bego',
#  'kali',
#  'bego',
#  'sih',
#  'doank',
#  'kompascom',
#  'prinsip',
#  'anies',
#  'dlu',
#  'pilih',
#  'janji',
#  'masyarakat',
#  'bego',
#  'makan',
#  'omong',
#  'benci',
#  'anies',
#  'sandy',
#  'kecebong',
#  'bego',
#  'permanen',
#  'kampanye',
#  'ngomong',
#  'sih',
#  'anies',
#  'ente',
#  'rekam',
#  'gak',
#  'suaraanies',
#  'solusi',
#  'banjir',
#  'versi',
#  'baswedan',
#  'koq',
#  'bego',
#  'gubernur',
#  'jakarta',
#  'pbgdawgqly',
#  'kompascom',
#  'bodoh',
#  'dibodohin',
#  'pura2',
#  'bego',
#  'anies',
#  'sllu',
#  'usaha',
#  'lepas',
#  'bayang2',
#  'ahok',
#  'klo',
#  'ide',
#  'judul',
#  'sllu',
#  'beda',
#  'lwt',
#  'main',
#  'kata2',
#  'sensng',
#  'anies',
#  'sengaja',
#  'bikin',
#  'menang',
#  'biar',
#  'congor',
#  'ente',
#  'tdk',
#  'teriak',
#  'teriak',
#  'biar',
#  'negara',
#  'kondusif',
#  'indonesia',
#  'hancur',
#  'perang',
#  'agama',
#  'bego',
#  'tau',
#  'politik',
#  'tau',
#  'demo',
#  'makan',
#  'nasbus',
#  'berak',
#  'kencing',
#  'pohon',
#  'hihihi',
#  'ucpxtgez5r',
#  'gue',
#  'mah',
#  'santai',
#  'aja',
#  'karna',
#  'gue',
#  'gak',
#  'milih',
#  'anies',
#  'sandi',
#  'elu',
#  'pilih',
#  'anies',
#  'sandi',
#  'elu',
#  'tipu',
#  'kasihan',
#  'deh',
#  'nasib',
#  'mikir',
#  'bego',
#  'piara',
#  'gewfltxfec',
#  'krizz39907724',
#  'ngoceh',
#  'dasar',
#  'bani',
#  'cabul',
#  'bego',
#  'idiot',
#  'anak',
#  'didik',
#  'rizieq',
#  'cabul',
#  'mabur',
#  'gak',
#  'pulang',
#  'pulang',
#  'anies',
#  'banyak',
#  'bacot',
#  'persis',
#  'kek',
#  'mulut',
#  'anies',
#  'sandi',
#  'jefrinaldi',
#  'anandasukarlan',
#  'aniesbaswedan',
#  'lukmansaifuddin',
#  'dasar',
#  'bego',
#  'jelas2',
#  'beda',
#  'sukrlala',
#  'krn',
#  'gak',
#  'pidato',
#  'anies',
#  'karap',
#  'koh',
#  'hok',
#  'situ',
#  'naah',
#  'monas',
#  'adlh',
#  'muslim',
#  'kecewa',
#  'dgn',
#  'menteri',
#  'krn',
#  'gak',
#  'muslim',
#  'udah',
#  'paham',
#  'dasar',
#  'cebong',
#  'suara',
#  'satubkolam',
#  'butek',
#  'suaraanies',
#  'kawal',
#  'jkt',
#  'halah',
#  'pura2',
#  'bego',
#  'aja',
#  'loe',
#  'org',
#  'jawab',
#  'loe',
#  'org',
#  'aja',
#  'loe',
#  'ngak',
#  'dukung',
#  'anies',
#  'percaya',
#  'omong',
#  'loe',
#  'krn',
#  'cekok',
#  'doang',
#  'ngecek',
#  'kyk',
#  'aniesbaswedan',
#  'ngeles',
#  'krn',
#  'emang',
#  'kgk',
#  'ngecek',
#  'anies',
#  'baswedan',
#  'bantu',
#  'dana',
#  'partai',
#  'kali',
#  'lipat',
#  'sdbbx8wgxj',
#  'tvonenews',
#  'ayo',
#  'vangke',
#  'ahoker',
#  'bego',
#  'takviri',
#  'nyinyirin',
#  'lahhh',
#  'bego',
#  'otak',
#  'kaya',
#  'kebo',
#  'y0rbun8fyi',
#  'bang',
#  'udin19',
#  'ferryh19',
#  'tsamaradki',
#  'wooyyyy',
#  'berpikirk',
#  'otak',
#  'anggar',
#  'taon',
#  'msh',
#  'milik',
#  'djarot',
#  'bkn',
#  'anies',
#  'klo',
#  'taon',
#  'dpn',
#  'tanggung',
#  'jwb',
#  'anies',
#  'klo',
#  'bego',
#  'ush',
#  'bagi2',
#  'takviri',
#  'jamban',
#  'gemacan70',
#  'anies',
#  'baswedan',
#  'bantu',
#  'dana',
#  'partai',
#  'kali',
#  'lipat',
#  'fwhhn5k6pg',
#  'tvonenews',
#  'ayo',
#  'vangke',
#  'ahoker',
#  'bego',
#  'takviri',
#  'nyinyirin',
#  'lahhh',
#  'bego',
#  'otak',
#  'kaya',
#  'kebo',
#  'cnnindonesia',
#  'hehehe',
#  'nomer',
#  'anies',
#  'tdk',
#  'ganggu',
#  'pkl',
#  'tenabang',
#  'ttp',
#  'pkl',
#  'tenabang',
#  'gpp',
#  'timbul',
#  'macet',
#  'doel2',
#  'sisi',
#  'seolah2',
#  'sisi',
#  'laen',
#  'pura2',
#  'bego',
#  'setiawan87iwan',
#  'lilianbih',
#  'mastbp',
#  'mbok',
#  'ngerti',
#  'siklus',
#  'hidrologi',
#  'anies',
#  'sok',
#  'pinteerr',
#  'kliahatan',
#  'ian',
#  'bego',
#  'nya',
#  'andrearya15',
#  'awanmrs',
#  'kompascom',
#  'aniesbaswedan',
#  'sandiuno',
#  'bilang',
#  'anies',
#  'bego',
#  'cba',
#  'test',
#  'takviri',
#  'bego',
#  'sidang',
#  'nama',
#  'anies',
#  'sudirman',
#  'said',
#  'taikviri',
#  'tolol',
#  'bego',
#  'tukangkoprol',
#  'jawapos',
#  'bego',
#  'poling',
#  'harum',
#  'nama',
#  'ahok',
#  'jatuh',
#  'anies',
#  'dinaayu73107460',
#  'ruhutsitompul',
#  'susah',
#  'klw',
#  'bego',
#  'permanen',
#  'bru',
#  '2bln',
#  'jabat',
#  'gub',
#  'salahin',
#  'jgn',
#  'samain',
#  'dgn',
#  '5thn',
#  'shrus',
#  'klw',
#  'junjung',
#  'brhasil',
#  'ngtasin',
#  'banjir',
#  'zaman',
#  'anies',
#  'gad',
#  'banjir',
#  'scra',
#  'lsng',
#  'gub',
#  'napi',
#  'gagal',
#  'bnyak',
#  'baca',
#  'biar',
#  'pinter',
#  'muka',
#  'cantik',
#  'cerdas',
#  'retjapentung',
#  'jakarta',
#  'gak',
#  'cantik',
#  'gak',
#  'rapi',
#  'gak',
#  'pake',
#  'proyek',
#  'anies',
#  'bego',
#  'masak',
#  'bangun',
#  'isfraktruktur',
#  'langsung',
#  'bangun',
#  'emang',
#  'candi',
#  'boro',
#  'budur',
#  'bangun',
#  'jin',
#  'mikir',
#  'asu',
#  'aing',
#  'phantom',
#  'gyoucancallme',
#  'detikcom',
#  'aniesbaswedan',
#  'bego',
#  'orang',
#  'gak',
#  'nalar',
#  'anies',
#  'top',
#  'komunikasi',
#  'bagus',
#  'cerdas',
#  'awemany',
#  'koq',
#  'anies',
#  'bego',
#  'wkwkwkwk',
#  'dana',
#  'kagak',
#  'lha',
#  'kmr',
#  'fitnah',
#  'anggar',
#  'lonjak',
#  'krn',
#  'ahok',
#  'jarot',
#  'pdhal',
#  'bengkakin',
#  'nudingnya',
#  'fix',
#  'dah',
#  'gub',
#  'ngak',
#  'apa2',
#  'bong',
#  'dengerin',
#  'tuh',
#  'buru',
#  'gubernur',
#  'jakarta',
#  'anies',
#  'banjir',
#  'biar',
#  'bego',
#  'hoax',
#  'liatdknopd',
#  'heroe',
#  'bad',
#  'tempodotco',
#  'mdh',
#  'oct',
#  'tdtgn',
#  'silah',
#  'tunjukin',
#  'tgl',
#  'oct',
#  'anies',
#  'dokumen',
#  'asli',
#  'knp',
#  'tunjukin',
#  'dok',
#  'amp',
#  'tanda',
#  'tgnnya',
#  'gampang',
#  'buktiinnya',
#  'sesbangpol',
#  'tau',
#  'sandi',
#  'tau',
#  'apbd',
#  'diajuin',
#  'mendagri',
#  'kalo',
#  'anies',
#  'tau',
#  'bego',
#  'triwul82',
#  'tolong',
#  'netizen',
#  'cerdas',
#  'dikit',
#  'taikers',
#  'bego',
#  'naik',
#  'dana',
#  'parpol',
#  'djarot',
#  'dgn',
#  'tabrak',
#  'atur',
#  'daerah',
#  'berak',
#  'jalan',
#  'ganti',
#  'anies',
#  'enak',
#  'berak',
#  'sembarang',
#  'suruh',
#  'bersihin',
#  'and',
#  'cebokin',
#  'anies',
#  'substansial',
#  'pake',
#  'kritisi',
#  'anies',
#  'sandi',
#  'kritis',
#  'ngga',
#  'bego',
#  'bahan',
#  'nih',
#  'lupa',
#  'gun',
#  'romli',
#  'gunromli',
#  'nanda',
#  'tanganin',
#  'perda',
#  'bantu',
#  'parpol',
#  'orgnya',
#  'nyalahin',
#  'anies',
#  'sandi',
#  'bego',
#  'pelihara',
#  'pg6izq3otj',
#  'linden',
#  'dollar',
#  'policybermoz',
#  'mbahuyok',
#  'lusihq',
#  'anies',
#  'woooi',
#  'banjir',
#  'tinggal',
#  'napi',
#  'ahok',
#  'tanggul2',
#  'jebol',
#  'coba',
#  'krn',
#  'ahok',
#  'bego',
#  'bin',
#  'dongo',
#  'gak',
#  'kerja',
#  'tunggu',
#  'kalo',
#  'banjir',
#  'parah',
#  'gue',
#  'ikut',
#  'ngebully',
#  'anies',
#  'dah',
#  'kompascom',
#  'meme',
#  'kalah',
#  'pergub',
#  'aniesbaswedan',
#  'sandiuno',
#  'detik',
#  'depan',
#  'bego',
#  'bodoh',
#  'paham',
#  'anies',
#  'amp',
#  'uno',
#  'tolong',
#  'kasih',
#  'solusi',
#  'juragantahu',
#  '99',
#  'john',
#  'nelwan',
#  'cnnindonesia',
#  'yusejahtera',
#  'oke',
#  'skrg',
#  'anies',
#  'sandi',
#  'jauhhhhh',
#  'bego',
#  'sblm',
#  'nya',
#  'sepakat',
#  'wa',
#  'subarkah',
#  'tangan',
#  'banjir',
#  'tangan',
#  'abadi',
#  'tdk',
#  'banjr',
#  'kota',
#  'bener2',
#  'apung',
#  'pompa',
#  'gak',
#  'dinyalain',
#  'tetep',
#  'genang',
#  'air',
#  'alat',
#  'anies',
#  'sandi',
#  'bego',
#  'gak',
#  'ngapa2in',
#  'addiems',
#  'benar2',
#  'bego',
#  'gabener',
#  'wagebener',
#  'pimpin',
#  'pilih',
#  'paksa',
#  'pakai',
#  'politik',
#  'sara',
#  'hancur',
#  'pimpin',
#  'indonesia',
#  'pikir',
#  'kaya',
#  'anies',
#  'sandi',
#  'indonesia',
#  'jaman',
#  'batu',
#  'kalah',
#  'negara2',
#  'asia',
#  'kerberooz',
#  'bullfront',
#  'partaisocmed',
#  'teretam',
#  'sahal',
#  'as',
#  'gisellauci',
#  'perisyantik',
#  'mutia',
#  'raaaaa',
#  ...]

# %%
# Melakukan proses perhitungan dari setiap kemunculan isi content tweet
from nltk.probability import FreqDist
fqdist_content = FreqDist(word_tokenize_content)
fqdist_content
# Out:
# FreqDist({'jokowi': 781, 'bodoh': 733, 'tolol': 709, 'bego': 684, 'anies': 678, 'fadlizon': 633, 'orang': 303, 'gak': 271, 'aja': 241, 'nya': 196, ...})

# %%
# Menampilkan isi content tweet yang sering muncul sebanyak 500 kata
fqdist_content.most_common(500)
# Out:
# [('jokowi', 781),
#  ('bodoh', 733),
#  ('tolol', 709),
#  ('bego', 684),
#  ('anies', 678),
#  ('fadlizon', 633),
#  ('orang', 303),
#  ('gak', 271),
#  ('aja', 241),
#  ('nya', 196),
#  ('aniesbaswedan', 168),
#  ('ahok', 143),
#  ('org', 141),
#  ('rakyat', 138),
#  ('sandi', 126),
#  ('tau', 121),
#  ('loe', 121),
#  ('jgn', 116),
#  ('tdk', 109),
#  ('klo', 109),
#  ('kalo', 108),
#  ('gubernur', 107),
#  ('otak', 105),
#  ('dgn', 104),
#  ('emang', 97),
#  ('dukung', 95),
#  ('sandiuno', 89),
#  ('udah', 87),
#  ('bilang', 85),
#  ('pilih', 83),
#  ('kompascom', 81),
#  ('kerja', 79),
#  ('prabowo', 79),
#  ('salah', 78),
#  ('krn', 78),
#  ('fahrihamzah', 78),
#  ('dasar', 77),
#  ('cebong', 77),
#  ('goblok', 77),
#  ('baca', 74),
#  ('sih', 74),
#  ('gerindra', 73),
#  ('nana', 73),
#  ('amp', 71),
#  ('banjir', 71),
#  ('presiden', 70),
#  ('pinter', 69),
#  ('muslim', 68),
#  ('negara', 67),
#  ('ri', 66),
#  ('pake', 65),
#  ('indonesia', 65),
#  ('sdh', 62),
#  ('tuh', 62),
#  ('utk', 61),
#  ('rosaa', 61),
#  ('bikin', 59),
#  ('agama', 59),
#  ('paham', 57),
#  ('pikir', 57),
#  ('jakarta', 56),
#  ('banget', 54),
#  ('biar', 54),
#  ('gunromli', 54),
#  ('pintar', 54),
#  ('gm', 54),
#  ('janji', 53),
#  ('gue', 51),
#  ('pimpin', 51),
#  ('kayak', 50),
#  ('maspiyuuu', 49),
#  ('makan', 48),
#  ('liat', 47),
#  ('islam', 47),
#  ('anak', 46),
#  ('gua', 46),
#  ('dki', 45),
#  ('kau', 44),
#  ('pribumi', 44),
#  ('restycayah', 44),
#  ('malu', 43),
#  ('dungu', 43),
#  ('dpr', 43),
#  ('beda', 42),
#  ('warga', 42),
#  ('suka', 42),
#  ('jalan', 41),
#  ('cerdas', 41),
#  ('bukti', 41),
#  ('zul', 41),
#  ('jabat', 40),
#  ('ngomong', 40),
#  ('bkn', 40),
#  ('nama', 40),
#  ('bersatu1', 40),
#  ('hasan', 40),
#  ('kaya', 39),
#  ('ilc', 39),
#  ('perintah', 39),
#  ('joeda', 39),
#  ('ente', 38),
#  ('ngerti', 38),
#  ('dah', 38),
#  ('tni', 38),
#  ('rockygerung', 38),
#  ('bin', 37),
#  ('percaya', 37),
#  ('gembok', 37),
#  ('wakil', 37),
#  ('nyinyir', 37),
#  ('btp', 37),
#  ('benci', 36),
#  ('triwul82', 36),
#  ('skrg', 36),
#  ('milih', 36),
#  ('sok', 36),
#  ('manusia', 36),
#  ('pakai', 35),
#  ('tvonenews', 35),
#  ('hahaha', 35),
#  ('basuki', 35),
#  ('andreas', 35),
#  ('berita', 34),
#  ('pura2', 34),
#  ('kangdede78', 34),
#  ('gemacan70', 34),
#  ('nih', 34),
#  ('wahhabicc', 34),
#  ('divhumaspolri', 34),
#  ('ngga', 33),
#  ('partaisocmed', 33),
#  ('lawan', 32),
#  ('politik', 32),
#  ('kasih', 32),
#  ('hasil', 32),
#  ('akun', 32),
#  ('zonk', 32),
#  ('elu', 31),
#  ('detikcom', 31),
#  ('pelihara', 31),
#  ('sekolah', 31),
#  ('bangsa', 31),
#  ('kritik', 30),
#  ('mah', 30),
#  ('djarot', 30),
#  ('gitu', 30),
#  ('anggar', 29),
#  ('mas', 29),
#  ('kali', 29),
#  ('pidato', 29),
#  ('doang', 29),
#  ('lihat', 29),
#  ('lbh', 29),
#  ('riau', 29),
#  ('yusuf', 29),
#  ('menang', 28),
#  ('piara', 28),
#  ('gub', 28),
#  ('fitnah', 28),
#  ('tolak', 28),
#  ('turun', 28),
#  ('ardi', 28),
#  ('ahmaddhaniprast', 28),
#  ('anggap', 27),
#  ('jaman', 27),
#  ('takviri', 27),
#  ('bong', 27),
#  ('bayar', 27),
#  ('ajar', 27),
#  ('cari', 27),
#  ('tong', 26),
#  ('jual', 26),
#  ('sara', 26),
#  ('apbd', 26),
#  ('dana', 26),
#  ('data', 26),
#  ('jabar', 26),
#  ('pecat', 26),
#  ('klu', 26),
#  ('msh', 25),
#  ('omong', 25),
#  ('susah', 25),
#  ('bangun', 25),
#  ('hati', 25),
#  ('fadli', 25),
#  ('allah', 24),
#  ('mikir', 24),
#  ('kalah', 24),
#  ('masuk', 24),
#  ('iya', 24),
#  ('mrk', 24),
#  ('tribunnews', 24),
#  ('gila', 24),
#  ('org2', 24),
#  ('dennysiregar7', 24),
#  ('id', 24),
#  ('fpi', 24),
#  ('miskin', 24),
#  ('si', 24),
#  ('andre', 24),
#  ('hartoyomdn', 24),
#  ('kpk', 23),
#  ('uang', 23),
#  ('gin', 23),
#  ('spt', 23),
#  ('hrs', 23),
#  ('pura', 23),
#  ('212', 23),
#  ('timomanullang', 23),
#  ('rayya', 23),
#  ('liyandra', 23),
#  ('sumut', 23),
#  ('bonekakayu', 23),
#  ('suaraanies', 22),
#  ('tinggal', 22),
#  ('kecebong', 22),
#  ('karna', 22),
#  ('hoax', 22),
#  ('suruh', 22),
#  ('coba', 22),
#  ('twit', 22),
#  ('kasi', 22),
#  ('urus', 22),
#  ('maaf', 22),
#  ('rainembleketek', 22),
#  ('pramonoanung', 22),
#  ('gnpfmui', 22),
#  ('nyata', 21),
#  ('langsung', 21),
#  ('laku', 21),
#  ('gabener', 21),
#  ('program', 21),
#  ('mulut', 21),
#  ('bang', 21),
#  ('muka', 21),
#  ('mbahuyok', 21),
#  ('yah', 21),
#  ('duit', 21),
#  ('p3nj3l4j4h', 21),
#  ('trus', 21),
#  ('gimana', 21),
#  ('bro', 21),
#  ('anggota', 21),
#  ('hnurwahid', 21),
#  ('zon', 21),
#  ('mahendradatta', 21),
#  ('puspen', 21),
#  ('official', 21),
#  ('yuspihan1964', 21),
#  ('darma1muslim', 21),
#  ('octaputra', 21),
#  ('tetapahokdjarot', 20),
#  ('bicara', 20),
#  ('elo', 20),
#  ('koq', 20),
#  ('deh', 20),
#  ('kek', 20),
#  ('knp', 20),
#  ('bawa', 20),
#  ('undang', 20),
#  ('panca66', 20),
#  ('felixsiauw', 20),
#  ('kemenag', 20),
#  ('hebat', 19),
#  ('situ', 19),
#  ('jkt', 19),
#  ('bantu', 19),
#  ('junjung', 19),
#  ('parah', 19),
#  ('pas', 19),
#  ('harga', 19),
#  ('terima', 19),
#  ('chajanjr', 19),
#  ('ccicpolri', 19),
#  ('didien79', 19),
#  ('mui', 19),
#  ('elina', 19),
#  ('vay', 19),
#  ('johnysibuea', 19),
#  ('anti', 18),
#  ('baswedan', 18),
#  ('arab', 18),
#  ('banyak', 18),
#  ('gampang', 18),
#  ('kuasa', 18),
#  ('kaum', 18),
#  ('citra', 18),
#  ('hukum', 18),
#  ('sampe', 18),
#  ('orang2', 18),
#  ('sampah', 18),
#  ('kumpul', 18),
#  ('mohmahfudmd', 18),
#  ('wajar', 18),
#  ('bener', 18),
#  ('fahiraidris', 18),
#  ('gnpf', 18),
#  ('pan', 18),
#  ('lgbt', 18),
#  ('sandblazt', 18),
#  ('bonekakayujayus', 18),
#  ('supermancemong', 18),
#  ('anantarajasa', 18),
#  ('michaeljag', 18),
#  ('date', 18),
#  ('tamanratu4', 18),
#  ('ngaku', 17),
#  ('solusi', 17),
#  ('menteri', 17),
#  ('partai', 17),
#  ('apa2', 17),
#  ('jkw', 17),
#  ('rizmawidiono', 17),
#  ('metro', 17),
#  ('tutup', 17),
#  ('karniilyas', 17),
#  ('bela', 17),
#  ('abu', 17),
#  ('tniau', 17),
#  ('nyuknyangnyok', 17),
#  ('deonadesky', 17),
#  ('yosspunky', 17),
#  ('joedaandreas', 17),
#  ('andreasjoeda', 17),
#  ('andreeoctaputra', 17),
#  ('rosaaa', 17),
#  ('nanaa', 17),
#  ('kompakdki', 17),
#  ('jangkardki', 17),
#  ('bobbyirwanda', 17),
#  ('ruben', 17),
#  ('yuanito', 17),
#  ('ruhutsitompul', 16),
#  ('masyarakat', 16),
#  ('kampanye', 16),
#  ('main', 16),
#  ('kasihan', 16),
#  ('bacot', 16),
#  ('ikut', 16),
#  ('korupsi', 16),
#  ('apa', 16),
#  ('maju', 16),
#  ('tv', 16),
#  ('ama', 16),
#  ('blg', 16),
#  ('bohong', 16),
#  ('bgt', 16),
#  ('dll', 16),
#  ('isi', 16),
#  ('mudah', 16),
#  ('dlm', 16),
#  ('media', 16),
#  ('klaim', 16),
#  ('pajak', 16),
#  ('ato', 16),
#  ('foto', 16),
#  ('el', 16),
#  ('hidup', 16),
#  ('ilmu', 16),
#  ('sugi', 16),
#  ('0706', 16),
#  ('ulinyusron', 16),
#  ('teroris', 16),
#  ('bbm', 16),
#  ('kanuhate', 16),
#  ('semiaji', 15),
#  ('w', 15),
#  ('pkl', 15),
#  ('gaji', 15),
#  ('teriak', 15),
#  ('hancur', 15),
#  ('demo', 15),
#  ('ngak', 15),
#  ('ganti', 15),
#  ('nyalahin', 15),
#  ('pilkada', 15),
#  ('setan', 15),
#  ('jadi', 15),
#  ('lantik', 15),
#  ('yunartowijaya', 15),
#  ('adil', 15),
#  ('ketua', 15),
#  ('ustadtengkuzul', 15),
#  ('micin', 15),
#  ('maksud', 15),
#  ('bijak', 15),
#  ('tolakbigotri', 15),
#  ('sbyudhoyono', 15),
#  ('faylaff', 15),
#  ('pksejahtera', 15),
#  ('almirayushi', 15),
#  ('tunjuk', 14),
#  ('smua', 14),
#  ('tipu', 14),
#  ('kyk', 14),
#  ('ngeles', 14),
#  ('cnnindonesia', 14),
#  ('macet', 14),
#  ('mastbp', 14),
#  ('gagal', 14),
#  ('asu', 14),
#  ('netizen', 14),
#  ('tuju', 14),
#  ('kompastv', 14),
#  ('dpt', 14),
#  ('ngapain', 14),
#  ('beli', 14),
#  ('blm', 14),
#  ('acara', 14),
#  ('loh', 14),
#  ('polisi', 14),
#  ('dumdum', 14),
#  ('tpi', 14),
#  ('mati', 14),
#  ('luh', 14),
#  ('lawanpolitikjkw', 14),
#  ('tifsembiring', 14),
#  ('muzzammil', 14),
#  ('romosyafii', 14),
#  ('ustadabujanda', 14),
#  ('ad', 14),
#  ('filbertstw', 14),
#  ('mohammed', 14),
#  ('askary', 14),
#  ('budhiariesandi', 14),
#  ('haha', 13),
#  ('udh', 13),
#  ('kemendagri', 13),
#  ('debat', 13),
#  ('asli', 13),
#  ('tim', 13),
#  ('fakta', 13),
#  ('penjara', 13),
#  ('ambarwatirexy', 13),
#  ('badjanuswantara', 13),
#  ('emg', 13),
#  ('buta', 13),
#  ('kelas', 13),
#  ('maklum', 13),
#  ('bos', 13),
#  ('zarazettirazr', 13),
#  ('umnia77', 13),
#  ('jajah', 13),
#  ('yaa', 13),
#  ('grand', 13),
#  ('light88', 13),
#  ('ndeso', 13),
#  ('sadar', 13),
#  ('bnyk', 13),
#  ('wkwkwk', 13),
#  ('komen', 13),
#  ('rezim', 13),
#  ('banding', 13),
#  ('netizentofa', 13),
#  ('takut', 13),
#  ('janda', 13),
#  ('ibrahim', 13),
#  ('tnial', 13),
#  ('jkfc23456789', 13),
#  ('achmadmacmore', 13),
#  ('milik', 12),
#  ('tahu', 12),
#  ('tolong', 12),
#  ('perang', 12),
#  ('bani', 12),
#  ('didik', 12),
#  ('adlh', 12),
#  ('nyinyirin', 12),
#  ('jatuh', 12),
#  ('zaman', 12),
#  ('bagus', 12),
#  ('atur', 12),
#  ('bahan', 12),
#  ('ronavioleta', 12),
#  ('umat', 12),
#  ('djanchoek', 12),
#  ('publik', 12),
#  ('bangga', 12),
#  ('alexis', 12),
#  ('hilang', 12),
#  ('hahahaha', 12),
#  ('pandji', 12),
#  ('butuh', 12),
#  ('sugikawuloalit', 12),
#  ('kena', 12),
#  ('lugu', 12),
#  ('anis', 12),
#  ('hansjedi671', 12),
#  ('thn', 12),
#  ('sibuk', 12),
#  ('mata', 12),
#  ('opini', 12),
#  ('atas', 12),
#  ('mentimoen', 12),
#  ('jdi', 12),
#  ('dkijakarta', 12),
#  ('kmu', 12),
#  ('kepala', 12),
#  ('tukang', 12),
#  ('diam', 12)]

# %%
# Membuat visualisasi tweet berdasarkan isi tweet yang sering muncul sebanyak 30 kata yang sering digunakan
from cycler import cycler

plt.figure(figsize=(10, 7))
plt.title("Visualisasi Kata Yang Sering Dipakai Di Dalam Tweet", fontdict={"fontsize":15}, pad=15)
plt.rc("axes", prop_cycle=(cycler("color", ["g"])))
fqdist_content.plot(30, cumulative=False)
plt.show()

# %% [markdown]
# ## 4. Visualisasi Dengan Wordclouds

# %% [markdown]
# ### Semua Label (Positif & Negatif)

# %%
# Menampilkan sekaligus memvisualisasikan kata menggunakan wordcloud dari DataFrame "data_2017" dari kolom "content_bersih"  
all_tweet_post = " ".join(word for word in data_2017["content_bersih"])
wordcloud = WordCloud(colormap="OrRd", width=700, height=300, 
                      mode="RGBA", background_color="lightgrey").generate(all_tweet_post)
plt.figure(figsize=(17,10))
plt.title("Menampilkan Semua Isi Content Tweet Dari Kolom 'content_bersih'", fontdict={"fontsize":15}, pad = 15);
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# Jika dilihat dari visualisasi diatas tampilan tersebut merupakan visualisasi dari wordcloud yang bertujuan untuk mendapatkan insight pemahaman secara utuh tentang suatu ide atau gagasan dari seseorang atau tulisan seseorang dalam suatu waktu tertentu. Visualsasi ini banyak sekali digunakan dalam pengujian analisa sentimen karena untuk melihat setiap kata-kata yang telah diketikkan oleh masyarakat.
#
# Namun tampilan visualisasi diatas masih mencakup semua label (positif & negatif) yang membuat kita kesulitan untuk mengetahui kata-kata mana yang bernilai positif/negatif. Maka dari itu kami akan membuatnya secara terpisah antara visualisasi wordcloud yang bernilai positif dan wordcloud yang bernilai negatif.

# %% [markdown]
# ### Label Positif

# %%
# Memisahkan semua data yang memiliki label positif yang disesuaikan dari kolom "label"
data_2017_label_positif = data_2017[data_2017.label == "positif"]
data_2017_label_positif.head()
# Out:
#                         date  \
# 1  2017-12-28 02:12:13+00:00
# 2  2017-12-27 12:32:16+00:00
# 3  2017-12-26 13:01:10+00:00
# 4  2017-12-26 08:29:32+00:00
# 5  2017-12-24 09:14:35+00:00
#
#                                              content    label  \
# 1   tonywibowo12 michael24007966 triwul82 semiaji...  positif
# 2   detikfinance aduh anies jng mgeliatin bego ny...  positif
# 3  emangnya anies lakukan kmpanye hitam dmn apa m...  positif
# 4   dahnilanzar anies itu toleran kalau menguntun...  positif
# 5  anies baswedan menurut saya adalah gubernur pa...  positif
#
#                                   content_tokenizing  \
# 1  [tonywibowo12, michael24007966, triwul82, semi...
# 2  [detikfinance, aduh, anies, jng, mgeliatin, be...
# 3  [emangnya, anies, lakukan, kmpanye, hitam, dmn...
# 4  [dahnilanzar, anies, itu, toleran, kalau, meng...
# 5  [anies, baswedan, menurut, saya, adalah, guber...
#
#                                    content_stopwords  \
# 1  [tonywibowo12, michael24007966, triwul82, semi...
# 2  [detikfinance, aduh, anies, jng, mgeliatin, be...
# 3  [emangnya, anies, lakukan, kmpanye, hitam, dmn...
# 4  [dahnilanzar, anies, toleran, menguntungkan, e...
# 5  [anies, baswedan, gubernur, bego, dimiliki, ja...
#
#                                     content_stemming  \
# 1  [tonywibowo12, michael24007966, triwul82, semi...
# 2  [detikfinance, aduh, anies, jng, mgeliatin, be...
# 3  [emang, anies, laku, kmpanye, hitam, dmn, mate...
# 4  [dahnilanzar, anies, toleran, untung, ente, be...
# 5  [anies, baswedan, gubernur, bego, milik, jakar...
#
#                                       content_bersih
# 1  tonywibowo12 michael24007966 triwul82 semiaji ...
# 2  detikfinance aduh anies jng mgeliatin bego nya...
# 3  emang anies laku kmpanye hitam dmn materi tunj...
# 4  dahnilanzar anies toleran untung ente bego pur...
# 5  anies baswedan gubernur bego milik jakarta gub...

# %%
# Memvisualisasikan menggunakan wordcloud dari DataFrame "data_2017_label_positif" dari kolom "content_bersih"  
all_content_positive = " ".join(word for word in data_2017_label_positif["content_bersih"])
wordcloud = WordCloud(colormap="cool", width=700, height=300, 
                      mode="RGBA", background_color="lightgrey").generate(all_content_positive)
plt.figure(figsize=(17,10))
plt.title("Menampilkan Semua Isi Content Yang Bersifat Positif Dari Kolom 'content_bersih'", 
          fontdict={"fontsize":15}, pad = 15);
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# ### Label Negatif

# %%
# Memisahkan semua data yang memiliki label negatif yang disesuaikan dari kolom "label"
data_2017_label_negatif = data_2017[data_2017.label == "negatif"]
data_2017_label_negatif.head()
# Out:
#                          date  \
# 0   2017-12-29 08:09:29+00:00
# 7   2017-12-23 18:43:39+00:00
# 8   2017-12-23 17:40:31+00:00
# 9   2017-12-23 08:09:13+00:00
# 14  2017-12-22 02:03:00+00:00
#
#                                               content    label  \
# 0    pendjaca herditiya1 berharap menkeu meralat p...  negatif
# 7   jeg likte youtube video https fyojwcreia anies...  negatif
# 8    cagubnyinyir padahal lulung sempet2nya mengat...  negatif
# 9   anies sandi gubernur mendagri yang bego itu gu...  negatif
# 14   kompascom kok semakin hari semakin tdk karuan...  negatif
#
#                                    content_tokenizing  \
# 0   [pendjaca, herditiya1, berharap, menkeu, meral...
# 7   [jeg, likte, youtube, video, https, fyojwcreia...
# 8   [cagubnyinyir, padahal, lulung, sempet2nya, me...
# 9   [anies, sandi, gubernur, mendagri, yang, bego,...
# 14  [kompascom, kok, semakin, hari, semakin, tdk, ...
#
#                                     content_stopwords  \
# 0   [pendjaca, herditiya1, berharap, menkeu, meral...
# 7   [jeg, likte, youtube, video, fyojwcreia, anies...
# 8   [cagubnyinyir, lulung, sempet2nya, anies, jeni...
# 9   [anies, sandi, gubernur, mendagri, bego, guber...
# 14  [kompascom, tdk, karuan, menganggap, warga, dk...
#
#                                      content_stemming  \
# 0   [pendjaca, herditiya1, harap, menkeu, ralat, n...
# 7   [jeg, likte, youtube, video, fyojwcreia, anies...
# 8   [cagubnyinyir, lulung, sempet2nya, anies, jeni...
# 9   [anies, sandi, gubernur, mendagri, bego, guber...
# 14  [kompascom, tdk, karuan, anggap, warga, dki, b...
#
#                                        content_bersih
# 0   pendjaca herditiya1 harap menkeu ralat nyata b...
# 7   jeg likte youtube video fyojwcreia anies sandi...
# 8   cagubnyinyir lulung sempet2nya anies jenius ta...
# 9   anies sandi gubernur mendagri bego gubernur me...
# 14  kompascom tdk karuan anggap warga dki bego tgu...

# %%
# Membuat Tampilan Visualisasi menggunakan wordcloud dari DataFrame "data_2017_label_negatif" dari kolom "content_bersih" 
all_content_negative = " ".join(word for word in data_2017_label_negatif["content_bersih"])
wordcloud = WordCloud(colormap="Wistia", width=700, height=300, 
                      mode="RGBA", background_color="lightgrey").generate(all_content_negative)
plt.figure(figsize=(17,10))
plt.title("Menampilkan Semua Isi Tweet Yang Bersifat Netral Dari Kolom Tweet_Bersih", 
          fontdict={"fontsize":15}, pad = 15);
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# ## 5. Melakukan Pemodelan Dengan Model Machine Learning

# %%
# Menampilkan keseluruhan data dari DataFrame "data_2017"
data_2017.head()
# Out:
#                         date  \
# 0  2017-12-29 08:09:29+00:00
# 1  2017-12-28 02:12:13+00:00
# 2  2017-12-27 12:32:16+00:00
# 3  2017-12-26 13:01:10+00:00
# 4  2017-12-26 08:29:32+00:00
#
#                                              content    label  \
# 0   pendjaca herditiya1 berharap menkeu meralat p...  negatif
# 1   tonywibowo12 michael24007966 triwul82 semiaji...  positif
# 2   detikfinance aduh anies jng mgeliatin bego ny...  positif
# 3  emangnya anies lakukan kmpanye hitam dmn apa m...  positif
# 4   dahnilanzar anies itu toleran kalau menguntun...  positif
#
#                                   content_tokenizing  \
# 0  [pendjaca, herditiya1, berharap, menkeu, meral...
# 1  [tonywibowo12, michael24007966, triwul82, semi...
# 2  [detikfinance, aduh, anies, jng, mgeliatin, be...
# 3  [emangnya, anies, lakukan, kmpanye, hitam, dmn...
# 4  [dahnilanzar, anies, itu, toleran, kalau, meng...
#
#                                    content_stopwords  \
# 0  [pendjaca, herditiya1, berharap, menkeu, meral...
# 1  [tonywibowo12, michael24007966, triwul82, semi...
# 2  [detikfinance, aduh, anies, jng, mgeliatin, be...
# 3  [emangnya, anies, lakukan, kmpanye, hitam, dmn...
# 4  [dahnilanzar, anies, toleran, menguntungkan, e...
#
#                                     content_stemming  \
# 0  [pendjaca, herditiya1, harap, menkeu, ralat, n...
# 1  [tonywibowo12, michael24007966, triwul82, semi...
# 2  [detikfinance, aduh, anies, jng, mgeliatin, be...
# 3  [emang, anies, laku, kmpanye, hitam, dmn, mate...
# 4  [dahnilanzar, anies, toleran, untung, ente, be...
#
#                                       content_bersih
# 0  pendjaca herditiya1 harap menkeu ralat nyata b...
# 1  tonywibowo12 michael24007966 triwul82 semiaji ...
# 2  detikfinance aduh anies jng mgeliatin bego nya...
# 3  emang anies laku kmpanye hitam dmn materi tunj...
# 4  dahnilanzar anies toleran untung ente bego pur...

# %% [markdown]
# Karena pada pengujian kali ini data yang bersifat lebih dominan terhadap data dokumen maka kami akan menggunakan sebuah pembobotan nilai yang bernama TF-IDF (term frequency-inverse document frequency). Pembobotan dengan TF-IDF merupakan salah satu faktor pembobotan yang sering digunakan dalam konteks penambangan data yang bersifat full text. Selain itu TF-IDF juga dapat dapat digunakan untuk menganalisa hubungan antara sebuah frase/kalimat dengan sekumpulan dokumen. Teknik ini akan melakukan perhitungan dari sebuah kata kunci terhadap masing-masing dokumen.

# %%
# Melakukan proses pembobotan nilai dengan TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
data_2017_tfidf = tfidf.fit_transform(data_2017["content_bersih"].astype("U"))
data_2017_tfidf
# Out:
# <1800x7359 sparse matrix of type '<class 'numpy.float64'>'
# 	with 31265 stored elements in Compressed Sparse Row format>

# %%
# Melakukan pembagian data menjadi 2 bagian (data train & data test) menggunakan train_test_split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(data_2017_tfidf, data_2017["label"], test_size=0.2, random_state=20)

# %% [markdown]
# Penjelasan dari proses pemisahan data menjadi 2 variabel dan fungsi train_test_split:
#
# 1. data_2017_tfidf: merupakan sebuah fungsi yang berisi nilai pembobotan dari kolom "content_bersih"
# 2. data_2017: merupakan sebuah fungsi untuk mendeklarasikan/memanggil kolom "label" dari masing-masing nilai sentimen
# 3. test_size: Nilai presentase dari sebuah ukuran untuk membagi data test. Dalam pengujian ini saya memakai nilai test_size = 0.3 yang dimana ukuran dari data test mencapai 30% dan data train mencapai 70%.
# 4. random_state: Menetapkan nilai. Jika nilainya sama maka fungsi train_test_split akan menghasilkan pemisahan nilai yang sama persis di setiap waktunya. Namun jika ditentukan nilai random_statenya maka data akan diacak (random).

# %% [markdown]
# Setelah melakukan proses split yaitu membagi keutuhan data menjadi 2 bagian (data test & data train) langkah selanjutnya adalah melakukan pemodelan dengan menggunakan model multinomial naive bayes atau yang biasa dikenal sebagai MultinomialNB. Multinomial naive bayes merupakan sebuah teknik turunan dari naive bayes yang menggunakan teknik yang bernama conditional probability yaitu sebuah teknik yang dapat dilakukan dengan menggunakan frekuensi kemunculan suatu kata pada suatu kelas.

# %%
# Pemanggilan model Multinomial Naive Bayes (MultinomialNB) beserta parameternya
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV

model_mnb_train = MultinomialNB()

parameters = {
    "alpha": [6.5],
    "fit_prior": [False]
    
}

grid_search_mnb_train = GridSearchCV(model_mnb_train, parameters, cv=25) # CV = Cross Validation

grid_search_mnb_train.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=25, estimator=MultinomialNB(),
#              param_grid={'alpha': [6.5], 'fit_prior': [False]})

# %% [markdown]
# Penjelasan dari poin-poin yang ada di codingan diatas:
# 1. Parameters merupakan sebuah teknik pemanggilan fungsi-fungsi yang menjadi bagian dari sebuah model itu sendiri. Untuk mengecek parameter dari setiap model bisa dicek pada website sckit-learn. Pada codingan diatas, fungsi alpha dan fit_prior merupakan bagian dari parameter MultinomialNB.
# 2. GridSearchCV merupakan sebuah teknik untuk mencari best paramater/parameter terbaik untuk kasus klasifikasi. Pada codingan diatas, teknik GridSearchCV saya gunakan untuk memanggil variabel model dari MultinomialNB (model_mnb), fungsi serta nilai dari paramater model MultinomialNB, dan fungsi cross validation yang bernilai 30.
# 3. Cross Validation merupakan sebuah metode yang biasa dipakai dalam pengujian data mining yang bertujuan untuk memperoleh hasil akhir yang optimal. Metode ini akan menilai dengan cara mengestimasi rotasi yang hasil statistik analisisnya akan menggeneralisasi kumpulan data yang bersifat independen.
# 4. .fit merupakan sebuah fungsi yang bertujuan untuk melatih model dengan data training.

# %% [markdown]
# Namun setelah melakukan proses pemodelan untuk data train, saya juga akan melakukan pemodelan untuk data latih (test) supaya hasil akurasi yang di dapatkan tidak mengalami overfitting.

# %%
"""
Karena pada langkah sebelumnya sudah melakukan pemanggilan model Multinomial Naive Bayes terhadap data train (latih) selanjutnya
adalah melakukan pemanggilan model Multinomial Naive Bayes untuk data latih
"""
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV

model_mnb_test = MultinomialNB()

parameters = {
    "alpha": [6.5],
    "fit_prior": [False]
}

grid_search_mnb_test = GridSearchCV(model_mnb_test, parameters, cv=30) # CV = Cross Validation

grid_search_mnb_test.fit(x_test, y_test) # Melatih model MultinomialNB dengan data test supaya tidak terjadi imbalanced
# Out:
# GridSearchCV(cv=30, estimator=MultinomialNB(),
#              param_grid={'alpha': [6.5], 'fit_prior': [False]})

# %%
# Melakukan pengujian untuk variabel test & varibael train
print("------------------------Prediksi Dari Data Uji---------------------------------")
prediction_test = grid_search_mnb_train.predict(x_test)
print(prediction_test)

print()

print("----------------------Prediksi Dari Data Latih---------------------------------")
prediction_train = grid_search_mnb_test.predict(x_train)
print(prediction_train)
# Out:
# ------------------------Prediksi Dari Data Uji---------------------------------
# ['positif' 'negatif' 'negatif' 'positif' 'negatif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'negatif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'negatif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'negatif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'negatif' 'negatif' 'positif' 'negatif' 'positif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'negatif' 'negatif' 'positif' 'positif' 'negatif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'negatif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'negatif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'negatif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'negatif' 'positif'
#  'negatif' 'positif' 'positif' 'negatif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'negatif' 'negatif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'negatif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'negatif' 'positif' 'negatif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'negatif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'negatif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'negatif'
#  'positif' 'positif' 'negatif' 'negatif' 'negatif' 'positif' 'positif'
#  'positif' 'negatif' 'positif' 'positif' 'positif' 'positif' 'negatif'
#  'positif' 'positif' 'positif' 'negatif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'negatif'
#  'positif' 'positif' 'negatif' 'positif' 'positif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'positif' 'negatif' 'negatif' 'positif'
#  'positif' 'positif' 'positif' 'negatif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'negatif'
#  'positif' 'positif' 'positif']
#
# ----------------------Prediksi Dari Data Latih---------------------------------
# ['positif' 'negatif' 'positif' ... 'positif' 'positif' 'positif']

# %%
# Membuat visualisasi untuk menampilkan pengukuran performa dari hasil prediksi pada variabel uji & latih

f, ax = plt.subplots(figsize=(9, 4))
sns.heatmap(confusion_matrix(y_test, prediction_test), annot=True, cmap="RdYlBu", fmt=".0f", ax=ax)
plt.xlabel("Prediksi")
plt.ylabel("Aktual")
plt.title("Pengukuran Performa Hasil Klasifikasi Dari Variabel Uji", fontdict={"fontsize":13}, pad=13)
plt.show()

f, ax = plt.subplots(figsize=(9, 4))
sns.heatmap(confusion_matrix(y_train, prediction_train), annot=True, cmap="RdYlBu", fmt=".0f", ax=ax)
plt.xlabel("Nilai Prediksi")
plt.ylabel("Nilai Aktual")
plt.title("Pengukuran Performa Hasil Klasifikasi Dari Variabel Latih", fontdict={"fontsize":13}, pad=13)
plt.show()

# %% [markdown]
# Penjelasan dari visualisasi pada confusion matrix:
# - Data Test
# 1. True Positive pada data test memiliki nilai sejumlah 31. True Positive merupakan data yang bernilai positif yang diprediksi tepat.
# 2. True Negative pada data test memiliki nilai sejumlah 198. True Negative sendiri merupakan data yang bernilai negatif yang diprediksi secara tepat.
# 3. False Positive pada data test memiliki nilai sejumlah 116. False Positive sendiri merupakan data yang bernilai negatif namun pada saat diprediksi terhitung sebagai data positif.
# 4. False Negative pada data test memiliki nilai sejumlah 15. False Negative sendiri merupakan data yang bernilai positif namun pada saat diprediksi terhitung sebagai data yang negatif.
#
# - Data Train
# 1. True Positive pada data train memiliki nilai sejumlah 90. True Positive merupakan data yang bernilai positif yang diprediksi tepat.
# 2. True Negative pada data train memiliki nilai sejumlah 795. True Negative sendiri merupakan data yang bernilai negatif yang diprediksi secara tepat.
# 3. False Positive pada data train memiliki nilai sejumlah 501. False Positive sendiri merupakan data yang bernilai negatif namun pada saat diprediksi terhitung sebagai data positif.
# 4. False Negative pada data train memiliki nilai sejumlah 54. False Negative sendiri merupakan data yang bernilai positif namun pada saat diprediksi terhitung sebagai data yang negatif.

# %%
# Menampilkan tingkat akurasi, precision, recall & f1-score dari model Multonimial Naive Bayes

print("------------------------Prediksi Dari Variabel Uji-------------------------------")
cr_test = classification_report(y_test, prediction_test)
print(cr_test)

print("------------------------Prediksi Dari Variabel Latih-------------------------------")
cr_train = classification_report(y_train, prediction_train)
print(cr_train)
# Out:
# ------------------------Prediksi Dari Variabel Uji-------------------------------
#               precision    recall  f1-score   support
#
#      negatif       0.67      0.21      0.32       147
#      positif       0.63      0.93      0.75       213
#
#     accuracy                           0.64       360
#    macro avg       0.65      0.57      0.54       360
# weighted avg       0.65      0.64      0.58       360
#
# ------------------------Prediksi Dari Variabel Latih-------------------------------
#               precision    recall  f1-score   support
#
#      negatif       0.62      0.15      0.24       591
#      positif       0.61      0.94      0.74       849
#
#     accuracy                           0.61      1440
#    macro avg       0.62      0.54      0.49      1440
# weighted avg       0.62      0.61      0.54      1440

# %% [markdown]
# ## 6. Membuat Prediksi Akhir & Visualisasi Tahap Akhir

# %%
# Membuat variabel baru yang dihasilkan dari prediksi label content sentimen terhadap data test
content_output_test_2017 = pd.DataFrame({"label": prediction_test})
content_output_test_2017.head()
# Out:
#      label
# 0  positif
# 1  negatif
# 2  negatif
# 3  positif
# 4  negatif

# %%
# Membuat variabel baru yang dihasilkan dari prediksi label content sentimen terhadap data train
content_output_train_2017 = pd.DataFrame({"label": prediction_train})
content_output_train_2017.head()
# Out:
#      label
# 0  positif
# 1  negatif
# 2  positif
# 3  positif
# 4  positif

# %%
# Visualisasi untuk melihat sekaligus membandingkan hasil sentimen dari data test & data train
plt.figure(figsize=(15, 5))

# Visualiasi dari hasil prediksi pada variabel test/uji
plt.subplot(1, 2, 1)
sns.countplot(x="label", hue="label", data=content_output_test_2017)
plt.title("Visualisasi Label Sentimen Pada Data Uji Setelah Di Prediksi (Tahun 2017)", fontdict={"fontsize":13}, pad=13)
plt.xlabel("Label Sentimen Pada Data Uji")
plt.ylabel("Jumlah Tweet")
plt.legend()

# Visualiasi dari hasil prediksi pada variabel train/latih
plt.subplot(1, 2, 2)
sns.countplot(x="label", hue="label", data=content_output_train_2017)
plt.title("Visualisasi Label Sentimen Pada Data Latih Setelah Di Prediksi (Tahun 2017)", fontdict={"fontsize":13}, pad=13)
plt.xlabel("Label Sentimen Pada Data Latih")
plt.ylabel("Jumlah Tweet")
plt.show()

# %% [markdown]
# Penjelasan dari bar plot sebagai berikut:
# - Variabel content_output_test_2017
# 1. Pada variabel content_output_test_2017 dengan nilai label "positif" memiliki jumlah akhir isi content tweet sebanyak 314. Sedangkan pada nilai label "negatif" di variabel content_output_test_2017 memiliki jumlah nilai isi content tweet sebanyak 46. Jadi dapat disimpulkan bahwasanya jumlah akhir setelah dilakukan klasifikasi nilai label "positif" lebih banyak daripada nilai label "negatif" yang memiliki selisih nilai sebanyak 268.
#
# - Variabel content_ouutput_train_2017
# 1. Pada variabel content_output_train_2017 dengan nilai label "positif" memiliki jumlah akhir isi content tweet sebanyak 1296. Sedangkan pada nilai label "negatif" di variabel content_output_train_2017 memiliki jumlah nilai isi content tweet sebanyak 144. Jadi dapat disimpulkan bahwasanya jumlah akhir setelah dilakukan klasifikasi nilai label "positif" lebih banyak daripada nilai label "negatif" yang memiliki selisih nilai sebanyak 1152 nilai.
